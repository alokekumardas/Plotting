# %%
import ROOT
import os
# !pwd
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/TTGammaSemiLep_13TeV/Plotting/CombineFitting/MisIDEleFittingWithSystematics_test

# %%
# !combine -M FitDiagnostics -n CR123  datacard_CR123.txt --redefineSignalPOIs r,MisIDEleSeventeen,MisIDEleEighteen,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties --plots 
# !combine -M FitDiagnostics -n allyear  datacard_allyear.txt --redefineSignalPOIs r,MisIDEleSeventeen,MisIDEleEighteen,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties --plots

# %%
# !combine -M FitDiagnostics -n six  datacard16test.txt -v2

# %%
# !combine -M FitDiagnostics -n allyear_test  datacard_allyear_test.txt --redefineSignalPOIs r,MisIDEleSeventeen,MisIDEleEighteen,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties --plots -v2

# %%
# !ls -lrth *.root

# %%
# !combine -M FitDiagnostics -n CR123 datacard_CR123_allyear.txt --redefineSignalPOIs r,MisIDEleSeventeenSF,MisIDEleEighteenSF,ZGammaBkgPhotonSF,WGammaBkgPhotonSF -v2 --saveWithUncertainties --plots &
# Out:
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Creating pdfs for individual modes (6): Channel ch1_mu will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch1_mu
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2413.095625     80.625053       total sum
# 0          896.000000      29.933259       Unweighted events, alpha=2.693187
#   => Total parameter prop_binch1_mu_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          3526.791843     116.372707      total sum
# 1          918.000000      30.298515       Unweighted events, alpha=3.841821
#   => Total parameter prop_binch1_mu_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          4311.063765     125.813429      total sum
# 2          1174.000000     34.263683       Unweighted events, alpha=3.672116
#   => Total parameter prop_binch1_mu_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          3831.792171     173.949557      total sum
# 3          485.000000      22.022716       Unweighted events, alpha=7.900602
#   => Total parameter prop_binch1_mu_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          2982.508762     69.048375       total sum
# 4          1866.000000     43.197222       Unweighted events, alpha=1.598343
#   => Total parameter prop_binch1_mu_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1750.954414     58.840121       total sum
# 5          886.000000      29.765752       Unweighted events, alpha=1.976247
#   => Total parameter prop_binch1_mu_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1624.234171     127.246408      total sum
# 6          163.000000      12.767145       Unweighted events, alpha=9.964627
#   => Total parameter prop_binch1_mu_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1312.596411     69.701987       total sum
# 7          355.000000      18.841444       Unweighted events, alpha=3.697455
#   => Total parameter prop_binch1_mu_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1103.560519     134.093195      total sum
# 8          68.000000       8.246211        Unweighted events, alpha=16.228831
#   => Total parameter prop_binch1_mu_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          870.415475      45.993412       total sum
# 9          358.000000      18.920888       Unweighted events, alpha=2.431328
#   => Total parameter prop_binch1_mu_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         650.535315      37.594652       total sum
# 10         299.000000      17.291616       Unweighted events, alpha=2.175703
#   => Total parameter prop_binch1_mu_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         781.713896      167.083754      total sum
# 11         22.000000       4.690416        Unweighted events, alpha=35.532450
#   => Total parameter prop_binch1_mu_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .    1Channel ch1_ele will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch1_ele
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1882.401367     177.788206      total sum
# 0          112.000000      10.583005       Unweighted events, alpha=16.807155
#   => Total parameter prop_binch1_ele_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          2167.104622     202.754647      total sum
# 1          114.000000      10.677078       Unweighted events, alpha=19.009690
#   => Total parameter prop_binch1_ele_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          2514.708893     103.288856      total sum
# 2          593.000000      24.351591       Unweighted events, alpha=4.240656
#   => Total parameter prop_binch1_ele_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          3055.704819     178.472162      total sum
# 3          293.000000      17.117243       Unweighted events, alpha=10.429027
#   => Total parameter prop_binch1_ele_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          572.984810      43.470644       total sum
# 4          174.000000      13.190906       Unweighted events, alpha=3.293016
#   => Total parameter prop_binch1_ele_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          695.995850      75.430896       total sum
# 5          85.000000       9.219544        Unweighted events, alpha=8.188186
#   => Total parameter prop_binch1_ele_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          782.942543      46.240092       total sum
# 6          287.000000      16.941074       Unweighted events, alpha=2.728023
#   => Total parameter prop_binch1_ele_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1158.226608     61.029081       total sum
# 7          360.000000      18.973666       Unweighted events, alpha=3.217296
#   => Total parameter prop_binch1_ele_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1604.119659     50.816709       total sum
# 8          996.000000      31.559468       Unweighted events, alpha=1.610562
#   => Total parameter prop_binch1_ele_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1846.019653     62.228085       total sum
# 9          880.000000      29.664794       Unweighted events, alpha=2.097750
#   => Total parameter prop_binch1_ele_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1230.542313     57.646151       total sum
# 10         456.000000      21.354157       Unweighted events, alpha=2.698558
#   => Total parameter prop_binch1_ele_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         675.744759      40.868047       total sum
# 11         273.000000      16.522712       Unweighted events, alpha=2.475256
#   => Total parameter prop_binch1_ele_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         435.609833      36.799174       total sum
# 12         140.000000      11.832160       Unweighted events, alpha=3.111499
#   => Total parameter prop_binch1_ele_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         435.349155      72.858235       total sum
# 13         36.000000       6.000000        Unweighted events, alpha=12.093032
#   => Total parameter prop_binch1_ele_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1474.691833     113.869340      total sum
# 14         168.000000      12.961481       Unweighted events, alpha=8.777928
#   => Total parameter prop_binch1_ele_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         1124.108810     57.042059       total sum
# 15         388.000000      19.697716       Unweighted events, alpha=2.897188
#   => Total parameter prop_binch1_ele_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         903.494127      82.318006       total sum
# 16         120.000000      10.954451       Unweighted events, alpha=7.529118
#   => Total parameter prop_binch1_ele_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         806.281425      76.456479       total sum
# 17         111.000000      10.535654       Unweighted events, alpha=7.263797
#   => Total parameter prop_binch1_ele_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         520.270929      31.543404       total sum
# 18         272.000000      16.492423       Unweighted events, alpha=1.912761
#   => Total parameter prop_binch1_ele_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         639.272049      90.820938       total sum
# 19         50.000000       7.071068        Unweighted events, alpha=12.785441
#   => Total parameter prop_binch1_ele_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .    2Channel ch2_mu will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch2_mu
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2923.188259     210.389217      total sum
# 0          193.000000      13.892444       Unweighted events, alpha=15.146053
#   => Total parameter prop_binch2_mu_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          4135.710701     212.200725      total sum
# 1          380.000000      19.493589       Unweighted events, alpha=10.883449
#   => Total parameter prop_binch2_mu_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          6204.981430     1071.177462     total sum
# 2          34.000000       5.830952        Unweighted events, alpha=182.499454
#   => Total parameter prop_binch2_mu_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          4638.697647     141.594217      total sum
# 3          1073.000000     32.756679       Unweighted events, alpha=4.323111
#   => Total parameter prop_binch2_mu_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          3814.720165     129.891198      total sum
# 4          863.000000      29.376862       Unweighted events, alpha=4.420301
#   => Total parameter prop_binch2_mu_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          3718.490841     1218.042742     total sum
# 5          9.000000        3.000000        Unweighted events, alpha=413.165649
#   => Total parameter prop_binch2_mu_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1910.691650     260.570861      total sum
# 6          54.000000       7.348469        Unweighted events, alpha=35.383179
#   => Total parameter prop_binch2_mu_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1668.503716     163.642247      total sum
# 7          104.000000      10.198039       Unweighted events, alpha=16.043305
#   => Total parameter prop_binch2_mu_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1200.885208     77.515137       total sum
# 8          240.000000      15.491933       Unweighted events, alpha=5.003688
#   => Total parameter prop_binch2_mu_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          923.950808      49.909899       total sum
# 9          343.000000      18.520259       Unweighted events, alpha=2.693734
#   => Total parameter prop_binch2_mu_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         916.496769      93.565804       total sum
# 10         96.000000       9.797959        Unweighted events, alpha=9.546841
#   => Total parameter prop_binch2_mu_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         729.030876      67.818376       total sum
# 11         116.000000      10.770330       Unweighted events, alpha=6.284749
#   => Total parameter prop_binch2_mu_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .    3Channel ch2_ele will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch2_ele
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1967.045380     86.663212       total sum
# 0          515.000000      22.693611       Unweighted events, alpha=3.819506
#   => Total parameter prop_binch2_ele_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          2540.544312     105.370163      total sum
# 1          581.000000      24.103942       Unweighted events, alpha=4.372710
#   => Total parameter prop_binch2_ele_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          3151.067657     93.084694       total sum
# 2          1146.000000     33.852622       Unweighted events, alpha=2.749623
#   => Total parameter prop_binch2_ele_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          3723.182983     130.738868      total sum
# 3          811.000000      28.478062       Unweighted events, alpha=4.590854
#   => Total parameter prop_binch2_ele_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          952.036179      66.147624       total sum
# 4          207.000000      14.387495       Unweighted events, alpha=4.599209
#   => Total parameter prop_binch2_ele_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1038.725990     83.903243       total sum
# 5          153.000000      12.369317       Unweighted events, alpha=6.789059
#   => Total parameter prop_binch2_ele_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          2167.097672     400.737531      total sum
# 6          29.000000       5.385165        Unweighted events, alpha=74.727506
#   => Total parameter prop_binch2_ele_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          2899.682396     142.598449      total sum
# 7          413.000000      20.322401       Unweighted events, alpha=7.021023
#   => Total parameter prop_binch2_ele_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          4577.039429     174.774259      total sum
# 8          686.000000      26.191602       Unweighted events, alpha=6.672069
#   => Total parameter prop_binch2_ele_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          5291.324097     192.918022      total sum
# 9          752.000000      27.422618       Unweighted events, alpha=7.036335
#   => Total parameter prop_binch2_ele_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         3348.153099     146.093972      total sum
# 10         525.000000      22.912878       Unweighted events, alpha=6.377434
#   => Total parameter prop_binch2_ele_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         1641.094254     99.468121       total sum
# 11         272.000000      16.492423       Unweighted events, alpha=6.033435
#   => Total parameter prop_binch2_ele_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1164.499664     236.857544      total sum
# 12         24.000000       4.898979        Unweighted events, alpha=48.520819
#   => Total parameter prop_binch2_ele_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         704.435913      81.841488       total sum
# 13         74.000000       8.602325        Unweighted events, alpha=9.519404
#   => Total parameter prop_binch2_ele_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         2089.434204     105.858355      total sum
# 14         390.000000      19.748418       Unweighted events, alpha=5.357524
#   => Total parameter prop_binch2_ele_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         1334.821487     64.724389       total sum
# 15         425.000000      20.615528       Unweighted events, alpha=3.140756
#   => Total parameter prop_binch2_ele_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         1106.737259     83.661441       total sum
# 16         175.000000      13.228757       Unweighted events, alpha=6.324213
#   => Total parameter prop_binch2_ele_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         942.239861      87.330957       total sum
# 17         116.000000      10.770330       Unweighted events, alpha=8.122757
#   => Total parameter prop_binch2_ele_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         717.845642      47.632217       total sum
# 18         227.000000      15.066519       Unweighted events, alpha=3.162316
#   => Total parameter prop_binch2_ele_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         593.039268      49.885161       total sum
# 19         141.000000      11.874342       Unweighted events, alpha=4.205952
#   => Total parameter prop_binch2_ele_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .    4Channel ch3_mu will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch3_mu
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          3888.256241     357.798753      total sum
# 0          118.000000      10.862780       Unweighted events, alpha=32.951324
#   => Total parameter prop_binch3_mu_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          5152.626671     152.148244      total sum
# 1          1147.000000     33.867388       Unweighted events, alpha=4.492264
#   => Total parameter prop_binch3_mu_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          8265.407928     1703.323955     total sum
# 2          24.000000       4.898979        Unweighted events, alpha=344.391997
#   => Total parameter prop_binch3_mu_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          7433.159889     1329.975242     total sum
# 3          31.000000       5.567764        Unweighted events, alpha=239.779351
#   => Total parameter prop_binch3_mu_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          4635.998245     118.595699      total sum
# 4          1528.000000     39.089641       Unweighted events, alpha=3.034030
#   => Total parameter prop_binch3_mu_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          2933.111969     238.594947      total sum
# 5          151.000000      12.288206       Unweighted events, alpha=19.424583
#   => Total parameter prop_binch3_mu_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          2206.791901     101.786619      total sum
# 6          470.000000      21.679483       Unweighted events, alpha=4.695302
#   => Total parameter prop_binch3_mu_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          2113.465141     219.707284      total sum
# 7          93.000000       9.643651        Unweighted events, alpha=22.725432
#   => Total parameter prop_binch3_mu_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1681.009224     90.682699       total sum
# 8          344.000000      18.547237       Unweighted events, alpha=4.886655
#   => Total parameter prop_binch3_mu_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1252.899128     82.390507       total sum
# 9          231.000000      15.198684       Unweighted events, alpha=5.423806
#   => Total parameter prop_binch3_mu_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1158.513119     70.440636       total sum
# 10         270.000000      16.431677       Unweighted events, alpha=4.290789
#   => Total parameter prop_binch3_mu_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         946.313511      60.264456       total sum
# 11         247.000000      15.716234       Unweighted events, alpha=3.831229
#   => Total parameter prop_binch3_mu_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .    5Channel ch3_ele will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch3_ele
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2651.779556     109.374741      total sum
# 0          588.000000      24.248711       Unweighted events, alpha=4.509829
#   => Total parameter prop_binch3_ele_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          3418.737122     139.358068      total sum
# 1          602.000000      24.535688       Unweighted events, alpha=5.678965
#   => Total parameter prop_binch3_ele_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          4181.431458     145.979540      total sum
# 2          820.000000      28.635642       Unweighted events, alpha=5.099307
#   => Total parameter prop_binch3_ele_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          5232.642944     159.895419      total sum
# 3          1071.000000     32.726136       Unweighted events, alpha=4.885754
#   => Total parameter prop_binch3_ele_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1692.843735     130.246536      total sum
# 4          169.000000      13.000000       Unweighted events, alpha=10.016827
#   => Total parameter prop_binch3_ele_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          2253.737335     122.868339      total sum
# 5          336.000000      18.330303       Unweighted events, alpha=6.707552
#   => Total parameter prop_binch3_ele_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          3037.240585     147.838282      total sum
# 6          422.000000      20.542639       Unweighted events, alpha=7.197253
#   => Total parameter prop_binch3_ele_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          5643.972137     208.451491      total sum
# 7          733.000000      27.073973       Unweighted events, alpha=7.699826
#   => Total parameter prop_binch3_ele_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          9332.336670     284.297693      total sum
# 8          1078.000000     32.832910       Unweighted events, alpha=8.657084
#   => Total parameter prop_binch3_ele_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          11686.902435    2708.319150     total sum
# 9          19.000000       4.358899        Unweighted events, alpha=615.100128
#   => Total parameter prop_binch3_ele_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         5656.132492     213.294866      total sum
# 10         703.000000      26.514147       Unweighted events, alpha=8.045708
#   => Total parameter prop_binch3_ele_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         2333.912636     133.498639      total sum
# 11         306.000000      17.492856       Unweighted events, alpha=7.627165
#   => Total parameter prop_binch3_ele_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1764.801842     358.295346      total sum
# 12         24.000000       4.898979        Unweighted events, alpha=73.533410
#   => Total parameter prop_binch3_ele_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         811.646248      69.473159       total sum
# 13         136.000000      11.661904       Unweighted events, alpha=5.967987
#   => Total parameter prop_binch3_ele_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         2732.423431     152.334806      total sum
# 14         322.000000      17.944358       Unweighted events, alpha=8.485787
#   => Total parameter prop_binch3_ele_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         2193.311554     173.378555      total sum
# 15         160.000000      12.649111       Unweighted events, alpha=13.708197
#   => Total parameter prop_binch3_ele_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         1527.953247     152.272568      total sum
# 16         101.000000      10.049876       Unweighted events, alpha=15.128250
#   => Total parameter prop_binch3_ele_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         1362.451797     111.702560      total sum
# 17         149.000000      12.206556       Unweighted events, alpha=9.143972
#   => Total parameter prop_binch3_ele_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         1002.899994     64.365349       total sum
# 18         243.000000      15.588457       Unweighted events, alpha=4.127160
#   => Total parameter prop_binch3_ele_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         909.389534      61.549403       total sum
# 19         218.000000      14.764823       Unweighted events, alpha=4.171512
#   => Total parameter prop_binch3_ele_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .   done.
# Importing combined pdf model_s
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-qQXK2n.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
# Redefining the POIs to be: RooArgSet:: = (r,MisIDEleSeventeenSF,MisIDEleEighteenSF,ZGammaBkgPhotonSF,WGammaBkgPhotonSF)
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9ab52f0
#   Clients:
#     (0x9c33c90,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9ab68c0,V-) RooRealSumPdf::pdf_binch1_mu_nuis ""
#     (0x9d2ec60,V-) RooProdPdf::pdfbins_binch1_mu ""
#     (0x9820700,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x9a84d10,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x9a885a0,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x9ab00a0,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x9ab34f0,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x9af8b50,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)        BTagSF_b_Pdf
#       2)        BTagSF_l_Pdf
#       3)           MuEff_Pdf
#       4)              PU_Pdf
#       5)          PhoEff_Pdf
#       6)            lumi_Pdf
#       7)  pdf_binch1_mu_nuis
#       8)   pdfbins_binch1_mu
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch1_mu"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch1_mu (ch1_mu)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch1_mu_CMS_th1x, pdf pdf_binch1_mu = 25159.3
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9afa110
#   Clients:
#     (0x9c33c90,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9ac3a10,V-) RooRealSumPdf::pdf_binch1_ele_nuis ""
#     (0x9afb0d0,V-) RooProdPdf::pdfbins_binch1_ele ""
#     (0x9820700,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x9a84d10,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x9a885a0,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x9ab00a0,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x9ab34f0,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x9af8b50,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         BTagSF_b_Pdf
#       2)         BTagSF_l_Pdf
#       3)            MuEff_Pdf
#       4)               PU_Pdf
#       5)           PhoEff_Pdf
#       6)             lumi_Pdf
#       7)  pdf_binch1_ele_nuis
#       8)   pdfbins_binch1_ele
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch1_ele"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch1_ele (ch1_ele)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch1_ele_CMS_th1x, pdf pdf_binch1_ele = 24525.6
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9c450d0
#   Clients:
#     (0x9c33c90,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9c46040,V-) RooRealSumPdf::pdf_binch2_mu_nuis ""
#     (0x9e186f0,V-) RooProdPdf::pdfbins_binch2_mu ""
#     (0x9820700,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x9a84d10,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x9a885a0,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x9ab00a0,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x9ab34f0,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x9af8b50,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)        BTagSF_b_Pdf
#       2)        BTagSF_l_Pdf
#       3)           MuEff_Pdf
#       4)              PU_Pdf
#       5)          PhoEff_Pdf
#       6)            lumi_Pdf
#       7)  pdf_binch2_mu_nuis
#       8)   pdfbins_binch2_mu
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch2_mu"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch2_mu (ch2_mu)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch2_mu_CMS_th1x, pdf pdf_binch2_mu = 32785.3
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9e084e0
#   Clients:
#     (0x9c33c90,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9e09430,V-) RooRealSumPdf::pdf_binch2_ele_nuis ""
#     (0x9ce2730,V-) RooProdPdf::pdfbins_binch2_ele ""
#     (0x9820700,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x9a84d10,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x9a885a0,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x9ab00a0,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x9ab34f0,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x9af8b50,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         BTagSF_b_Pdf
#       2)         BTagSF_l_Pdf
#       3)            MuEff_Pdf
#       4)               PU_Pdf
#       5)           PhoEff_Pdf
#       6)             lumi_Pdf
#       7)  pdf_binch2_ele_nuis
#       8)   pdfbins_binch2_ele
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch2_ele"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch2_ele (ch2_ele)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch2_ele_CMS_th1x, pdf pdf_binch2_ele = 41950
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9d9db00
#   Clients:
#     (0x9c33c90,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9d9ea50,V-) RooRealSumPdf::pdf_binch3_mu_nuis ""
#     (0x9d812a0,V-) RooProdPdf::pdfbins_binch3_mu ""
#     (0x9820700,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x9a84d10,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x9a885a0,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x9ab00a0,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x9ab34f0,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x9af8b50,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)        BTagSF_b_Pdf
#       2)        BTagSF_l_Pdf
#       3)           MuEff_Pdf
#       4)              PU_Pdf
#       5)          PhoEff_Pdf
#       6)            lumi_Pdf
#       7)  pdf_binch3_mu_nuis
#       8)   pdfbins_binch3_mu
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch3_mu"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch3_mu (ch3_mu)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch3_mu_CMS_th1x, pdf pdf_binch3_mu = 41667.6
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9d70e70
#   Clients:
#     (0x9c33c90,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9d71dc0,V-) RooRealSumPdf::pdf_binch3_ele_nuis ""
#     (0x9d40690,V-) RooProdPdf::pdfbins_binch3_ele ""
#     (0x9820700,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x9a84d10,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x9a885a0,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x9ab00a0,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x9ab34f0,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x9af8b50,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         BTagSF_b_Pdf
#       2)         BTagSF_l_Pdf
#       3)            MuEff_Pdf
#       4)               PU_Pdf
#       5)           PhoEff_Pdf
#       6)             lumi_Pdf
#       7)  pdf_binch3_ele_nuis
#       8)   pdfbins_binch3_ele
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch3_ele"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch3_ele (ch3_ele)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch3_ele_CMS_th1x, pdf pdf_binch3_ele = 69426.5
# Error in <TList::Clear>: A list is accessing an object (0x9ed5294) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9ed553c) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9ed57e4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9ed5a8c) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9ed5d34) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9ed5fdc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./ch1_mu_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./ch1_ele_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./ch2_mu_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./ch2_ele_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./ch3_mu_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./ch3_ele_CMS_th1x_prefit.png has been created
#
#   RooFitResult: minimized FCN value: -5778.66, estimated distance to minimum: 6.3754e-05
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#            BTagSF_b_In    0.0000e+00
#            BTagSF_l_In    0.0000e+00
#               MuEff_In    0.0000e+00
#                    ONE    1.0000e+00
#                  PU_In    0.0000e+00
#              PhoEff_In    0.0000e+00
#                lumi_In    0.0000e+00
#   prop_binch1_ele_bin0_In    0.0000e+00
#   prop_binch1_ele_bin10_In    0.0000e+00
#   prop_binch1_ele_bin11_In    0.0000e+00
#   prop_binch1_ele_bin12_In    0.0000e+00
#   prop_binch1_ele_bin13_In    0.0000e+00
#   prop_binch1_ele_bin14_In    0.0000e+00
#   prop_binch1_ele_bin15_In    0.0000e+00
#   prop_binch1_ele_bin16_In    0.0000e+00
#   prop_binch1_ele_bin17_In    0.0000e+00
#   prop_binch1_ele_bin18_In    0.0000e+00
#   prop_binch1_ele_bin19_In    0.0000e+00
#   prop_binch1_ele_bin1_In    0.0000e+00
#   prop_binch1_ele_bin2_In    0.0000e+00
#   prop_binch1_ele_bin3_In    0.0000e+00
#   prop_binch1_ele_bin4_In    0.0000e+00
#   prop_binch1_ele_bin5_In    0.0000e+00
#   prop_binch1_ele_bin6_In    0.0000e+00
#   prop_binch1_ele_bin7_In    0.0000e+00
#   prop_binch1_ele_bin8_In    0.0000e+00
#   prop_binch1_ele_bin9_In    0.0000e+00
#   prop_binch1_mu_bin0_In    0.0000e+00
#   prop_binch1_mu_bin10_In    0.0000e+00
#   prop_binch1_mu_bin11_In    0.0000e+00
#   prop_binch1_mu_bin1_In    0.0000e+00
#   prop_binch1_mu_bin2_In    0.0000e+00
#   prop_binch1_mu_bin3_In    0.0000e+00
#   prop_binch1_mu_bin4_In    0.0000e+00
#   prop_binch1_mu_bin5_In    0.0000e+00
#   prop_binch1_mu_bin6_In    0.0000e+00
#   prop_binch1_mu_bin7_In    0.0000e+00
#   prop_binch1_mu_bin8_In    0.0000e+00
#   prop_binch1_mu_bin9_In    0.0000e+00
#   prop_binch2_ele_bin0_In    0.0000e+00
#   prop_binch2_ele_bin10_In    0.0000e+00
#   prop_binch2_ele_bin11_In    0.0000e+00
#   prop_binch2_ele_bin12_In    0.0000e+00
#   prop_binch2_ele_bin13_In    0.0000e+00
#   prop_binch2_ele_bin14_In    0.0000e+00
#   prop_binch2_ele_bin15_In    0.0000e+00
#   prop_binch2_ele_bin16_In    0.0000e+00
#   prop_binch2_ele_bin17_In    0.0000e+00
#   prop_binch2_ele_bin18_In    0.0000e+00
#   prop_binch2_ele_bin19_In    0.0000e+00
#   prop_binch2_ele_bin1_In    0.0000e+00
#   prop_binch2_ele_bin2_In    0.0000e+00
#   prop_binch2_ele_bin3_In    0.0000e+00
#   prop_binch2_ele_bin4_In    0.0000e+00
#   prop_binch2_ele_bin5_In    0.0000e+00
#   prop_binch2_ele_bin6_In    0.0000e+00
#   prop_binch2_ele_bin7_In    0.0000e+00
#   prop_binch2_ele_bin8_In    0.0000e+00
#   prop_binch2_ele_bin9_In    0.0000e+00
#   prop_binch2_mu_bin0_In    0.0000e+00
#   prop_binch2_mu_bin10_In    0.0000e+00
#   prop_binch2_mu_bin11_In    0.0000e+00
#   prop_binch2_mu_bin1_In    0.0000e+00
#   prop_binch2_mu_bin2_In    0.0000e+00
#   prop_binch2_mu_bin3_In    0.0000e+00
#   prop_binch2_mu_bin4_In    0.0000e+00
#   prop_binch2_mu_bin5_In    0.0000e+00
#   prop_binch2_mu_bin6_In    0.0000e+00
#   prop_binch2_mu_bin7_In    0.0000e+00
#   prop_binch2_mu_bin8_In    0.0000e+00
#   prop_binch2_mu_bin9_In    0.0000e+00
#   prop_binch3_ele_bin0_In    0.0000e+00
#   prop_binch3_ele_bin10_In    0.0000e+00
#   prop_binch3_ele_bin11_In    0.0000e+00
#   prop_binch3_ele_bin12_In    0.0000e+00
#   prop_binch3_ele_bin13_In    0.0000e+00
#   prop_binch3_ele_bin14_In    0.0000e+00
#   prop_binch3_ele_bin15_In    0.0000e+00
#   prop_binch3_ele_bin16_In    0.0000e+00
#   prop_binch3_ele_bin17_In    0.0000e+00
#   prop_binch3_ele_bin18_In    0.0000e+00
#   prop_binch3_ele_bin19_In    0.0000e+00
#   prop_binch3_ele_bin1_In    0.0000e+00
#   prop_binch3_ele_bin2_In    0.0000e+00
#   prop_binch3_ele_bin3_In    0.0000e+00
#   prop_binch3_ele_bin4_In    0.0000e+00
#   prop_binch3_ele_bin5_In    0.0000e+00
#   prop_binch3_ele_bin6_In    0.0000e+00
#   prop_binch3_ele_bin7_In    0.0000e+00
#   prop_binch3_ele_bin8_In    0.0000e+00
#   prop_binch3_ele_bin9_In    0.0000e+00
#   prop_binch3_mu_bin0_In    0.0000e+00
#   prop_binch3_mu_bin10_In    0.0000e+00
#   prop_binch3_mu_bin11_In    0.0000e+00
#   prop_binch3_mu_bin1_In    0.0000e+00
#   prop_binch3_mu_bin2_In    0.0000e+00
#   prop_binch3_mu_bin3_In    0.0000e+00
#   prop_binch3_mu_bin4_In    0.0000e+00
#   prop_binch3_mu_bin5_In    0.0000e+00
#   prop_binch3_mu_bin6_In    0.0000e+00
#   prop_binch3_mu_bin7_In    0.0000e+00
#   prop_binch3_mu_bin8_In    0.0000e+00
#   prop_binch3_mu_bin9_In    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#               BTagSF_b    0.0000e+00   -6.3696e-02 +/-  9.90e-01  <none>
#               BTagSF_l    0.0000e+00    4.8610e-01 +/-  9.87e-01  <none>
#     MisIDEleEighteenSF    2.0000e+00    7.8305e-01 +/-  2.81e-02  <none>
#    MisIDEleSeventeenSF    2.0000e+00    1.1051e+00 +/-  4.02e-02  <none>
#                  MuEff    0.0000e+00   -7.8649e-01 +/-  9.30e-01  <none>
#                     PU    0.0000e+00    1.1111e+00 +/-  5.82e-01  <none>
#                 PhoEff    0.0000e+00    2.5010e+00 +/-  5.81e-01  <none>
#      WGammaBkgPhotonSF    1.0000e+00    1.0932e+00 +/-  9.04e-02  <none>
#      ZGammaBkgPhotonSF    1.0000e+00    8.4297e-01 +/-  6.47e-02  <none>
#                   lumi    0.0000e+00    1.6323e+00 +/-  1.03e+00  <none>
#   prop_binch1_ele_bin0    0.0000e+00   -1.3682e+00 +/-  2.21e-01  <none>
#   prop_binch1_ele_bin1    0.0000e+00   -1.0876e+00 +/-  2.23e-01  <none>
#   prop_binch1_ele_bin10    0.0000e+00   -3.5999e-01 +/-  5.67e-01  <none>
#   prop_binch1_ele_bin11    0.0000e+00   -2.9029e-01 +/-  5.15e-01  <none>
#   prop_binch1_ele_bin12    0.0000e+00    4.7208e-01 +/-  4.73e-01  <none>
#   prop_binch1_ele_bin13    0.0000e+00   -3.2363e-01 +/-  2.69e-01  <none>
#   prop_binch1_ele_bin14    0.0000e+00   -9.4989e-01 +/-  3.17e-01  <none>
#   prop_binch1_ele_bin15    0.0000e+00   -4.3691e-01 +/-  4.90e-01  <none>
#   prop_binch1_ele_bin16    0.0000e+00    1.2534e-01 +/-  3.39e-01  <none>
#   prop_binch1_ele_bin17    0.0000e+00   -5.1695e-01 +/-  3.49e-01  <none>
#   prop_binch1_ele_bin18    0.0000e+00    1.6598e+00 +/-  5.66e-01  <none>
#   prop_binch1_ele_bin19    0.0000e+00   -8.3139e-01 +/-  2.49e-01  <none>
#   prop_binch1_ele_bin2    0.0000e+00   -9.6161e-01 +/-  4.42e-01  <none>
#   prop_binch1_ele_bin3    0.0000e+00   -2.2782e+00 +/-  3.08e-01  <none>
#   prop_binch1_ele_bin4    0.0000e+00    3.1312e-02 +/-  4.51e-01  <none>
#   prop_binch1_ele_bin5    0.0000e+00   -9.1381e-01 +/-  3.25e-01  <none>
#   prop_binch1_ele_bin6    0.0000e+00   -1.4950e+00 +/-  4.80e-01  <none>
#   prop_binch1_ele_bin7    0.0000e+00   -3.6681e-01 +/-  5.18e-01  <none>
#   prop_binch1_ele_bin8    0.0000e+00    1.0094e+00 +/-  6.69e-01  <none>
#   prop_binch1_ele_bin9    0.0000e+00    6.3924e-01 +/-  6.73e-01  <none>
#    prop_binch1_mu_bin0    0.0000e+00   -1.0635e+00 +/-  5.21e-01  <none>
#    prop_binch1_mu_bin1    0.0000e+00   -1.3728e+00 +/-  4.68e-01  <none>
#   prop_binch1_mu_bin10    0.0000e+00    4.7298e-01 +/-  5.65e-01  <none>
# ...
#   prop_binch2_ele_bin16    0.0000e+00    9.6533e-01         +/-  3.77e-01  <none>
#   prop_binch2_ele_bin17    0.0000e+00    7.2737e-01         +/-  3.25e-01  <none>
#   prop_binch2_ele_bin18    0.0000e+00    1.8396e+00         +/-  4.85e-01  <none>
#   prop_binch2_ele_bin19    0.0000e+00    1.5112e+00         +/-  4.23e-01  <none>
#   prop_binch2_ele_bin2    0.0000e+00   -4.6624e-03         +/-  5.86e-01  <none>
#   prop_binch2_ele_bin3    0.0000e+00   -1.0691e+00         +/-  4.60e-01  <none>
#   prop_binch2_ele_bin4    0.0000e+00   -2.9543e-02         +/-  4.20e-01  <none>
#   prop_binch2_ele_bin5    0.0000e+00    1.3700e+00         +/-  3.70e-01  <none>
#   prop_binch2_ele_bin6    0.0000e+00   -9.4447e-01         +/-  1.38e-01  <none>
#   prop_binch2_ele_bin7    0.0000e+00   -4.0172e-01         +/-  4.67e-01  <none>
#   prop_binch2_ele_bin8    0.0000e+00   -4.3016e-01         +/-  5.66e-01  <none>
#   prop_binch2_ele_bin9    0.0000e+00   -4.0531e-01         +/-  5.95e-01  <none>
#    prop_binch2_mu_bin0    0.0000e+00   -3.4257e-01         +/-  2.97e-01  <none>
#    prop_binch2_mu_bin1    0.0000e+00   -8.7483e-01         +/-  3.47e-01  <none>
#   prop_binch2_mu_bin10    0.0000e+00   -6.3605e-01         +/-  3.08e-01  <none>
#   prop_binch2_mu_bin11    0.0000e+00    3.9476e-01         +/-  3.85e-01  <none>
#    prop_binch2_mu_bin2    0.0000e+00   -9.4345e-01         +/-  1.27e-01  <none>
#    prop_binch2_mu_bin3    0.0000e+00    9.2569e-01         +/-  5.38e-01  <none>
#    prop_binch2_mu_bin4    0.0000e+00    1.1093e+00         +/-  5.00e-01  <none>
#    prop_binch2_mu_bin5    0.0000e+00   -1.0953e+00         +/-  6.99e-02  <none>
#    prop_binch2_mu_bin6    0.0000e+00   -1.5422e-01         +/-  2.07e-01  <none>
#    prop_binch2_mu_bin7    0.0000e+00   -8.2604e-01         +/-  2.55e-01  <none>
#    prop_binch2_mu_bin8    0.0000e+00    6.9044e-01         +/-  4.35e-01  <none>
#    prop_binch2_mu_bin9    0.0000e+00    1.2573e+00         +/-  5.37e-01  <none>
#   prop_binch3_ele_bin0    0.0000e+00    1.1252e+00         +/-  4.79e-01  <none>
#   prop_binch3_ele_bin1    0.0000e+00    4.1531e-01         +/-  4.22e-01  <none>
#   prop_binch3_ele_bin10    0.0000e+00   -1.2366e+00         +/-  5.55e-01  <none>
#   prop_binch3_ele_bin11    0.0000e+00    1.2889e+00         +/-  4.66e-01  <none>
#   prop_binch3_ele_bin12    0.0000e+00   -8.5711e-01         +/-  1.09e-01  <none>
#   prop_binch3_ele_bin13    0.0000e+00    1.6071e+00         +/-  4.25e-01  <none>
#   prop_binch3_ele_bin14    0.0000e+00    2.1296e+00         +/-  3.78e-01  <none>
#   prop_binch3_ele_bin15    0.0000e+00   -9.9714e-01         +/-  2.54e-01  <none>
#   prop_binch3_ele_bin16    0.0000e+00    2.7372e-01         +/-  2.60e-01  <none>
#   prop_binch3_ele_bin17    0.0000e+00   -8.9936e-01         +/-  4.81e-01  <none>
#   prop_binch3_ele_bin18    0.0000e+00    2.0795e+00         +/-  4.57e-01  <none>
#   prop_binch3_ele_bin19    0.0000e+00    4.8497e-01         +/-  4.39e-01  <none>
#   prop_binch3_ele_bin2    0.0000e+00    1.8881e+00         +/-  4.73e-01  <none>
#   prop_binch3_ele_bin3    0.0000e+00    2.0030e+00         +/-  5.05e-01  <none>
#   prop_binch3_ele_bin4    0.0000e+00   -1.0414e+00         +/-  3.31e-01  <none>
#   prop_binch3_ele_bin5    0.0000e+00   -8.7981e-01         +/-  4.37e-01  <none>
#   prop_binch3_ele_bin6    0.0000e+00    1.0912e+00         +/-  4.84e-01  <none>
#   prop_binch3_ele_bin7    0.0000e+00    1.4315e-01         +/-  5.62e-01  <none>
#   prop_binch3_ele_bin8    0.0000e+00   -1.4131e+00         +/-  6.35e-01  <none>
#   prop_binch3_ele_bin9    0.0000e+00   -7.4142e-01         +/-  7.84e-02  <none>
#    prop_binch3_mu_bin0    0.0000e+00   -1.1822e+00         +/-  1.82e-01  <none>
#    prop_binch3_mu_bin1    0.0000e+00   -9.1928e-01         +/-  5.02e-01  <none>
#   prop_binch3_mu_bin10    0.0000e+00   -7.5907e-01         +/-  4.47e-01  <none>
#   prop_binch3_mu_bin11    0.0000e+00   -3.7269e-01         +/-  4.64e-01  <none>
#    prop_binch3_mu_bin2    0.0000e+00   -1.0994e+00         +/-  1.28e-01  <none>
#    prop_binch3_mu_bin3    0.0000e+00   -1.1666e+00         +/-  7.52e-02  <none>
#    prop_binch3_mu_bin4    0.0000e+00    3.9225e-01         +/-  5.51e-01  <none>
#    prop_binch3_mu_bin5    0.0000e+00   -7.9373e-01         +/-  2.47e-01  <none>
#    prop_binch3_mu_bin6    0.0000e+00    5.2577e-02         +/-  4.52e-01  <none>
#    prop_binch3_mu_bin7    0.0000e+00   -8.1373e-01         +/-  2.33e-01  <none>
#    prop_binch3_mu_bin8    0.0000e+00   -1.7535e+00         +/-  4.60e-01  <none>
#    prop_binch3_mu_bin9    0.0000e+00    5.1127e-01         +/-  4.12e-01  <none>
#                      r    1.0000e+00    1.6960e+00 (+1.05e-01,-9.88e-02)  <none>
#
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9ab52f0
#   Clients:
#     (0x9c33c90,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9ab68c0,V-) RooRealSumPdf::pdf_binch1_mu_nuis ""
#     (0x9d2ec60,V-) RooProdPdf::pdfbins_binch1_mu ""
#     (0x9820700,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x9a84d10,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x9a885a0,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x9ab00a0,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x9ab34f0,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x9af8b50,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)        BTagSF_b_Pdf
#       2)        BTagSF_l_Pdf
#       3)           MuEff_Pdf
#       4)              PU_Pdf
#       5)          PhoEff_Pdf
#       6)            lumi_Pdf
#       7)  pdf_binch1_mu_nuis
#       8)   pdfbins_binch1_mu
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch1_mu"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch1_mu (ch1_mu)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch1_mu_CMS_th1x, pdf pdf_binch1_mu = 27659.2
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9afa110
#   Clients:
#     (0x9c33c90,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9ac3a10,V-) RooRealSumPdf::pdf_binch1_ele_nuis ""
#     (0x9afb0d0,V-) RooProdPdf::pdfbins_binch1_ele ""
#     (0x9820700,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x9a84d10,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x9a885a0,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x9ab00a0,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x9ab34f0,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x9af8b50,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         BTagSF_b_Pdf
#       2)         BTagSF_l_Pdf
#       3)            MuEff_Pdf
#       4)               PU_Pdf
#       5)           PhoEff_Pdf
#       6)             lumi_Pdf
#       7)  pdf_binch1_ele_nuis
#       8)   pdfbins_binch1_ele
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch1_ele"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch1_ele (ch1_ele)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch1_ele_CMS_th1x, pdf pdf_binch1_ele = 32610
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9c450d0
#   Clients:
#     (0x9c33c90,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9c46040,V-) RooRealSumPdf::pdf_binch2_mu_nuis ""
#     (0x9e186f0,V-) RooProdPdf::pdfbins_binch2_mu ""
#     (0x9820700,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x9a84d10,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x9a885a0,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x9ab00a0,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x9ab34f0,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x9af8b50,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)        BTagSF_b_Pdf
#       2)        BTagSF_l_Pdf
#       3)           MuEff_Pdf
#       4)              PU_Pdf
#       5)          PhoEff_Pdf
#       6)            lumi_Pdf
#       7)  pdf_binch2_mu_nuis
#       8)   pdfbins_binch2_mu
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch2_mu"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch2_mu (ch2_mu)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch2_mu_CMS_th1x, pdf pdf_binch2_mu = 36405.8
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9e084e0
#   Clients:
#     (0x9c33c90,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9e09430,V-) RooRealSumPdf::pdf_binch2_ele_nuis ""
#     (0x9ce2730,V-) RooProdPdf::pdfbins_binch2_ele ""
#     (0x9820700,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x9a84d10,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x9a885a0,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x9ab00a0,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x9ab34f0,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x9af8b50,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         BTagSF_b_Pdf
#       2)         BTagSF_l_Pdf
#       3)            MuEff_Pdf
#       4)               PU_Pdf
#       5)           PhoEff_Pdf
#       6)             lumi_Pdf
#       7)  pdf_binch2_ele_nuis
#       8)   pdfbins_binch2_ele
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch2_ele"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch2_ele (ch2_ele)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch2_ele_CMS_th1x, pdf pdf_binch2_ele = 49922.3
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9d9db00
#   Clients:
#     (0x9c33c90,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9d9ea50,V-) RooRealSumPdf::pdf_binch3_mu_nuis ""
#     (0x9d812a0,V-) RooProdPdf::pdfbins_binch3_mu ""
#     (0x9820700,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x9a84d10,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x9a885a0,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x9ab00a0,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x9ab34f0,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x9af8b50,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)        BTagSF_b_Pdf
#       2)        BTagSF_l_Pdf
#       3)           MuEff_Pdf
#       4)              PU_Pdf
#       5)          PhoEff_Pdf
#       6)            lumi_Pdf
#       7)  pdf_binch3_mu_nuis
#       8)   pdfbins_binch3_mu
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch3_mu"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch3_mu (ch3_mu)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch3_mu_CMS_th1x, pdf pdf_binch3_mu = 41612.1
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9d70e70
#   Clients:
#     (0x9c33c90,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9d71dc0,V-) RooRealSumPdf::pdf_binch3_ele_nuis ""
#     (0x9d40690,V-) RooProdPdf::pdfbins_binch3_ele ""
#     (0x9820700,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x9a84d10,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x9a885a0,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x9ab00a0,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x9ab34f0,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x9af8b50,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         BTagSF_b_Pdf
#       2)         BTagSF_l_Pdf
#       3)            MuEff_Pdf
#       4)               PU_Pdf
#       5)           PhoEff_Pdf
#       6)             lumi_Pdf
#       7)  pdf_binch3_ele_nuis
#       8)   pdfbins_binch3_ele
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch3_ele"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch3_ele (ch3_ele)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch3_ele_CMS_th1x, pdf pdf_binch3_ele = 63220.6
# Error in <TList::Clear>: A list is accessing an object (0x9ed7274) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9ed751c) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9ed77c4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9ed7a6c) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9ed7d14) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9ed7fbc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./ch1_mu_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./ch1_ele_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./ch2_mu_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./ch2_ele_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./ch3_mu_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./ch3_ele_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.69603  -0.0987996/+0.105454  (68% CL)
# Done in 0.10 min (cpu), 0.11 min (real)
# Printing Message Summary From ... combine_logger.out
# ----------------------------------------------
# Messages of type INFO : 9
# Messages of type DEBUG : 2
# Messages of type ERROR : 0
# ----------------------------------------------
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=-1
# DEBUG: (function: improveOnce) CascadeMinimizer.cc: 196 -- Minimization ended with latest status != 0 or 1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: doFit) FitterAlgoBase.cc: 318 -- Running Minos for POI r
# DEBUG: (function: runSpecific) FitDiagnostics.cc: 412 -- Fit S+B, status = 0, numBadNLL = 0, covariance quality = 3

# %%
# !combine -M FitDiagnostics -n CR1 datacard_CR1_allyear.txt --redefineSignalPOIs r,MisIDEleSeventeenSF,MisIDEleEighteenSF,ZGammaBkgPhotonSF,WGammaBkgPhotonSF -v2 --saveWithUncertainties --plots &
# Out:
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Creating pdfs for individual modes (6): Channel ch1_mu will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch1_mu
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1677.905720     69.203806       total sum
# 0          588.000000      24.248711       Unweighted events, alpha=2.853581
#   => Total parameter prop_binch1_mu_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          2576.051142     109.875056      total sum
# 1          550.000000      23.452079       Unweighted events, alpha=4.683729
#   => Total parameter prop_binch1_mu_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          3228.814949     116.544240      total sum
# 2          768.000000      27.712813       Unweighted events, alpha=4.204186
#   => Total parameter prop_binch1_mu_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          2905.560116     168.883183      total sum
# 3          296.000000      17.204651       Unweighted events, alpha=9.816081
#   => Total parameter prop_binch1_mu_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          2258.053452     59.827386       total sum
# 4          1425.000000     37.749172       Unweighted events, alpha=1.584599
#   => Total parameter prop_binch1_mu_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1282.209514     51.865669       total sum
# 5          611.000000      24.718414       Unweighted events, alpha=2.098543
#   => Total parameter prop_binch1_mu_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1061.216392     54.470155       total sum
# 6          380.000000      19.493589       Unweighted events, alpha=2.792675
#   => Total parameter prop_binch1_mu_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          928.992489      64.459146       total sum
# 7          208.000000      14.422205       Unweighted events, alpha=4.466310
#   => Total parameter prop_binch1_mu_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          655.180427      38.624082       total sum
# 8          288.000000      16.970563       Unweighted events, alpha=2.274932
#   => Total parameter prop_binch1_mu_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          566.585290      37.981895       total sum
# 9          223.000000      14.933185       Unweighted events, alpha=2.540741
#   => Total parameter prop_binch1_mu_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         456.778764      32.955163       total sum
# 10         192.000000      13.856406       Unweighted events, alpha=2.379056
#   => Total parameter prop_binch1_mu_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         542.047266      165.563778      total sum
# 11         11.000000       3.316625        Unweighted events, alpha=49.277024
#   => Total parameter prop_binch1_mu_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .    1Channel ch1_ele will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch1_ele
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1318.724970     169.601165      total sum
# 0          60.000000       7.745967        Unweighted events, alpha=21.978749
#   => Total parameter prop_binch1_ele_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1410.177811     49.527703       total sum
# 1          811.000000      28.478062       Unweighted events, alpha=1.738814
#   => Total parameter prop_binch1_ele_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1873.094109     98.060749       total sum
# 2          365.000000      19.104973       Unweighted events, alpha=5.131765
#   => Total parameter prop_binch1_ele_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          2270.135040     142.209651      total sum
# 3          255.000000      15.968719       Unweighted events, alpha=8.902490
#   => Total parameter prop_binch1_ele_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          452.958321      41.499387       total sum
# 4          119.000000      10.908712       Unweighted events, alpha=3.806372
#   => Total parameter prop_binch1_ele_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          545.844208      73.943832       total sum
# 5          54.000000       7.348469        Unweighted events, alpha=10.108226
#   => Total parameter prop_binch1_ele_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          586.931187      42.670190       total sum
# 6          189.000000      13.747727       Unweighted events, alpha=3.105456
#   => Total parameter prop_binch1_ele_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          870.999611      49.091362       total sum
# 7          315.000000      17.748239       Unweighted events, alpha=2.765078
#   => Total parameter prop_binch1_ele_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1246.286507     44.890922       total sum
# 8          771.000000      27.766887       Unweighted events, alpha=1.616455
#   => Total parameter prop_binch1_ele_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1397.885395     55.902489       total sum
# 9          625.000000      25.000000       Unweighted events, alpha=2.236617
#   => Total parameter prop_binch1_ele_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         964.303539      53.376387       total sum
# 10         326.000000      18.055470       Unweighted events, alpha=2.957986
#   => Total parameter prop_binch1_ele_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         490.175159      36.360712       total sum
# 11         182.000000      13.490738       Unweighted events, alpha=2.693270
#   => Total parameter prop_binch1_ele_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         311.434174      33.575239       total sum
# 12         86.000000       9.273618        Unweighted events, alpha=3.621328
#   => Total parameter prop_binch1_ele_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         252.085335      22.136174       total sum
# 13         130.000000      11.401754       Unweighted events, alpha=1.939118
#   => Total parameter prop_binch1_ele_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1051.550095     105.470151      total sum
# 14         99.000000       9.949874        Unweighted events, alpha=10.621718
#   => Total parameter prop_binch1_ele_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         782.860985      50.734065       total sum
# 15         238.000000      15.427249       Unweighted events, alpha=3.289332
#   => Total parameter prop_binch1_ele_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         602.026213      70.750303       total sum
# 16         72.000000       8.485281        Unweighted events, alpha=8.361475
#   => Total parameter prop_binch1_ele_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         558.254375      72.208565       total sum
# 17         60.000000       7.745967        Unweighted events, alpha=9.304240
#   => Total parameter prop_binch1_ele_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         336.645989      25.988015       total sum
# 18         168.000000      12.961481       Unweighted events, alpha=2.003845
#   => Total parameter prop_binch1_ele_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         394.539564      78.239044       total sum
# 19         25.000000       5.000000        Unweighted events, alpha=15.781583
#   => Total parameter prop_binch1_ele_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .    2Channel ch2_mu will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch2_mu
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1959.305101     103.190090      total sum
# 0          361.000000      19.000000       Unweighted events, alpha=5.427438
#   => Total parameter prop_binch2_mu_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          3132.920349     206.205970      total sum
# 1          231.000000      15.198684       Unweighted events, alpha=13.562426
#   => Total parameter prop_binch2_mu_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          4805.129097     1030.371800     total sum
# 2          22.000000       4.690416        Unweighted events, alpha=218.414959
#   => Total parameter prop_binch2_mu_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          3447.442474     113.969239      total sum
# 3          915.000000      30.248967       Unweighted events, alpha=3.767697
#   => Total parameter prop_binch2_mu_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          2920.669361     115.939183      total sum
# 4          635.000000      25.199206       Unweighted events, alpha=4.599479
#   => Total parameter prop_binch2_mu_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          2985.340000     1214.078696     total sum
# 5          6.000000        2.449490        Unweighted events, alpha=497.556667
#   => Total parameter prop_binch2_mu_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1402.786043     249.878928      total sum
# 6          32.000000       5.656854        Unweighted events, alpha=43.837064
#   => Total parameter prop_binch2_mu_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1189.925110     152.027470      total sum
# 7          61.000000       7.810250        Unweighted events, alpha=19.506969
#   => Total parameter prop_binch2_mu_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          827.692242      70.989693       total sum
# 8          136.000000      11.661904       Unweighted events, alpha=6.085972
#   => Total parameter prop_binch2_mu_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          639.024013      42.620992       total sum
# 9          225.000000      15.000000       Unweighted events, alpha=2.840107
#   => Total parameter prop_binch2_mu_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         632.941921      78.992697       total sum
# 10         64.000000       8.000000        Unweighted events, alpha=9.889718
#   => Total parameter prop_binch2_mu_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         493.548697      48.875584       total sum
# 11         102.000000      10.099505       Unweighted events, alpha=4.838713
#   => Total parameter prop_binch2_mu_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .    3Channel ch2_ele will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch2_ele
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1414.035202     74.511967       total sum
# 0          360.000000      18.973666       Unweighted events, alpha=3.927876
#   => Total parameter prop_binch2_ele_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1807.521225     79.330940       total sum
# 1          519.000000      22.781571       Unweighted events, alpha=3.482700
#   => Total parameter prop_binch2_ele_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          2334.512985     79.142011       total sum
# 2          870.000000      29.495762       Unweighted events, alpha=2.683348
#   => Total parameter prop_binch2_ele_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          2832.498444     99.862846       total sum
# 3          805.000000      28.372522       Unweighted events, alpha=3.518632
#   => Total parameter prop_binch2_ele_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          735.277176      60.416120       total sum
# 4          148.000000      12.165525       Unweighted events, alpha=4.968089
#   => Total parameter prop_binch2_ele_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          836.279343      79.627254       total sum
# 5          110.000000      10.488088       Unweighted events, alpha=7.602539
#   => Total parameter prop_binch2_ele_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1819.377014     398.493643      total sum
# 6          21.000000       4.582576        Unweighted events, alpha=86.637001
#   => Total parameter prop_binch2_ele_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          2290.901955     128.982340      total sum
# 7          315.000000      17.748239       Unweighted events, alpha=7.272705
#   => Total parameter prop_binch2_ele_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          3545.285217     152.507633      total sum
# 8          540.000000      23.237900       Unweighted events, alpha=6.565343
#   => Total parameter prop_binch2_ele_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          4155.887955     173.151145      total sum
# 9          576.000000      24.000000       Unweighted events, alpha=7.215083
#   => Total parameter prop_binch2_ele_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         2579.675903     128.722889      total sum
# 10         402.000000      20.049938       Unweighted events, alpha=6.417104
#   => Total parameter prop_binch2_ele_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         1303.527283     89.905026       total sum
# 11         210.000000      14.491377       Unweighted events, alpha=6.207273
#   => Total parameter prop_binch2_ele_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         677.008644      60.425295       total sum
# 12         126.000000      11.224972       Unweighted events, alpha=5.373084
#   => Total parameter prop_binch2_ele_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         494.567726      73.157788       total sum
# 13         46.000000       6.782330        Unweighted events, alpha=10.751472
#   => Total parameter prop_binch2_ele_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1534.649765     95.556870       total sum
# 14         258.000000      16.062378       Unweighted events, alpha=5.948255
#   => Total parameter prop_binch2_ele_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         956.622833      54.203237       total sum
# 15         311.000000      17.635192       Unweighted events, alpha=3.075958
#   => Total parameter prop_binch2_ele_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         760.286560      72.784482       total sum
# 16         109.000000      10.440307       Unweighted events, alpha=6.975106
#   => Total parameter prop_binch2_ele_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         679.941082      83.089956       total sum
# 17         67.000000       8.185353        Unweighted events, alpha=10.148374
#   => Total parameter prop_binch2_ele_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         499.880829      40.794753       total sum
# 18         150.000000      12.247449       Unweighted events, alpha=3.332539
#   => Total parameter prop_binch2_ele_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         432.395832      45.820849       total sum
# 19         89.000000       9.433981        Unweighted events, alpha=4.858380
#   => Total parameter prop_binch2_ele_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .    4Channel ch3_mu will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch3_mu
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2418.994118     97.896256       total sum
# 0          611.000000      24.718414       Unweighted events, alpha=3.959074
#   => Total parameter prop_binch3_mu_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          3841.843292     136.044434      total sum
# 1          797.000000      28.231188       Unweighted events, alpha=4.820381
#   => Total parameter prop_binch3_mu_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          6715.616295     1700.142136     total sum
# 2          16.000000       4.000000        Unweighted events, alpha=419.726018
#   => Total parameter prop_binch3_mu_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          6071.315544     1326.714854     total sum
# 3          21.000000       4.582576        Unweighted events, alpha=289.110264
#   => Total parameter prop_binch3_mu_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          3494.831100     102.127360      total sum
# 4          1171.000000     34.219877       Unweighted events, alpha=2.984484
#   => Total parameter prop_binch3_mu_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          2154.862648     232.906997      total sum
# 5          86.000000       9.273618        Unweighted events, alpha=25.056542
#   => Total parameter prop_binch3_mu_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1566.944839     90.083954       total sum
# 6          303.000000      17.406895       Unweighted events, alpha=5.171435
#   => Total parameter prop_binch3_mu_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1539.767719     215.003349      total sum
# 7          51.000000       7.141428        Unweighted events, alpha=30.191524
#   => Total parameter prop_binch3_mu_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1162.266514     79.726573       total sum
# 8          213.000000      14.594520       Unweighted events, alpha=5.456650
#   => Total parameter prop_binch3_mu_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          926.923872      76.388896       total sum
# 9          147.000000      12.124356       Unweighted events, alpha=6.305605
#   => Total parameter prop_binch3_mu_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         798.288437      60.213026       total sum
# 10         176.000000      13.266499       Unweighted events, alpha=4.535730
#   => Total parameter prop_binch3_mu_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         682.140255      53.429485       total sum
# 11         163.000000      12.767145       Unweighted events, alpha=4.184910
#   => Total parameter prop_binch3_mu_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .    5Channel ch3_ele will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch3_ele
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2004.885849     100.218495      total sum
# 0          400.000000      20.000000       Unweighted events, alpha=5.012215
#   => Total parameter prop_binch3_ele_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          2543.337799     124.606401      total sum
# 1          417.000000      20.420578       Unweighted events, alpha=6.099131
#   => Total parameter prop_binch3_ele_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          3149.671570     129.989648      total sum
# 2          587.000000      24.228083       Unweighted events, alpha=5.365710
#   => Total parameter prop_binch3_ele_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          4104.120789     145.478292      total sum
# 3          796.000000      28.213472       Unweighted events, alpha=5.155931
#   => Total parameter prop_binch3_ele_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1384.311859     123.284403      total sum
# 4          126.000000      11.224972       Unweighted events, alpha=10.986602
#   => Total parameter prop_binch3_ele_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1830.275970     111.016728      total sum
# 5          272.000000      16.492423       Unweighted events, alpha=6.728956
#   => Total parameter prop_binch3_ele_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          2348.273895     130.182564      total sum
# 6          325.000000      18.027756       Unweighted events, alpha=7.225458
#   => Total parameter prop_binch3_ele_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          4483.057510     186.422753      total sum
# 7          578.000000      24.041631       Unweighted events, alpha=7.756155
#   => Total parameter prop_binch3_ele_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          7369.769836     253.311104      total sum
# 8          846.000000      29.086079       Unweighted events, alpha=8.711312
#   => Total parameter prop_binch3_ele_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          7028.300613     236.746485      total sum
# 9          881.000000      29.681644       Unweighted events, alpha=7.977640
#   => Total parameter prop_binch3_ele_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         4620.812866     193.841776      total sum
# 10         568.000000      23.832751       Unweighted events, alpha=8.135234
#   => Total parameter prop_binch3_ele_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         1648.217125     111.597099      total sum
# 11         218.000000      14.764823       Unweighted events, alpha=7.560629
#   => Total parameter prop_binch3_ele_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1077.592194     86.627999       total sum
# 12         155.000000      12.449900       Unweighted events, alpha=6.952208
#   => Total parameter prop_binch3_ele_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         604.121216      60.184060       total sum
# 13         101.000000      10.049876       Unweighted events, alpha=5.981398
#   => Total parameter prop_binch3_ele_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1917.605896     110.712355      total sum
# 14         300.000000      17.320508       Unweighted events, alpha=6.392020
#   => Total parameter prop_binch3_ele_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         1622.210205     166.333411      total sum
# 15         95.000000       9.746794        Unweighted events, alpha=17.075897
#   => Total parameter prop_binch3_ele_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         1119.516052     137.912205      total sum
# 16         66.000000       8.124038        Unweighted events, alpha=16.962364
#   => Total parameter prop_binch3_ele_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         916.486328      103.237238      total sum
# 17         79.000000       8.888194        Unweighted events, alpha=11.601093
#   => Total parameter prop_binch3_ele_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         670.268204      52.336937       total sum
# 18         164.000000      12.806248       Unweighted events, alpha=4.087001
#   => Total parameter prop_binch3_ele_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         618.543617      52.129321       total sum
# 19         141.000000      11.874342       Unweighted events, alpha=4.386834
#   => Total parameter prop_binch3_ele_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .   done.
# Importing combined pdf model_s
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-cHIiu9.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
# Redefining the POIs to be: RooArgSet:: = (r,MisIDEleSeventeenSF,MisIDEleEighteenSF,ZGammaBkgPhotonSF,WGammaBkgPhotonSF)
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8461250
#   Clients:
#     (0x85dfbb0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8462820,V-) RooRealSumPdf::pdf_binch1_mu_nuis ""
#     (0x880a6b0,V-) RooProdPdf::pdfbins_binch1_mu ""
#     (0x81cc370,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x8430c90,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x8434520,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x845c000,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x845f450,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x84a4a60,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)        BTagSF_b_Pdf
#       2)        BTagSF_l_Pdf
#       3)           MuEff_Pdf
#       4)              PU_Pdf
#       5)          PhoEff_Pdf
#       6)            lumi_Pdf
#       7)  pdf_binch1_mu_nuis
#       8)   pdfbins_binch1_mu
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch1_mu"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch1_mu (ch1_mu)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch1_mu_CMS_th1x, pdf pdf_binch1_mu = 18139.4
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x84a6020
#   Clients:
#     (0x85dfbb0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x846f970,V-) RooRealSumPdf::pdf_binch1_ele_nuis ""
#     (0x84a6fe0,V-) RooProdPdf::pdfbins_binch1_ele ""
#     (0x81cc370,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x8430c90,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x8434520,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x845c000,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x845f450,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x84a4a60,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         BTagSF_b_Pdf
#       2)         BTagSF_l_Pdf
#       3)            MuEff_Pdf
#       4)               PU_Pdf
#       5)           PhoEff_Pdf
#       6)             lumi_Pdf
#       7)  pdf_binch1_ele_nuis
#       8)   pdfbins_binch1_ele
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch1_ele"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch1_ele (ch1_ele)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch1_ele_CMS_th1x, pdf pdf_binch1_ele = 17716.9
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x85f0ff0
#   Clients:
#     (0x85dfbb0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x85f1f60,V-) RooRealSumPdf::pdf_binch2_mu_nuis ""
#     (0x87c0ee0,V-) RooProdPdf::pdfbins_binch2_mu ""
#     (0x81cc370,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x8430c90,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x8434520,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x845c000,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x845f450,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x84a4a60,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)        BTagSF_b_Pdf
#       2)        BTagSF_l_Pdf
#       3)           MuEff_Pdf
#       4)              PU_Pdf
#       5)          PhoEff_Pdf
#       6)            lumi_Pdf
#       7)  pdf_binch2_mu_nuis
#       8)   pdfbins_binch2_mu
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch2_mu"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch2_mu (ch2_mu)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch2_mu_CMS_th1x, pdf pdf_binch2_mu = 24436.7
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x87b0d30
#   Clients:
#     (0x85dfbb0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x87b1c80,V-) RooRealSumPdf::pdf_binch2_ele_nuis ""
#     (0x868e920,V-) RooProdPdf::pdfbins_binch2_ele ""
#     (0x81cc370,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x8430c90,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x8434520,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x845c000,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x845f450,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x84a4a60,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         BTagSF_b_Pdf
#       2)         BTagSF_l_Pdf
#       3)            MuEff_Pdf
#       4)               PU_Pdf
#       5)           PhoEff_Pdf
#       6)             lumi_Pdf
#       7)  pdf_binch2_ele_nuis
#       8)   pdfbins_binch2_ele
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch2_ele"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch2_ele (ch2_ele)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch2_ele_CMS_th1x, pdf pdf_binch2_ele = 31690.1
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x87463b0
#   Clients:
#     (0x85dfbb0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8747300,V-) RooRealSumPdf::pdf_binch3_mu_nuis ""
#     (0x8729b50,V-) RooProdPdf::pdfbins_binch3_mu ""
#     (0x81cc370,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x8430c90,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x8434520,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x845c000,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x845f450,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x84a4a60,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)        BTagSF_b_Pdf
#       2)        BTagSF_l_Pdf
#       3)           MuEff_Pdf
#       4)              PU_Pdf
#       5)          PhoEff_Pdf
#       6)            lumi_Pdf
#       7)  pdf_binch3_mu_nuis
#       8)   pdfbins_binch3_mu
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch3_mu"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch3_mu (ch3_mu)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch3_mu_CMS_th1x, pdf pdf_binch3_mu = 31373.8
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8719710
#   Clients:
#     (0x85dfbb0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x871a660,V-) RooRealSumPdf::pdf_binch3_ele_nuis ""
#     (0x86e8f30,V-) RooProdPdf::pdfbins_binch3_ele ""
#     (0x81cc370,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x8430c90,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x8434520,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x845c000,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x845f450,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x84a4a60,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         BTagSF_b_Pdf
#       2)         BTagSF_l_Pdf
#       3)            MuEff_Pdf
#       4)               PU_Pdf
#       5)           PhoEff_Pdf
#       6)             lumi_Pdf
#       7)  pdf_binch3_ele_nuis
#       8)   pdfbins_binch3_ele
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch3_ele"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch3_ele (ch3_ele)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch3_ele_CMS_th1x, pdf pdf_binch3_ele = 51061.4
# Error in <TList::Clear>: A list is accessing an object (0x883daa4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x883dd4c) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x883dff4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x883e29c) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x883e544) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x883e7ec) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./ch1_mu_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./ch1_ele_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./ch2_mu_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./ch2_ele_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./ch3_mu_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./ch3_ele_CMS_th1x_prefit.png has been created
#
#   RooFitResult: minimized FCN value: -4181.37, estimated distance to minimum: 1.13099e-05
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#            BTagSF_b_In    0.0000e+00
#            BTagSF_l_In    0.0000e+00
#               MuEff_In    0.0000e+00
#                    ONE    1.0000e+00
#                  PU_In    0.0000e+00
#              PhoEff_In    0.0000e+00
#                lumi_In    0.0000e+00
#   prop_binch1_ele_bin0_In    0.0000e+00
#   prop_binch1_ele_bin10_In    0.0000e+00
#   prop_binch1_ele_bin11_In    0.0000e+00
#   prop_binch1_ele_bin12_In    0.0000e+00
#   prop_binch1_ele_bin13_In    0.0000e+00
#   prop_binch1_ele_bin14_In    0.0000e+00
#   prop_binch1_ele_bin15_In    0.0000e+00
#   prop_binch1_ele_bin16_In    0.0000e+00
#   prop_binch1_ele_bin17_In    0.0000e+00
#   prop_binch1_ele_bin18_In    0.0000e+00
#   prop_binch1_ele_bin19_In    0.0000e+00
#   prop_binch1_ele_bin1_In    0.0000e+00
#   prop_binch1_ele_bin2_In    0.0000e+00
#   prop_binch1_ele_bin3_In    0.0000e+00
#   prop_binch1_ele_bin4_In    0.0000e+00
#   prop_binch1_ele_bin5_In    0.0000e+00
#   prop_binch1_ele_bin6_In    0.0000e+00
#   prop_binch1_ele_bin7_In    0.0000e+00
#   prop_binch1_ele_bin8_In    0.0000e+00
#   prop_binch1_ele_bin9_In    0.0000e+00
#   prop_binch1_mu_bin0_In    0.0000e+00
#   prop_binch1_mu_bin10_In    0.0000e+00
#   prop_binch1_mu_bin11_In    0.0000e+00
#   prop_binch1_mu_bin1_In    0.0000e+00
#   prop_binch1_mu_bin2_In    0.0000e+00
#   prop_binch1_mu_bin3_In    0.0000e+00
#   prop_binch1_mu_bin4_In    0.0000e+00
#   prop_binch1_mu_bin5_In    0.0000e+00
#   prop_binch1_mu_bin6_In    0.0000e+00
#   prop_binch1_mu_bin7_In    0.0000e+00
#   prop_binch1_mu_bin8_In    0.0000e+00
#   prop_binch1_mu_bin9_In    0.0000e+00
#   prop_binch2_ele_bin0_In    0.0000e+00
#   prop_binch2_ele_bin10_In    0.0000e+00
#   prop_binch2_ele_bin11_In    0.0000e+00
#   prop_binch2_ele_bin12_In    0.0000e+00
#   prop_binch2_ele_bin13_In    0.0000e+00
#   prop_binch2_ele_bin14_In    0.0000e+00
#   prop_binch2_ele_bin15_In    0.0000e+00
#   prop_binch2_ele_bin16_In    0.0000e+00
#   prop_binch2_ele_bin17_In    0.0000e+00
#   prop_binch2_ele_bin18_In    0.0000e+00
#   prop_binch2_ele_bin19_In    0.0000e+00
#   prop_binch2_ele_bin1_In    0.0000e+00
#   prop_binch2_ele_bin2_In    0.0000e+00
#   prop_binch2_ele_bin3_In    0.0000e+00
#   prop_binch2_ele_bin4_In    0.0000e+00
#   prop_binch2_ele_bin5_In    0.0000e+00
#   prop_binch2_ele_bin6_In    0.0000e+00
#   prop_binch2_ele_bin7_In    0.0000e+00
#   prop_binch2_ele_bin8_In    0.0000e+00
#   prop_binch2_ele_bin9_In    0.0000e+00
#   prop_binch2_mu_bin0_In    0.0000e+00
#   prop_binch2_mu_bin10_In    0.0000e+00
#   prop_binch2_mu_bin11_In    0.0000e+00
#   prop_binch2_mu_bin1_In    0.0000e+00
#   prop_binch2_mu_bin2_In    0.0000e+00
#   prop_binch2_mu_bin3_In    0.0000e+00
#   prop_binch2_mu_bin4_In    0.0000e+00
#   prop_binch2_mu_bin5_In    0.0000e+00
#   prop_binch2_mu_bin6_In    0.0000e+00
#   prop_binch2_mu_bin7_In    0.0000e+00
#   prop_binch2_mu_bin8_In    0.0000e+00
#   prop_binch2_mu_bin9_In    0.0000e+00
#   prop_binch3_ele_bin0_In    0.0000e+00
#   prop_binch3_ele_bin10_In    0.0000e+00
#   prop_binch3_ele_bin11_In    0.0000e+00
#   prop_binch3_ele_bin12_In    0.0000e+00
#   prop_binch3_ele_bin13_In    0.0000e+00
#   prop_binch3_ele_bin14_In    0.0000e+00
#   prop_binch3_ele_bin15_In    0.0000e+00
#   prop_binch3_ele_bin16_In    0.0000e+00
#   prop_binch3_ele_bin17_In    0.0000e+00
#   prop_binch3_ele_bin18_In    0.0000e+00
#   prop_binch3_ele_bin19_In    0.0000e+00
#   prop_binch3_ele_bin1_In    0.0000e+00
#   prop_binch3_ele_bin2_In    0.0000e+00
#   prop_binch3_ele_bin3_In    0.0000e+00
#   prop_binch3_ele_bin4_In    0.0000e+00
#   prop_binch3_ele_bin5_In    0.0000e+00
#   prop_binch3_ele_bin6_In    0.0000e+00
#   prop_binch3_ele_bin7_In    0.0000e+00
#   prop_binch3_ele_bin8_In    0.0000e+00
#   prop_binch3_ele_bin9_In    0.0000e+00
#   prop_binch3_mu_bin0_In    0.0000e+00
#   prop_binch3_mu_bin10_In    0.0000e+00
#   prop_binch3_mu_bin11_In    0.0000e+00
#   prop_binch3_mu_bin1_In    0.0000e+00
#   prop_binch3_mu_bin2_In    0.0000e+00
#   prop_binch3_mu_bin3_In    0.0000e+00
#   prop_binch3_mu_bin4_In    0.0000e+00
#   prop_binch3_mu_bin5_In    0.0000e+00
#   prop_binch3_mu_bin6_In    0.0000e+00
#   prop_binch3_mu_bin7_In    0.0000e+00
#   prop_binch3_mu_bin8_In    0.0000e+00
#   prop_binch3_mu_bin9_In    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#               BTagSF_b    0.0000e+00    1.6575e-03 +/-  9.93e-01  <none>
#               BTagSF_l    0.0000e+00    3.0863e-01 +/-  9.90e-01  <none>
#     MisIDEleEighteenSF    2.0000e+00    7.9373e-01 +/-  2.83e-02  <none>
#    MisIDEleSeventeenSF    2.0000e+00    1.1084e+00 +/-  4.39e-02  <none>
#                  MuEff    0.0000e+00   -5.0279e-01 +/-  9.44e-01  <none>
#                     PU    0.0000e+00    1.3035e+00 +/-  5.51e-01  <none>
#                 PhoEff    0.0000e+00    2.1088e+00 +/-  6.15e-01  <none>
#      WGammaBkgPhotonSF    1.0000e+00    1.1617e+00 +/-  8.83e-02  <none>
#      ZGammaBkgPhotonSF    1.0000e+00    8.3425e-01 +/-  6.53e-02  <none>
#                   lumi    0.0000e+00    1.1820e+00 +/-  9.82e-01  <none>
#   prop_binch1_ele_bin0    0.0000e+00   -1.0797e+00 +/-  1.94e-01  <none>
#   prop_binch1_ele_bin1    0.0000e+00   -2.1665e-01 +/-  5.83e-01  <none>
#   prop_binch1_ele_bin10    0.0000e+00   -1.1949e+00 +/-  5.56e-01  <none>
#   prop_binch1_ele_bin11    0.0000e+00    3.2487e-01 +/-  5.10e-01  <none>
#   prop_binch1_ele_bin12    0.0000e+00    4.4440e-01 +/-  4.51e-01  <none>
#   prop_binch1_ele_bin13    0.0000e+00    1.0446e+00 +/-  5.20e-01  <none>
#   prop_binch1_ele_bin14    0.0000e+00   -9.6164e-01 +/-  2.95e-01  <none>
#   prop_binch1_ele_bin15    0.0000e+00   -2.2562e-01 +/-  4.66e-01  <none>
#   prop_binch1_ele_bin16    0.0000e+00    5.7567e-02 +/-  3.28e-01  <none>
#   prop_binch1_ele_bin17    0.0000e+00   -2.8269e-01 +/-  3.14e-01  <none>
#   prop_binch1_ele_bin18    0.0000e+00    1.6250e+00 +/-  5.50e-01  <none>
#   prop_binch1_ele_bin19    0.0000e+00   -6.0248e-02 +/-  2.56e-01  <none>
#   prop_binch1_ele_bin2    0.0000e+00   -6.8506e-01 +/-  4.08e-01  <none>
#   prop_binch1_ele_bin3    0.0000e+00   -2.0499e+00 +/-  3.45e-01  <none>
#   prop_binch1_ele_bin4    0.0000e+00   -7.6295e-01 +/-  4.21e-01  <none>
#   prop_binch1_ele_bin5    0.0000e+00   -7.7563e-01 +/-  3.11e-01  <none>
#   prop_binch1_ele_bin6    0.0000e+00   -1.4799e+00 +/-  4.69e-01  <none>
#   prop_binch1_ele_bin7    0.0000e+00   -4.6617e-03 +/-  5.35e-01  <none>
#   prop_binch1_ele_bin8    0.0000e+00    6.1443e-01 +/-  6.63e-01  <none>
#   prop_binch1_ele_bin9    0.0000e+00    9.0896e-01 +/-  6.69e-01  <none>
#    prop_binch1_mu_bin0    0.0000e+00   -1.1762e+00 +/-  5.06e-01  <none>
#    prop_binch1_mu_bin1    0.0000e+00   -1.0354e+00 +/-  4.29e-01  <none>
#   prop_binch1_mu_bin10    0.0000e+00   -1.0649e-01 +/-  5.37e-01  <none>
# ...
#   prop_binch2_ele_bin16    0.0000e+00    1.2661e+00         +/-  3.73e-01  <none>
#   prop_binch2_ele_bin17    0.0000e+00    3.1162e-01         +/-  2.94e-01  <none>
#   prop_binch2_ele_bin18    0.0000e+00    1.4954e+00         +/-  4.75e-01  <none>
#   prop_binch2_ele_bin19    0.0000e+00    6.4226e-01         +/-  3.94e-01  <none>
#   prop_binch2_ele_bin2    0.0000e+00    2.2355e-01         +/-  5.82e-01  <none>
#   prop_binch2_ele_bin3    0.0000e+00   -7.8259e-01         +/-  5.04e-01  <none>
#   prop_binch2_ele_bin4    0.0000e+00    3.3789e-01         +/-  3.98e-01  <none>
#   prop_binch2_ele_bin5    0.0000e+00    1.1060e+00         +/-  3.56e-01  <none>
#   prop_binch2_ele_bin6    0.0000e+00   -1.0345e+00         +/-  1.22e-01  <none>
#   prop_binch2_ele_bin7    0.0000e+00   -3.6136e-01         +/-  4.64e-01  <none>
#   prop_binch2_ele_bin8    0.0000e+00   -3.4031e-01         +/-  5.74e-01  <none>
#   prop_binch2_ele_bin9    0.0000e+00   -4.6565e-01         +/-  5.84e-01  <none>
#    prop_binch2_mu_bin0    0.0000e+00    2.3036e-01         +/-  4.57e-01  <none>
#    prop_binch2_mu_bin1    0.0000e+00   -1.3511e+00         +/-  3.01e-01  <none>
#   prop_binch2_mu_bin10    0.0000e+00   -6.5464e-01         +/-  3.02e-01  <none>
#   prop_binch2_mu_bin11    0.0000e+00    3.8051e-01         +/-  4.21e-01  <none>
#    prop_binch2_mu_bin2    0.0000e+00   -7.7039e-01         +/-  1.05e-01  <none>
#    prop_binch2_mu_bin3    0.0000e+00    1.1977e+00         +/-  5.75e-01  <none>
#    prop_binch2_mu_bin4    0.0000e+00    1.0996e+00         +/-  4.76e-01  <none>
#    prop_binch2_mu_bin5    0.0000e+00   -1.0409e+00         +/-  6.13e-02  <none>
#    prop_binch2_mu_bin6    0.0000e+00   -3.2459e-01         +/-  1.74e-01  <none>
#    prop_binch2_mu_bin7    0.0000e+00   -8.0699e-01         +/-  2.36e-01  <none>
#    prop_binch2_mu_bin8    0.0000e+00    1.6814e-01         +/-  4.09e-01  <none>
#    prop_binch2_mu_bin9    0.0000e+00    7.8480e-01         +/-  5.14e-01  <none>
#   prop_binch3_ele_bin0    0.0000e+00   -9.7563e-02         +/-  4.49e-01  <none>
#   prop_binch3_ele_bin1    0.0000e+00    2.2399e-02         +/-  3.95e-01  <none>
#   prop_binch3_ele_bin10    0.0000e+00   -2.0525e+00         +/-  5.06e-01  <none>
#   prop_binch3_ele_bin11    0.0000e+00    1.6845e+00         +/-  4.38e-01  <none>
#   prop_binch3_ele_bin12    0.0000e+00    2.9247e-01         +/-  4.10e-01  <none>
#   prop_binch3_ele_bin13    0.0000e+00    1.4223e+00         +/-  4.19e-01  <none>
#   prop_binch3_ele_bin14    0.0000e+00    2.3890e+00         +/-  4.30e-01  <none>
#   prop_binch3_ele_bin15    0.0000e+00   -7.6257e-01         +/-  2.20e-01  <none>
#   prop_binch3_ele_bin16    0.0000e+00   -5.3448e-03         +/-  2.33e-01  <none>
#   prop_binch3_ele_bin17    0.0000e+00   -5.3668e-01         +/-  4.84e-01  <none>
#   prop_binch3_ele_bin18    0.0000e+00    2.3677e+00         +/-  4.52e-01  <none>
#   prop_binch3_ele_bin19    0.0000e+00    6.2230e-01         +/-  4.25e-01  <none>
#   prop_binch3_ele_bin2    0.0000e+00    1.5299e+00         +/-  4.50e-01  <none>
#   prop_binch3_ele_bin3    0.0000e+00    1.0182e+00         +/-  4.84e-01  <none>
#   prop_binch3_ele_bin4    0.0000e+00   -1.3537e+00         +/-  2.89e-01  <none>
#   prop_binch3_ele_bin5    0.0000e+00   -1.7027e+00         +/-  4.07e-01  <none>
#   prop_binch3_ele_bin6    0.0000e+00    1.4155e+00         +/-  4.59e-01  <none>
#   prop_binch3_ele_bin7    0.0000e+00   -2.3223e-01         +/-  5.11e-01  <none>
#   prop_binch3_ele_bin8    0.0000e+00   -1.6389e+00         +/-  5.57e-01  <none>
#   prop_binch3_ele_bin9    0.0000e+00    9.2517e-01         +/-  6.28e-01  <none>
#    prop_binch3_mu_bin0    0.0000e+00    2.2994e-02         +/-  4.55e-01  <none>
#    prop_binch3_mu_bin1    0.0000e+00   -7.0188e-01         +/-  4.62e-01  <none>
#   prop_binch3_mu_bin10    0.0000e+00   -1.1133e-02         +/-  4.50e-01  <none>
#   prop_binch3_mu_bin11    0.0000e+00   -5.1470e-01         +/-  4.46e-01  <none>
#    prop_binch3_mu_bin2    0.0000e+00   -1.0447e+00         +/-  1.10e-01  <none>
#    prop_binch3_mu_bin3    0.0000e+00   -1.1432e+00         +/-  7.35e-02  <none>
#    prop_binch3_mu_bin4    0.0000e+00    3.5579e-01         +/-  5.62e-01  <none>
#    prop_binch3_mu_bin5    0.0000e+00   -9.4774e-01         +/-  2.28e-01  <none>
#    prop_binch3_mu_bin6    0.0000e+00   -4.0379e-01         +/-  4.30e-01  <none>
#    prop_binch3_mu_bin7    0.0000e+00   -9.6618e-01         +/-  1.93e-01  <none>
#    prop_binch3_mu_bin8    0.0000e+00   -1.3730e+00         +/-  4.22e-01  <none>
#    prop_binch3_mu_bin9    0.0000e+00   -6.1428e-02         +/-  3.86e-01  <none>
#                      r    1.0000e+00    1.7407e+00 (+1.14e-01,-1.07e-01)  <none>
#
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8461250
#   Clients:
#     (0x85dfbb0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8462820,V-) RooRealSumPdf::pdf_binch1_mu_nuis ""
#     (0x880a6b0,V-) RooProdPdf::pdfbins_binch1_mu ""
#     (0x81cc370,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x8430c90,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x8434520,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x845c000,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x845f450,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x84a4a60,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)        BTagSF_b_Pdf
#       2)        BTagSF_l_Pdf
#       3)           MuEff_Pdf
#       4)              PU_Pdf
#       5)          PhoEff_Pdf
#       6)            lumi_Pdf
#       7)  pdf_binch1_mu_nuis
#       8)   pdfbins_binch1_mu
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch1_mu"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch1_mu (ch1_mu)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch1_mu_CMS_th1x, pdf pdf_binch1_mu = 19850.8
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x84a6020
#   Clients:
#     (0x85dfbb0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x846f970,V-) RooRealSumPdf::pdf_binch1_ele_nuis ""
#     (0x84a6fe0,V-) RooProdPdf::pdfbins_binch1_ele ""
#     (0x81cc370,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x8430c90,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x8434520,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x845c000,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x845f450,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x84a4a60,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         BTagSF_b_Pdf
#       2)         BTagSF_l_Pdf
#       3)            MuEff_Pdf
#       4)               PU_Pdf
#       5)           PhoEff_Pdf
#       6)             lumi_Pdf
#       7)  pdf_binch1_ele_nuis
#       8)   pdfbins_binch1_ele
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch1_ele"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch1_ele (ch1_ele)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch1_ele_CMS_th1x, pdf pdf_binch1_ele = 24059.6
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x85f0ff0
#   Clients:
#     (0x85dfbb0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x85f1f60,V-) RooRealSumPdf::pdf_binch2_mu_nuis ""
#     (0x87c0ee0,V-) RooProdPdf::pdfbins_binch2_mu ""
#     (0x81cc370,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x8430c90,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x8434520,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x845c000,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x845f450,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x84a4a60,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)        BTagSF_b_Pdf
#       2)        BTagSF_l_Pdf
#       3)           MuEff_Pdf
#       4)              PU_Pdf
#       5)          PhoEff_Pdf
#       6)            lumi_Pdf
#       7)  pdf_binch2_mu_nuis
#       8)   pdfbins_binch2_mu
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch2_mu"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch2_mu (ch2_mu)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch2_mu_CMS_th1x, pdf pdf_binch2_mu = 25909.3
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x87b0d30
#   Clients:
#     (0x85dfbb0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x87b1c80,V-) RooRealSumPdf::pdf_binch2_ele_nuis ""
#     (0x868e920,V-) RooProdPdf::pdfbins_binch2_ele ""
#     (0x81cc370,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x8430c90,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x8434520,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x845c000,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x845f450,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x84a4a60,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         BTagSF_b_Pdf
#       2)         BTagSF_l_Pdf
#       3)            MuEff_Pdf
#       4)               PU_Pdf
#       5)           PhoEff_Pdf
#       6)             lumi_Pdf
#       7)  pdf_binch2_ele_nuis
#       8)   pdfbins_binch2_ele
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch2_ele"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch2_ele (ch2_ele)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch2_ele_CMS_th1x, pdf pdf_binch2_ele = 37376.8
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x87463b0
#   Clients:
#     (0x85dfbb0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8747300,V-) RooRealSumPdf::pdf_binch3_mu_nuis ""
#     (0x8729b50,V-) RooProdPdf::pdfbins_binch3_mu ""
#     (0x81cc370,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x8430c90,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x8434520,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x845c000,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x845f450,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x84a4a60,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)        BTagSF_b_Pdf
#       2)        BTagSF_l_Pdf
#       3)           MuEff_Pdf
#       4)              PU_Pdf
#       5)          PhoEff_Pdf
#       6)            lumi_Pdf
#       7)  pdf_binch3_mu_nuis
#       8)   pdfbins_binch3_mu
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch3_mu"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch3_mu (ch3_mu)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch3_mu_CMS_th1x, pdf pdf_binch3_mu = 30135
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8719710
#   Clients:
#     (0x85dfbb0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x871a660,V-) RooRealSumPdf::pdf_binch3_ele_nuis ""
#     (0x86e8f30,V-) RooProdPdf::pdfbins_binch3_ele ""
#     (0x81cc370,V-) SimpleGaussianConstraint::BTagSF_b_Pdf "BTagSF_b_Pdf"
#     (0x8430c90,V-) SimpleGaussianConstraint::BTagSF_l_Pdf "BTagSF_l_Pdf"
#     (0x8434520,V-) SimpleGaussianConstraint::MuEff_Pdf "MuEff_Pdf"
#     (0x845c000,V-) SimpleGaussianConstraint::PU_Pdf "PU_Pdf"
#     (0x845f450,V-) SimpleGaussianConstraint::PhoEff_Pdf "PhoEff_Pdf"
#     (0x84a4a60,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         BTagSF_b_Pdf
#       2)         BTagSF_l_Pdf
#       3)            MuEff_Pdf
#       4)               PU_Pdf
#       5)           PhoEff_Pdf
#       6)             lumi_Pdf
#       7)  pdf_binch3_ele_nuis
#       8)   pdfbins_binch3_ele
# --- RooAbsReal ---
#
#   Plot label is "pdf_binch3_ele"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore ch3_ele (ch3_ele)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in ch3_ele_CMS_th1x, pdf pdf_binch3_ele = 47656.8
# Error in <TList::Clear>: A list is accessing an object (0x883fa84) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x883fd2c) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x883ffd4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x884027c) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8840524) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x88407cc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./ch1_mu_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./ch1_ele_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./ch2_mu_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./ch2_ele_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./ch3_mu_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./ch3_ele_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.74073  -0.107035/+0.113927  (68% CL)
# Done in 0.10 min (cpu), 0.11 min (real)
# Printing Message Summary From ... combine_logger.out
# ----------------------------------------------
# Messages of type INFO : 9
# Messages of type DEBUG : 2
# Messages of type ERROR : 0
# ----------------------------------------------
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=-1
# DEBUG: (function: improveOnce) CascadeMinimizer.cc: 196 -- Minimization ended with latest status != 0 or 1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: doFit) FitterAlgoBase.cc: 318 -- Running Minos for POI r
# DEBUG: (function: runSpecific) FitDiagnostics.cc: 412 -- Fit S+B, status = 0, numBadNLL = 0, covariance quality = 3

# %%
# !combine -M FitDiagnostics -n CR2 datacard_CR2_allyear.txt --redefineSignalPOIs r,MisIDEleSeventeenSF,MisIDEleEighteenSF,ZGammaBkgPhotonSF,WGammaBkgPhotonSF -v2 --saveWithUncertainties --plots &
# Out:
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456

# %%
# !combine -M FitDiagnostics -n CR3 datacard_CR3_allyear.txt --redefineSignalPOIs r,MisIDEleSeventeenSF,MisIDEleEighteenSF,ZGammaBkgPhotonSF,WGammaBkgPhotonSF -v2 --saveWithUncertainties --plots &

# %%
# !combine -M FitDiagnostics -n CR4 datacard_CR4_allyear.txt --redefineSignalPOIs r,MisIDEleSeventeenSF,MisIDEleEighteenSF,ZGammaBkgPhotonSF,WGammaBkgPhotonSF -v2 --saveWithUncertainties --plots &
