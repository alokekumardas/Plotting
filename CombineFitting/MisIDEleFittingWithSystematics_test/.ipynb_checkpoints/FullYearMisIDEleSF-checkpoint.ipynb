# %%
import ROOT
# !pwd
# !ls -lrth *.root
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/TTGammaSemiLep_13TeV/Plotting/CombineFitting/MisIDEleFittingWithSystematics_test
# -rw-r--r-- 1 npoudyal us_cms  20K Nov 17 12:29 datacard16test.root
# -rw-r--r-- 1 npoudyal us_cms 185K Nov 17 12:43 fitDiagnosticssix.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 12:43 higgsCombinesix.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin2.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin3.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin4.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin5.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin6.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin7.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin8.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin9.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:19 higgsCombine_paramFit_Test_prop_binch3_mu_bin0.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:20 higgsCombine_paramFit_Test_prop_binch3_mu_bin1.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:20 higgsCombine_paramFit_Test_prop_binch3_mu_bin10.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:20 higgsCombine_paramFit_Test_prop_binch3_mu_bin11.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:20 higgsCombine_paramFit_Test_prop_binch3_mu_bin2.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:20 higgsCombine_paramFit_Test_prop_binch3_mu_bin3.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 13:20 higgsCombine_paramFit_Test_prop_binch3_mu_bin4.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:20 higgsCombine_paramFit_Test_prop_binch3_mu_bin5.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:20 higgsCombine_paramFit_Test_prop_binch3_mu_bin6.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:20 higgsCombine_paramFit_Test_prop_binch3_mu_bin7.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:21 higgsCombine_paramFit_Test_prop_binch3_mu_bin8.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 13:21 higgsCombine_paramFit_Test_prop_binch3_mu_bin9.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 539K Nov 17 13:40 fitDiagnosticsallyear.root
# -rw-r--r-- 1 npoudyal us_cms 6.2K Nov 17 13:40 higgsCombineallyear.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 348K Nov 17 14:00 fitDiagnosticsallyear_test.root
# -rw-r--r-- 1 npoudyal us_cms 6.3K Nov 17 14:00 higgsCombineallyear_test.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:12 higgsCombine_paramFit_Test_prop_binch1_ele_bin11.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:12 higgsCombine_paramFit_Test_prop_binch1_ele_bin12.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:12 higgsCombine_paramFit_Test_prop_binch1_ele_bin13.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:12 higgsCombine_paramFit_Test_prop_binch1_ele_bin14.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:12 higgsCombine_paramFit_Test_prop_binch1_ele_bin15.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:12 higgsCombine_paramFit_Test_prop_binch1_ele_bin16.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:12 higgsCombine_paramFit_Test_prop_binch1_ele_bin17.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:13 higgsCombine_paramFit_Test_prop_binch1_ele_bin18.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:13 higgsCombine_paramFit_Test_prop_binch1_ele_bin19.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:13 higgsCombine_paramFit_Test_prop_binch1_ele_bin2.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:13 higgsCombine_paramFit_Test_prop_binch1_ele_bin3.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:13 higgsCombine_paramFit_Test_prop_binch1_ele_bin4.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:13 higgsCombine_paramFit_Test_prop_binch1_ele_bin5.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:13 higgsCombine_paramFit_Test_prop_binch1_ele_bin6.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:13 higgsCombine_paramFit_Test_prop_binch1_ele_bin7.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:13 higgsCombine_paramFit_Test_prop_binch1_ele_bin8.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:14 higgsCombine_paramFit_Test_prop_binch1_ele_bin9.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:14 higgsCombine_paramFit_Test_prop_binch1_mu_bin0.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:14 higgsCombine_paramFit_Test_prop_binch1_mu_bin1.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:14 higgsCombine_paramFit_Test_prop_binch1_mu_bin10.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:14 higgsCombine_paramFit_Test_prop_binch1_mu_bin11.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:14 higgsCombine_paramFit_Test_prop_binch1_mu_bin2.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:14 higgsCombine_paramFit_Test_prop_binch1_mu_bin3.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:14 higgsCombine_paramFit_Test_prop_binch1_mu_bin4.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:14 higgsCombine_paramFit_Test_prop_binch1_mu_bin5.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:15 higgsCombine_paramFit_Test_prop_binch1_mu_bin6.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:15 higgsCombine_paramFit_Test_prop_binch1_mu_bin7.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:15 higgsCombine_paramFit_Test_prop_binch1_mu_bin8.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 14:15 higgsCombine_paramFit_Test_prop_binch1_mu_bin9.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:15 higgsCombine_paramFit_Test_prop_binch2_ele_bin0.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:15 higgsCombine_paramFit_Test_prop_binch2_ele_bin1.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:15 higgsCombine_paramFit_Test_prop_binch2_ele_bin10.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:15 higgsCombine_paramFit_Test_prop_binch2_ele_bin11.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:16 higgsCombine_paramFit_Test_prop_binch2_ele_bin12.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:16 higgsCombine_paramFit_Test_prop_binch2_ele_bin13.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:16 higgsCombine_paramFit_Test_prop_binch2_ele_bin14.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:16 higgsCombine_paramFit_Test_prop_binch2_ele_bin15.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:16 higgsCombine_paramFit_Test_prop_binch2_ele_bin16.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:16 higgsCombine_paramFit_Test_prop_binch2_ele_bin17.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:16 higgsCombine_paramFit_Test_prop_binch2_ele_bin18.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:16 higgsCombine_paramFit_Test_prop_binch2_ele_bin19.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:16 higgsCombine_paramFit_Test_prop_binch2_ele_bin2.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:17 higgsCombine_paramFit_Test_prop_binch2_ele_bin3.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:17 higgsCombine_paramFit_Test_prop_binch2_ele_bin4.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:17 higgsCombine_paramFit_Test_prop_binch2_ele_bin5.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:17 higgsCombine_paramFit_Test_prop_binch2_ele_bin6.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:17 higgsCombine_paramFit_Test_prop_binch2_ele_bin7.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:17 higgsCombine_paramFit_Test_prop_binch2_ele_bin8.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:17 higgsCombine_paramFit_Test_prop_binch2_ele_bin9.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:17 higgsCombine_paramFit_Test_prop_binch2_mu_bin0.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:17 higgsCombine_paramFit_Test_prop_binch2_mu_bin1.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:18 higgsCombine_paramFit_Test_prop_binch2_mu_bin10.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:18 higgsCombine_paramFit_Test_prop_binch2_mu_bin11.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:18 higgsCombine_paramFit_Test_prop_binch2_mu_bin2.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:18 higgsCombine_paramFit_Test_prop_binch2_mu_bin3.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:18 higgsCombine_paramFit_Test_prop_binch2_mu_bin4.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:18 higgsCombine_paramFit_Test_prop_binch2_mu_bin5.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:18 higgsCombine_paramFit_Test_prop_binch2_mu_bin6.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:18 higgsCombine_paramFit_Test_prop_binch2_mu_bin7.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:19 higgsCombine_paramFit_Test_prop_binch2_mu_bin8.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:19 higgsCombine_paramFit_Test_prop_binch2_mu_bin9.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin0.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin1.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin10.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin11.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin12.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin13.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin14.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:19 higgsCombine_paramFit_Test_prop_binch3_ele_bin15.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:20 higgsCombine_paramFit_Test_prop_binch3_ele_bin16.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:20 higgsCombine_paramFit_Test_prop_binch3_ele_bin17.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:20 higgsCombine_paramFit_Test_prop_binch3_ele_bin18.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:20 higgsCombine_paramFit_Test_prop_binch3_ele_bin19.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 641K Nov 17 14:20 fitDiagnosticsCR123.root
# -rw-r--r-- 1 npoudyal us_cms 6.2K Nov 17 14:20 higgsCombineCR123.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 641K Nov 17 14:20 fitDiagnosticsCR1.root
# -rw-r--r-- 1 npoudyal us_cms 6.2K Nov 17 14:20 higgsCombineCR1.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms  97K Nov 17 14:20 datacard_CR123_allyear.root
# -rw-r--r-- 1 npoudyal us_cms 6.4K Nov 17 14:21 higgsCombine_initialFit_Test.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 642K Nov 17 14:21 fitDiagnosticsCR2.root
# -rw-r--r-- 1 npoudyal us_cms 6.2K Nov 17 14:21 higgsCombineCR2.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 14:21 higgsCombine_paramFit_Test_BTagSF_b.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 14:21 higgsCombine_paramFit_Test_BTagSF_l.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 641K Nov 17 14:21 fitDiagnosticsCR3.root
# -rw-r--r-- 1 npoudyal us_cms 6.2K Nov 17 14:21 higgsCombineCR3.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 14:21 higgsCombine_paramFit_Test_MisIDEleEighteenSF.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 641K Nov 17 14:21 fitDiagnosticsCR4.root
# -rw-r--r-- 1 npoudyal us_cms 6.2K Nov 17 14:21 higgsCombineCR4.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 14:21 higgsCombine_paramFit_Test_MisIDEleSeventeenSF.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 14:21 higgsCombine_paramFit_Test_MuEff.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 14:22 higgsCombine_paramFit_Test_PU.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 14:22 higgsCombine_paramFit_Test_PhoEff.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 14:22 higgsCombine_paramFit_Test_WGammaBkgPhotonSF.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 14:22 higgsCombine_paramFit_Test_ZGammaBkgPhotonSF.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 14:22 higgsCombine_paramFit_Test_lumi.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:22 higgsCombine_paramFit_Test_prop_binch1_ele_bin0.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 14:22 higgsCombine_paramFit_Test_prop_binch1_ele_bin1.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms  445 Nov 17 14:22 higgsCombine_paramFit_Test_prop_binch1_ele_bin10.MultiDimFit.mH125.root

# %%
ListOfFiles = ["fitDiagnosticsCR123.root", "fitDiagnosticsCR1.root",  "fitDiagnosticsCR2.root", "fitDiagnosticsCR3.root","fitDiagnosticsCR4.root"]

# %%
controlRegionDict ={"SR8":"tight", "CR123":"looseCRge2e0", "AR":"looseCRge2ge0", "CR7":"looseCRe3ge2", "CR3":"looseCRge4e0", "CR2":"looseCRe3e0", 
				   "CR4":"looseCRe2e1", "CR1":"looseCRe2e0", "CR6":"looseCRe2e2", "CR5":"looseCRe3e1" }


CRDictMisID ={"SR8":"misIDsfSReight", "CR123":"misIDsfCRall", "CR7":"misIDsfCRseven", "CR3":"misIDsfCRthree", "CR2":"misIDsfCRtwo", 
		 "CR4":"misIDsfCRfour", "CR1":"misIDsfCRone", "CR6":"misIDsfCRsix", "CR5":"misIDsfCRfive" }

CRDictZGamma ={"SR8":"zGammasfSReight", "CR123":"zGammasfCRall", "CR7":"zGammasfCRseven", "CR3":"zGammasfCRthree", "CR2":"zGammasfCRtwo", 
		 "CR4":"zGammasfCRfour", "CR1":"zGammasfCRone", "CR6":"zGammasfCRsix", "CR5":"zGammasfCRfive" }

CRDictWGamma ={"SR8":"wGammasfSReight", "CR123":"wGammasfCRall", "CR7":"wGammasfCRseven", "CR3":"wGammasfCRthree", "CR2":"wGammasfCRtwo", 
		 "CR4":"wGammasfCRfour", "CR1":"wGammasfCRone", "CR6":"wGammasfCRsix", "CR5":"wGammasfCRfive" }

# %%
line = ""
for ifile in ListOfFiles:
    myfile = ROOT.TFile(ifile,"read")
    if myfile.GetListOfKeys().Contains("fit_s") is False:
        print ifile[14:-5], ": Fit failed."
        continue
    fit_s = myfile.Get("fit_s")
    line += "MisIDEleSF_2016_%s = %.3f \n"%(controlRegionDict[ifile[14:-5]],fit_s.floatParsFinal().find("r").getVal())
    line += "MisIDEleSF_2017_%s = %.3f \n"%(controlRegionDict[ifile[14:-5]],fit_s.floatParsFinal().find("MisIDEleSeventeenSF").getVal())
    line += "MisIDEleSF_2018_%s = %.3f \n"%(controlRegionDict[ifile[14:-5]],fit_s.floatParsFinal().find("MisIDEleEighteenSF").getVal())
    line +=   "ZGammaSF_%s = %.3f \n"%(controlRegionDict[ifile[14:-5]],fit_s.floatParsFinal().find("ZGammaBkgPhotonSF").getVal())
    line +=   "WGammaSF_%s = %.3f \n"%(controlRegionDict[ifile[14:-5]],fit_s.floatParsFinal().find("WGammaBkgPhotonSF").getVal())

with open("FullYearMisIDEleSFvalues.py","w") as _file:
    _file.write(line)

# %%
# !cat FullYearMisIDEleSFvalues.py
# copy the file to plotting folder
# !cp FullYearMisIDEleSFvalues.py /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/TTGammaSemiLep_13TeV/Plotting
# Out:
# MisIDEleSF_2016_looseCRge2e0 = 1.474
# MisIDEleSF_2017_looseCRge2e0 = 1.113
# MisIDEleSF_2018_looseCRge2e0 = 0.774
# ZGammaSF_looseCRge2e0 = 0.698
# WGammaSF_looseCRge2e0 = 0.854
# MisIDEleSF_2016_looseCRe2e0 = 1.544
# MisIDEleSF_2017_looseCRe2e0 = 1.113
# MisIDEleSF_2018_looseCRe2e0 = 0.789
# ZGammaSF_looseCRe2e0 = 0.713
# WGammaSF_looseCRe2e0 = 0.966
# MisIDEleSF_2016_looseCRe3e0 = 1.748
# MisIDEleSF_2017_looseCRe3e0 = 1.107
# MisIDEleSF_2018_looseCRe3e0 = 0.735
# ZGammaSF_looseCRe3e0 = 0.808
# WGammaSF_looseCRe3e0 = 0.945
# MisIDEleSF_2016_looseCRge4e0 = 1.986
# MisIDEleSF_2017_looseCRge4e0 = 1.312
# MisIDEleSF_2018_looseCRge4e0 = 0.887
# ZGammaSF_looseCRge4e0 = 1.166
# WGammaSF_looseCRge4e0 = 1.872
# MisIDEleSF_2016_looseCRe2e1 = 2.009
# MisIDEleSF_2017_looseCRe2e1 = 1.170
# MisIDEleSF_2018_looseCRe2e1 = 0.727
# ZGammaSF_looseCRe2e1 = 0.872
# WGammaSF_looseCRe2e1 = 1.123

# %%
line = ""
for ifile in ListOfFiles:
    myfile = ROOT.TFile(ifile,"read")
    if myfile.GetListOfKeys().Contains("fit_s") is False:
        print ifile[14:-5], ": Fit failed."
        continue
    fit_s = myfile.Get("fit_s")
    line += "\\newcommand{\\%s} {\ensuremath{%.3f \\substack{+%.3f \\\\ %.3f }}}\n"%("allyear"+CRDictMisID[ifile[14:-5]]+"Sixteen",fit_s.floatParsFinal().find("r").getVal(),fit_s.floatParsFinal().find("r").getErrorLo(),fit_s.floatParsFinal().find("r").getErrorHi())
    line += "\\newcommand{\\%s} {\ensuremath{%.3f \\substack{+%.3f \\\\ %.3f }}}\n"%("allyear"+CRDictMisID[ifile[14:-5]]+"Seventeen",fit_s.floatParsFinal().find("MisIDEleSeventeenSF").getVal(),fit_s.floatParsFinal().find("MisIDEleSeventeenSF").getErrorLo(),fit_s.floatParsFinal().find("MisIDEleSeventeenSF").getErrorHi())
    line += "\\newcommand{\\%s} {\ensuremath{%.3f \\substack{+%.3f \\\\ %.3f }}}\n"%("allyear"+CRDictMisID[ifile[14:-5]]+"Eighteen",fit_s.floatParsFinal().find("MisIDEleEighteenSF").getVal(),fit_s.floatParsFinal().find("MisIDEleEighteenSF").getErrorLo(),fit_s.floatParsFinal().find("MisIDEleEighteenSF").getErrorHi())
    line += "\\newcommand{\\%s} {\ensuremath{%.3f \\substack{+%.3f \\\\ %.3f }}}\n"%("allyear"+CRDictZGamma[ifile[14:-5]],fit_s.floatParsFinal().find("ZGammaBkgPhotonSF").getVal(),fit_s.floatParsFinal().find("r").getErrorLo(),fit_s.floatParsFinal().find("ZGammaBkgPhotonSF").getErrorHi())
    line += "\\newcommand{\\%s} {\ensuremath{%.3f \\substack{+%.3f \\\\ %.3f }}}\n"%("allyear"+CRDictWGamma[ifile[14:-5]],fit_s.floatParsFinal().find("WGammaBkgPhotonSF").getVal(),fit_s.floatParsFinal().find("r").getErrorLo(),fit_s.floatParsFinal().find("WGammaBkgPhotonSF").getErrorHi())


with open("FullYearMisIDEleSFvalues.tex","w") as _file:
    _file.write(line)

# %%
# !cat FullYearMisIDEleSFvalues.tex
## copy the file to plotting folder
# !cp FullYearMisIDEleSFvalues.tex ../AllTexFiles
# Out:
# \newcommand{\allyearmisIDsfCRallSixteen} {\ensuremath{1.474 \substack{-0.121 \\ +0.121}}}
# \newcommand{\allyearmisIDsfCRallSeventeen} {\ensuremath{1.113 \substack{-0.041 \\ +0.041}}}
# \newcommand{\allyearmisIDsfCRallEighteen} {\ensuremath{0.774 \substack{-0.028 \\ +0.028}}}
# \newcommand{\allyearzGammasfCRall} {\ensuremath{0.698 \substack{-0.121 \\ +0.077}}}
# \newcommand{\allyearwGammasfCRall} {\ensuremath{0.854 \substack{-0.121 \\ +0.114}}}
# \newcommand{\allyearmisIDsfCRoneSixteen} {\ensuremath{1.544 \substack{-0.131 \\ +0.144}}}
# \newcommand{\allyearmisIDsfCRoneSeventeen} {\ensuremath{1.113 \substack{-0.045 \\ +0.045}}}
# \newcommand{\allyearmisIDsfCRoneEighteen} {\ensuremath{0.789 \substack{-0.029 \\ +0.029}}}
# \newcommand{\allyearzGammasfCRone} {\ensuremath{0.713 \substack{-0.131 \\ +0.097}}}
# \newcommand{\allyearwGammasfCRone} {\ensuremath{0.966 \substack{-0.131 \\ +0.144}}}
# \newcommand{\allyearmisIDsfCRtwoSixteen} {\ensuremath{1.748 \substack{-0.194 \\ +0.210}}}
# \newcommand{\allyearmisIDsfCRtwoSeventeen} {\ensuremath{1.107 \substack{-0.092 \\ +0.092}}}
# \newcommand{\allyearmisIDsfCRtwoEighteen} {\ensuremath{0.735 \substack{-0.061 \\ +0.061}}}
# \newcommand{\allyearzGammasfCRtwo} {\ensuremath{0.808 \substack{-0.194 \\ +0.123}}}
# \newcommand{\allyearwGammasfCRtwo} {\ensuremath{0.945 \substack{-0.194 \\ +0.181}}}
# \newcommand{\allyearmisIDsfCRthreeSixteen} {\ensuremath{1.986 \substack{-0.266 \\ +0.310}}}
# \newcommand{\allyearmisIDsfCRthreeSeventeen} {\ensuremath{1.312 \substack{-0.209 \\ +0.209}}}
# \newcommand{\allyearmisIDsfCRthreeEighteen} {\ensuremath{0.887 \substack{-0.123 \\ +0.123}}}
# \newcommand{\allyearzGammasfCRthree} {\ensuremath{1.166 \substack{-0.266 \\ +0.346}}}
# \newcommand{\allyearwGammasfCRthree} {\ensuremath{1.872 \substack{-0.266 \\ +0.380}}}
# \newcommand{\allyearmisIDsfCRfourSixteen} {\ensuremath{2.009 \substack{-0.229 \\ +0.257}}}
# \newcommand{\allyearmisIDsfCRfourSeventeen} {\ensuremath{1.170 \substack{-0.124 \\ +0.124}}}
# \newcommand{\allyearmisIDsfCRfourEighteen} {\ensuremath{0.727 \substack{-0.062 \\ +0.062}}}
# \newcommand{\allyearzGammasfCRfour} {\ensuremath{0.872 \substack{-0.229 \\ +0.181}}}
# \newcommand{\allyearwGammasfCRfour} {\ensuremath{1.123 \substack{-0.229 \\ +0.557}}}
