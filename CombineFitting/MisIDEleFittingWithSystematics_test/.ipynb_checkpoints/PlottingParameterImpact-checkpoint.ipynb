# %%
# !text2workspace.py datacard16test.txt

# %%
# !combineTool.py -M Impacts -d datacard16test.root -m 125 --doInitialFit --robustFit 1
# Out:
# Have POIs: ['r']
# >> combine -M MultiDimFit -n _initialFit_Test --algo singles --redefineSignalPOIs r --robustFit 1 -m 125 -d datacard16test.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
# PDF didn't factorize!
# Parameters:
#   1) RooRealVar:: n_exp_binele_proc_OtherSampleBkgPhoton = 1822.29
#   2) RooRealVar::      n_exp_binele_proc_WgammaBkgPhoton = 81.1405
#   3) RooRealVar::      n_exp_binele_proc_ZgammaBkgPhoton = 48.2156
#   4) RooRealVar::  n_exp_binmu_proc_OtherSampleBkgPhoton = 2910.74
#   5) RooRealVar::       n_exp_binmu_proc_WgammaBkgPhoton = 133.2
#   6) RooRealVar::       n_exp_binmu_proc_ZgammaBkgPhoton = 52.539
#   7) RooRealVar::                                      r = 1
# Obs:
#   1) RooRealVar::    CMS_th1x = 19.5
#   2) RooCategory:: CMS_channel = mu(idx = 0)
#
# ...

# %%
# !combineTool.py -M Impacts -d datacard16test.root -m 125 --robustFit 1 --doFits
# Out:
# Have POIs: ['r']
# Have parameters: 34
# >> combine -M MultiDimFit -n _paramFit_Test_WGammaBkgPhotonSF --algo impact --redefineSignalPOIs r -P WGammaBkgPhotonSF --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_16.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
# Error: minimization failed at WGammaBkgPhotonSF = 6.25e+27
# Error: minimization failed at WGammaBkgPhotonSF = -6.25e+27
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter         :   Best-fit               r
#   WGammaBkgPhotonSF :   +1.292  +0.000/+0.000  -0.000/-0.000
# Done in 0.01 min (cpu), 0.01 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_ZGammaBkgPhotonSF --algo impact --redefineSignalPOIs r -P ZGammaBkgPhotonSF --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_16.root
# ...

# %%
# !combineTool.py -M Impacts -d datacard16test.root -m 125 -o impacts.json
# Out:
# Have POIs: ['r']
# Have parameters: 0

# %%
# !plotImpacts.py -i impacts.json -o impacts

# %%
# from IPython.display import IFrame
# IFrame("impacts.pdf", width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="impacts.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
