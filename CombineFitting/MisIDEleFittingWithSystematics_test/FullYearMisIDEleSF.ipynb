# %%
import ROOT
# !pwd
# !ls -lrth *.root
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/TTGammaSemiLep_13TeV/Plotting/CombineFitting/MisIDEleFittingWithSystematics_test
# -rw-r--r-- 1 npoudyal us_cms  20K Nov 17 12:29 datacard16test.root
# -rw-r--r-- 1 npoudyal us_cms 185K Nov 17 12:43 fitDiagnosticssix.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 12:43 higgsCombinesix.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 539K Nov 17 13:40 fitDiagnosticsallyear.root
# -rw-r--r-- 1 npoudyal us_cms 6.2K Nov 17 13:40 higgsCombineallyear.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 348K Nov 17 14:00 fitDiagnosticsallyear_test.root
# -rw-r--r-- 1 npoudyal us_cms 6.3K Nov 17 14:00 higgsCombineallyear_test.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:28 higgsCombine_paramFit_Test_prop_binch2_mu_bin6.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:28 higgsCombine_paramFit_Test_prop_binch2_mu_bin7.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:28 higgsCombine_paramFit_Test_prop_binch2_mu_bin8.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:28 higgsCombine_paramFit_Test_prop_binch2_mu_bin9.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:28 higgsCombine_paramFit_Test_prop_binch3_ele_bin0.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:28 higgsCombine_paramFit_Test_prop_binch3_ele_bin1.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:28 higgsCombine_paramFit_Test_prop_binch3_ele_bin10.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:29 higgsCombine_paramFit_Test_prop_binch3_ele_bin11.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:29 higgsCombine_paramFit_Test_prop_binch3_ele_bin12.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:29 higgsCombine_paramFit_Test_prop_binch3_ele_bin13.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:29 higgsCombine_paramFit_Test_prop_binch3_ele_bin14.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:29 higgsCombine_paramFit_Test_prop_binch3_ele_bin15.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:29 higgsCombine_paramFit_Test_prop_binch3_ele_bin16.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:29 higgsCombine_paramFit_Test_prop_binch3_ele_bin17.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:29 higgsCombine_paramFit_Test_prop_binch3_ele_bin18.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:29 higgsCombine_paramFit_Test_prop_binch3_ele_bin19.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:30 higgsCombine_paramFit_Test_prop_binch3_ele_bin2.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:30 higgsCombine_paramFit_Test_prop_binch3_ele_bin3.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:30 higgsCombine_paramFit_Test_prop_binch3_ele_bin4.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:30 higgsCombine_paramFit_Test_prop_binch3_ele_bin5.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:30 higgsCombine_paramFit_Test_prop_binch3_ele_bin6.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:30 higgsCombine_paramFit_Test_prop_binch3_ele_bin7.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:30 higgsCombine_paramFit_Test_prop_binch3_ele_bin8.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:30 higgsCombine_paramFit_Test_prop_binch3_ele_bin9.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:30 higgsCombine_paramFit_Test_prop_binch3_mu_bin0.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:31 higgsCombine_paramFit_Test_prop_binch3_mu_bin1.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:31 higgsCombine_paramFit_Test_prop_binch3_mu_bin10.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:31 higgsCombine_paramFit_Test_prop_binch3_mu_bin11.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:31 higgsCombine_paramFit_Test_prop_binch3_mu_bin2.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:31 higgsCombine_paramFit_Test_prop_binch3_mu_bin3.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:31 higgsCombine_paramFit_Test_prop_binch3_mu_bin4.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:31 higgsCombine_paramFit_Test_prop_binch3_mu_bin5.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:31 higgsCombine_paramFit_Test_prop_binch3_mu_bin6.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:31 higgsCombine_paramFit_Test_prop_binch3_mu_bin7.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:32 higgsCombine_paramFit_Test_prop_binch3_mu_bin8.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:32 higgsCombine_paramFit_Test_prop_binch3_mu_bin9.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms  95K Nov 17 16:43 datacard_CR123_allyear.root
# -rw-r--r-- 1 npoudyal us_cms 6.4K Nov 17 16:43 higgsCombine_initialFit_Test.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 16:44 higgsCombine_paramFit_Test_BTagSF_b.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 16:44 higgsCombine_paramFit_Test_BTagSF_l.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 16:44 higgsCombine_paramFit_Test_MisIDEleEighteenSF.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 16:44 higgsCombine_paramFit_Test_MisIDEleSeventeenSF.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 16:44 higgsCombine_paramFit_Test_MuEff.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 16:44 higgsCombine_paramFit_Test_PU.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 16:44 higgsCombine_paramFit_Test_PhoEff.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 16:45 higgsCombine_paramFit_Test_WGammaBkgPhotonSF.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 16:45 higgsCombine_paramFit_Test_ZGammaBkgPhotonSF.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.5K Nov 17 16:45 higgsCombine_paramFit_Test_lumi.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:45 higgsCombine_paramFit_Test_prop_binch1_ele_bin0.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:45 higgsCombine_paramFit_Test_prop_binch1_ele_bin1.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:45 higgsCombine_paramFit_Test_prop_binch1_ele_bin10.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:45 higgsCombine_paramFit_Test_prop_binch1_ele_bin11.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:45 higgsCombine_paramFit_Test_prop_binch1_ele_bin12.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:45 higgsCombine_paramFit_Test_prop_binch1_ele_bin13.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:46 higgsCombine_paramFit_Test_prop_binch1_ele_bin14.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:46 higgsCombine_paramFit_Test_prop_binch1_ele_bin15.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:46 higgsCombine_paramFit_Test_prop_binch1_ele_bin16.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:46 higgsCombine_paramFit_Test_prop_binch1_ele_bin17.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:46 higgsCombine_paramFit_Test_prop_binch1_ele_bin18.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:46 higgsCombine_paramFit_Test_prop_binch1_ele_bin19.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:46 higgsCombine_paramFit_Test_prop_binch1_ele_bin2.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:46 higgsCombine_paramFit_Test_prop_binch1_ele_bin3.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:46 higgsCombine_paramFit_Test_prop_binch1_ele_bin4.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:46 higgsCombine_paramFit_Test_prop_binch1_ele_bin5.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:47 higgsCombine_paramFit_Test_prop_binch1_ele_bin6.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:47 higgsCombine_paramFit_Test_prop_binch1_ele_bin7.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:47 higgsCombine_paramFit_Test_prop_binch1_ele_bin8.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:47 higgsCombine_paramFit_Test_prop_binch1_ele_bin9.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:47 higgsCombine_paramFit_Test_prop_binch1_mu_bin0.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:47 higgsCombine_paramFit_Test_prop_binch1_mu_bin1.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:47 higgsCombine_paramFit_Test_prop_binch1_mu_bin10.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:47 higgsCombine_paramFit_Test_prop_binch1_mu_bin11.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:47 higgsCombine_paramFit_Test_prop_binch1_mu_bin2.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:48 higgsCombine_paramFit_Test_prop_binch1_mu_bin3.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:48 higgsCombine_paramFit_Test_prop_binch1_mu_bin4.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:48 higgsCombine_paramFit_Test_prop_binch1_mu_bin5.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:48 higgsCombine_paramFit_Test_prop_binch1_mu_bin6.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:48 higgsCombine_paramFit_Test_prop_binch1_mu_bin7.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:48 higgsCombine_paramFit_Test_prop_binch1_mu_bin8.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:48 higgsCombine_paramFit_Test_prop_binch1_mu_bin9.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:48 higgsCombine_paramFit_Test_prop_binch2_ele_bin0.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:48 higgsCombine_paramFit_Test_prop_binch2_ele_bin1.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:48 higgsCombine_paramFit_Test_prop_binch2_ele_bin10.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:49 higgsCombine_paramFit_Test_prop_binch2_ele_bin11.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:49 higgsCombine_paramFit_Test_prop_binch2_ele_bin12.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:49 higgsCombine_paramFit_Test_prop_binch2_ele_bin13.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:49 higgsCombine_paramFit_Test_prop_binch2_ele_bin14.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:49 higgsCombine_paramFit_Test_prop_binch2_ele_bin15.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:49 higgsCombine_paramFit_Test_prop_binch2_ele_bin16.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:49 higgsCombine_paramFit_Test_prop_binch2_ele_bin17.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:49 higgsCombine_paramFit_Test_prop_binch2_ele_bin18.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:49 higgsCombine_paramFit_Test_prop_binch2_ele_bin19.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:50 higgsCombine_paramFit_Test_prop_binch2_ele_bin2.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 889K Nov 17 16:50 fitDiagnosticsCR123.root
# -rw-r--r-- 1 npoudyal us_cms 6.2K Nov 17 16:50 higgsCombineCR123.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:50 higgsCombine_paramFit_Test_prop_binch2_ele_bin3.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:50 higgsCombine_paramFit_Test_prop_binch2_ele_bin4.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:50 higgsCombine_paramFit_Test_prop_binch2_ele_bin5.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 889K Nov 17 16:50 fitDiagnosticsCR1.root
# -rw-r--r-- 1 npoudyal us_cms 6.2K Nov 17 16:50 higgsCombineCR1.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:50 higgsCombine_paramFit_Test_prop_binch2_ele_bin6.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:50 higgsCombine_paramFit_Test_prop_binch2_ele_bin7.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:50 higgsCombine_paramFit_Test_prop_binch2_ele_bin8.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:50 higgsCombine_paramFit_Test_prop_binch2_ele_bin9.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 890K Nov 17 16:50 fitDiagnosticsCR2.root
# -rw-r--r-- 1 npoudyal us_cms 6.2K Nov 17 16:50 higgsCombineCR2.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:50 higgsCombine_paramFit_Test_prop_binch2_mu_bin0.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:50 higgsCombine_paramFit_Test_prop_binch2_mu_bin1.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:51 higgsCombine_paramFit_Test_prop_binch2_mu_bin10.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 890K Nov 17 16:51 fitDiagnosticsCR3.root
# -rw-r--r-- 1 npoudyal us_cms 6.2K Nov 17 16:51 higgsCombineCR3.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:51 higgsCombine_paramFit_Test_prop_binch2_mu_bin11.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:51 higgsCombine_paramFit_Test_prop_binch2_mu_bin2.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:51 higgsCombine_paramFit_Test_prop_binch2_mu_bin3.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms 890K Nov 17 16:51 fitDiagnosticsCR4.root
# -rw-r--r-- 1 npoudyal us_cms 6.2K Nov 17 16:51 higgsCombineCR4.FitDiagnostics.mH120.root
# -rw-r--r-- 1 npoudyal us_cms 6.6K Nov 17 16:51 higgsCombine_paramFit_Test_prop_binch2_mu_bin4.MultiDimFit.mH125.root
# -rw-r--r-- 1 npoudyal us_cms  441 Nov 17 16:51 higgsCombine_paramFit_Test_prop_binch2_mu_bin5.MultiDimFit.mH125.root

# %%
ListOfFiles = ["fitDiagnosticsCR123.root", "fitDiagnosticsCR1.root",  "fitDiagnosticsCR2.root", "fitDiagnosticsCR3.root","fitDiagnosticsCR4.root"]

# %%
controlRegionDict ={"SR8":"tight", "CR123":"looseCRge2e0", "AR":"looseCRge2ge0", "CR7":"looseCRe3ge2", "CR3":"looseCRge4e0", "CR2":"looseCRe3e0", 
				   "CR4":"looseCRe2e1", "CR1":"looseCRe2e0", "CR6":"looseCRe2e2", "CR5":"looseCRe3e1" }


CRDictMisID ={"SR8":"misIDsfSReight", "CR123":"misIDsfCRall", "CR7":"misIDsfCRseven", "CR3":"misIDsfCRthree", "CR2":"misIDsfCRtwo", 
		 "CR4":"misIDsfCRfour", "CR1":"misIDsfCRone", "CR6":"misIDsfCRsix", "CR5":"misIDsfCRfive" }

CRDictZGamma ={"SR8":"zGammasfSReight", "CR123":"zGammasfCRall", "CR7":"zGammasfCRseven", "CR3":"zGammasfCRthree", "CR2":"zGammasfCRtwo", 
		 "CR4":"zGammasfCRfour", "CR1":"zGammasfCRone", "CR6":"zGammasfCRsix", "CR5":"zGammasfCRfive" }

CRDictWGamma ={"SR8":"wGammasfSReight", "CR123":"wGammasfCRall", "CR7":"wGammasfCRseven", "CR3":"wGammasfCRthree", "CR2":"wGammasfCRtwo", 
		 "CR4":"wGammasfCRfour", "CR1":"wGammasfCRone", "CR6":"wGammasfCRsix", "CR5":"wGammasfCRfive" }

# %%
line = ""
for ifile in ListOfFiles:
    myfile = ROOT.TFile(ifile,"read")
    if myfile.GetListOfKeys().Contains("fit_s") is False:
        print ifile[14:-5], ": Fit failed."
        continue
    fit_s = myfile.Get("fit_s")
    line += "MisIDEleSF_2016_%s = %.3f \n"%(controlRegionDict[ifile[14:-5]],fit_s.floatParsFinal().find("r").getVal())
    line += "MisIDEleSF_2017_%s = %.3f \n"%(controlRegionDict[ifile[14:-5]],fit_s.floatParsFinal().find("MisIDEleSeventeenSF").getVal())
    line += "MisIDEleSF_2018_%s = %.3f \n"%(controlRegionDict[ifile[14:-5]],fit_s.floatParsFinal().find("MisIDEleEighteenSF").getVal())
    line +=   "ZGammaSF_%s = %.3f \n"%(controlRegionDict[ifile[14:-5]],fit_s.floatParsFinal().find("ZGammaBkgPhotonSF").getVal())
    line +=   "WGammaSF_%s = %.3f \n"%(controlRegionDict[ifile[14:-5]],fit_s.floatParsFinal().find("WGammaBkgPhotonSF").getVal())

with open("FullYearMisIDEleSFvalues.py","w") as _file:
    _file.write(line)

# %%
# !cat FullYearMisIDEleSFvalues.py
# copy the file to plotting folder
# !cp FullYearMisIDEleSFvalues.py /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/TTGammaSemiLep_13TeV/Plotting
# Out:
# MisIDEleSF_2016_looseCRge2e0 = 1.773
# MisIDEleSF_2017_looseCRge2e0 = 1.956
# MisIDEleSF_2018_looseCRge2e0 = 1.392
# ZGammaSF_looseCRge2e0 = 0.892
# WGammaSF_looseCRge2e0 = 1.174
# MisIDEleSF_2016_looseCRe2e0 = 1.798
# MisIDEleSF_2017_looseCRe2e0 = 1.991
# MisIDEleSF_2018_looseCRe2e0 = 1.429
# ZGammaSF_looseCRe2e0 = 0.870
# WGammaSF_looseCRe2e0 = 1.219
# MisIDEleSF_2016_looseCRe3e0 = 2.054
# MisIDEleSF_2017_looseCRe3e0 = 2.275
# MisIDEleSF_2018_looseCRe3e0 = 1.524
# ZGammaSF_looseCRe3e0 = 0.991
# WGammaSF_looseCRe3e0 = 1.260
# MisIDEleSF_2016_looseCRge4e0 = 1.914
# MisIDEleSF_2017_looseCRge4e0 = 2.502
# MisIDEleSF_2018_looseCRge4e0 = 1.696
# ZGammaSF_looseCRge4e0 = 1.133
# WGammaSF_looseCRge4e0 = 1.744
# MisIDEleSF_2016_looseCRe2e1 = 2.161
# MisIDEleSF_2017_looseCRe2e1 = 2.591
# MisIDEleSF_2018_looseCRe2e1 = 1.594
# ZGammaSF_looseCRe2e1 = 1.004
# WGammaSF_looseCRe2e1 = 1.668

# %%
line = ""
for ifile in ListOfFiles:
    myfile = ROOT.TFile(ifile,"read")
    if myfile.GetListOfKeys().Contains("fit_s") is False:
        print ifile[14:-5], ": Fit failed."
        continue
    fit_s = myfile.Get("fit_s")
    line += "\\newcommand{\\%s} {\ensuremath{%.3f \\substack{+%.3f \\\\ %.3f }}}\n"%("allyear"+CRDictMisID[ifile[14:-5]]+"Sixteen",fit_s.floatParsFinal().find("r").getVal(),fit_s.floatParsFinal().find("r").getErrorHi(),fit_s.floatParsFinal().find("r").getErrorLo())
    line += "\\newcommand{\\%s} {\ensuremath{%.3f \\substack{+%.3f \\\\ %.3f }}}\n"%("allyear"+CRDictMisID[ifile[14:-5]]+"Seventeen",fit_s.floatParsFinal().find("MisIDEleSeventeenSF").getVal(),fit_s.floatParsFinal().find("MisIDEleSeventeenSF").getErrorHi(),fit_s.floatParsFinal().find("MisIDEleSeventeenSF").getErrorLo())
    line += "\\newcommand{\\%s} {\ensuremath{%.3f \\substack{+%.3f \\\\ %.3f }}}\n"%("allyear"+CRDictMisID[ifile[14:-5]]+"Eighteen",fit_s.floatParsFinal().find("MisIDEleEighteenSF").getVal(),fit_s.floatParsFinal().find("MisIDEleEighteenSF").getErrorHi(),fit_s.floatParsFinal().find("MisIDEleEighteenSF").getErrorLo())
    line += "\\newcommand{\\%s} {\ensuremath{%.3f \\substack{+%.3f \\\\ %.3f }}}\n"%("allyear"+CRDictZGamma[ifile[14:-5]],fit_s.floatParsFinal().find("ZGammaBkgPhotonSF").getVal(),fit_s.floatParsFinal().find("r").getErrorHi(),fit_s.floatParsFinal().find("ZGammaBkgPhotonSF").getErrorLo())
    line += "\\newcommand{\\%s} {\ensuremath{%.3f \\substack{+%.3f \\\\ %.3f }}}\n"%("allyear"+CRDictWGamma[ifile[14:-5]],fit_s.floatParsFinal().find("WGammaBkgPhotonSF").getVal(),fit_s.floatParsFinal().find("r").getErrorHi(),fit_s.floatParsFinal().find("WGammaBkgPhotonSF").getErrorLo())


with open("FullYearMisIDEleSFvalues.tex","w") as _file:
    _file.write(line)

# %%
# !cat FullYearMisIDEleSFvalues.tex
## copy the file to plotting folder
# !cp FullYearMisIDEleSFvalues.tex ../AllTexFiles
# Out:
# \newcommand{\allyearmisIDsfCRallSixteen} {\ensuremath{1.773 \substack{+0.093 \\ -0.089 }}}
# \newcommand{\allyearmisIDsfCRallSeventeen} {\ensuremath{1.956 \substack{+0.103 \\ -0.103 }}}
# \newcommand{\allyearmisIDsfCRallEighteen} {\ensuremath{1.392 \substack{+0.059 \\ -0.059 }}}
# \newcommand{\allyearzGammasfCRall} {\ensuremath{0.892 \substack{+0.093 \\ -0.054 }}}
# \newcommand{\allyearwGammasfCRall} {\ensuremath{1.174 \substack{+0.093 \\ -0.067 }}}
# \newcommand{\allyearmisIDsfCRoneSixteen} {\ensuremath{1.798 \substack{+0.099 \\ -0.094 }}}
# \newcommand{\allyearmisIDsfCRoneSeventeen} {\ensuremath{1.991 \substack{+0.112 \\ -0.112 }}}
# \newcommand{\allyearmisIDsfCRoneEighteen} {\ensuremath{1.429 \substack{+0.062 \\ -0.062 }}}
# \newcommand{\allyearzGammasfCRone} {\ensuremath{0.870 \substack{+0.099 \\ -0.056 }}}
# \newcommand{\allyearwGammasfCRone} {\ensuremath{1.219 \substack{+0.099 \\ -0.068 }}}
# \newcommand{\allyearmisIDsfCRtwoSixteen} {\ensuremath{2.054 \substack{+0.166 \\ -0.183 }}}
# \newcommand{\allyearmisIDsfCRtwoSeventeen} {\ensuremath{2.275 \substack{+0.197 \\ -0.197 }}}
# \newcommand{\allyearmisIDsfCRtwoEighteen} {\ensuremath{1.524 \substack{+0.100 \\ -0.100 }}}
# \newcommand{\allyearzGammasfCRtwo} {\ensuremath{0.991 \substack{+0.166 \\ -0.096 }}}
# \newcommand{\allyearwGammasfCRtwo} {\ensuremath{1.260 \substack{+0.166 \\ -0.103 }}}
# \newcommand{\allyearmisIDsfCRthreeSixteen} {\ensuremath{1.914 \substack{+0.238 \\ -0.213 }}}
# \newcommand{\allyearmisIDsfCRthreeSeventeen} {\ensuremath{2.502 \substack{+0.339 \\ -0.339 }}}
# \newcommand{\allyearmisIDsfCRthreeEighteen} {\ensuremath{1.696 \substack{+0.168 \\ -0.168 }}}
# \newcommand{\allyearzGammasfCRthree} {\ensuremath{1.133 \substack{+0.238 \\ -0.320 }}}
# \newcommand{\allyearwGammasfCRthree} {\ensuremath{1.744 \substack{+0.238 \\ -0.227 }}}
# \newcommand{\allyearmisIDsfCRfourSixteen} {\ensuremath{2.161 \substack{+0.235 \\ -0.214 }}}
# \newcommand{\allyearmisIDsfCRfourSeventeen} {\ensuremath{2.591 \substack{+0.288 \\ -0.288 }}}
# \newcommand{\allyearmisIDsfCRfourEighteen} {\ensuremath{1.594 \substack{+0.130 \\ -0.130 }}}
# \newcommand{\allyearzGammasfCRfour} {\ensuremath{1.004 \substack{+0.235 \\ -0.155 }}}
# \newcommand{\allyearwGammasfCRfour} {\ensuremath{1.668 \substack{+0.235 \\ -0.354 }}}
