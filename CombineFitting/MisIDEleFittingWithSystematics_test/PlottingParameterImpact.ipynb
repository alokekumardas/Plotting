# %%
# !text2workspace.py  datacard_CR123_allyear.txt
# Out:
# Warning: Bin ch2_mu has no signal processes contributing to it
# Warning: Bin ch2_ele has no signal processes contributing to it
# Warning: Bin ch3_mu has no signal processes contributing to it
# Warning: Bin ch3_ele has no signal processes contributing to it
# Channel ch1_mu will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch1_mu
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2413.095625     80.625053       total sum
# 0          896.000000      29.933259       Unweighted events, alpha=2.693187
#   => Total parameter prop_binch1_mu_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          3526.791843     116.372707      total sum
# 1          918.000000      30.298515       Unweighted events, alpha=3.841821
#   => Total parameter prop_binch1_mu_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          4311.063765     125.813429      total sum
# 2          1174.000000     34.263683       Unweighted events, alpha=3.672116
#   => Total parameter prop_binch1_mu_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          3831.792171     173.949557      total sum
# 3          485.000000      22.022716       Unweighted events, alpha=7.900602
#   => Total parameter prop_binch1_mu_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          2982.508762     69.048375       total sum
# 4          1866.000000     43.197222       Unweighted events, alpha=1.598343
#   => Total parameter prop_binch1_mu_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1750.954414     58.840121       total sum
# 5          886.000000      29.765752       Unweighted events, alpha=1.976247
#   => Total parameter prop_binch1_mu_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1624.234171     127.246408      total sum
# 6          163.000000      12.767145       Unweighted events, alpha=9.964627
#   => Total parameter prop_binch1_mu_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1312.596411     69.701987       total sum
# 7          355.000000      18.841444       Unweighted events, alpha=3.697455
#   => Total parameter prop_binch1_mu_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1103.560519     134.093195      total sum
# 8          68.000000       8.246211        Unweighted events, alpha=16.228831
#   => Total parameter prop_binch1_mu_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          870.415475      45.993412       total sum
# 9          358.000000      18.920888       Unweighted events, alpha=2.431328
#   => Total parameter prop_binch1_mu_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         650.535315      37.594652       total sum
# 10         299.000000      17.291616       Unweighted events, alpha=2.175703
#   => Total parameter prop_binch1_mu_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         781.713896      167.083754      total sum
# 11         22.000000       4.690416        Unweighted events, alpha=35.532450
#   => Total parameter prop_binch1_mu_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel ch1_ele will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch1_ele
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1882.401367     177.788206      total sum
# 0          112.000000      10.583005       Unweighted events, alpha=16.807155
#   => Total parameter prop_binch1_ele_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          2167.104622     202.754647      total sum
# 1          114.000000      10.677078       Unweighted events, alpha=19.009690
#   => Total parameter prop_binch1_ele_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          2514.708893     103.288856      total sum
# 2          593.000000      24.351591       Unweighted events, alpha=4.240656
#   => Total parameter prop_binch1_ele_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          3055.704819     178.472162      total sum
# 3          293.000000      17.117243       Unweighted events, alpha=10.429027
#   => Total parameter prop_binch1_ele_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          572.984810      43.470644       total sum
# 4          174.000000      13.190906       Unweighted events, alpha=3.293016
#   => Total parameter prop_binch1_ele_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          695.995850      75.430896       total sum
# 5          85.000000       9.219544        Unweighted events, alpha=8.188186
#   => Total parameter prop_binch1_ele_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          782.942543      46.240092       total sum
# 6          287.000000      16.941074       Unweighted events, alpha=2.728023
#   => Total parameter prop_binch1_ele_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1158.226608     61.029081       total sum
# 7          360.000000      18.973666       Unweighted events, alpha=3.217296
#   => Total parameter prop_binch1_ele_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1604.119659     50.816709       total sum
# 8          996.000000      31.559468       Unweighted events, alpha=1.610562
#   => Total parameter prop_binch1_ele_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1846.019653     62.228085       total sum
# 9          880.000000      29.664794       Unweighted events, alpha=2.097750
#   => Total parameter prop_binch1_ele_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1230.542313     57.646151       total sum
# 10         456.000000      21.354157       Unweighted events, alpha=2.698558
#   => Total parameter prop_binch1_ele_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         675.744759      40.868047       total sum
# 11         273.000000      16.522712       Unweighted events, alpha=2.475256
#   => Total parameter prop_binch1_ele_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         435.609833      36.799174       total sum
# 12         140.000000      11.832160       Unweighted events, alpha=3.111499
#   => Total parameter prop_binch1_ele_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         435.349155      72.858235       total sum
# 13         36.000000       6.000000        Unweighted events, alpha=12.093032
#   => Total parameter prop_binch1_ele_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1474.691833     113.869340      total sum
# 14         168.000000      12.961481       Unweighted events, alpha=8.777928
#   => Total parameter prop_binch1_ele_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         1124.108810     57.042059       total sum
# 15         388.000000      19.697716       Unweighted events, alpha=2.897188
#   => Total parameter prop_binch1_ele_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         903.494127      82.318006       total sum
# 16         120.000000      10.954451       Unweighted events, alpha=7.529118
#   => Total parameter prop_binch1_ele_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         806.281425      76.456479       total sum
# 17         111.000000      10.535654       Unweighted events, alpha=7.263797
#   => Total parameter prop_binch1_ele_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         520.270929      31.543404       total sum
# 18         272.000000      16.492423       Unweighted events, alpha=1.912761
#   => Total parameter prop_binch1_ele_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         639.272049      90.820938       total sum
# 19         50.000000       7.071068        Unweighted events, alpha=12.785441
#   => Total parameter prop_binch1_ele_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel ch2_mu will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch2_mu
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2923.188259     210.389217      total sum
# 0          193.000000      13.892444       Unweighted events, alpha=15.146053
#   => Total parameter prop_binch2_mu_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          4135.710701     212.200725      total sum
# 1          380.000000      19.493589       Unweighted events, alpha=10.883449
#   => Total parameter prop_binch2_mu_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          6204.981430     1071.177462     total sum
# 2          34.000000       5.830952        Unweighted events, alpha=182.499454
#   => Total parameter prop_binch2_mu_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          4638.697647     141.594217      total sum
# 3          1073.000000     32.756679       Unweighted events, alpha=4.323111
#   => Total parameter prop_binch2_mu_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          3814.720165     129.891198      total sum
# 4          863.000000      29.376862       Unweighted events, alpha=4.420301
#   => Total parameter prop_binch2_mu_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          3718.490841     1218.042742     total sum
# 5          9.000000        3.000000        Unweighted events, alpha=413.165649
#   => Total parameter prop_binch2_mu_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1910.691650     260.570861      total sum
# 6          54.000000       7.348469        Unweighted events, alpha=35.383179
#   => Total parameter prop_binch2_mu_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1668.503716     163.642247      total sum
# 7          104.000000      10.198039       Unweighted events, alpha=16.043305
#   => Total parameter prop_binch2_mu_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1200.885208     77.515137       total sum
# 8          240.000000      15.491933       Unweighted events, alpha=5.003688
#   => Total parameter prop_binch2_mu_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          923.950808      49.909899       total sum
# 9          343.000000      18.520259       Unweighted events, alpha=2.693734
#   => Total parameter prop_binch2_mu_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         916.496769      93.565804       total sum
# 10         96.000000       9.797959        Unweighted events, alpha=9.546841
#   => Total parameter prop_binch2_mu_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         729.030876      67.818376       total sum
# 11         116.000000      10.770330       Unweighted events, alpha=6.284749
#   => Total parameter prop_binch2_mu_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel ch2_ele will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch2_ele
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1967.045380     86.663212       total sum
# 0          515.000000      22.693611       Unweighted events, alpha=3.819506
#   => Total parameter prop_binch2_ele_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          2540.544312     105.370163      total sum
# 1          581.000000      24.103942       Unweighted events, alpha=4.372710
#   => Total parameter prop_binch2_ele_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          3151.067657     93.084694       total sum
# 2          1146.000000     33.852622       Unweighted events, alpha=2.749623
#   => Total parameter prop_binch2_ele_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          3723.182983     130.738868      total sum
# 3          811.000000      28.478062       Unweighted events, alpha=4.590854
#   => Total parameter prop_binch2_ele_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          952.036179      66.147624       total sum
# 4          207.000000      14.387495       Unweighted events, alpha=4.599209
#   => Total parameter prop_binch2_ele_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1038.725990     83.903243       total sum
# 5          153.000000      12.369317       Unweighted events, alpha=6.789059
#   => Total parameter prop_binch2_ele_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          2167.097672     400.737531      total sum
# 6          29.000000       5.385165        Unweighted events, alpha=74.727506
#   => Total parameter prop_binch2_ele_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          2899.682396     142.598449      total sum
# 7          413.000000      20.322401       Unweighted events, alpha=7.021023
#   => Total parameter prop_binch2_ele_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          4577.039429     174.774259      total sum
# 8          686.000000      26.191602       Unweighted events, alpha=6.672069
#   => Total parameter prop_binch2_ele_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          5291.324097     192.918022      total sum
# 9          752.000000      27.422618       Unweighted events, alpha=7.036335
#   => Total parameter prop_binch2_ele_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         3348.153099     146.093972      total sum
# 10         525.000000      22.912878       Unweighted events, alpha=6.377434
#   => Total parameter prop_binch2_ele_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         1641.094254     99.468121       total sum
# 11         272.000000      16.492423       Unweighted events, alpha=6.033435
#   => Total parameter prop_binch2_ele_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1164.499664     236.857544      total sum
# 12         24.000000       4.898979        Unweighted events, alpha=48.520819
#   => Total parameter prop_binch2_ele_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         704.435913      81.841488       total sum
# 13         74.000000       8.602325        Unweighted events, alpha=9.519404
#   => Total parameter prop_binch2_ele_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         2089.434204     105.858355      total sum
# 14         390.000000      19.748418       Unweighted events, alpha=5.357524
#   => Total parameter prop_binch2_ele_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         1334.821487     64.724389       total sum
# 15         425.000000      20.615528       Unweighted events, alpha=3.140756
#   => Total parameter prop_binch2_ele_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         1106.737259     83.661441       total sum
# 16         175.000000      13.228757       Unweighted events, alpha=6.324213
#   => Total parameter prop_binch2_ele_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         942.239861      87.330957       total sum
# 17         116.000000      10.770330       Unweighted events, alpha=8.122757
#   => Total parameter prop_binch2_ele_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         717.845642      47.632217       total sum
# 18         227.000000      15.066519       Unweighted events, alpha=3.162316
#   => Total parameter prop_binch2_ele_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         593.039268      49.885161       total sum
# 19         141.000000      11.874342       Unweighted events, alpha=4.205952
#   => Total parameter prop_binch2_ele_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel ch3_mu will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch3_mu
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          3888.256241     357.798753      total sum
# 0          118.000000      10.862780       Unweighted events, alpha=32.951324
#   => Total parameter prop_binch3_mu_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          5152.626671     152.148244      total sum
# 1          1147.000000     33.867388       Unweighted events, alpha=4.492264
#   => Total parameter prop_binch3_mu_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          8265.407928     1703.323955     total sum
# 2          24.000000       4.898979        Unweighted events, alpha=344.391997
#   => Total parameter prop_binch3_mu_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          7433.159889     1329.975242     total sum
# 3          31.000000       5.567764        Unweighted events, alpha=239.779351
#   => Total parameter prop_binch3_mu_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          4635.998245     118.595699      total sum
# 4          1528.000000     39.089641       Unweighted events, alpha=3.034030
#   => Total parameter prop_binch3_mu_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          2933.111969     238.594947      total sum
# 5          151.000000      12.288206       Unweighted events, alpha=19.424583
#   => Total parameter prop_binch3_mu_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          2206.791901     101.786619      total sum
# 6          470.000000      21.679483       Unweighted events, alpha=4.695302
#   => Total parameter prop_binch3_mu_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          2113.465141     219.707284      total sum
# 7          93.000000       9.643651        Unweighted events, alpha=22.725432
#   => Total parameter prop_binch3_mu_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1681.009224     90.682699       total sum
# 8          344.000000      18.547237       Unweighted events, alpha=4.886655
#   => Total parameter prop_binch3_mu_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1252.899128     82.390507       total sum
# 9          231.000000      15.198684       Unweighted events, alpha=5.423806
#   => Total parameter prop_binch3_mu_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1158.513119     70.440636       total sum
# 10         270.000000      16.431677       Unweighted events, alpha=4.290789
#   => Total parameter prop_binch3_mu_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         946.313511      60.264456       total sum
# 11         247.000000      15.716234       Unweighted events, alpha=3.831229
#   => Total parameter prop_binch3_mu_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel ch3_ele will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binch3_ele
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2651.779556     109.374741      total sum
# 0          588.000000      24.248711       Unweighted events, alpha=4.509829
#   => Total parameter prop_binch3_ele_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          3418.737122     139.358068      total sum
# 1          602.000000      24.535688       Unweighted events, alpha=5.678965
#   => Total parameter prop_binch3_ele_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          4181.431458     145.979540      total sum
# 2          820.000000      28.635642       Unweighted events, alpha=5.099307
#   => Total parameter prop_binch3_ele_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          5232.642944     159.895419      total sum
# 3          1071.000000     32.726136       Unweighted events, alpha=4.885754
#   => Total parameter prop_binch3_ele_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1692.843735     130.246536      total sum
# 4          169.000000      13.000000       Unweighted events, alpha=10.016827
#   => Total parameter prop_binch3_ele_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          2253.737335     122.868339      total sum
# 5          336.000000      18.330303       Unweighted events, alpha=6.707552
#   => Total parameter prop_binch3_ele_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          3037.240585     147.838282      total sum
# 6          422.000000      20.542639       Unweighted events, alpha=7.197253
#   => Total parameter prop_binch3_ele_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          5643.972137     208.451491      total sum
# 7          733.000000      27.073973       Unweighted events, alpha=7.699826
#   => Total parameter prop_binch3_ele_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          9332.336670     284.297693      total sum
# 8          1078.000000     32.832910       Unweighted events, alpha=8.657084
#   => Total parameter prop_binch3_ele_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          11686.902435    2708.319150     total sum
# 9          19.000000       4.358899        Unweighted events, alpha=615.100128
#   => Total parameter prop_binch3_ele_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         5656.132492     213.294866      total sum
# 10         703.000000      26.514147       Unweighted events, alpha=8.045708
#   => Total parameter prop_binch3_ele_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         2333.912636     133.498639      total sum
# 11         306.000000      17.492856       Unweighted events, alpha=7.627165
#   => Total parameter prop_binch3_ele_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1764.801842     358.295346      total sum
# 12         24.000000       4.898979        Unweighted events, alpha=73.533410
#   => Total parameter prop_binch3_ele_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         811.646248      69.473159       total sum
# 13         136.000000      11.661904       Unweighted events, alpha=5.967987
#   => Total parameter prop_binch3_ele_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         2732.423431     152.334806      total sum
# 14         322.000000      17.944358       Unweighted events, alpha=8.485787
#   => Total parameter prop_binch3_ele_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         2193.311554     173.378555      total sum
# 15         160.000000      12.649111       Unweighted events, alpha=13.708197
#   => Total parameter prop_binch3_ele_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         1527.953247     152.272568      total sum
# 16         101.000000      10.049876       Unweighted events, alpha=15.128250
#   => Total parameter prop_binch3_ele_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         1362.451797     111.702560      total sum
# 17         149.000000      12.206556       Unweighted events, alpha=9.143972
#   => Total parameter prop_binch3_ele_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         1002.899994     64.365349       total sum
# 18         243.000000      15.588457       Unweighted events, alpha=4.127160
#   => Total parameter prop_binch3_ele_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         909.389534      61.549403       total sum
# 19         218.000000      14.764823       Unweighted events, alpha=4.171512
#   => Total parameter prop_binch3_ele_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------

# %%
# !combineTool.py -M Impacts -d datacard_CR123_allyear.root -m 125 --doInitialFit --robustFit 1
# Out:
# Have POIs: ['r']
# >> combine -M MultiDimFit -n _initialFit_Test --algo singles --redefineSignalPOIs r --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# best fit parameter values and profile-likelihood uncertainties:
#    r :    +1.773   -0.093/+0.090 (68%)
# Done in 0.04 min (cpu), 0.04 min (real)

# %%
# !combineTool.py -M Impacts -d datacard_CR123_allyear.root -m 125 --robustFit 1 --doFits
# Out:
# Have POIs: ['r']
# Have parameters: 106
# >> combine -M MultiDimFit -n _paramFit_Test_BTagSF_b --algo impact --redefineSignalPOIs r -P BTagSF_b --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter :   Best-fit               r
#   BTagSF_b  :   -0.039  -0.989/+0.990  -0.007/-0.000
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_BTagSF_l --algo impact --redefineSignalPOIs r -P BTagSF_l --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter :   Best-fit               r
#   BTagSF_l  :   +0.521  -0.989/+0.986  -0.012/+0.004
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_MisIDEleEighteenSF --algo impact --redefineSignalPOIs r -P MisIDEleEighteenSF --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
# Error: minimization failed at MisIDEleEighteenSF = 6.25e+27
# Error: closed range without finding crossing.
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter          :   Best-fit               r
#   MisIDEleEighteenSF :   +1.392  +0.000/+0.000  -0.002/-0.002
# Done in 0.16 min (cpu), 0.16 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_MisIDEleSeventeenSF --algo impact --redefineSignalPOIs r -P MisIDEleSeventeenSF --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
# Error: minimization failed at MisIDEleSeventeenSF = 6.25e+27
# Error: closed range without finding crossing.
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   MisIDEleSeventeenSF :   +1.956  +0.000/+0.000  -0.001/-0.001
# Done in 0.15 min (cpu), 0.15 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_MuEff --algo impact --redefineSignalPOIs r -P MuEff --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter :   Best-fit               r
#   MuEff     :   -0.861  -0.928/+0.925  -0.004/-0.004
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_PU --algo impact --redefineSignalPOIs r -P PU --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter :   Best-fit               r
#   PU        :   +1.168  -0.536/+0.609  +0.058/-0.065
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_PhoEff --algo impact --redefineSignalPOIs r -P PhoEff --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter :   Best-fit               r
#   PhoEff    :   +2.622  -0.577/+0.559  -0.004/-0.013
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_WGammaBkgPhotonSF --algo impact --redefineSignalPOIs r -P WGammaBkgPhotonSF --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
# Error: minimization failed at WGammaBkgPhotonSF = 6.25e+27
# Error: minimization failed at WGammaBkgPhotonSF = -6.25e+27
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter         :   Best-fit               r
#   WGammaBkgPhotonSF :   +1.174  +0.000/+0.000  -0.004/-0.004
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_ZGammaBkgPhotonSF --algo impact --redefineSignalPOIs r -P ZGammaBkgPhotonSF --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
# Error: minimization failed at ZGammaBkgPhotonSF = 6.25e+27
# Error: minimization failed at ZGammaBkgPhotonSF = -6.25e+27
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter         :   Best-fit               r
#   ZGammaBkgPhotonSF :   +0.892  +0.000/+0.000  -0.004/-0.004
# Done in 0.06 min (cpu), 0.06 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_lumi --algo impact --redefineSignalPOIs r -P lumi --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter :   Best-fit               r
#   lumi      :   +1.020  -0.980/+0.991  +0.041/-0.047
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin0 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin0 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch1_ele_bin0 :   -1.382  -0.226/+0.232  +0.017/-0.021
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin1 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin1 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch1_ele_bin1 :   -1.084  -0.227/+0.235  +0.019/-0.024
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin10 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin10 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch1_ele_bin10 :   -0.360  -0.568/+0.572  +0.016/-0.024
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin11 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin11 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch1_ele_bin11 :   -0.285  -0.506/+0.527  +0.027/-0.033
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin12 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin12 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch1_ele_bin12 :   +0.499  -0.477/+0.478  -0.006/-0.001
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin13 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin13 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch1_ele_bin13 :   -0.286  -0.271/+0.281  +0.008/-0.012
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin14 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin14 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch1_ele_bin14 :   -0.912  -0.325/+0.326  -0.004/-0.001
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin15 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin15 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch1_ele_bin15 :   -0.433  -0.492/+0.496  -0.003/-0.005
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin16 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin16 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch1_ele_bin16 :   +0.153  -0.344/+0.350  -0.002/-0.004
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin17 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin17 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch1_ele_bin17 :   -0.447  -0.343/+0.360  +0.012/-0.017
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin18 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin18 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch1_ele_bin18 :   +1.706  -0.562/+0.566  -0.009/+0.000
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin19 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin19 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch1_ele_bin19 :   -0.786  -0.251/+0.259  -0.001/-0.004
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin2 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin2 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch1_ele_bin2 :   -0.937  -0.450/+0.455  +0.004/-0.010
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin3 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin3 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch1_ele_bin3 :   -2.290  -0.321/+0.312  -0.013/+0.007
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin4 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin4 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch1_ele_bin4 :   +0.040  -0.452/+0.463  +0.008/-0.014
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin5 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin5 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch1_ele_bin5 :   -0.907  -0.329/+0.341  +0.021/-0.025
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin6 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin6 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch1_ele_bin6 :   -1.479  -0.479/+0.490  +0.013/-0.020
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin7 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin7 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch1_ele_bin7 :   -0.341  -0.515/+0.528  +0.023/-0.029
# Done in 0.03 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin8 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin8 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch1_ele_bin8 :   +1.001  -0.663/+0.671  +0.022/-0.030
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_ele_bin9 --algo impact --redefineSignalPOIs r -P prop_binch1_ele_bin9 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch1_ele_bin9 :   +0.638  -0.672/+0.675  +0.019/-0.027
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_mu_bin0 --algo impact --redefineSignalPOIs r -P prop_binch1_mu_bin0 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch1_mu_bin0 :   -1.126  -0.518/+0.528  +0.008/-0.015
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_mu_bin1 --algo impact --redefineSignalPOIs r -P prop_binch1_mu_bin1 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch1_mu_bin1 :   -1.379  -0.476/+0.479  +0.003/-0.009
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_mu_bin10 --algo impact --redefineSignalPOIs r -P prop_binch1_mu_bin10 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch1_mu_bin10 :   +0.422  -0.557/+0.562  -0.006/-0.003
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_mu_bin11 --algo impact --redefineSignalPOIs r -P prop_binch1_mu_bin11 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch1_mu_bin11 :   -1.348  -0.162/+0.161  -0.009/+0.005
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_mu_bin2 --algo impact --redefineSignalPOIs r -P prop_binch1_mu_bin2 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch1_mu_bin2 :   -1.501  -0.529/+0.538  +0.011/-0.017
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_mu_bin3 --algo impact --redefineSignalPOIs r -P prop_binch1_mu_bin3 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch1_mu_bin3 :   -0.573  -0.381/+0.376  -0.010/+0.005
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_mu_bin4 --algo impact --redefineSignalPOIs r -P prop_binch1_mu_bin4 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch1_mu_bin4 :   +0.919  -0.655/+0.659  +0.004/-0.011
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_mu_bin5 --algo impact --redefineSignalPOIs r -P prop_binch1_mu_bin5 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch1_mu_bin5 :   +0.691  -0.590/+0.592  -0.007/-0.001
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_mu_bin6 --algo impact --redefineSignalPOIs r -P prop_binch1_mu_bin6 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch1_mu_bin6 :   -1.711  -0.316/+0.319  +0.002/-0.007
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_mu_bin7 --algo impact --redefineSignalPOIs r -P prop_binch1_mu_bin7 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch1_mu_bin7 :   -1.735  -0.473/+0.482  +0.002/-0.009
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_mu_bin8 --algo impact --redefineSignalPOIs r -P prop_binch1_mu_bin8 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch1_mu_bin8 :   -0.901  -0.332/+0.313  -0.042/+0.034
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch1_mu_bin9 --algo impact --redefineSignalPOIs r -P prop_binch1_mu_bin9 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch1_mu_bin9 :   -0.420  -0.543/+0.565  +0.014/-0.021
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin0 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin0 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch2_ele_bin0 :   +0.884  -0.473/+0.485  -0.001/-0.007
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin1 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin1 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch2_ele_bin1 :   -1.126  -0.471/+0.470  -0.020/+0.013
# Done in 0.03 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin10 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin10 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch2_ele_bin10 :   +0.276  -0.541/+0.545  -0.009/+0.000
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin11 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin11 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch2_ele_bin11 :   +1.191  -0.445/+0.462  +0.007/-0.014
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin12 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin12 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch2_ele_bin12 :   -0.985  -0.140/+0.137  -0.024/+0.019
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin13 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin13 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch2_ele_bin13 :   -0.845  -0.278/+0.291  +0.001/-0.006
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin14 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin14 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch2_ele_bin14 :   -0.118  -0.391/+0.405  +0.005/-0.011
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin15 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin15 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch2_ele_bin15 :   +0.982  -0.483/+0.487  -0.011/+0.003
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin16 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin16 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch2_ele_bin16 :   +1.058  -0.371/+0.379  -0.016/+0.010
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin17 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin17 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch2_ele_bin17 :   +0.794  -0.321/+0.331  -0.007/+0.001
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin18 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin18 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch2_ele_bin18 :   +1.869  -0.487/+0.486  -0.021/+0.014
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin19 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin19 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch2_ele_bin19 :   +1.529  -0.422/+0.430  -0.008/+0.001
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin2 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin2 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch2_ele_bin2 :   -0.058  -0.583/+0.590  -0.006/-0.002
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin3 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin3 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch2_ele_bin3 :   -1.081  -0.458/+0.468  -0.004/-0.003
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin4 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin4 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch2_ele_bin4 :   -0.063  -0.424/+0.422  -0.019/+0.011
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin5 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin5 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch2_ele_bin5 :   +1.404  -0.369/+0.379  -0.006/-0.000
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin6 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin6 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch2_ele_bin6 :   -0.938  -0.137/+0.146  +0.031/-0.036
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin7 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin7 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch2_ele_bin7 :   -0.384  -0.460/+0.478  +0.008/-0.015
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin8 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin8 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch2_ele_bin8 :   -0.427  -0.560/+0.573  +0.001/-0.009
# Done in 0.03 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_ele_bin9 --algo impact --redefineSignalPOIs r -P prop_binch2_ele_bin9 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch2_ele_bin9 :   -0.413  -0.598/+0.597  -0.011/+0.003
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_mu_bin0 --algo impact --redefineSignalPOIs r -P prop_binch2_mu_bin0 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch2_mu_bin0 :   -0.331  -0.303/+0.305  -0.025/+0.018
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_mu_bin1 --algo impact --redefineSignalPOIs r -P prop_binch2_mu_bin1 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch2_mu_bin1 :   -0.852  -0.350/+0.360  -0.013/+0.007
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_mu_bin10 --algo impact --redefineSignalPOIs r -P prop_binch2_mu_bin10 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch2_mu_bin10 :   -0.597  -0.309/+0.318  -0.011/+0.005
# Done in 0.03 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_mu_bin11 --algo impact --redefineSignalPOIs r -P prop_binch2_mu_bin11 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch2_mu_bin11 :   +0.446  -0.386/+0.392  -0.019/+0.011
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_mu_bin2 --algo impact --redefineSignalPOIs r -P prop_binch2_mu_bin2 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch2_mu_bin2 :   -0.924  -0.121/+0.132  +0.023/-0.029
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_mu_bin3 --algo impact --redefineSignalPOIs r -P prop_binch2_mu_bin3 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch2_mu_bin3 :   +0.966  -0.546/+0.541  -0.026/+0.019
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_mu_bin4 --algo impact --redefineSignalPOIs r -P prop_binch2_mu_bin4 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch2_mu_bin4 :   +1.202  -0.501/+0.498  -0.028/+0.022
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_mu_bin5 --algo impact --redefineSignalPOIs r -P prop_binch2_mu_bin5 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch2_mu_bin5 :   -1.092  -0.068/+0.074  +0.036/-0.040
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_mu_bin6 --algo impact --redefineSignalPOIs r -P prop_binch2_mu_bin6 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch2_mu_bin6 :   -0.086  -0.198/+0.211  -0.002/-0.004
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_mu_bin7 --algo impact --redefineSignalPOIs r -P prop_binch2_mu_bin7 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch2_mu_bin7 :   -0.797  -0.259/+0.264  -0.013/+0.006
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_mu_bin8 --algo impact --redefineSignalPOIs r -P prop_binch2_mu_bin8 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch2_mu_bin8 :   +0.716  -0.438/+0.440  -0.018/+0.010
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch2_mu_bin9 --algo impact --redefineSignalPOIs r -P prop_binch2_mu_bin9 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch2_mu_bin9 :   +1.194  -0.529/+0.535  -0.009/+0.001
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin0 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin0 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch3_ele_bin0 :   +1.088  -0.470/+0.488  +0.017/-0.025
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin1 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin1 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
# ...
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch3_ele_bin14 :   +2.238  -0.374/+0.372  -0.022/+0.015
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin15 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin15 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch3_ele_bin15 :   -0.951  -0.256/+0.261  -0.002/-0.004
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin16 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin16 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch3_ele_bin16 :   +0.366  -0.255/+0.258  -0.015/+0.008
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin17 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin17 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch3_ele_bin17 :   -0.862  -0.501/+0.462  -0.055/+0.047
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin18 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin18 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch3_ele_bin18 :   +2.162  -0.450/+0.457  -0.008/+0.000
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin19 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin19 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binch3_ele_bin19 :   +0.503  -0.433/+0.444  -0.001/-0.007
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin2 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin2 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch3_ele_bin2 :   +1.963  -0.482/+0.473  -0.020/+0.012
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin3 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin3 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch3_ele_bin3 :   +2.035  -0.500/+0.515  +0.011/-0.019
# Done in 0.03 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin4 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin4 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch3_ele_bin4 :   -1.024  -0.328/+0.349  +0.023/-0.029
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin5 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin5 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch3_ele_bin5 :   -0.914  -0.429/+0.444  +0.010/-0.017
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin6 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin6 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch3_ele_bin6 :   +1.077  -0.479/+0.490  -0.001/-0.007
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin7 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin7 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch3_ele_bin7 :   +0.128  -0.558/+0.569  -0.001/-0.007
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin8 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin8 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch3_ele_bin8 :   -1.441  -0.641/+0.635  -0.017/+0.009
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_ele_bin9 --algo impact --redefineSignalPOIs r -P prop_binch3_ele_bin9 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch3_ele_bin9 :   -0.733  -0.076/+0.083  +0.038/-0.046
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_mu_bin0 --algo impact --redefineSignalPOIs r -P prop_binch3_mu_bin0 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch3_mu_bin0 :   -1.183  -0.184/+0.193  +0.020/-0.027
# Done in 0.03 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_mu_bin1 --algo impact --redefineSignalPOIs r -P prop_binch3_mu_bin1 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch3_mu_bin1 :   -0.876  -0.514/+0.499  -0.024/+0.016
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_mu_bin10 --algo impact --redefineSignalPOIs r -P prop_binch3_mu_bin10 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch3_mu_bin10 :   -0.748  -0.437/+0.456  +0.010/-0.017
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_mu_bin11 --algo impact --redefineSignalPOIs r -P prop_binch3_mu_bin11 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binch3_mu_bin11 :   -0.430  -0.448/+0.468  +0.009/-0.018
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_mu_bin2 --algo impact --redefineSignalPOIs r -P prop_binch3_mu_bin2 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch3_mu_bin2 :   -1.091  -0.120/+0.136  +0.052/-0.059
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_mu_bin3 --algo impact --redefineSignalPOIs r -P prop_binch3_mu_bin3 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch3_mu_bin3 :   -1.152  -0.077/+0.078  +0.005/-0.012
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_mu_bin4 --algo impact --redefineSignalPOIs r -P prop_binch3_mu_bin4 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch3_mu_bin4 :   +0.381  -0.551/+0.552  +0.000/-0.009
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_mu_bin5 --algo impact --redefineSignalPOIs r -P prop_binch3_mu_bin5 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch3_mu_bin5 :   -0.784  -0.259/+0.252  -0.017/+0.012
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_mu_bin6 --algo impact --redefineSignalPOIs r -P prop_binch3_mu_bin6 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch3_mu_bin6 :   +0.066  -0.447/+0.455  -0.003/-0.005
# Done in 0.03 min (cpu), 0.03 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_mu_bin7 --algo impact --redefineSignalPOIs r -P prop_binch3_mu_bin7 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch3_mu_bin7 :   -0.779  -0.232/+0.244  +0.015/-0.022
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_mu_bin8 --algo impact --redefineSignalPOIs r -P prop_binch3_mu_bin8 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch3_mu_bin8 :   -1.789  -0.463/+0.454  -0.023/+0.014
# Done in 0.04 min (cpu), 0.04 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_prop_binch3_mu_bin9 --algo impact --redefineSignalPOIs r -P prop_binch3_mu_bin9 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123_allyear.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter           :   Best-fit               r
#   prop_binch3_mu_bin9 :   +0.534  -0.413/+0.417  -0.009/+0.001
# Done in 0.03 min (cpu), 0.04 min (real)

# %%
# !combineTool.py -M Impacts -d datacard_CR123_allyear.root -m 125 -o impacts.json
# Out:
# Have POIs: ['r']
# Have parameters: 106

# %%
# !plotImpacts.py -i impacts.json -o impacts
# Out:
# >> Doing page 0, have 30 parameters
# Info in <TCanvas::Print>: pdf file ./impacts.pdf has been created using the current canvas
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: impacts
# >> Doing page 1, have 30 parameters
# Info in <TCanvas::Print>: Current canvas added to pdf file ./impacts.pdf
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: impacts
# >> Doing page 2, have 30 parameters
# Info in <TCanvas::Print>: Current canvas added to pdf file ./impacts.pdf
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: impacts
# >> Doing page 3, have 16 parameters
# Info in <TCanvas::Print>: Current canvas added to pdf file ./impacts.pdf and file closed

# %%
# from IPython.display import IFrame
# IFrame("impacts.pdf", width=800, height=600)

# %%
# !pwd
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/TTGammaSemiLep_13TeV/Plotting/CombineFitting/MisIDEleFittingWithSystematics_test
