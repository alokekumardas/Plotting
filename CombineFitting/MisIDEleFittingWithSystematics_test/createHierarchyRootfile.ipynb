# %%
import ROOT
from ROOT import gDirectory

# %%
myfile = ROOT.TFile("misIdentifiedEle.root", "RECREATE")
##################
eldir = myfile.mkdir("elJets/nominal")

eldir = myfile.mkdir("elJets/btagSF_bUp")
eldir = myfile.mkdir("elJets/btagSF_bDown")

eldir = myfile.mkdir("elJets/btagSF_lUp")
eldir = myfile.mkdir("elJets/btagSF_lDown")
#################
mudir = myfile.mkdir("muJets/nominal")

mudir = myfile.mkdir("muJets/btagSF_bUp")
mudir = myfile.mkdir("muJets/btagSF_bDown")

mudir = myfile.mkdir("muJets/btagSF_lUp")
mudir = myfile.mkdir("muJets/btagSF_lDown")

myfile.cd()
gDirectory.cd("elJets/nominal")
h1_data_obs = ROOT.TH1F('data_obs','',5,0,5)
h1_misIDEle = ROOT.TH1F('misIDEle','',5,0,5)
h1_Wgamma   = ROOT.TH1F('Wgamma','',5,0,5)
h1_Zgamma   = ROOT.TH1F('Zgamma','',5,0,5)
h1_other    = ROOT.TH1F('other','',5,0,5)
h1_data_obs.Write();h1_misIDEle.Write();h1_Wgamma.Write();h1_Zgamma.Write();h1_other.Write()

myfile.cd()
gDirectory.cd("elJets/btagSF_bUp")
h11_misIDEle = ROOT.TH1F('misIDEle_btagSF_bUp','',5,0,5)
h11_Wgamma   = ROOT.TH1F('Wgamma_btagSF_bUp','',5,0,5)
h11_Zgamma   = ROOT.TH1F('Zgamma_btagSF_bUp','',5,0,5)
h11_other    = ROOT.TH1F('other_btagSF_bUp','',5,0,5)
h11_misIDEle.Write();h11_Wgamma.Write();h11_Zgamma.Write();h11_other.Write()

myfile.cd()
gDirectory.cd("elJets/btagSF_bDown")
h12_misIDEle = ROOT.TH1F('misIDEle_btagSF_bDown','',5,0,5)
h12_Wgamma   = ROOT.TH1F('Wgamma_btagSF_bDown','',5,0,5)
h12_Zgamma   = ROOT.TH1F('Zgamma_btagSF_bDown','',5,0,5)
h12_other    = ROOT.TH1F('other_btagSF_bDown','',5,0,5)
h12_misIDEle.Write();h12_Wgamma.Write();h12_Zgamma.Write();h12_other.Write()

myfile.cd()
gDirectory.cd("muJets/nominal")
h2_data_obs = ROOT.TH1F('data_obs','',5,0,5)
h2_misIDEle = ROOT.TH1F('misIDEle','',5,0,5)
h2_Wgamma   = ROOT.TH1F('Wgamma','',5,0,5)
h2_Zgamma   = ROOT.TH1F('Zgamma','',5,0,5)
h2_other    = ROOT.TH1F('other','',5,0,5)
h2_data_obs.Write();h2_misIDEle.Write();h2_Wgamma.Write();h2_Zgamma.Write();h2_other.Write()

myfile.cd()
gDirectory.cd("muJets/btagSF_bUp")
h21_misIDEle = ROOT.TH1F('misIDEle_btagSF_bUp','',5,0,5)
h21_Wgamma   = ROOT.TH1F('Wgamma_btagSF_bUp','',5,0,5)
h21_Zgamma   = ROOT.TH1F('Zgamma_btagSF_bUp','',5,0,5)
h21_other    = ROOT.TH1F('other_btagSF_bUp','',5,0,5)
h21_misIDEle.Write();h21_Wgamma.Write();h21_Zgamma.Write();h21_other.Write()

myfile.cd()
gDirectory.cd("muJets/btagSF_bDown")
h22_misIDEle = ROOT.TH1F('misIDEle_btagSF_bDown','',5,0,5)
h22_Wgamma   = ROOT.TH1F('Wgamma_btagSF_bDown','',5,0,5)
h22_Zgamma   = ROOT.TH1F('Zgamma_btagSF_bDown','',5,0,5)
h22_other    = ROOT.TH1F('other_btagSF_bDown','',5,0,5)
h22_misIDEle.Write();h22_Wgamma.Write();h22_Zgamma.Write();h22_other.Write()

myfile.Close()

# %%
TFile outputFile("OutputFileName","RECREATE");
TDirectory* subD1 = outputFile.mkdir("SubDir1");
TDirectory* subSubD1 = outputFile.mkdir("SubDir1/SubSubDir1");

TDirectory* subSubD1 = subD1->mkdir(SubDir1/SubSubDir1");



 TDirectory* subD1 = outputFile.mkdir("SubDir1/SubSubDir1");
 // Both "SubDir1" and "SubDir1/SubSubDir1" are now created;
 // now get a pointer to the subdirectory
 TDirectory* subSubD1 = subD1->GetDirectory("SubSubDir1");
