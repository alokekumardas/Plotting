# %%
import ROOT
import os

# %%
# !combine --help
# !pwd

# %% [markdown]
# ### Important:
# signal strength r = (number of signal events / number of expected signal events).
# It scales the signal up and down in such a way after considering all the nuisance parameters. Signal strength * signal = eg. expectation of number of events in the cut and count physics process.
# data_obs = e.g., observed number of events in the data
# POI = e.g., ttgamma crossection which is burried in signal histogram.
#
# ### FitDiagnostics:
# performs maximum likelihood fits to extract the signal yield and provide diagnostic tools such as pre and post-fit models and correlations
#
# ### MultiDimFit:
# perform maximum likelihood fits in multiple parameters and likelihood scans

# %% [markdown]
# ### Doing exercise for misIDEle

# %%
# myfile = ROOT.TFile("MyFiles/pho_looseCRe2e0plots_ele_2016/myMisIDEle_Prefit.root")
# myfile.ls()
# MyDataHist = myfile.Get("myData")
# MisIDEle   = myfile.Get("myMisIDEle")
# MisIDEle.SetLineWidth(2)
# MisIDEle.SetLineColor(2)
# OtherHist  = myfile.Get("myBackground")
# OtherHist.SetLineWidth(2)
# OtherHist.SetLineColor(3)

# c = ROOT.TCanvas()
# MyDataHist.Draw("hist")
# MisIDEle.Draw("same") # red
# OtherHist.Draw("same") # yellow
# c.Draw()

# %%
# !text2workspace.py datacard_AR.txt

# %%
# f_shapes_TH1 = ROOT.TFile("datacard_AR.root","READ")
# w_shapes_TH1 = f_shapes_TH1.Get("w")
# w_shapes_TH1.Print()

# %%
# !python ../test/printWorkspaceNormalisations.py datacard_AR.root

# %%
# !combine -M MultiDimFit -n AR  datacard_AR.txt --redefineSignalPOIs r,mybackground_norm

# %%
# !combine -M MultiDimFit -n AR  datacard_AR.txt --redefineSignalPOIs r,WGammaSF

# %%
# !combine -M FitDiagnostics -n CR123  datacard_CR123.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF -v2

# %%
# !combine -M FitDiagnostics -n CR1  datacard_CR1.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF -v2
# Out:
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Creating pdfs for individual modes (2): Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          144.168633      47.848889       total sum
# 0          9.000000        3.000000        Unweighted events, alpha=16.018737
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          133.413374      63.252003       total sum
# 1          4.000000        2.000000        Unweighted events, alpha=33.353343
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          81.382341       31.625106       total sum
# 2          7.000000        2.645751        Unweighted events, alpha=11.626049
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          79.119495       12.072415       total sum
# 3          43.000000       6.557439        Unweighted events, alpha=1.839988
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          82.259844       13.986874       total sum
# 4          35.000000       5.916080        Unweighted events, alpha=2.350281
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          189.536371      112.778456      total sum
# 5          3.000000        1.732051        Unweighted events, alpha=63.178790
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          70.507397       13.898544       total sum
# 6          26.000000       5.099020        Unweighted events, alpha=2.711823
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          196.023695      59.582115       total sum
# 7          11.000000       3.316625        Unweighted events, alpha=17.820336
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          130.702858      34.096400       total sum
# 8          15.000000       3.872983        Unweighted events, alpha=8.713524
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          98.613464       14.517825       total sum
# 9          46.000000       6.782330        Unweighted events, alpha=2.143771
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         157.722862      35.673945       total sum
# 10         20.000000       4.472136        Unweighted events, alpha=7.886143
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         268.752670      71.067994       total sum
# 11         14.000000       3.741657        Unweighted events, alpha=19.196619
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         317.683777      37.109668       total sum
# 12         73.000000       8.544004        Unweighted events, alpha=4.351833
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         531.985115      42.128644       total sum
# 13         159.000000      12.609520       Unweighted events, alpha=3.345818
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         832.171288      33.287931       total sum
# 14         625.000000      25.000000       Unweighted events, alpha=1.331474
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         981.548759      46.985813       total sum
# 15         436.000000      20.880613       Unweighted events, alpha=2.251259
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         670.751915      46.419769       total sum
# 16         209.000000      14.456832       Unweighted events, alpha=3.209339
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         287.483765      26.665052       total sum
# 17         116.000000      10.770330       Unweighted events, alpha=2.478308
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         162.334709      28.097630       total sum
# 18         33.000000       5.744563        Unweighted events, alpha=4.919234
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         90.406475       11.881250       total sum
# 19         58.000000       7.615773        Unweighted events, alpha=1.558732
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         80.030106       11.621893       total sum
# 20         47.000000       6.855655        Unweighted events, alpha=1.702768
#   => Total parameter prop_bineleJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         205.062080      97.197644       total sum
# 21         4.000000        2.000000        Unweighted events, alpha=51.265520
#   => Total parameter prop_bineleJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         52.296166       9.184392        total sum
# 22         32.000000       5.656854        Unweighted events, alpha=1.634255
#   => Total parameter prop_bineleJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         42.515812       6.956320        total sum
# 23         37.000000       6.082763        Unweighted events, alpha=1.149076
#   => Total parameter prop_bineleJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         65.979366       10.457325       total sum
# 24         40.000000       6.324555        Unweighted events, alpha=1.649484
#   => Total parameter prop_bineleJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         35.397436       6.219854        total sum
# 25         32.000000       5.656854        Unweighted events, alpha=1.106170
#   => Total parameter prop_bineleJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         64.357815       32.860669       total sum
# 26         4.000000        2.000000        Unweighted events, alpha=16.089454
#   => Total parameter prop_bineleJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         51.910536       11.163403       total sum
# 27         22.000000       4.690416        Unweighted events, alpha=2.359570
#   => Total parameter prop_bineleJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         47.430946       9.711869        total sum
# 28         24.000000       4.898979        Unweighted events, alpha=1.976289
#   => Total parameter prop_bineleJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         37.340250       7.312687        total sum
# 29         26.000000       5.099020        Unweighted events, alpha=1.436163
#   => Total parameter prop_bineleJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         26.524644       6.145106        total sum
# 30         19.000000       4.358899        Unweighted events, alpha=1.396034
#   => Total parameter prop_bineleJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         36.551435       7.633042        total sum
# 31         23.000000       4.795832        Unweighted events, alpha=1.589193
#   => Total parameter prop_bineleJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         23.177326       4.002083        total sum
# 32         34.000000       5.830952        Unweighted events, alpha=0.681686
#   => Total parameter prop_bineleJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         21.141959       4.292776        total sum
# 33         24.000000       4.898979        Unweighted events, alpha=0.880915
#   => Total parameter prop_bineleJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         80.766189       63.533032       total sum
# 34         2.000000        1.414214        Unweighted events, alpha=40.383094
#   => Total parameter prop_bineleJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         137.602874      58.271614       total sum
# 35         6.000000        2.449490        Unweighted events, alpha=22.933812
#   => Total parameter prop_bineleJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         57.441851       32.796665       total sum
# 36         3.000000        1.732051        Unweighted events, alpha=19.147284
#   => Total parameter prop_bineleJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         26.406467       6.217313        total sum
# 37         18.000000       4.242641        Unweighted events, alpha=1.467026
#   => Total parameter prop_bineleJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         20.032091       5.614731        total sum
# 38         13.000000       3.605551        Unweighted events, alpha=1.540930
#   => Total parameter prop_bineleJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         8.895292        4.653593        total sum
# 39         4.000000        2.000000        Unweighted events, alpha=2.223823
#   => Total parameter prop_bineleJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .    1Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          155.061186      39.387895       total sum
# 0          15.000000       3.872983        Unweighted events, alpha=10.337412
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          211.237432      85.280096       total sum
# 1          6.000000        2.449490        Unweighted events, alpha=35.206239
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          97.862687       11.143438       total sum
# 2          77.000000       8.774964        Unweighted events, alpha=1.270944
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          139.169877      19.162501       total sum
# 3          53.000000       7.280110        Unweighted events, alpha=2.625847
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          124.764375      19.799516       total sum
# 4          40.000000       6.324555        Unweighted events, alpha=3.119109
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          114.245790      13.507207       total sum
# 5          72.000000       8.485281        Unweighted events, alpha=1.586747
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          141.464963      16.500999       total sum
# 6          73.000000       8.544004        Unweighted events, alpha=1.937876
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          218.736052      75.199179       total sum
# 7          8.000000        2.828427        Unweighted events, alpha=27.342006
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          82.542918       13.551156       total sum
# 8          37.000000       6.082763        Unweighted events, alpha=2.230890
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          255.547104      154.608792      total sum
# 9          3.000000        1.732051        Unweighted events, alpha=85.182368
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         80.604894       14.770713       total sum
# 10         30.000000       5.477226        Unweighted events, alpha=2.686830
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         85.456638       8.832359        total sum
# 11         94.000000       9.695360        Unweighted events, alpha=0.909113
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         78.364683       15.028174       total sum
# 12         27.000000       5.196152        Unweighted events, alpha=2.902396
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         73.429627       9.104910        total sum
# 13         65.000000       8.062258        Unweighted events, alpha=1.129687
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         83.967825       12.388938       total sum
# 14         46.000000       6.782330        Unweighted events, alpha=1.825387
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         60.329059       9.694526        total sum
# 15         39.000000       6.244998        Unweighted events, alpha=1.546899
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         74.408632       12.714491       total sum
# 16         34.000000       5.830952        Unweighted events, alpha=2.188489
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         66.536214       12.593453       total sum
# 17         28.000000       5.291503        Unweighted events, alpha=2.376293
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         52.520249       8.155547        total sum
# 18         41.000000       6.403124        Unweighted events, alpha=1.280982
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         76.042156       10.943040       total sum
# 19         48.000000       6.928203        Unweighted events, alpha=1.584212
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         75.205080       22.211344       total sum
# 20         11.000000       3.316625        Unweighted events, alpha=6.836825
#   => Total parameter prop_binmuJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         62.899766       13.353696       total sum
# 21         22.000000       4.690416        Unweighted events, alpha=2.859080
#   => Total parameter prop_binmuJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         68.532578       14.551464       total sum
# 22         22.000000       4.690416        Unweighted events, alpha=3.115117
#   => Total parameter prop_binmuJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         63.906826       12.844571       total sum
# 23         25.000000       5.000000        Unweighted events, alpha=2.556273
#   => Total parameter prop_binmuJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         58.651069       12.122103       total sum
# 24         23.000000       4.795832        Unweighted events, alpha=2.550046
#   => Total parameter prop_binmuJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         47.145030       7.515427        total sum
# 25         39.000000       6.244998        Unweighted events, alpha=1.208847
#   => Total parameter prop_binmuJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         75.803047       29.976852       total sum
# 26         6.000000        2.449490        Unweighted events, alpha=12.633841
#   => Total parameter prop_binmuJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         38.463426       6.250641        total sum
# 27         38.000000       6.164414        Unweighted events, alpha=1.012195
#   => Total parameter prop_binmuJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         97.956050       36.632698       total sum
# 28         7.000000        2.645751        Unweighted events, alpha=13.993721
#   => Total parameter prop_binmuJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         30.413530       9.121548        total sum
# 29         11.000000       3.316625        Unweighted events, alpha=2.764866
#   => Total parameter prop_binmuJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         36.477523       5.806970        total sum
# 30         39.000000       6.244998        Unweighted events, alpha=0.935321
#   => Total parameter prop_binmuJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         53.129848       11.658933       total sum
# 31         21.000000       4.582576        Unweighted events, alpha=2.529993
#   => Total parameter prop_binmuJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         26.348420       5.999219        total sum
# 32         19.000000       4.358899        Unweighted events, alpha=1.386759
#   => Total parameter prop_binmuJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         36.404353       6.967878        total sum
# 33         27.000000       5.196152        Unweighted events, alpha=1.348309
#   => Total parameter prop_binmuJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         26.414248       7.241467        total sum
# 34         13.000000       3.605551        Unweighted events, alpha=2.031865
#   => Total parameter prop_binmuJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         50.376636       14.825226       total sum
# 35         12.000000       3.464102        Unweighted events, alpha=4.198053
#   => Total parameter prop_binmuJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         34.106490       10.415657       total sum
# 36         11.000000       3.316625        Unweighted events, alpha=3.100590
#   => Total parameter prop_binmuJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         25.837415       7.644782        total sum
# 37         11.000000       3.316625        Unweighted events, alpha=2.348856
#   => Total parameter prop_binmuJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         22.522950       3.718430        total sum
# 38         37.000000       6.082763        Unweighted events, alpha=0.608728
#   => Total parameter prop_binmuJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         19.564263       3.494654        total sum
# 39         31.000000       5.567764        Unweighted events, alpha=0.631105
#   => Total parameter prop_binmuJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .   done.
# Importing combined pdf model_s
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-TxTUej.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
# Redefining the POIs to be: RooArgSet:: = (r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF)
#
#   RooFitResult: minimized FCN value: -19868.1, estimated distance to minimum: 0.000145183
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_bineleJets_proc_OtherSampleBkgPhoton    1.0000e+00
#   n_exp_binmuJets_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_bineleJets_bin0_In    0.0000e+00
#   prop_bineleJets_bin10_In    0.0000e+00
#   prop_bineleJets_bin11_In    0.0000e+00
#   prop_bineleJets_bin12_In    0.0000e+00
#   prop_bineleJets_bin13_In    0.0000e+00
#   prop_bineleJets_bin14_In    0.0000e+00
#   prop_bineleJets_bin15_In    0.0000e+00
#   prop_bineleJets_bin16_In    0.0000e+00
#   prop_bineleJets_bin17_In    0.0000e+00
#   prop_bineleJets_bin18_In    0.0000e+00
#   prop_bineleJets_bin19_In    0.0000e+00
#   prop_bineleJets_bin1_In    0.0000e+00
#   prop_bineleJets_bin20_In    0.0000e+00
#   prop_bineleJets_bin21_In    0.0000e+00
#   prop_bineleJets_bin22_In    0.0000e+00
#   prop_bineleJets_bin23_In    0.0000e+00
#   prop_bineleJets_bin24_In    0.0000e+00
#   prop_bineleJets_bin25_In    0.0000e+00
#   prop_bineleJets_bin26_In    0.0000e+00
#   prop_bineleJets_bin27_In    0.0000e+00
#   prop_bineleJets_bin28_In    0.0000e+00
#   prop_bineleJets_bin29_In    0.0000e+00
#   prop_bineleJets_bin2_In    0.0000e+00
#   prop_bineleJets_bin30_In    0.0000e+00
#   prop_bineleJets_bin31_In    0.0000e+00
#   prop_bineleJets_bin32_In    0.0000e+00
#   prop_bineleJets_bin33_In    0.0000e+00
#   prop_bineleJets_bin34_In    0.0000e+00
#   prop_bineleJets_bin35_In    0.0000e+00
#   prop_bineleJets_bin36_In    0.0000e+00
#   prop_bineleJets_bin37_In    0.0000e+00
#   prop_bineleJets_bin38_In    0.0000e+00
#   prop_bineleJets_bin39_In    0.0000e+00
#   prop_bineleJets_bin3_In    0.0000e+00
#   prop_bineleJets_bin4_In    0.0000e+00
#   prop_bineleJets_bin5_In    0.0000e+00
#   prop_bineleJets_bin6_In    0.0000e+00
#   prop_bineleJets_bin7_In    0.0000e+00
#   prop_bineleJets_bin8_In    0.0000e+00
#   prop_bineleJets_bin9_In    0.0000e+00
#   prop_binmuJets_bin0_In    0.0000e+00
#   prop_binmuJets_bin10_In    0.0000e+00
#   prop_binmuJets_bin11_In    0.0000e+00
#   prop_binmuJets_bin12_In    0.0000e+00
#   prop_binmuJets_bin13_In    0.0000e+00
#   prop_binmuJets_bin14_In    0.0000e+00
#   prop_binmuJets_bin15_In    0.0000e+00
#   prop_binmuJets_bin16_In    0.0000e+00
#    prop_binmuJets_bin7    0.0000e+00   -6.7508e-01 +/-  3.20e-01  <none>
#    prop_binmuJets_bin8    0.0000e+00   -6.3105e-01 +/-  5.68e-01  <none>
#    prop_binmuJets_bin9    0.0000e+00   -5.7546e-01 +/-  1.64e-01  <none>
#                      r    1.0000e+00    2.7686e+00 +/-  7.05e-02  <none>
#
# Running Minos for POI
# Run Minos in  Real time 0:00:00, CP time 0.070
#
#
#   RooFitResult: minimized FCN value: -19868.1, estimated distance to minimum: 0.000145183
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_bineleJets_proc_OtherSampleBkgPhoton    1.0000e+00
#   n_exp_binmuJets_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_bineleJets_bin0_In    0.0000e+00
#   prop_bineleJets_bin10_In    0.0000e+00
#   prop_bineleJets_bin11_In    0.0000e+00
#   prop_bineleJets_bin12_In    0.0000e+00
#   prop_bineleJets_bin13_In    0.0000e+00
#   prop_bineleJets_bin14_In    0.0000e+00
#   prop_bineleJets_bin15_In    0.0000e+00
#   prop_bineleJets_bin16_In    0.0000e+00
#   prop_bineleJets_bin17_In    0.0000e+00
#   prop_bineleJets_bin18_In    0.0000e+00
#   prop_bineleJets_bin19_In    0.0000e+00
#   prop_bineleJets_bin1_In    0.0000e+00
#   prop_bineleJets_bin20_In    0.0000e+00
#   prop_bineleJets_bin21_In    0.0000e+00
#   prop_bineleJets_bin22_In    0.0000e+00
#   prop_bineleJets_bin23_In    0.0000e+00
#   prop_bineleJets_bin24_In    0.0000e+00
#   prop_bineleJets_bin25_In    0.0000e+00
#   prop_bineleJets_bin26_In    0.0000e+00
#   prop_bineleJets_bin27_In    0.0000e+00
#   prop_bineleJets_bin28_In    0.0000e+00
#   prop_bineleJets_bin29_In    0.0000e+00
#   prop_bineleJets_bin2_In    0.0000e+00
#   prop_bineleJets_bin30_In    0.0000e+00
#   prop_bineleJets_bin31_In    0.0000e+00
#   prop_bineleJets_bin32_In    0.0000e+00
#   prop_bineleJets_bin33_In    0.0000e+00
#   prop_bineleJets_bin34_In    0.0000e+00
#   prop_bineleJets_bin35_In    0.0000e+00
#   prop_bineleJets_bin36_In    0.0000e+00
#   prop_bineleJets_bin37_In    0.0000e+00
#   prop_bineleJets_bin38_In    0.0000e+00
#   prop_bineleJets_bin39_In    0.0000e+00
#   prop_bineleJets_bin3_In    0.0000e+00
#   prop_bineleJets_bin4_In    0.0000e+00
#   prop_bineleJets_bin5_In    0.0000e+00
#   prop_bineleJets_bin6_In    0.0000e+00
#   prop_bineleJets_bin7_In    0.0000e+00
#   prop_bineleJets_bin8_In    0.0000e+00
#   prop_bineleJets_bin9_In    0.0000e+00
#   prop_binmuJets_bin0_In    0.0000e+00
#   prop_binmuJets_bin10_In    0.0000e+00
#   prop_binmuJets_bin11_In    0.0000e+00
#   prop_binmuJets_bin12_In    0.0000e+00
#   prop_binmuJets_bin13_In    0.0000e+00
#   prop_binmuJets_bin14_In    0.0000e+00
#   prop_binmuJets_bin15_In    0.0000e+00
#   prop_binmuJets_bin16_In    0.0000e+00
#   prop_binmuJets_bin17_In    0.0000e+00
#   prop_binmuJets_bin18_In    0.0000e+00
#   prop_binmuJets_bin19_In    0.0000e+00
#   prop_binmuJets_bin1_In    0.0000e+00
#   prop_binmuJets_bin20_In    0.0000e+00
#   prop_binmuJets_bin21_In    0.0000e+00
#   prop_binmuJets_bin22_In    0.0000e+00
#   prop_binmuJets_bin23_In    0.0000e+00
#   prop_binmuJets_bin24_In    0.0000e+00
#   prop_binmuJets_bin25_In    0.0000e+00
#   prop_binmuJets_bin26_In    0.0000e+00
#   prop_binmuJets_bin27_In    0.0000e+00
#   prop_binmuJets_bin28_In    0.0000e+00
#   prop_binmuJets_bin29_In    0.0000e+00
#   prop_binmuJets_bin2_In    0.0000e+00
#   prop_binmuJets_bin30_In    0.0000e+00
#   prop_binmuJets_bin31_In    0.0000e+00
#   prop_binmuJets_bin32_In    0.0000e+00
#   prop_binmuJets_bin33_In    0.0000e+00
#   prop_binmuJets_bin34_In    0.0000e+00
#   prop_binmuJets_bin35_In    0.0000e+00
#   prop_binmuJets_bin36_In    0.0000e+00
#   prop_binmuJets_bin37_In    0.0000e+00
#   prop_binmuJets_bin38_In    0.0000e+00
#   prop_binmuJets_bin39_In    0.0000e+00
#   prop_binmuJets_bin3_In    0.0000e+00
#   prop_binmuJets_bin4_In    0.0000e+00
#   prop_binmuJets_bin5_In    0.0000e+00
#   prop_binmuJets_bin6_In    0.0000e+00
#   prop_binmuJets_bin7_In    0.0000e+00
#   prop_binmuJets_bin8_In    0.0000e+00
#   prop_binmuJets_bin9_In    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue (+HiError,-LoError)    GblCorr.
#   --------------------  ------------  ----------------------------------  --------
#      WGammaBkgPhotonSF    0.0000e+00    1.4183e+00         +/-  6.15e-02  <none>
#      ZGammaBkgPhotonSF    0.0000e+00    8.9612e-01         +/-  6.27e-02  <none>
#   prop_bineleJets_bin0    0.0000e+00   -1.0160e+00         +/-  3.36e-01  <none>
#   prop_bineleJets_bin1    0.0000e+00   -7.6117e-01         +/-  2.73e-01  <none>
#   prop_bineleJets_bin10    0.0000e+00   -9.9856e-01         +/-  4.27e-01  <none>
#   prop_bineleJets_bin11    0.0000e+00   -1.1852e+00         +/-  3.16e-01  <none>
#   prop_bineleJets_bin12    0.0000e+00   -1.0604e+00         +/-  4.72e-01  <none>
#   prop_bineleJets_bin13    0.0000e+00    8.1690e-02         +/-  5.39e-01  <none>
#   prop_bineleJets_bin14    0.0000e+00    3.2486e-01         +/-  6.49e-01  <none>
#   prop_bineleJets_bin15    0.0000e+00    7.1612e-01         +/-  6.64e-01  <none>
#   prop_bineleJets_bin16    0.0000e+00   -1.1043e+00         +/-  5.54e-01  <none>
#   prop_bineleJets_bin17    0.0000e+00   -1.7068e-01         +/-  5.00e-01  <none>
#   prop_bineleJets_bin18    0.0000e+00    5.5865e-01         +/-  4.51e-01  <none>
#   prop_bineleJets_bin19    0.0000e+00    8.2302e-01         +/-  5.03e-01  <none>
#   prop_bineleJets_bin2    0.0000e+00   -2.1330e-01         +/-  4.23e-01  <none>
#   prop_bineleJets_bin20    0.0000e+00    4.7555e-01         +/-  4.98e-01  <none>
#   prop_bineleJets_bin21    0.0000e+00   -1.8009e+00         +/-  1.67e-01  <none>
#   prop_bineleJets_bin22    0.0000e+00    4.7669e-01         +/-  5.18e-01  <none>
#   prop_bineleJets_bin23    0.0000e+00    1.5521e+00         +/-  5.27e-01  <none>
#   prop_bineleJets_bin24    0.0000e+00   -2.7376e-01         +/-  4.96e-01  <none>
#   prop_bineleJets_bin25    0.0000e+00   -1.2440e-01         +/-  5.09e-01  <none>
#   prop_bineleJets_bin26    0.0000e+00   -9.0973e-01         +/-  3.25e-01  <none>
#   prop_bineleJets_bin27    0.0000e+00   -4.0728e-01         +/-  4.83e-01  <none>
#   prop_bineleJets_bin28    0.0000e+00   -3.0285e-01         +/-  4.99e-01  <none>
#   prop_bineleJets_bin29    0.0000e+00    2.1449e+00         +/-  5.52e-01  <none>
#   prop_bineleJets_bin3    0.0000e+00    1.7647e+00         +/-  6.11e-01  <none>
#   prop_bineleJets_bin30    0.0000e+00    5.5036e-01         +/-  5.22e-01  <none>
#   prop_bineleJets_bin31    0.0000e+00    2.0015e-01         +/-  5.20e-01  <none>
#   prop_bineleJets_bin32    0.0000e+00    2.1031e+00         +/-  5.62e-01  <none>
#   prop_bineleJets_bin33    0.0000e+00    1.3552e-01         +/-  5.09e-01  <none>
#   prop_bineleJets_bin34    0.0000e+00   -8.8533e-01         +/-  1.64e-01  <none>
#   prop_bineleJets_bin35    0.0000e+00   -1.6645e+00         +/-  1.78e-01  <none>
#   prop_bineleJets_bin36    0.0000e+00    6.9641e-02         +/-  2.98e-01  <none>
#   prop_bineleJets_bin37    0.0000e+00    3.9491e-01         +/-  5.08e-01  <none>
#   prop_bineleJets_bin38    0.0000e+00    3.5959e-01         +/-  5.11e-01  <none>
#   prop_bineleJets_bin39    0.0000e+00    1.6918e+00         +/-  5.27e-01  <none>
#   prop_bineleJets_bin4    0.0000e+00    5.5196e-01         +/-  5.34e-01  <none>
#   prop_bineleJets_bin5    0.0000e+00   -4.1590e-01         +/-  1.87e-01  <none>
#   prop_bineleJets_bin6    0.0000e+00    9.7828e-01         +/-  5.38e-01  <none>
#   prop_bineleJets_bin7    0.0000e+00   -1.8890e+00         +/-  3.08e-01  <none>
#   prop_bineleJets_bin8    0.0000e+00   -1.5890e+00         +/-  4.19e-01  <none>
#   prop_bineleJets_bin9    0.0000e+00   -1.3903e+00         +/-  5.09e-01  <none>
#    prop_binmuJets_bin0    0.0000e+00   -3.8315e-01         +/-  4.86e-01  <none>
#    prop_binmuJets_bin1    0.0000e+00   -5.2974e-01         +/-  3.05e-01  <none>
#   prop_binmuJets_bin10    0.0000e+00    4.2551e-01         +/-  5.96e-01  <none>
#   prop_binmuJets_bin11    0.0000e+00    4.8250e-01         +/-  6.02e-01  <none>
#   prop_binmuJets_bin12    0.0000e+00   -7.7839e-02         +/-  5.89e-01  <none>
#   prop_binmuJets_bin13    0.0000e+00    1.1032e+00         +/-  6.02e-01  <none>
#   prop_binmuJets_bin14    0.0000e+00   -2.8330e-01         +/-  5.53e-01  <none>
#   prop_binmuJets_bin15    0.0000e+00    9.5531e-01         +/-  5.59e-01  <none>
#   prop_binmuJets_bin16    0.0000e+00   -8.1331e-01         +/-  5.09e-01  <none>
#   prop_binmuJets_bin17    0.0000e+00   -9.5574e-01         +/-  4.99e-01  <none>
#   prop_binmuJets_bin18    0.0000e+00   -3.3038e-01         +/-  5.25e-01  <none>
#   prop_binmuJets_bin19    0.0000e+00   -1.8854e-01         +/-  5.24e-01  <none>
#    prop_binmuJets_bin2    0.0000e+00   -3.0483e-01         +/-  6.28e-01  <none>
#   prop_binmuJets_bin20    0.0000e+00   -7.6800e-01         +/-  4.45e-01  <none>
#   prop_binmuJets_bin21    0.0000e+00   -2.3241e+00         +/-  4.65e-01  <none>
#   prop_binmuJets_bin22    0.0000e+00   -1.2523e+00         +/-  4.75e-01  <none>
#   prop_binmuJets_bin23    0.0000e+00    6.4202e-01         +/-  5.24e-01  <none>
#   prop_binmuJets_bin24    0.0000e+00    1.8843e-01         +/-  5.08e-01  <none>
#   prop_binmuJets_bin25    0.0000e+00   -6.5991e-01         +/-  5.08e-01  <none>
#   prop_binmuJets_bin26    0.0000e+00   -1.3719e+00         +/-  3.71e-01  <none>
#   prop_binmuJets_bin27    0.0000e+00   -4.8219e-01         +/-  5.10e-01  <none>
#   prop_binmuJets_bin28    0.0000e+00   -1.5301e+00         +/-  3.20e-01  <none>
#   prop_binmuJets_bin29    0.0000e+00    4.4509e-03         +/-  5.04e-01  <none>
#    prop_binmuJets_bin3    0.0000e+00   -1.5537e-01         +/-  6.03e-01  <none>
#   prop_binmuJets_bin30    0.0000e+00    9.4418e-01         +/-  5.39e-01  <none>
#   prop_binmuJets_bin31    0.0000e+00    5.1326e-01         +/-  5.14e-01  <none>
#   prop_binmuJets_bin32    0.0000e+00    6.4171e-01         +/-  5.23e-01  <none>
#   prop_binmuJets_bin33    0.0000e+00   -1.3509e+00         +/-  4.80e-01  <none>
#   prop_binmuJets_bin34    0.0000e+00    5.1659e-02         +/-  4.98e-01  <none>
#   prop_binmuJets_bin35    0.0000e+00   -6.5504e-01         +/-  4.60e-01  <none>
#   prop_binmuJets_bin36    0.0000e+00   -7.1920e-01         +/-  4.73e-01  <none>
#   prop_binmuJets_bin37    0.0000e+00   -4.1517e-01         +/-  4.87e-01  <none>
#   prop_binmuJets_bin38    0.0000e+00    8.6622e-01         +/-  5.31e-01  <none>
#   prop_binmuJets_bin39    0.0000e+00    3.3758e-01         +/-  5.19e-01  <none>
#    prop_binmuJets_bin4    0.0000e+00   -5.5614e-01         +/-  5.81e-01  <none>
#    prop_binmuJets_bin5    0.0000e+00    1.9261e+00         +/-  6.23e-01  <none>
#    prop_binmuJets_bin6    0.0000e+00   -2.5333e-01         +/-  5.96e-01  <none>
#    prop_binmuJets_bin7    0.0000e+00   -6.7508e-01         +/-  3.20e-01  <none>
#    prop_binmuJets_bin8    0.0000e+00   -6.3105e-01         +/-  5.68e-01  <none>
#    prop_binmuJets_bin9    0.0000e+00   -5.7546e-01         +/-  1.64e-01  <none>
#                      r    1.0000e+00    2.7686e+00 (+7.18e-02,-6.92e-02)  <none>
#  --- FitDiagnostics ---
# Best fit r: 2.76865  -0.06923/+0.0717404  (68% CL)
# Done in 0.01 min (cpu), 0.02 min (real)
# Printing Message Summary From ... combine_logger.out
# ----------------------------------------------
# Messages of type INFO : 9
# Messages of type DEBUG : 2
# Messages of type ERROR : 0
# ----------------------------------------------
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=-1
# DEBUG: (function: improveOnce) CascadeMinimizer.cc: 196 -- Minimization ended with latest status != 0 or 1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: doFit) FitterAlgoBase.cc: 318 -- Running Minos for POI r
# DEBUG: (function: runSpecific) FitDiagnostics.cc: 412 -- Fit S+B, status = 0, numBadNLL = 0, covariance quality = 3

# %%
# !combine -M FitDiagnostics -n CR2  datacard_CR2.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF -v2

# %%
# !combine -M FitDiagnostics -n CR3  datacard_CR3.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF -v2

# %%
# !pwd
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/ttgammaCombineFitting/Datacard_fourTemplate_bothChannel_2016

# %%
# !combine -M MultiDimFit -n CR4  datacard_CR4.txt --redefineSignalPOIs r,WGammaSF

# %%
# !combine -M MultiDimFit -n CR5  datacard_CR5.txt --redefineSignalPOIs r,WGammaSF

# %%
# !combine -M MultiDimFit -n CR6  datacard_CR6.txt --redefineSignalPOIs r,WGammaSF

# %%
# !combine -M MultiDimFit -n CR7  datacard_CR7.txt --redefineSignalPOIs r,WGammaSF

# %%
# !combine -M MultiDimFit -n SR8  datacard_SR8.txt --redefineSignalPOIs r,WGammaSF

# %%
# f_input_shapes_TH1 = ROOT.TFile("simple-shapes-TH1_input.root","READ")
# f_input_shapes_TH1.ls()

# %%
# h_background = f_input_shapes_TH1.Get("background")
# h_background.SetLineColor(ROOT.kBlack)
# print h_background.Integral(-1,-1)

# h_background_alphaUp = f_input_shapes_TH1.Get("background_alphaUp")
# h_background_alphaUp.SetLineColor(ROOT.kBlue)
# print h_background_alphaUp.Integral(-1,-1)

# h_background_alphaDown = f_input_shapes_TH1.Get("background_alphaDown")
# h_background_alphaDown.SetLineColor(ROOT.kRed)
# print h_background_alphaDown.Integral(-1,-1)

# c = ROOT.TCanvas()
# h_background_alphaDown.Draw()
# h_background.Draw("same")
# h_background_alphaUp.Draw("same")

# c.Draw()

# %%
# h_signal = f_input_shapes_TH1.Get("signal")
# h_signal.SetLineColor(ROOT.kBlack)
# print h_signal.Integral()

# h_signal_sigmaUp = f_input_shapes_TH1.Get("signal_sigmaUp")
# h_signal_sigmaUp.SetLineColor(ROOT.kBlue)
# print h_signal_sigmaUp.Integral()

# h_signal_sigmaDown = f_input_shapes_TH1.Get("signal_sigmaDown")
# h_signal_sigmaDown.SetLineColor(ROOT.kRed)
# print h_signal_sigmaDown.Integral()

# c = ROOT.TCanvas()
# h_signal_sigmaDown.Draw()
# h_signal.Draw("same")
# h_signal_sigmaUp.Draw("same")

# c.Draw()

# %% [markdown]
# The combine tool converts datacards into a RooWorkspace to build the likelihood

# %%
# !text2workspace.py ttgamma_sys.txt

# %%
# f_shapes_TH1 = ROOT.TFile("ttgamma_sys.root","READ")
# w_shapes_TH1 = f_shapes_TH1.Get("w")
# w_shapes_TH1.Print()

# %% [markdown]
# The workspace contains "model_s" i.e. the likelihood function, which is composed of the observable "CMS_th1x" which is split in several channels, the POI "r" and several nuisance parameters. Lets see how combine smoothly morphs the shape of the background as a function of the nuisance parameter alpha:

# %%
# shapeBkg = w_shapes_TH1.pdf("shapeBkg_mybin_background_morph")
# th1x = w_shapes_TH1.var("CMS_th1x")
# plot_th1x = th1x.frame()
# alpha = w_shapes_TH1.var("alpha")
# alpha.setVal(0.0)
# shapeBkg.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kBlack))
# alpha.setVal(0.5)
# shapeBkg.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kGreen))
# alpha.setVal(1.0)
# shapeBkg.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kRed))
# alpha.setVal(2.0)
# shapeBkg.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kOrange))

# c2 = ROOT.TCanvas()
# plot_th1x.Draw()
# c2.Draw()

# %%
# shapeSig = w_shapes_TH1.pdf("shapeSig_mybin_signal_morph")
# th1x = w_shapes_TH1.var("CMS_th1x")
# plot_th1x = th1x.frame()
# sigma = w_shapes_TH1.var("sigma")
# sigma.setVal(0.0)
# shapeSig.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kBlack))
# sigma.setVal(0.5)
# shapeSig.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kGreen))
# sigma.setVal(1.0)
# shapeSig.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kRed))
# sigma.setVal(2.0)
# shapeSig.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kOrange))

# c2 = ROOT.TCanvas()
# plot_th1x.Draw()
# c2.Draw()

# %% [markdown]
# Prints the workspace normalization

# %%
# !python ../test/printWorkspaceNormalisations.py ttgamma_sys.root

# %% [markdown]
# If we redefine POI then it will be float and can take any values. If we have things in datacard then everything will be used to produce the best r value.
# The option "--run both" tells combine to run both expected and observed limits.You can see we have computed an observed limit on r, and also the nominal expected, and +/- 1 and 2 sigma expected limits. [-s -1 == random seed]

# %%
# !combine -M MultiDimFit -n Nabin ttgamma_sys.txt

# %%
# !combine -n LimitTestNabin -M AsymptoticLimits ttgamma_sys.root --run both

# %%
# asymptoticfile = ROOT.TFile("higgsCombineLimitTestNabin.AsymptoticLimits.mH120.root")
# limit = asymptoticfile.Get("limit")
# for i in xrange(limit.GetEntries()):
#     limit.GetEntry(i)
#     print i,limit.mh,limit.limit

# %% [markdown]
# 1-sigma ==  68%, 2-sigma == 95%, 3-sigma == 99.7%. The higher sigma value means that the discovery is less likely to be accidently a mistake or 'random chance'.
# How do we test hypothesis?
# Null hypothesis  means A and B are not connected. Research hypothesis means A and B are connected. First assume Null hypothesis is true. Then calculate the probability of obtaining data as extreme as the kind they are observing.
# P-value close to zero means Null hypothesis is false, however, larger p-value means Null hypothesis is true. For example, p-value = 5% means that chance that the data sample being tested is drawn from where Null hypothesis is true.
# Next example, the chances of a result being greater than 1-sigma is 15.9%, 2-sigma is 2.3%, 3-sigma is 0.2%.
