# %%
import ROOT
import os

# %%
# !combine --help
# !pwd
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/ttgammaCombineFitting/Datacard_fourTemplate_2016

# %% [markdown]
# ### Important:
# signal strength r = (number of signal events / number of expected signal events).
# It scales the signal up and down in such a way after considering all the nuisance parameters. Signal strength * signal = eg. expectation of number of events in the cut and count physics process.
# data_obs = e.g., observed number of events in the data
# POI = e.g., ttgamma crossection which is burried in signal histogram.
#
# ### FitDiagnostics:
# performs maximum likelihood fits to extract the signal yield and provide diagnostic tools such as pre and post-fit models and correlations
#
# ### MultiDimFit:
# perform maximum likelihood fits in multiple parameters and likelihood scans

# %% [markdown]
# ### Doing exercise for misIDEle

# %%
# myfile = ROOT.TFile("MyFiles/pho_looseCRe2e0plots_ele_2016/myMisIDEle_Prefit.root")
# myfile.ls()
# MyDataHist = myfile.Get("myData")
# MisIDEle   = myfile.Get("myMisIDEle")
# MisIDEle.SetLineWidth(2)
# MisIDEle.SetLineColor(2)
# OtherHist  = myfile.Get("myBackground")
# OtherHist.SetLineWidth(2)
# OtherHist.SetLineColor(3)

# c = ROOT.TCanvas()
# MyDataHist.Draw("hist")
# MisIDEle.Draw("same") # red
# OtherHist.Draw("same") # yellow
# c.Draw()

# %%
# !text2workspace.py datacard_AR.txt

# %%
# f_shapes_TH1 = ROOT.TFile("datacard_AR.root","READ")
# w_shapes_TH1 = f_shapes_TH1.Get("w")
# w_shapes_TH1.Print()

# %%
# !python ../test/printWorkspaceNormalisations.py datacard_AR.root

# %%
# !combine -M MultiDimFit -n AR  datacard_AR.txt --redefineSignalPOIs r,mybackground_norm

# %%
# !combine -M MultiDimFit -n AR  datacard_AR.txt --redefineSignalPOIs r,WGammaSF

# %%
# !combine -M FitDiagnostics -n CR123  datacard_CR123.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF -v2
# Out:
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Creating pdfs for individual modes (1): Channel mybin will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmybin
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          177.953359      48.429815       total sum
# 0          14.000000       3.741657        Unweighted events, alpha=12.710954
#   => Total parameter prop_binmybin_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          163.547879      63.627665       total sum
# 1          7.000000        2.645751        Unweighted events, alpha=23.363983
#   => Total parameter prop_binmybin_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          119.233120      32.696230       total sum
# 2          13.000000       3.605551        Unweighted events, alpha=9.171778
#   => Total parameter prop_binmybin_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          114.010990      12.932605       total sum
# 3          78.000000       8.831761        Unweighted events, alpha=1.461679
#   => Total parameter prop_binmybin_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          125.073402      15.326666       total sum
# 4          67.000000       8.185353        Unweighted events, alpha=1.866767
#   => Total parameter prop_binmybin_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          238.490944      112.972914      total sum
# 5          4.000000        2.000000        Unweighted events, alpha=59.622736
#   => Total parameter prop_binmybin_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          203.536613      79.660166       total sum
# 6          7.000000        2.645751        Unweighted events, alpha=29.076659
#   => Total parameter prop_binmybin_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          239.009506      59.933471       total sum
# 7          16.000000       4.000000        Unweighted events, alpha=14.938094
#   => Total parameter prop_binmybin_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          243.014374      67.857873       total sum
# 8          13.000000       3.605551        Unweighted events, alpha=18.693413
#   => Total parameter prop_binmybin_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          156.207233      17.907914       total sum
# 9          76.000000       8.717798        Unweighted events, alpha=2.055358
#   => Total parameter prop_binmybin_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         213.570869      36.491030       total sum
# 10         34.000000       5.830952        Unweighted events, alpha=6.281496
#   => Total parameter prop_binmybin_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         335.682251      71.626638       total sum
# 11         22.000000       4.690416        Unweighted events, alpha=15.258284
#   => Total parameter prop_binmybin_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         409.292633      38.665021       total sum
# 12         112.000000      10.583005       Unweighted events, alpha=3.654399
#   => Total parameter prop_binmybin_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         721.214890      53.653583       total sum
# 13         181.000000      13.453624       Unweighted events, alpha=3.984613
#   => Total parameter prop_binmybin_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1070.967529     37.423875       total sum
# 14         819.000000      28.618176       Unweighted events, alpha=1.307653
#   => Total parameter prop_binmybin_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         1284.266052     51.091069       total sum
# 15         632.000000      25.139610       Unweighted events, alpha=2.032067
#   => Total parameter prop_binmybin_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         848.905487      49.084781       total sum
# 16         299.000000      17.291616       Unweighted events, alpha=2.839149
#   => Total parameter prop_binmybin_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         387.698380      28.765156       total sum
# 17         182.000000      13.490738       Unweighted events, alpha=2.130211
#   => Total parameter prop_binmybin_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         233.106888      29.960294       total sum
# 18         61.000000       7.810250        Unweighted events, alpha=3.821424
#   => Total parameter prop_binmybin_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         226.968559      69.821594       total sum
# 19         11.000000       3.316625        Unweighted events, alpha=20.633505
#   => Total parameter prop_binmybin_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         146.835796      34.582915       total sum
# 20         18.000000       4.242641        Unweighted events, alpha=8.157544
#   => Total parameter prop_binmybin_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         257.519493      97.836800       total sum
# 21         7.000000        2.645751        Unweighted events, alpha=36.788499
#   => Total parameter prop_binmybin_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         87.533733       13.210975       total sum
# 22         44.000000       6.633250        Unweighted events, alpha=1.989403
#   => Total parameter prop_binmybin_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         69.376057       8.369830        total sum
# 23         69.000000       8.306624        Unweighted events, alpha=1.005450
#   => Total parameter prop_binmybin_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         89.156319       11.416256       total sum
# 24         61.000000       7.810250        Unweighted events, alpha=1.461579
#   => Total parameter prop_binmybin_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         73.271654       11.135544       total sum
# 25         43.000000       6.557439        Unweighted events, alpha=1.703992
#   => Total parameter prop_binmybin_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         94.349318       33.402916       total sum
# 26         8.000000        2.828427        Unweighted events, alpha=11.793665
#   => Total parameter prop_binmybin_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         86.836277       13.301767       total sum
# 27         43.000000       6.557439        Unweighted events, alpha=2.019448
#   => Total parameter prop_binmybin_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         73.825112       11.003940       total sum
# 28         45.000000       6.708204        Unweighted events, alpha=1.640558
#   => Total parameter prop_binmybin_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         59.676437       8.769448        total sum
# 29         46.000000       6.782330        Unweighted events, alpha=1.297314
#   => Total parameter prop_binmybin_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         54.456443       8.945631        total sum
# 30         37.000000       6.082763        Unweighted events, alpha=1.471796
#   => Total parameter prop_binmybin_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         57.899238       8.904841        total sum
# 31         42.000000       6.480741        Unweighted events, alpha=1.378553
#   => Total parameter prop_binmybin_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         44.563216       6.332335        total sum
# 32         50.000000       7.071068        Unweighted events, alpha=0.891264
#   => Total parameter prop_binmybin_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         73.160058       36.393236       total sum
# 33         4.000000        2.000000        Unweighted events, alpha=18.290015
#   => Total parameter prop_binmybin_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         93.473884       63.554592       total sum
# 34         2.000000        1.414214        Unweighted events, alpha=46.736942
#   => Total parameter prop_binmybin_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         158.668900      58.452862       total sum
# 35         7.000000        2.645751        Unweighted events, alpha=22.666986
#   => Total parameter prop_binmybin_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         71.124382       33.215531       total sum
# 36         5.000000        2.236068        Unweighted events, alpha=14.224876
#   => Total parameter prop_binmybin_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         39.165412       8.517746        total sum
# 37         21.000000       4.582576        Unweighted events, alpha=1.865020
#   => Total parameter prop_binmybin_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         63.330733       15.319230       total sum
# 38         17.000000       4.123106        Unweighted events, alpha=3.725337
#   => Total parameter prop_binmybin_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         28.900288       5.834543        total sum
# 39         25.000000       5.000000        Unweighted events, alpha=1.156012
#   => Total parameter prop_binmybin_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .   done.
# Importing combined pdf model_s
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-9Feiat.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
# Redefining the POIs to be: RooArgSet:: = (r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF)
#
#   RooFitResult: minimized FCN value: -10463.2, estimated distance to minimum: 0.000105273
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_binmybin_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_binmybin_bin0_In    0.0000e+00
#   prop_binmybin_bin10_In    0.0000e+00
#   prop_binmybin_bin11_In    0.0000e+00
#   prop_binmybin_bin12_In    0.0000e+00
#   prop_binmybin_bin13_In    0.0000e+00
#   prop_binmybin_bin14_In    0.0000e+00
#   prop_binmybin_bin15_In    0.0000e+00
#   prop_binmybin_bin16_In    0.0000e+00
#   prop_binmybin_bin17_In    0.0000e+00
#   prop_binmybin_bin18_In    0.0000e+00
#   prop_binmybin_bin19_In    0.0000e+00
#   prop_binmybin_bin1_In    0.0000e+00
#   prop_binmybin_bin20_In    0.0000e+00
#   prop_binmybin_bin21_In    0.0000e+00
#   prop_binmybin_bin22_In    0.0000e+00
#   prop_binmybin_bin23_In    0.0000e+00
#   prop_binmybin_bin24_In    0.0000e+00
#   prop_binmybin_bin25_In    0.0000e+00
#   prop_binmybin_bin26_In    0.0000e+00
#   prop_binmybin_bin27_In    0.0000e+00
#   prop_binmybin_bin28_In    0.0000e+00
#   prop_binmybin_bin29_In    0.0000e+00
#   prop_binmybin_bin2_In    0.0000e+00
#   prop_binmybin_bin30_In    0.0000e+00
#   prop_binmybin_bin31_In    0.0000e+00
#   prop_binmybin_bin32_In    0.0000e+00
#   prop_binmybin_bin33_In    0.0000e+00
#   prop_binmybin_bin34_In    0.0000e+00
#   prop_binmybin_bin35_In    0.0000e+00
#   prop_binmybin_bin36_In    0.0000e+00
#   prop_binmybin_bin37_In    0.0000e+00
#   prop_binmybin_bin38_In    0.0000e+00
#   prop_binmybin_bin39_In    0.0000e+00
#   prop_binmybin_bin3_In    0.0000e+00
#   prop_binmybin_bin4_In    0.0000e+00
#   prop_binmybin_bin5_In    0.0000e+00
#   prop_binmybin_bin6_In    0.0000e+00
#   prop_binmybin_bin7_In    0.0000e+00
#   prop_binmybin_bin8_In    0.0000e+00
#   prop_binmybin_bin9_In    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#      WGammaBkgPhotonSF    0.0000e+00    1.5564e+00 +/-  1.04e-01  <none>
#      ZGammaBkgPhotonSF    0.0000e+00    6.0803e-01 +/-  1.53e-01  <none>
#     prop_binmybin_bin0    0.0000e+00   -9.6174e-01 +/-  4.14e-01  <none>
#     prop_binmybin_bin1    0.0000e+00   -1.6633e-01 +/-  3.78e-01  <none>
#    prop_binmybin_bin10    0.0000e+00    1.8216e-01 +/-  4.99e-01  <none>
#    prop_binmybin_bin11    0.0000e+00   -6.2635e-01 +/-  3.72e-01  <none>
#    prop_binmybin_bin12    0.0000e+00   -4.8131e-01 +/-  4.95e-01  <none>
#    prop_binmybin_bin13    0.0000e+00   -8.6456e-02 +/-  5.28e-01  <none>
#    prop_binmybin_bin14    0.0000e+00    7.9707e-01 +/-  6.58e-01  <none>
#    prop_binmybin_bin15    0.0000e+00    4.3531e-01 +/-  6.75e-01  <none>
#    prop_binmybin_bin16    0.0000e+00   -5.7306e-01 +/-  5.67e-01  <none>
#    prop_binmybin_bin17    0.0000e+00   -1.0866e+00 +/-  5.06e-01  <none>
#    prop_binmybin_bin18    0.0000e+00    3.8026e-01 +/-  4.71e-01  <none>
#    prop_binmybin_bin19    0.0000e+00   -4.0181e-01 +/-  3.00e-01  <none>
#     prop_binmybin_bin2    0.0000e+00    2.4986e-01 +/-  5.21e-01  <none>
#    prop_binmybin_bin20    0.0000e+00   -2.5929e-01 +/-  4.12e-01  <none>
#    prop_binmybin_bin21    0.0000e+00   -2.0327e+00 +/-  2.10e-01  <none>
#    prop_binmybin_bin22    0.0000e+00    1.0804e-01 +/-  5.37e-01  <none>
#    prop_binmybin_bin23    0.0000e+00    1.5562e+00 +/-  5.50e-01  <none>
#    prop_binmybin_bin24    0.0000e+00   -1.6540e-02 +/-  5.10e-01  <none>
#    prop_binmybin_bin25    0.0000e+00   -1.0036e+00 +/-  5.21e-01  <none>
#    prop_binmybin_bin26    0.0000e+00   -1.1122e+00 +/-  3.77e-01  <none>
#    prop_binmybin_bin27    0.0000e+00   -3.1262e-01 +/-  5.01e-01  <none>
#    prop_binmybin_bin28    0.0000e+00   -1.0546e+00 +/-  5.02e-01  <none>
#    prop_binmybin_bin29    0.0000e+00    1.5472e+00 +/-  5.54e-01  <none>
#     prop_binmybin_bin3    0.0000e+00    1.7728e+00 +/-  6.75e-01  <none>
#    prop_binmybin_bin30    0.0000e+00    5.3093e-02 +/-  5.28e-01  <none>
#    prop_binmybin_bin31    0.0000e+00   -4.5332e-02 +/-  5.26e-01  <none>
#    prop_binmybin_bin32    0.0000e+00    1.4254e+00 +/-  5.67e-01  <none>
#    prop_binmybin_bin33    0.0000e+00   -7.9851e-01 +/-  3.30e-01  <none>
#    prop_binmybin_bin34    0.0000e+00   -7.2803e-01 +/-  2.05e-01  <none>
#    prop_binmybin_bin35    0.0000e+00   -2.0051e+00 +/-  2.13e-01  <none>
#    prop_binmybin_bin36    0.0000e+00   -6.1233e-02 +/-  3.44e-01  <none>
#    prop_binmybin_bin37    0.0000e+00    5.7377e-01 +/-  5.18e-01  <none>
#    prop_binmybin_bin38    0.0000e+00   -1.0006e+00 +/-  4.48e-01  <none>
#    prop_binmybin_bin39    0.0000e+00    9.4291e-01 +/-  5.37e-01  <none>
#     prop_binmybin_bin4    0.0000e+00    9.8220e-01 +/-  6.00e-01  <none>
#     prop_binmybin_bin5    0.0000e+00    6.5539e-02 +/-  2.66e-01  <none>
#     prop_binmybin_bin6    0.0000e+00   -1.1201e-01 +/-  3.15e-01  <none>
#     prop_binmybin_bin7    0.0000e+00   -8.8305e-01 +/-  4.04e-01  <none>
#     prop_binmybin_bin8    0.0000e+00   -1.6738e+00 +/-  3.52e-01  <none>
#     prop_binmybin_bin9    0.0000e+00   -1.1667e+00 +/-  5.48e-01  <none>
#                      r    1.0000e+00    2.7628e+00 +/-  6.67e-02  <none>
#
# Running Minos for POI
# Run Minos in  Real time 0:00:00, CP time 0.010
#
#
#   RooFitResult: minimized FCN value: -10463.2, estimated distance to minimum: 0.000105273
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_binmybin_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_binmybin_bin0_In    0.0000e+00
#   prop_binmybin_bin10_In    0.0000e+00
#   prop_binmybin_bin11_In    0.0000e+00
#   prop_binmybin_bin12_In    0.0000e+00
#   prop_binmybin_bin13_In    0.0000e+00
#   prop_binmybin_bin14_In    0.0000e+00
#   prop_binmybin_bin15_In    0.0000e+00
#   prop_binmybin_bin16_In    0.0000e+00
#   prop_binmybin_bin17_In    0.0000e+00
#   prop_binmybin_bin18_In    0.0000e+00
#   prop_binmybin_bin19_In    0.0000e+00
#   prop_binmybin_bin1_In    0.0000e+00
#   prop_binmybin_bin20_In    0.0000e+00
#   prop_binmybin_bin21_In    0.0000e+00
#   prop_binmybin_bin22_In    0.0000e+00
#   prop_binmybin_bin23_In    0.0000e+00
#   prop_binmybin_bin24_In    0.0000e+00
#   prop_binmybin_bin25_In    0.0000e+00
#   prop_binmybin_bin26_In    0.0000e+00
#   prop_binmybin_bin27_In    0.0000e+00
#   prop_binmybin_bin28_In    0.0000e+00
#   prop_binmybin_bin29_In    0.0000e+00
#   prop_binmybin_bin2_In    0.0000e+00
#   prop_binmybin_bin30_In    0.0000e+00
#   prop_binmybin_bin31_In    0.0000e+00
#   prop_binmybin_bin32_In    0.0000e+00
#   prop_binmybin_bin33_In    0.0000e+00
#   prop_binmybin_bin34_In    0.0000e+00
#   prop_binmybin_bin35_In    0.0000e+00
#   prop_binmybin_bin36_In    0.0000e+00
#   prop_binmybin_bin37_In    0.0000e+00
#   prop_binmybin_bin38_In    0.0000e+00
#   prop_binmybin_bin39_In    0.0000e+00
#   prop_binmybin_bin3_In    0.0000e+00
#   prop_binmybin_bin4_In    0.0000e+00
#   prop_binmybin_bin5_In    0.0000e+00
#   prop_binmybin_bin6_In    0.0000e+00
#   prop_binmybin_bin7_In    0.0000e+00
#   prop_binmybin_bin8_In    0.0000e+00
#   prop_binmybin_bin9_In    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue (+HiError,-LoError)    GblCorr.
#   --------------------  ------------  ----------------------------------  --------
#      WGammaBkgPhotonSF    0.0000e+00    1.5564e+00         +/-  1.04e-01  <none>
#      ZGammaBkgPhotonSF    0.0000e+00    6.0803e-01         +/-  1.53e-01  <none>
#     prop_binmybin_bin0    0.0000e+00   -9.6174e-01         +/-  4.14e-01  <none>
#     prop_binmybin_bin1    0.0000e+00   -1.6633e-01         +/-  3.78e-01  <none>
#    prop_binmybin_bin10    0.0000e+00    1.8216e-01         +/-  4.99e-01  <none>
#    prop_binmybin_bin11    0.0000e+00   -6.2635e-01         +/-  3.72e-01  <none>
#    prop_binmybin_bin12    0.0000e+00   -4.8131e-01         +/-  4.95e-01  <none>
#    prop_binmybin_bin13    0.0000e+00   -8.6456e-02         +/-  5.28e-01  <none>
#    prop_binmybin_bin14    0.0000e+00    7.9707e-01         +/-  6.58e-01  <none>
#    prop_binmybin_bin15    0.0000e+00    4.3531e-01         +/-  6.75e-01  <none>
#    prop_binmybin_bin16    0.0000e+00   -5.7306e-01         +/-  5.67e-01  <none>
#    prop_binmybin_bin17    0.0000e+00   -1.0866e+00         +/-  5.06e-01  <none>
#    prop_binmybin_bin18    0.0000e+00    3.8026e-01         +/-  4.71e-01  <none>
#    prop_binmybin_bin19    0.0000e+00   -4.0181e-01         +/-  3.00e-01  <none>
#     prop_binmybin_bin2    0.0000e+00    2.4986e-01         +/-  5.21e-01  <none>
#    prop_binmybin_bin20    0.0000e+00   -2.5929e-01         +/-  4.12e-01  <none>
#    prop_binmybin_bin21    0.0000e+00   -2.0327e+00         +/-  2.10e-01  <none>
#    prop_binmybin_bin22    0.0000e+00    1.0804e-01         +/-  5.37e-01  <none>
#    prop_binmybin_bin23    0.0000e+00    1.5562e+00         +/-  5.50e-01  <none>
#    prop_binmybin_bin24    0.0000e+00   -1.6540e-02         +/-  5.10e-01  <none>
#    prop_binmybin_bin25    0.0000e+00   -1.0036e+00         +/-  5.21e-01  <none>
#    prop_binmybin_bin26    0.0000e+00   -1.1122e+00         +/-  3.77e-01  <none>
#    prop_binmybin_bin27    0.0000e+00   -3.1262e-01         +/-  5.01e-01  <none>
#    prop_binmybin_bin28    0.0000e+00   -1.0546e+00         +/-  5.02e-01  <none>
#    prop_binmybin_bin29    0.0000e+00    1.5472e+00         +/-  5.54e-01  <none>
#     prop_binmybin_bin3    0.0000e+00    1.7728e+00         +/-  6.75e-01  <none>
#    prop_binmybin_bin30    0.0000e+00    5.3093e-02         +/-  5.28e-01  <none>
#    prop_binmybin_bin31    0.0000e+00   -4.5332e-02         +/-  5.26e-01  <none>
#    prop_binmybin_bin32    0.0000e+00    1.4254e+00         +/-  5.67e-01  <none>
#    prop_binmybin_bin33    0.0000e+00   -7.9851e-01         +/-  3.30e-01  <none>
#    prop_binmybin_bin34    0.0000e+00   -7.2803e-01         +/-  2.05e-01  <none>
#    prop_binmybin_bin35    0.0000e+00   -2.0051e+00         +/-  2.13e-01  <none>
#    prop_binmybin_bin36    0.0000e+00   -6.1233e-02         +/-  3.44e-01  <none>
#    prop_binmybin_bin37    0.0000e+00    5.7377e-01         +/-  5.18e-01  <none>
#    prop_binmybin_bin38    0.0000e+00   -1.0006e+00         +/-  4.48e-01  <none>
#    prop_binmybin_bin39    0.0000e+00    9.4291e-01         +/-  5.37e-01  <none>
#     prop_binmybin_bin4    0.0000e+00    9.8220e-01         +/-  6.00e-01  <none>
#     prop_binmybin_bin5    0.0000e+00    6.5539e-02         +/-  2.66e-01  <none>
#     prop_binmybin_bin6    0.0000e+00   -1.1201e-01         +/-  3.15e-01  <none>
#     prop_binmybin_bin7    0.0000e+00   -8.8305e-01         +/-  4.04e-01  <none>
#     prop_binmybin_bin8    0.0000e+00   -1.6738e+00         +/-  3.52e-01  <none>
#     prop_binmybin_bin9    0.0000e+00   -1.1667e+00         +/-  5.48e-01  <none>
#                      r    1.0000e+00    2.7628e+00 (+6.77e-02,-6.57e-02)  <none>
#
#
#  --- FitDiagnostics ---
# Best fit r: 2.76283  -0.0656477/+0.0677706  (68% CL)
# Done in 0.00 min (cpu), 0.01 min (real)
# Printing Message Summary From ... combine_logger.out
# ----------------------------------------------
# Messages of type INFO : 9
# Messages of type DEBUG : 2
# Messages of type ERROR : 0
# ----------------------------------------------
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=-1
# DEBUG: (function: improveOnce) CascadeMinimizer.cc: 196 -- Minimization ended with latest status != 0 or 1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: doFit) FitterAlgoBase.cc: 318 -- Running Minos for POI r
# DEBUG: (function: runSpecific) FitDiagnostics.cc: 412 -- Fit S+B, status = 0, numBadNLL = 0, covariance quality = 3

# %%
# !combine -M FitDiagnostics -n CR1  datacard_CR1.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF -v2
# Out:
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Creating pdfs for individual modes (1): Channel mybin will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmybin
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          144.168633      47.848889       total sum
# 0          9.000000        3.000000        Unweighted events, alpha=16.018737
#   => Total parameter prop_binmybin_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          133.413374      63.252003       total sum
# 1          4.000000        2.000000        Unweighted events, alpha=33.353343
#   => Total parameter prop_binmybin_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          81.382341       31.625106       total sum
# 2          7.000000        2.645751        Unweighted events, alpha=11.626049
#   => Total parameter prop_binmybin_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          79.119495       12.072415       total sum
# 3          43.000000       6.557439        Unweighted events, alpha=1.839988
#   => Total parameter prop_binmybin_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          82.259844       13.986874       total sum
# 4          35.000000       5.916080        Unweighted events, alpha=2.350281
#   => Total parameter prop_binmybin_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          189.536371      112.778456      total sum
# 5          3.000000        1.732051        Unweighted events, alpha=63.178790
#   => Total parameter prop_binmybin_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          70.507397       13.898544       total sum
# 6          26.000000       5.099020        Unweighted events, alpha=2.711823
#   => Total parameter prop_binmybin_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          196.023695      59.582115       total sum
# 7          11.000000       3.316625        Unweighted events, alpha=17.820336
#   => Total parameter prop_binmybin_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          130.702858      34.096400       total sum
# 8          15.000000       3.872983        Unweighted events, alpha=8.713524
#   => Total parameter prop_binmybin_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          98.613464       14.517825       total sum
# 9          46.000000       6.782330        Unweighted events, alpha=2.143771
#   => Total parameter prop_binmybin_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         157.722862      35.673945       total sum
# 10         20.000000       4.472136        Unweighted events, alpha=7.886143
#   => Total parameter prop_binmybin_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         268.752670      71.067994       total sum
# 11         14.000000       3.741657        Unweighted events, alpha=19.196619
#   => Total parameter prop_binmybin_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         317.683777      37.109668       total sum
# 12         73.000000       8.544004        Unweighted events, alpha=4.351833
#   => Total parameter prop_binmybin_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         531.985115      42.128644       total sum
# 13         159.000000      12.609520       Unweighted events, alpha=3.345818
#   => Total parameter prop_binmybin_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         832.171288      33.287931       total sum
# 14         625.000000      25.000000       Unweighted events, alpha=1.331474
#   => Total parameter prop_binmybin_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         981.548759      46.985813       total sum
# 15         436.000000      20.880613       Unweighted events, alpha=2.251259
#   => Total parameter prop_binmybin_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         670.751915      46.419769       total sum
# 16         209.000000      14.456832       Unweighted events, alpha=3.209339
#   => Total parameter prop_binmybin_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         287.483765      26.665052       total sum
# 17         116.000000      10.770330       Unweighted events, alpha=2.478308
#   => Total parameter prop_binmybin_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         162.334709      28.097630       total sum
# 18         33.000000       5.744563        Unweighted events, alpha=4.919234
#   => Total parameter prop_binmybin_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         90.406475       11.881250       total sum
# 19         58.000000       7.615773        Unweighted events, alpha=1.558732
#   => Total parameter prop_binmybin_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         80.030106       11.621893       total sum
# 20         47.000000       6.855655        Unweighted events, alpha=1.702768
#   => Total parameter prop_binmybin_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         205.062080      97.197644       total sum
# 21         4.000000        2.000000        Unweighted events, alpha=51.265520
#   => Total parameter prop_binmybin_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         52.296166       9.184392        total sum
# 22         32.000000       5.656854        Unweighted events, alpha=1.634255
#   => Total parameter prop_binmybin_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         42.515812       6.956320        total sum
# 23         37.000000       6.082763        Unweighted events, alpha=1.149076
#   => Total parameter prop_binmybin_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         65.979366       10.457325       total sum
# 24         40.000000       6.324555        Unweighted events, alpha=1.649484
#   => Total parameter prop_binmybin_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         35.397436       6.219854        total sum
# 25         32.000000       5.656854        Unweighted events, alpha=1.106170
#   => Total parameter prop_binmybin_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         64.357815       32.860669       total sum
# 26         4.000000        2.000000        Unweighted events, alpha=16.089454
#   => Total parameter prop_binmybin_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         51.910536       11.163403       total sum
# 27         22.000000       4.690416        Unweighted events, alpha=2.359570
#   => Total parameter prop_binmybin_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         47.430946       9.711869        total sum
# 28         24.000000       4.898979        Unweighted events, alpha=1.976289
#   => Total parameter prop_binmybin_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         37.340250       7.312687        total sum
# 29         26.000000       5.099020        Unweighted events, alpha=1.436163
#   => Total parameter prop_binmybin_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         26.524644       6.145106        total sum
# 30         19.000000       4.358899        Unweighted events, alpha=1.396034
#   => Total parameter prop_binmybin_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         36.551435       7.633042        total sum
# 31         23.000000       4.795832        Unweighted events, alpha=1.589193
#   => Total parameter prop_binmybin_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         23.177326       4.002083        total sum
# 32         34.000000       5.830952        Unweighted events, alpha=0.681686
#   => Total parameter prop_binmybin_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         21.141959       4.292776        total sum
# 33         24.000000       4.898979        Unweighted events, alpha=0.880915
#   => Total parameter prop_binmybin_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         80.766189       63.533032       total sum
# 34         2.000000        1.414214        Unweighted events, alpha=40.383094
#   => Total parameter prop_binmybin_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         137.602874      58.271614       total sum
# 35         6.000000        2.449490        Unweighted events, alpha=22.933812
#   => Total parameter prop_binmybin_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         57.441851       32.796665       total sum
# 36         3.000000        1.732051        Unweighted events, alpha=19.147284
#   => Total parameter prop_binmybin_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         26.406467       6.217313        total sum
# 37         18.000000       4.242641        Unweighted events, alpha=1.467026
#   => Total parameter prop_binmybin_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         20.032091       5.614731        total sum
# 38         13.000000       3.605551        Unweighted events, alpha=1.540930
#   => Total parameter prop_binmybin_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         8.895292        4.653593        total sum
# 39         4.000000        2.000000        Unweighted events, alpha=2.223823
#   => Total parameter prop_binmybin_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .   done.
# Importing combined pdf model_s
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-tsEEdy.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
# Redefining the POIs to be: RooArgSet:: = (r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF)
#
#   RooFitResult: minimized FCN value: -8794.04, estimated distance to minimum: 0.000121813
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_binmybin_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_binmybin_bin0_In    0.0000e+00
#   prop_binmybin_bin10_In    0.0000e+00
#   prop_binmybin_bin11_In    0.0000e+00
#   prop_binmybin_bin12_In    0.0000e+00
#   prop_binmybin_bin13_In    0.0000e+00
#   prop_binmybin_bin14_In    0.0000e+00
#   prop_binmybin_bin15_In    0.0000e+00
#   prop_binmybin_bin16_In    0.0000e+00
#   prop_binmybin_bin17_In    0.0000e+00
#   prop_binmybin_bin18_In    0.0000e+00
#   prop_binmybin_bin19_In    0.0000e+00
#   prop_binmybin_bin1_In    0.0000e+00
#   prop_binmybin_bin20_In    0.0000e+00
#   prop_binmybin_bin21_In    0.0000e+00
#   prop_binmybin_bin22_In    0.0000e+00
#   prop_binmybin_bin23_In    0.0000e+00
#   prop_binmybin_bin24_In    0.0000e+00
#   prop_binmybin_bin25_In    0.0000e+00
#   prop_binmybin_bin26_In    0.0000e+00
#   prop_binmybin_bin27_In    0.0000e+00
#   prop_binmybin_bin28_In    0.0000e+00
#   prop_binmybin_bin29_In    0.0000e+00
#   prop_binmybin_bin2_In    0.0000e+00
#   prop_binmybin_bin30_In    0.0000e+00
#   prop_binmybin_bin31_In    0.0000e+00
#   prop_binmybin_bin32_In    0.0000e+00
#   prop_binmybin_bin33_In    0.0000e+00
#   prop_binmybin_bin34_In    0.0000e+00
#   prop_binmybin_bin35_In    0.0000e+00
#   prop_binmybin_bin36_In    0.0000e+00
#   prop_binmybin_bin37_In    0.0000e+00
#   prop_binmybin_bin38_In    0.0000e+00
#   prop_binmybin_bin39_In    0.0000e+00
#   prop_binmybin_bin3_In    0.0000e+00
#   prop_binmybin_bin4_In    0.0000e+00
#   prop_binmybin_bin5_In    0.0000e+00
#   prop_binmybin_bin6_In    0.0000e+00
#   prop_binmybin_bin7_In    0.0000e+00
#   prop_binmybin_bin8_In    0.0000e+00
#   prop_binmybin_bin9_In    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#      WGammaBkgPhotonSF    0.0000e+00    1.6961e+00 +/-  1.29e-01  <none>
#      ZGammaBkgPhotonSF    0.0000e+00    5.9849e-01 +/-  1.61e-01  <none>
#     prop_binmybin_bin0    0.0000e+00   -8.8287e-01 +/-  3.75e-01  <none>
#     prop_binmybin_bin1    0.0000e+00   -5.5328e-01 +/-  3.25e-01  <none>
#    prop_binmybin_bin10    0.0000e+00   -7.7202e-01 +/-  4.59e-01  <none>
#    prop_binmybin_bin11    0.0000e+00   -9.7173e-01 +/-  3.42e-01  <none>
#    prop_binmybin_bin12    0.0000e+00   -8.2528e-01 +/-  4.80e-01  <none>
#    prop_binmybin_bin13    0.0000e+00    2.5684e-01 +/-  5.40e-01  <none>
#    prop_binmybin_bin14    0.0000e+00    3.9559e-01 +/-  6.52e-01  <none>
#    prop_binmybin_bin15    0.0000e+00    8.4966e-01 +/-  6.74e-01  <none>
#    prop_binmybin_bin16    0.0000e+00   -1.1517e+00 +/-  5.58e-01  <none>
#    prop_binmybin_bin17    0.0000e+00   -3.5867e-01 +/-  4.98e-01  <none>
#    prop_binmybin_bin18    0.0000e+00    2.9284e-01 +/-  4.52e-01  <none>
#    prop_binmybin_bin19    0.0000e+00    3.4345e-01 +/-  5.12e-01  <none>
#     prop_binmybin_bin2    0.0000e+00   -2.1143e-02 +/-  4.71e-01  <none>
#    prop_binmybin_bin20    0.0000e+00    9.2419e-02 +/-  4.97e-01  <none>
#    prop_binmybin_bin21    0.0000e+00   -2.0756e+00 +/-  1.98e-01  <none>
#    prop_binmybin_bin22    0.0000e+00   -1.4297e-01 +/-  5.31e-01  <none>
#    prop_binmybin_bin23    0.0000e+00    1.1572e+00 +/-  5.20e-01  <none>
#    prop_binmybin_bin24    0.0000e+00   -5.6162e-01 +/-  4.80e-01  <none>
#    prop_binmybin_bin25    0.0000e+00   -7.4566e-01 +/-  5.14e-01  <none>
#    prop_binmybin_bin26    0.0000e+00   -1.2309e+00 +/-  3.38e-01  <none>
#    prop_binmybin_bin27    0.0000e+00   -7.8952e-01 +/-  4.71e-01  <none>
#    prop_binmybin_bin28    0.0000e+00   -6.7336e-01 +/-  4.80e-01  <none>
#    prop_binmybin_bin29    0.0000e+00    1.8104e+00 +/-  5.40e-01  <none>
#     prop_binmybin_bin3    0.0000e+00    2.4199e+00 +/-  7.13e-01  <none>
#    prop_binmybin_bin30    0.0000e+00    7.7377e-02 +/-  5.11e-01  <none>
#    prop_binmybin_bin31    0.0000e+00   -1.4994e-01 +/-  4.97e-01  <none>
#    prop_binmybin_bin32    0.0000e+00    1.5804e+00 +/-  5.55e-01  <none>
#    prop_binmybin_bin33    0.0000e+00   -3.6649e-01 +/-  4.96e-01  <none>
#    prop_binmybin_bin34    0.0000e+00   -1.0509e+00 +/-  1.77e-01  <none>
#    prop_binmybin_bin35    0.0000e+00   -1.8040e+00 +/-  1.85e-01  <none>
#    prop_binmybin_bin36    0.0000e+00   -1.3440e-01 +/-  3.03e-01  <none>
#    prop_binmybin_bin37    0.0000e+00   -1.9201e-02 +/-  4.90e-01  <none>
#    prop_binmybin_bin38    0.0000e+00    5.0566e-03 +/-  4.86e-01  <none>
#    prop_binmybin_bin39    0.0000e+00    1.2760e+00 +/-  5.12e-01  <none>
#     prop_binmybin_bin4    0.0000e+00    6.3148e-01 +/-  5.59e-01  <none>
#     prop_binmybin_bin5    0.0000e+00   -2.4644e-01 +/-  2.32e-01  <none>
#     prop_binmybin_bin6    0.0000e+00    1.0845e+00 +/-  5.69e-01  <none>
#     prop_binmybin_bin7    0.0000e+00   -1.7282e+00 +/-  3.60e-01  <none>
#     prop_binmybin_bin8    0.0000e+00   -1.4550e+00 +/-  4.60e-01  <none>
#     prop_binmybin_bin9    0.0000e+00   -1.2581e+00 +/-  5.34e-01  <none>
#                      r    1.0000e+00    2.7625e+00 +/-  7.47e-02  <none>
#
# Running Minos for POI
# Run Minos in  Real time 0:00:00, CP time 0.010
#
#
#   RooFitResult: minimized FCN value: -8794.04, estimated distance to minimum: 0.000121813
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_binmybin_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_binmybin_bin0_In    0.0000e+00
#   prop_binmybin_bin10_In    0.0000e+00
#   prop_binmybin_bin11_In    0.0000e+00
#   prop_binmybin_bin12_In    0.0000e+00
#   prop_binmybin_bin13_In    0.0000e+00
#   prop_binmybin_bin14_In    0.0000e+00
#   prop_binmybin_bin15_In    0.0000e+00
#   prop_binmybin_bin16_In    0.0000e+00
#   prop_binmybin_bin17_In    0.0000e+00
#   prop_binmybin_bin18_In    0.0000e+00
#   prop_binmybin_bin19_In    0.0000e+00
#   prop_binmybin_bin1_In    0.0000e+00
#   prop_binmybin_bin20_In    0.0000e+00
#   prop_binmybin_bin21_In    0.0000e+00
#   prop_binmybin_bin22_In    0.0000e+00
#   prop_binmybin_bin23_In    0.0000e+00
#   prop_binmybin_bin24_In    0.0000e+00
#   prop_binmybin_bin25_In    0.0000e+00
#   prop_binmybin_bin26_In    0.0000e+00
#   prop_binmybin_bin27_In    0.0000e+00
#   prop_binmybin_bin28_In    0.0000e+00
#   prop_binmybin_bin29_In    0.0000e+00
#   prop_binmybin_bin2_In    0.0000e+00
#   prop_binmybin_bin30_In    0.0000e+00
#   prop_binmybin_bin31_In    0.0000e+00
#   prop_binmybin_bin32_In    0.0000e+00
#   prop_binmybin_bin33_In    0.0000e+00
#   prop_binmybin_bin34_In    0.0000e+00
#   prop_binmybin_bin35_In    0.0000e+00
#   prop_binmybin_bin36_In    0.0000e+00
#   prop_binmybin_bin37_In    0.0000e+00
#   prop_binmybin_bin38_In    0.0000e+00
#   prop_binmybin_bin39_In    0.0000e+00
#   prop_binmybin_bin3_In    0.0000e+00
#   prop_binmybin_bin4_In    0.0000e+00
#   prop_binmybin_bin5_In    0.0000e+00
#   prop_binmybin_bin6_In    0.0000e+00
#   prop_binmybin_bin7_In    0.0000e+00
#   prop_binmybin_bin8_In    0.0000e+00
#   prop_binmybin_bin9_In    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue (+HiError,-LoError)    GblCorr.
#   --------------------  ------------  ----------------------------------  --------
#      WGammaBkgPhotonSF    0.0000e+00    1.6961e+00         +/-  1.29e-01  <none>
#      ZGammaBkgPhotonSF    0.0000e+00    5.9849e-01         +/-  1.61e-01  <none>
#     prop_binmybin_bin0    0.0000e+00   -8.8287e-01         +/-  3.75e-01  <none>
#     prop_binmybin_bin1    0.0000e+00   -5.5328e-01         +/-  3.25e-01  <none>
#    prop_binmybin_bin10    0.0000e+00   -7.7202e-01         +/-  4.59e-01  <none>
#    prop_binmybin_bin11    0.0000e+00   -9.7173e-01         +/-  3.42e-01  <none>
#    prop_binmybin_bin12    0.0000e+00   -8.2528e-01         +/-  4.80e-01  <none>
#    prop_binmybin_bin13    0.0000e+00    2.5684e-01         +/-  5.40e-01  <none>
#    prop_binmybin_bin14    0.0000e+00    3.9559e-01         +/-  6.52e-01  <none>
#    prop_binmybin_bin15    0.0000e+00    8.4966e-01         +/-  6.74e-01  <none>
#    prop_binmybin_bin16    0.0000e+00   -1.1517e+00         +/-  5.58e-01  <none>
#    prop_binmybin_bin17    0.0000e+00   -3.5867e-01         +/-  4.98e-01  <none>
#    prop_binmybin_bin18    0.0000e+00    2.9284e-01         +/-  4.52e-01  <none>
#    prop_binmybin_bin19    0.0000e+00    3.4345e-01         +/-  5.12e-01  <none>
#     prop_binmybin_bin2    0.0000e+00   -2.1143e-02         +/-  4.71e-01  <none>
#    prop_binmybin_bin20    0.0000e+00    9.2419e-02         +/-  4.97e-01  <none>
#    prop_binmybin_bin21    0.0000e+00   -2.0756e+00         +/-  1.98e-01  <none>
#    prop_binmybin_bin22    0.0000e+00   -1.4297e-01         +/-  5.31e-01  <none>
#    prop_binmybin_bin23    0.0000e+00    1.1572e+00         +/-  5.20e-01  <none>
#    prop_binmybin_bin24    0.0000e+00   -5.6162e-01         +/-  4.80e-01  <none>
#    prop_binmybin_bin25    0.0000e+00   -7.4566e-01         +/-  5.14e-01  <none>
#    prop_binmybin_bin26    0.0000e+00   -1.2309e+00         +/-  3.38e-01  <none>
#    prop_binmybin_bin27    0.0000e+00   -7.8952e-01         +/-  4.71e-01  <none>
#    prop_binmybin_bin28    0.0000e+00   -6.7336e-01         +/-  4.80e-01  <none>
#    prop_binmybin_bin29    0.0000e+00    1.8104e+00         +/-  5.40e-01  <none>
#     prop_binmybin_bin3    0.0000e+00    2.4199e+00         +/-  7.13e-01  <none>
#    prop_binmybin_bin30    0.0000e+00    7.7377e-02         +/-  5.11e-01  <none>
#    prop_binmybin_bin31    0.0000e+00   -1.4994e-01         +/-  4.97e-01  <none>
#    prop_binmybin_bin32    0.0000e+00    1.5804e+00         +/-  5.55e-01  <none>
#    prop_binmybin_bin33    0.0000e+00   -3.6649e-01         +/-  4.96e-01  <none>
#    prop_binmybin_bin34    0.0000e+00   -1.0509e+00         +/-  1.77e-01  <none>
#    prop_binmybin_bin35    0.0000e+00   -1.8040e+00         +/-  1.85e-01  <none>
#    prop_binmybin_bin36    0.0000e+00   -1.3440e-01         +/-  3.03e-01  <none>
#    prop_binmybin_bin37    0.0000e+00   -1.9201e-02         +/-  4.90e-01  <none>
#    prop_binmybin_bin38    0.0000e+00    5.0566e-03         +/-  4.86e-01  <none>
#    prop_binmybin_bin39    0.0000e+00    1.2760e+00         +/-  5.12e-01  <none>
#     prop_binmybin_bin4    0.0000e+00    6.3148e-01         +/-  5.59e-01  <none>
#     prop_binmybin_bin5    0.0000e+00   -2.4644e-01         +/-  2.32e-01  <none>
#     prop_binmybin_bin6    0.0000e+00    1.0845e+00         +/-  5.69e-01  <none>
#     prop_binmybin_bin7    0.0000e+00   -1.7282e+00         +/-  3.60e-01  <none>
#     prop_binmybin_bin8    0.0000e+00   -1.4550e+00         +/-  4.60e-01  <none>
#     prop_binmybin_bin9    0.0000e+00   -1.2581e+00         +/-  5.34e-01  <none>
#                      r    1.0000e+00    2.7625e+00 (+7.59e-02,-7.35e-02)  <none>
#
#
#  --- FitDiagnostics ---
# Best fit r: 2.76247  -0.0735696/+0.0758347  (68% CL)
# Done in 0.00 min (cpu), 0.01 min (real)
# Printing Message Summary From ... combine_logger.out
# ----------------------------------------------
# Messages of type INFO : 9
# Messages of type DEBUG : 2
# Messages of type ERROR : 0
# ----------------------------------------------
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=-1
# DEBUG: (function: improveOnce) CascadeMinimizer.cc: 196 -- Minimization ended with latest status != 0 or 1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: doFit) FitterAlgoBase.cc: 318 -- Running Minos for POI r
# DEBUG: (function: runSpecific) FitDiagnostics.cc: 412 -- Fit S+B, status = 0, numBadNLL = 0, covariance quality = 3

# %%
# !combine -M FitDiagnostics -n CR2  datacard_CR2.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF -v2
# Out:
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Creating pdfs for individual modes (1): Channel mybin will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmybin
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          21.853806       7.181898        total sum
# 0          9.000000        3.000000        Unweighted events, alpha=2.428201
#   => Total parameter prop_binmybin_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          14.870016       5.134427        total sum
# 1          8.000000        2.828427        Unweighted events, alpha=1.858752
#   => Total parameter prop_binmybin_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          25.175880       8.049666        total sum
# 2          10.000000       3.162278        Unweighted events, alpha=2.517588
#   => Total parameter prop_binmybin_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          18.323088       3.010259        total sum
# 3          37.000000       6.082763        Unweighted events, alpha=0.495219
#   => Total parameter prop_binmybin_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          30.454980       5.720645        total sum
# 4          28.000000       5.291503        Unweighted events, alpha=1.087678
#   => Total parameter prop_binmybin_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          35.552159       6.143645        total sum
# 5          33.000000       5.744563        Unweighted events, alpha=1.077338
#   => Total parameter prop_binmybin_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          116.403368      78.360338       total sum
# 6          2.000000        1.414214        Unweighted events, alpha=58.201684
#   => Total parameter prop_binmybin_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          30.475310       6.086355        total sum
# 7          25.000000       5.000000        Unweighted events, alpha=1.219012
#   => Total parameter prop_binmybin_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          93.650080       58.573689       total sum
# 8          3.000000        1.732051        Unweighted events, alpha=31.216693
#   => Total parameter prop_binmybin_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          38.306341       9.164101        total sum
# 9          17.000000       4.123106        Unweighted events, alpha=2.253314
#   => Total parameter prop_binmybin_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         33.144428       5.343369        total sum
# 10         38.000000       6.164414        Unweighted events, alpha=0.872222
#   => Total parameter prop_binmybin_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         42.423183       7.687345        total sum
# 11         30.000000       5.477226        Unweighted events, alpha=1.414106
#   => Total parameter prop_binmybin_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         63.859606       9.392125        total sum
# 12         46.000000       6.782330        Unweighted events, alpha=1.388252
#   => Total parameter prop_binmybin_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         155.591690      32.705494       total sum
# 13         23.000000       4.795832        Unweighted events, alpha=6.764856
#   => Total parameter prop_binmybin_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         180.378107      15.016161       total sum
# 14         144.000000      12.000000       Unweighted events, alpha=1.252626
#   => Total parameter prop_binmybin_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         223.883339      17.465336       total sum
# 15         164.000000      12.806248       Unweighted events, alpha=1.365142
#   => Total parameter prop_binmybin_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         129.613461      13.706898       total sum
# 16         89.000000       9.433981        Unweighted events, alpha=1.456331
#   => Total parameter prop_binmybin_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         70.856766       8.811481        total sum
# 17         65.000000       8.062258        Unweighted events, alpha=1.090104
#   => Total parameter prop_binmybin_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         49.082317       8.893556        total sum
# 18         30.000000       5.477226        Unweighted events, alpha=1.636077
#   => Total parameter prop_binmybin_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         114.614908      68.443124       total sum
# 19         3.000000        1.732051        Unweighted events, alpha=38.204969
#   => Total parameter prop_binmybin_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         50.737506       32.216296       total sum
# 20         2.000000        1.414214        Unweighted events, alpha=25.368753
#   => Total parameter prop_binmybin_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         33.223615       9.604439        total sum
# 21         12.000000       3.464102        Unweighted events, alpha=2.768635
#   => Total parameter prop_binmybin_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         28.255722       8.062079        total sum
# 22         12.000000       3.464102        Unweighted events, alpha=2.354644
#   => Total parameter prop_binmybin_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         18.869270       4.063458        total sum
# 23         22.000000       4.690416        Unweighted events, alpha=0.857694
#   => Total parameter prop_binmybin_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         16.097177       4.129186        total sum
# 24         15.000000       3.872983        Unweighted events, alpha=1.073145
#   => Total parameter prop_binmybin_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         23.045287       7.710159        total sum
# 25         9.000000        3.000000        Unweighted events, alpha=2.560587
#   => Total parameter prop_binmybin_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         16.005957       3.384748        total sum
# 26         22.000000       4.690416        Unweighted events, alpha=0.727544
#   => Total parameter prop_binmybin_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         26.547354       6.980606        total sum
# 27         14.000000       3.741657        Unweighted events, alpha=1.896240
#   => Total parameter prop_binmybin_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         19.855237       5.043695        total sum
# 28         15.000000       3.872983        Unweighted events, alpha=1.323682
#   => Total parameter prop_binmybin_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         15.088384       4.612271        total sum
# 29         11.000000       3.316625        Unweighted events, alpha=1.371671
#   => Total parameter prop_binmybin_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         18.433208       5.042789        total sum
# 30         13.000000       3.605551        Unweighted events, alpha=1.417939
#   => Total parameter prop_binmybin_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         14.613251       4.422113        total sum
# 31         11.000000       3.316625        Unweighted events, alpha=1.328477
#   => Total parameter prop_binmybin_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         13.617277       4.666152        total sum
# 32         9.000000        3.000000        Unweighted events, alpha=1.513031
#   => Total parameter prop_binmybin_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         46.032023       36.114338       total sum
# 33         2.000000        1.414214        Unweighted events, alpha=23.016012
#   => Total parameter prop_binmybin_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         7.669490        1.301640        total sum
# 34         35.000000       5.916080        Unweighted events, alpha=0.219128
#   => Total parameter prop_binmybin_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         9.871537        2.360737        total sum
# 35         17.000000       4.123106        Unweighted events, alpha=0.580679
#   => Total parameter prop_binmybin_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         5.594083        4.686425        total sum
# 36         1.000000        1.000000        Unweighted events, alpha=5.594083
#   => Total parameter prop_binmybin_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         3.969047        4.274872        total sum
# 37         1.000000        1.000000        Unweighted events, alpha=3.969047
#   => Total parameter prop_binmybin_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         18.515428       11.138618       total sum
# 38         3.000000        1.732051        Unweighted events, alpha=6.171809
#   => Total parameter prop_binmybin_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         13.970811       3.244887        total sum
# 39         19.000000       4.358899        Unweighted events, alpha=0.735306
#   => Total parameter prop_binmybin_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .   done.
# Importing combined pdf model_s
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-376G5v.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
# Redefining the POIs to be: RooArgSet:: = (r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF)
#
#   RooFitResult: minimized FCN value: -5263.93, estimated distance to minimum: 0.000253967
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_binmybin_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_binmybin_bin0_In    0.0000e+00
#   prop_binmybin_bin10_In    0.0000e+00
#   prop_binmybin_bin11_In    0.0000e+00
#   prop_binmybin_bin12_In    0.0000e+00
#   prop_binmybin_bin13_In    0.0000e+00
#   prop_binmybin_bin14_In    0.0000e+00
#   prop_binmybin_bin15_In    0.0000e+00
#   prop_binmybin_bin16_In    0.0000e+00
#   prop_binmybin_bin17_In    0.0000e+00
#   prop_binmybin_bin18_In    0.0000e+00
#   prop_binmybin_bin19_In    0.0000e+00
#   prop_binmybin_bin1_In    0.0000e+00
#   prop_binmybin_bin20_In    0.0000e+00
#   prop_binmybin_bin21_In    0.0000e+00
#   prop_binmybin_bin22_In    0.0000e+00
#   prop_binmybin_bin23_In    0.0000e+00
#   prop_binmybin_bin24_In    0.0000e+00
#   prop_binmybin_bin25_In    0.0000e+00
#   prop_binmybin_bin26_In    0.0000e+00
#   prop_binmybin_bin27_In    0.0000e+00
#   prop_binmybin_bin28_In    0.0000e+00
#   prop_binmybin_bin29_In    0.0000e+00
#   prop_binmybin_bin2_In    0.0000e+00
#   prop_binmybin_bin30_In    0.0000e+00
#   prop_binmybin_bin31_In    0.0000e+00
#   prop_binmybin_bin32_In    0.0000e+00
#   prop_binmybin_bin33_In    0.0000e+00
#   prop_binmybin_bin34_In    0.0000e+00
#   prop_binmybin_bin35_In    0.0000e+00
#   prop_binmybin_bin36_In    0.0000e+00
#   prop_binmybin_bin37_In    0.0000e+00
#   prop_binmybin_bin38_In    0.0000e+00
#   prop_binmybin_bin39_In    0.0000e+00
#   prop_binmybin_bin3_In    0.0000e+00
#   prop_binmybin_bin4_In    0.0000e+00
#   prop_binmybin_bin5_In    0.0000e+00
#   prop_binmybin_bin6_In    0.0000e+00
#   prop_binmybin_bin7_In    0.0000e+00
#   prop_binmybin_bin8_In    0.0000e+00
#   prop_binmybin_bin9_In    0.0000e+00
#                      r    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#      WGammaBkgPhotonSF    0.0000e+00    3.0169e+01 +/-  2.61e+00  <none>
#      ZGammaBkgPhotonSF    0.0000e+00   -4.0483e+01 +/-  3.83e+00  <none>
#     prop_binmybin_bin0    0.0000e+00   -4.2651e-01 +/-  1.50e-01  <none>
#     prop_binmybin_bin1    0.0000e+00    8.5211e-01 +/-  1.85e-01  <none>
#    prop_binmybin_bin10    0.0000e+00    1.7483e+00 +/-  1.61e-01  <none>
#    prop_binmybin_bin11    0.0000e+00    8.3002e-01 +/-  1.57e-01  <none>
#    prop_binmybin_bin12    0.0000e+00    6.3806e-01 +/-  1.67e-01  <none>
#    prop_binmybin_bin13    0.0000e+00    1.1913e+00 +/-  1.76e-01  <none>
#    prop_binmybin_bin14    0.0000e+00    1.4653e+00 +/-  2.17e-01  <none>
#    prop_binmybin_bin15    0.0000e+00    1.3555e+00 +/-  2.22e-01  <none>
#    prop_binmybin_bin16    0.0000e+00   -2.3077e-01 +/-  1.67e-01  <none>
#    prop_binmybin_bin17    0.0000e+00   -3.4712e+00 +/-  5.93e-02  <none>
#    prop_binmybin_bin18    0.0000e+00   -1.4927e+00 +/-  8.25e-02  <none>
#    prop_binmybin_bin19    0.0000e+00   -1.7581e+00 +/-  6.60e-02  <none>
#     prop_binmybin_bin2    0.0000e+00    1.5624e+00 +/-  1.66e-01  <none>
#    prop_binmybin_bin20    0.0000e+00   -9.9260e-01 +/-  7.50e-02  <none>
#    prop_binmybin_bin21    0.0000e+00   -1.1837e+00 +/-  7.32e-02  <none>
#    prop_binmybin_bin22    0.0000e+00   -2.4335e+00 +/-  4.61e-02  <none>
#    prop_binmybin_bin23    0.0000e+00   -2.1178e+00 +/-  6.09e-02  <none>
#    prop_binmybin_bin24    0.0000e+00   -1.4851e+00 +/-  6.37e-02  <none>
#    prop_binmybin_bin25    0.0000e+00   -2.8382e+00 +/-  3.33e-02  <none>
#    prop_binmybin_bin26    0.0000e+00   -2.5106e+00 +/-  4.33e-02  <none>
#    prop_binmybin_bin27    0.0000e+00   -1.9282e+00 +/-  4.26e-02  <none>
#    prop_binmybin_bin28    0.0000e+00   -2.0302e+00 +/-  5.64e-02  <none>
#    prop_binmybin_bin29    0.0000e+00   -2.2801e+00 +/-  4.62e-02  <none>
#     prop_binmybin_bin3    0.0000e+00   -1.0290e-01 +/-  1.62e-01  <none>
#    prop_binmybin_bin30    0.0000e+00   -1.9223e+00 +/-  5.28e-02  <none>
#    prop_binmybin_bin31    0.0000e+00   -2.4022e+00 +/-  4.63e-02  <none>
#    prop_binmybin_bin32    0.0000e+00   -2.2351e+00 +/-  3.86e-02  <none>
#    prop_binmybin_bin33    0.0000e+00   -1.5069e+00 +/-  4.82e-02  <none>
#    prop_binmybin_bin34    0.0000e+00   -1.0683e+00 +/-  5.94e-02  <none>
#    prop_binmybin_bin35    0.0000e+00   -1.5714e+00 +/-  4.36e-02  <none>
#    prop_binmybin_bin36    0.0000e+00   -2.3043e+00 +/-  4.29e-02  <none>
#    prop_binmybin_bin37    0.0000e+00   -1.8579e+00 +/-  4.21e-02  <none>
#    prop_binmybin_bin38    0.0000e+00   -1.8544e+00 +/-  3.99e-02  <none>
#    prop_binmybin_bin39    0.0000e+00   -2.1640e+00 +/-  4.12e-02  <none>
#     prop_binmybin_bin4    0.0000e+00    5.3239e-01 +/-  1.78e-01  <none>
#     prop_binmybin_bin5    0.0000e+00    1.3920e+00 +/-  1.73e-01  <none>
#     prop_binmybin_bin6    0.0000e+00   -2.0153e-02 +/-  1.31e-01  <none>
#     prop_binmybin_bin7    0.0000e+00    5.7585e-01 +/-  1.40e-01  <none>
#     prop_binmybin_bin8    0.0000e+00   -3.8024e-01 +/-  1.46e-01  <none>
#     prop_binmybin_bin9    0.0000e+00   -9.5107e-01 +/-  1.40e-01  <none>
#
#
#   RooFitResult: minimized FCN value: -5263.93, estimated distance to minimum: 0.000253967
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_binmybin_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_binmybin_bin0_In    0.0000e+00
#   prop_binmybin_bin10_In    0.0000e+00
#   prop_binmybin_bin11_In    0.0000e+00
#   prop_binmybin_bin12_In    0.0000e+00
#   prop_binmybin_bin13_In    0.0000e+00
#   prop_binmybin_bin14_In    0.0000e+00
#   prop_binmybin_bin15_In    0.0000e+00
#   prop_binmybin_bin16_In    0.0000e+00
#   prop_binmybin_bin17_In    0.0000e+00
#   prop_binmybin_bin18_In    0.0000e+00
#   prop_binmybin_bin19_In    0.0000e+00
#   prop_binmybin_bin1_In    0.0000e+00
#   prop_binmybin_bin20_In    0.0000e+00
#   prop_binmybin_bin21_In    0.0000e+00
#   prop_binmybin_bin22_In    0.0000e+00
#   prop_binmybin_bin23_In    0.0000e+00
#   prop_binmybin_bin24_In    0.0000e+00
#   prop_binmybin_bin25_In    0.0000e+00
#   prop_binmybin_bin26_In    0.0000e+00
#   prop_binmybin_bin27_In    0.0000e+00
#   prop_binmybin_bin28_In    0.0000e+00
#   prop_binmybin_bin29_In    0.0000e+00
#   prop_binmybin_bin2_In    0.0000e+00
#   prop_binmybin_bin30_In    0.0000e+00
#   prop_binmybin_bin31_In    0.0000e+00
#   prop_binmybin_bin32_In    0.0000e+00
#   prop_binmybin_bin33_In    0.0000e+00
#   prop_binmybin_bin34_In    0.0000e+00
#   prop_binmybin_bin35_In    0.0000e+00
#   prop_binmybin_bin36_In    0.0000e+00
#   prop_binmybin_bin37_In    0.0000e+00
#   prop_binmybin_bin38_In    0.0000e+00
#   prop_binmybin_bin39_In    0.0000e+00
#   prop_binmybin_bin3_In    0.0000e+00
#   prop_binmybin_bin4_In    0.0000e+00
#   prop_binmybin_bin5_In    0.0000e+00
#   prop_binmybin_bin6_In    0.0000e+00
#   prop_binmybin_bin7_In    0.0000e+00
#   prop_binmybin_bin8_In    0.0000e+00
#   prop_binmybin_bin9_In    0.0000e+00
#                      r    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#      WGammaBkgPhotonSF    0.0000e+00    3.0169e+01 +/-  2.61e+00  <none>
#      ZGammaBkgPhotonSF    0.0000e+00   -4.0483e+01 +/-  3.83e+00  <none>
#     prop_binmybin_bin0    0.0000e+00   -4.2651e-01 +/-  1.50e-01  <none>
#     prop_binmybin_bin1    0.0000e+00    8.5211e-01 +/-  1.85e-01  <none>
#    prop_binmybin_bin10    0.0000e+00    1.7483e+00 +/-  1.61e-01  <none>
#    prop_binmybin_bin11    0.0000e+00    8.3002e-01 +/-  1.57e-01  <none>
#    prop_binmybin_bin12    0.0000e+00    6.3806e-01 +/-  1.67e-01  <none>
#    prop_binmybin_bin13    0.0000e+00    1.1913e+00 +/-  1.76e-01  <none>
#    prop_binmybin_bin14    0.0000e+00    1.4653e+00 +/-  2.17e-01  <none>
#    prop_binmybin_bin15    0.0000e+00    1.3555e+00 +/-  2.22e-01  <none>
#    prop_binmybin_bin16    0.0000e+00   -2.3077e-01 +/-  1.67e-01  <none>
#    prop_binmybin_bin17    0.0000e+00   -3.4712e+00 +/-  5.93e-02  <none>
#    prop_binmybin_bin18    0.0000e+00   -1.4927e+00 +/-  8.25e-02  <none>
#    prop_binmybin_bin19    0.0000e+00   -1.7581e+00 +/-  6.60e-02  <none>
#     prop_binmybin_bin2    0.0000e+00    1.5624e+00 +/-  1.66e-01  <none>
#    prop_binmybin_bin20    0.0000e+00   -9.9260e-01 +/-  7.50e-02  <none>
#    prop_binmybin_bin21    0.0000e+00   -1.1837e+00 +/-  7.32e-02  <none>
#    prop_binmybin_bin22    0.0000e+00   -2.4335e+00 +/-  4.61e-02  <none>
#    prop_binmybin_bin23    0.0000e+00   -2.1178e+00 +/-  6.09e-02  <none>
#    prop_binmybin_bin24    0.0000e+00   -1.4851e+00 +/-  6.37e-02  <none>
#    prop_binmybin_bin25    0.0000e+00   -2.8382e+00 +/-  3.33e-02  <none>
#    prop_binmybin_bin26    0.0000e+00   -2.5106e+00 +/-  4.33e-02  <none>
#    prop_binmybin_bin27    0.0000e+00   -1.9282e+00 +/-  4.26e-02  <none>
#    prop_binmybin_bin28    0.0000e+00   -2.0302e+00 +/-  5.64e-02  <none>
#    prop_binmybin_bin29    0.0000e+00   -2.2801e+00 +/-  4.62e-02  <none>
#     prop_binmybin_bin3    0.0000e+00   -1.0290e-01 +/-  1.62e-01  <none>
#    prop_binmybin_bin30    0.0000e+00   -1.9223e+00 +/-  5.28e-02  <none>
#    prop_binmybin_bin31    0.0000e+00   -2.4022e+00 +/-  4.63e-02  <none>
#    prop_binmybin_bin32    0.0000e+00   -2.2351e+00 +/-  3.86e-02  <none>
#    prop_binmybin_bin33    0.0000e+00   -1.5069e+00 +/-  4.82e-02  <none>
#    prop_binmybin_bin34    0.0000e+00   -1.0683e+00 +/-  5.94e-02  <none>
#    prop_binmybin_bin35    0.0000e+00   -1.5714e+00 +/-  4.36e-02  <none>
#    prop_binmybin_bin36    0.0000e+00   -2.3043e+00 +/-  4.29e-02  <none>
#    prop_binmybin_bin37    0.0000e+00   -1.8579e+00 +/-  4.21e-02  <none>
#    prop_binmybin_bin38    0.0000e+00   -1.8544e+00 +/-  3.99e-02  <none>
#    prop_binmybin_bin39    0.0000e+00   -2.1640e+00 +/-  4.12e-02  <none>
#     prop_binmybin_bin4    0.0000e+00    5.3239e-01 +/-  1.78e-01  <none>
#     prop_binmybin_bin5    0.0000e+00    1.3920e+00 +/-  1.73e-01  <none>
#     prop_binmybin_bin6    0.0000e+00   -2.0153e-02 +/-  1.31e-01  <none>
#     prop_binmybin_bin7    0.0000e+00    5.7585e-01 +/-  1.40e-01  <none>
#     prop_binmybin_bin8    0.0000e+00   -3.8024e-01 +/-  1.46e-01  <none>
#     prop_binmybin_bin9    0.0000e+00   -9.5107e-01 +/-  1.40e-01  <none>
#   RooFitResult: minimized FCN value: -2147.29, estimated distance to minimum: 5.12651e-05
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_binmybin_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_binmybin_bin0_In    0.0000e+00
#   prop_binmybin_bin10_In    0.0000e+00
#   prop_binmybin_bin11_In    0.0000e+00
#   prop_binmybin_bin12_In    0.0000e+00
#   prop_binmybin_bin13_In    0.0000e+00
#   prop_binmybin_bin14_In    0.0000e+00
#   prop_binmybin_bin15_In    0.0000e+00
#   prop_binmybin_bin16_In    0.0000e+00
#   prop_binmybin_bin17_In    0.0000e+00
#   prop_binmybin_bin18_In    0.0000e+00
#   prop_binmybin_bin19_In    0.0000e+00
#   prop_binmybin_bin1_In    0.0000e+00
#   prop_binmybin_bin20_In    0.0000e+00
#   prop_binmybin_bin21_In    0.0000e+00
#   prop_binmybin_bin22_In    0.0000e+00
#   prop_binmybin_bin23_In    0.0000e+00
#   prop_binmybin_bin24_In    0.0000e+00
#   prop_binmybin_bin25_In    0.0000e+00
#   prop_binmybin_bin26_In    0.0000e+00
#   prop_binmybin_bin27_In    0.0000e+00
#   prop_binmybin_bin28_In    0.0000e+00
#   prop_binmybin_bin29_In    0.0000e+00
#   prop_binmybin_bin2_In    0.0000e+00
#   prop_binmybin_bin30_In    0.0000e+00
#   prop_binmybin_bin31_In    0.0000e+00
#   prop_binmybin_bin32_In    0.0000e+00
#   prop_binmybin_bin33_In    0.0000e+00
#   prop_binmybin_bin34_In    0.0000e+00
#   prop_binmybin_bin35_In    0.0000e+00
#   prop_binmybin_bin36_In    0.0000e+00
#   prop_binmybin_bin37_In    0.0000e+00
#   prop_binmybin_bin38_In    0.0000e+00
#   prop_binmybin_bin39_In    0.0000e+00
#   prop_binmybin_bin3_In    0.0000e+00
#   prop_binmybin_bin4_In    0.0000e+00
#   prop_binmybin_bin5_In    0.0000e+00
#   prop_binmybin_bin6_In    0.0000e+00
#   prop_binmybin_bin7_In    0.0000e+00
#   prop_binmybin_bin8_In    0.0000e+00
#   prop_binmybin_bin9_In    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#      WGammaBkgPhotonSF    0.0000e+00    1.3861e+00 +/-  1.82e-01  <none>
#      ZGammaBkgPhotonSF    0.0000e+00    1.1017e+00 +/-  3.58e-01  <none>
#     prop_binmybin_bin0    0.0000e+00   -6.9693e-01 +/-  5.65e-01  <none>
#     prop_binmybin_bin1    0.0000e+00    8.6882e-02 +/-  6.43e-01  <none>
#    prop_binmybin_bin10    0.0000e+00    1.5642e+00 +/-  6.19e-01  <none>
#    prop_binmybin_bin11    0.0000e+00    5.1467e-01 +/-  5.62e-01  <none>
#    prop_binmybin_bin12    0.0000e+00   -1.0425e-01 +/-  5.29e-01  <none>
#    prop_binmybin_bin13    0.0000e+00   -1.2646e+00 +/-  4.63e-01  <none>
#    prop_binmybin_bin14    0.0000e+00    7.0585e-01 +/-  6.71e-01  <none>
#    prop_binmybin_bin15    0.0000e+00   -3.8012e-01 +/-  6.77e-01  <none>
#    prop_binmybin_bin16    0.0000e+00    8.2823e-01 +/-  5.97e-01  <none>
#    prop_binmybin_bin17    0.0000e+00   -1.6371e+00 +/-  5.15e-01  <none>
#    prop_binmybin_bin18    0.0000e+00   -1.2802e-01 +/-  5.12e-01  <none>
#    prop_binmybin_bin19    0.0000e+00   -9.0704e-01 +/-  1.53e-01  <none>
#     prop_binmybin_bin2    0.0000e+00   -2.8707e-01 +/-  6.24e-01  <none>
#    prop_binmybin_bin20    0.0000e+00   -3.6143e-01 +/-  2.45e-01  <none>
#    prop_binmybin_bin21    0.0000e+00   -1.0249e+00 +/-  4.71e-01  <none>
#    prop_binmybin_bin22    0.0000e+00   -6.9119e-01 +/-  4.93e-01  <none>
#    prop_binmybin_bin23    0.0000e+00    7.4615e-01 +/-  5.80e-01  <none>
#    prop_binmybin_bin24    0.0000e+00    3.8350e-01 +/-  5.59e-01  <none>
#    prop_binmybin_bin25    0.0000e+00   -5.8995e-01 +/-  5.11e-01  <none>
#    prop_binmybin_bin26    0.0000e+00   -2.9557e-01 +/-  5.37e-01  <none>
#    prop_binmybin_bin27    0.0000e+00   -2.0636e-01 +/-  5.01e-01  <none>
#    prop_binmybin_bin28    0.0000e+00   -1.9743e-01 +/-  5.49e-01  <none>
#    prop_binmybin_bin29    0.0000e+00    5.5245e-02 +/-  5.58e-01  <none>
#     prop_binmybin_bin3    0.0000e+00   -4.3679e-01 +/-  5.99e-01  <none>
#    prop_binmybin_bin30    0.0000e+00   -3.0892e-01 +/-  5.37e-01  <none>
#    prop_binmybin_bin31    0.0000e+00   -3.9436e-01 +/-  5.41e-01  <none>
#    prop_binmybin_bin32    0.0000e+00    3.1578e-01 +/-  5.61e-01  <none>
#    prop_binmybin_bin33    0.0000e+00   -6.2691e-01 +/-  1.78e-01  <none>
#    prop_binmybin_bin34    0.0000e+00    1.4274e+00 +/-  6.06e-01  <none>
#    prop_binmybin_bin35    0.0000e+00   -3.3453e-01 +/-  5.46e-01  <none>
#    prop_binmybin_bin36    0.0000e+00    5.7137e-02 +/-  5.21e-01  <none>
#    prop_binmybin_bin37    0.0000e+00    8.7858e-01 +/-  5.44e-01  <none>
#    prop_binmybin_bin38    0.0000e+00   -8.2243e-01 +/-  3.87e-01  <none>
#    prop_binmybin_bin39    0.0000e+00    2.9835e-01 +/-  5.76e-01  <none>
#     prop_binmybin_bin4    0.0000e+00   -5.5637e-01 +/-  6.40e-01  <none>
#     prop_binmybin_bin5    0.0000e+00    4.6330e-01 +/-  6.07e-01  <none>
#     prop_binmybin_bin6    0.0000e+00   -1.0792e+00 +/-  1.33e-01  <none>
#     prop_binmybin_bin7    0.0000e+00    7.2639e-01 +/-  5.77e-01  <none>
#     prop_binmybin_bin8    0.0000e+00   -1.1098e+00 +/-  1.91e-01  <none>
#     prop_binmybin_bin9    0.0000e+00   -6.7587e-01 +/-  5.19e-01  <none>
#                      r    1.0000e+00    2.8637e+00 +/-  1.73e-01  <none>
#
# Running Minos for POI
# Run Minos in  Real time 0:00:00, CP time 0.020
#
#
#   RooFitResult: minimized FCN value: -2147.29, estimated distance to minimum: 5.12651e-05
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_binmybin_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_binmybin_bin0_In    0.0000e+00
#   prop_binmybin_bin10_In    0.0000e+00
#   prop_binmybin_bin11_In    0.0000e+00
#   prop_binmybin_bin12_In    0.0000e+00
#   prop_binmybin_bin13_In    0.0000e+00
#   prop_binmybin_bin14_In    0.0000e+00
#   prop_binmybin_bin15_In    0.0000e+00
#   prop_binmybin_bin16_In    0.0000e+00
#   prop_binmybin_bin17_In    0.0000e+00
#   prop_binmybin_bin18_In    0.0000e+00
#   prop_binmybin_bin19_In    0.0000e+00
#   prop_binmybin_bin1_In    0.0000e+00
#   prop_binmybin_bin20_In    0.0000e+00
#   prop_binmybin_bin21_In    0.0000e+00
#   prop_binmybin_bin22_In    0.0000e+00
#   prop_binmybin_bin23_In    0.0000e+00
#   prop_binmybin_bin24_In    0.0000e+00
#   prop_binmybin_bin25_In    0.0000e+00
#   prop_binmybin_bin26_In    0.0000e+00
#   prop_binmybin_bin27_In    0.0000e+00
#   prop_binmybin_bin28_In    0.0000e+00
#   prop_binmybin_bin29_In    0.0000e+00
#   prop_binmybin_bin2_In    0.0000e+00
#   prop_binmybin_bin30_In    0.0000e+00
#   prop_binmybin_bin31_In    0.0000e+00
#   prop_binmybin_bin32_In    0.0000e+00
#   prop_binmybin_bin33_In    0.0000e+00
#   prop_binmybin_bin34_In    0.0000e+00
#   prop_binmybin_bin35_In    0.0000e+00
#   prop_binmybin_bin36_In    0.0000e+00
#   prop_binmybin_bin37_In    0.0000e+00
#   prop_binmybin_bin38_In    0.0000e+00
#   prop_binmybin_bin39_In    0.0000e+00
#   prop_binmybin_bin3_In    0.0000e+00
#   prop_binmybin_bin4_In    0.0000e+00
#   prop_binmybin_bin5_In    0.0000e+00
#   prop_binmybin_bin6_In    0.0000e+00
#   prop_binmybin_bin7_In    0.0000e+00
#   prop_binmybin_bin8_In    0.0000e+00
#   prop_binmybin_bin9_In    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue (+HiError,-LoError)    GblCorr.
#   --------------------  ------------  ----------------------------------  --------
#      WGammaBkgPhotonSF    0.0000e+00    1.3861e+00         +/-  1.82e-01  <none>
#      ZGammaBkgPhotonSF    0.0000e+00    1.1017e+00         +/-  3.58e-01  <none>
#     prop_binmybin_bin0    0.0000e+00   -6.9693e-01         +/-  5.65e-01  <none>
#     prop_binmybin_bin1    0.0000e+00    8.6882e-02         +/-  6.43e-01  <none>
#    prop_binmybin_bin10    0.0000e+00    1.5642e+00         +/-  6.19e-01  <none>
#    prop_binmybin_bin11    0.0000e+00    5.1467e-01         +/-  5.62e-01  <none>
#    prop_binmybin_bin12    0.0000e+00   -1.0425e-01         +/-  5.29e-01  <none>
#    prop_binmybin_bin13    0.0000e+00   -1.2646e+00         +/-  4.63e-01  <none>
#    prop_binmybin_bin14    0.0000e+00    7.0585e-01         +/-  6.71e-01  <none>
#    prop_binmybin_bin15    0.0000e+00   -3.8012e-01         +/-  6.77e-01  <none>
#    prop_binmybin_bin16    0.0000e+00    8.2823e-01         +/-  5.97e-01  <none>
#    prop_binmybin_bin17    0.0000e+00   -1.6371e+00         +/-  5.15e-01  <none>
#    prop_binmybin_bin18    0.0000e+00   -1.2802e-01         +/-  5.12e-01  <none>
#    prop_binmybin_bin19    0.0000e+00   -9.0704e-01         +/-  1.53e-01  <none>
#     prop_binmybin_bin2    0.0000e+00   -2.8707e-01         +/-  6.24e-01  <none>
#    prop_binmybin_bin20    0.0000e+00   -3.6143e-01         +/-  2.45e-01  <none>
#    prop_binmybin_bin21    0.0000e+00   -1.0249e+00         +/-  4.71e-01  <none>
#    prop_binmybin_bin22    0.0000e+00   -6.9119e-01         +/-  4.93e-01  <none>
#    prop_binmybin_bin23    0.0000e+00    7.4615e-01         +/-  5.80e-01  <none>
#    prop_binmybin_bin24    0.0000e+00    3.8350e-01         +/-  5.59e-01  <none>
#    prop_binmybin_bin25    0.0000e+00   -5.8995e-01         +/-  5.11e-01  <none>
#    prop_binmybin_bin26    0.0000e+00   -2.9557e-01         +/-  5.37e-01  <none>
#    prop_binmybin_bin27    0.0000e+00   -2.0636e-01         +/-  5.01e-01  <none>
#    prop_binmybin_bin28    0.0000e+00   -1.9743e-01         +/-  5.49e-01  <none>
#    prop_binmybin_bin29    0.0000e+00    5.5245e-02         +/-  5.58e-01  <none>
#     prop_binmybin_bin3    0.0000e+00   -4.3679e-01         +/-  5.99e-01  <none>
#    prop_binmybin_bin30    0.0000e+00   -3.0892e-01         +/-  5.37e-01  <none>
#    prop_binmybin_bin31    0.0000e+00   -3.9436e-01         +/-  5.41e-01  <none>
#    prop_binmybin_bin32    0.0000e+00    3.1578e-01         +/-  5.61e-01  <none>
#    prop_binmybin_bin33    0.0000e+00   -6.2691e-01         +/-  1.78e-01  <none>
#    prop_binmybin_bin34    0.0000e+00    1.4274e+00         +/-  6.06e-01  <none>
#    prop_binmybin_bin35    0.0000e+00   -3.3453e-01         +/-  5.46e-01  <none>
#    prop_binmybin_bin36    0.0000e+00    5.7137e-02         +/-  5.21e-01  <none>
#    prop_binmybin_bin37    0.0000e+00    8.7858e-01         +/-  5.44e-01  <none>
#    prop_binmybin_bin38    0.0000e+00   -8.2243e-01         +/-  3.87e-01  <none>
#    prop_binmybin_bin39    0.0000e+00    2.9835e-01         +/-  5.76e-01  <none>
#     prop_binmybin_bin4    0.0000e+00   -5.5637e-01         +/-  6.40e-01  <none>
#     prop_binmybin_bin5    0.0000e+00    4.6330e-01         +/-  6.07e-01  <none>
#     prop_binmybin_bin6    0.0000e+00   -1.0792e+00         +/-  1.33e-01  <none>
#     prop_binmybin_bin7    0.0000e+00    7.2639e-01         +/-  5.77e-01  <none>
#     prop_binmybin_bin8    0.0000e+00   -1.1098e+00         +/-  1.91e-01  <none>
#     prop_binmybin_bin9    0.0000e+00   -6.7587e-01         +/-  5.19e-01  <none>
#                      r    1.0000e+00    2.8637e+00 (+1.80e-01,-1.68e-01)  <none>
#
#
#  --- FitDiagnostics ---
# Best fit r: 2.8637  -0.167611/+0.179891  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)
# Printing Message Summary From ... combine_logger.out
# ----------------------------------------------
# Messages of type INFO : 10
# Messages of type DEBUG : 2
# Messages of type ERROR : 0
# ----------------------------------------------
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# DEBUG: (function: runSpecific) FitDiagnostics.cc: 304 -- Fit B-only, status = 0, numBadNLL = 0, covariance quality = 3
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: doFit) FitterAlgoBase.cc: 318 -- Running Minos for POI r
# DEBUG: (function: runSpecific) FitDiagnostics.cc: 412 -- Fit S+B, status = 0, numBadNLL = 0, covariance quality = 3

# %%
# !combine -M FitDiagnostics -n CR3  datacard_CR3.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF -v2
# Out:
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Creating pdfs for individual modes (1): Channel mybin will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmybin
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          11.930910       2.085956        total sum
# 0          33.000000       5.744563        Unweighted events, alpha=0.361543
#   => Total parameter prop_binmybin_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          15.264498       4.615367        total sum
# 1          11.000000       3.316625        Unweighted events, alpha=1.387682
#   => Total parameter prop_binmybin_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          12.674878       2.024597        total sum
# 2          39.000000       6.244998        Unweighted events, alpha=0.324997
#   => Total parameter prop_binmybin_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          16.568419       3.528089        total sum
# 3          22.000000       4.690416        Unweighted events, alpha=0.753110
#   => Total parameter prop_binmybin_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          12.358580       2.558959        total sum
# 4          23.000000       4.795832        Unweighted events, alpha=0.537330
#   => Total parameter prop_binmybin_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          13.402422       2.480873        total sum
# 5          29.000000       5.385165        Unweighted events, alpha=0.462152
#   => Total parameter prop_binmybin_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          16.625832       3.497135        total sum
# 6          23.000000       4.795832        Unweighted events, alpha=0.722862
#   => Total parameter prop_binmybin_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          12.510508       2.224593        total sum
# 7          32.000000       5.656854        Unweighted events, alpha=0.390953
#   => Total parameter prop_binmybin_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          18.661434       3.354016        total sum
# 8          31.000000       5.567764        Unweighted events, alpha=0.601982
#   => Total parameter prop_binmybin_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          19.287423       5.093663        total sum
# 9          14.000000       3.741657        Unweighted events, alpha=1.377673
#   => Total parameter prop_binmybin_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         22.703571       5.514826        total sum
# 10         17.000000       4.123106        Unweighted events, alpha=1.335504
#   => Total parameter prop_binmybin_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         24.506404       4.540943        total sum
# 11         29.000000       5.385165        Unweighted events, alpha=0.845048
#   => Total parameter prop_binmybin_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         27.749281       5.444668        total sum
# 12         26.000000       5.099020        Unweighted events, alpha=1.067280
#   => Total parameter prop_binmybin_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         33.638237       5.851069        total sum
# 13         33.000000       5.744563        Unweighted events, alpha=1.019341
#   => Total parameter prop_binmybin_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         58.417950       8.183826        total sum
# 14         51.000000       7.141428        Unweighted events, alpha=1.145450
#   => Total parameter prop_binmybin_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         78.834256       9.878904        total sum
# 15         64.000000       8.000000        Unweighted events, alpha=1.231785
#   => Total parameter prop_binmybin_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         48.540089       8.163437        total sum
# 16         35.000000       5.916080        Unweighted events, alpha=1.386860
#   => Total parameter prop_binmybin_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         29.357938       6.226314        total sum
# 17         22.000000       4.690416        Unweighted events, alpha=1.334452
#   => Total parameter prop_binmybin_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         21.689871       5.389535        total sum
# 18         16.000000       4.000000        Unweighted events, alpha=1.355617
#   => Total parameter prop_binmybin_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         21.947166       7.030621        total sum
# 19         10.000000       3.162278        Unweighted events, alpha=2.194717
#   => Total parameter prop_binmybin_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         16.068200       4.797906        total sum
# 20         11.000000       3.316625        Unweighted events, alpha=1.460745
#   => Total parameter prop_binmybin_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         19.233768       5.693166        total sum
# 21         11.000000       3.316625        Unweighted events, alpha=1.748524
#   => Total parameter prop_binmybin_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         6.981849        5.017937        total sum
# 22         2.000000        1.414214        Unweighted events, alpha=3.490925
#   => Total parameter prop_binmybin_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         7.990985        2.269795        total sum
# 23         12.000000       3.464102        Unweighted events, alpha=0.665915
#   => Total parameter prop_binmybin_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         7.079783        1.981179        total sum
# 24         13.000000       3.605551        Unweighted events, alpha=0.544599
#   => Total parameter prop_binmybin_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         14.828928       5.085981        total sum
# 25         9.000000        3.000000        Unweighted events, alpha=1.647659
#   => Total parameter prop_binmybin_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         13.985551       4.947193        total sum
# 26         8.000000        2.828427        Unweighted events, alpha=1.748194
#   => Total parameter prop_binmybin_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         8.378389        1.893825        total sum
# 27         20.000000       4.472136        Unweighted events, alpha=0.418919
#   => Total parameter prop_binmybin_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         6.538941        1.152140        total sum
# 28         32.000000       5.656854        Unweighted events, alpha=0.204342
#   => Total parameter prop_binmybin_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         7.247805        1.467915        total sum
# 29         24.000000       4.898979        Unweighted events, alpha=0.301992
#   => Total parameter prop_binmybin_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         9.498592        4.102714        total sum
# 30         5.000000        2.236068        Unweighted events, alpha=1.899718
#   => Total parameter prop_binmybin_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         6.734543        1.215638        total sum
# 31         31.000000       5.567764        Unweighted events, alpha=0.217243
#   => Total parameter prop_binmybin_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         7.768613        1.519479        total sum
# 32         26.000000       5.099020        Unweighted events, alpha=0.298793
#   => Total parameter prop_binmybin_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         5.986079        1.339522        total sum
# 33         20.000000       4.472136        Unweighted events, alpha=0.299304
#   => Total parameter prop_binmybin_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         5.038201        1.022620        total sum
# 34         24.000000       4.898979        Unweighted events, alpha=0.209925
#   => Total parameter prop_binmybin_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         11.194477       3.947534        total sum
# 35         8.000000        2.828427        Unweighted events, alpha=1.399310
#   => Total parameter prop_binmybin_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         8.088454        2.384891        total sum
# 36         12.000000       3.464102        Unweighted events, alpha=0.674038
#   => Total parameter prop_binmybin_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         8.789895        3.952529        total sum
# 37         5.000000        2.236068        Unweighted events, alpha=1.757979
#   => Total parameter prop_binmybin_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         24.783213       8.892963        total sum
# 38         8.000000        2.828427        Unweighted events, alpha=3.097902
#   => Total parameter prop_binmybin_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         6.034184        1.362596        total sum
# 39         20.000000       4.472136        Unweighted events, alpha=0.301709
#   => Total parameter prop_binmybin_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# .   done.
# Importing combined pdf model_s
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-B2io87.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
# Redefining the POIs to be: RooArgSet:: = (r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF)
#
#   RooFitResult: minimized FCN value: -1225.93, estimated distance to minimum: 4.65194e-05
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_binmybin_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_binmybin_bin0_In    0.0000e+00
#   prop_binmybin_bin10_In    0.0000e+00
#   prop_binmybin_bin11_In    0.0000e+00
#   prop_binmybin_bin12_In    0.0000e+00
#   prop_binmybin_bin13_In    0.0000e+00
#   prop_binmybin_bin14_In    0.0000e+00
#   prop_binmybin_bin15_In    0.0000e+00
#   prop_binmybin_bin16_In    0.0000e+00
#   prop_binmybin_bin17_In    0.0000e+00
#   prop_binmybin_bin18_In    0.0000e+00
#   prop_binmybin_bin19_In    0.0000e+00
#   prop_binmybin_bin1_In    0.0000e+00
#   prop_binmybin_bin20_In    0.0000e+00
#   prop_binmybin_bin21_In    0.0000e+00
#   prop_binmybin_bin22_In    0.0000e+00
#   prop_binmybin_bin23_In    0.0000e+00
#   prop_binmybin_bin24_In    0.0000e+00
#   prop_binmybin_bin25_In    0.0000e+00
#   prop_binmybin_bin26_In    0.0000e+00
#   prop_binmybin_bin27_In    0.0000e+00
#   prop_binmybin_bin28_In    0.0000e+00
#   prop_binmybin_bin29_In    0.0000e+00
#   prop_binmybin_bin2_In    0.0000e+00
#   prop_binmybin_bin30_In    0.0000e+00
#   prop_binmybin_bin31_In    0.0000e+00
#   prop_binmybin_bin32_In    0.0000e+00
#   prop_binmybin_bin33_In    0.0000e+00
#   prop_binmybin_bin34_In    0.0000e+00
#   prop_binmybin_bin35_In    0.0000e+00
#   prop_binmybin_bin36_In    0.0000e+00
#   prop_binmybin_bin37_In    0.0000e+00
#   prop_binmybin_bin38_In    0.0000e+00
#   prop_binmybin_bin39_In    0.0000e+00
#   prop_binmybin_bin3_In    0.0000e+00
#   prop_binmybin_bin4_In    0.0000e+00
#   prop_binmybin_bin5_In    0.0000e+00
#   prop_binmybin_bin6_In    0.0000e+00
#   prop_binmybin_bin7_In    0.0000e+00
#   prop_binmybin_bin8_In    0.0000e+00
#   prop_binmybin_bin9_In    0.0000e+00
#                      r    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#      WGammaBkgPhotonSF    0.0000e+00    6.9333e+00 +/-  1.07e+00  <none>
#      ZGammaBkgPhotonSF    0.0000e+00    1.4110e+00 +/-  4.88e-01  <none>
#     prop_binmybin_bin0    0.0000e+00   -2.1922e+00 +/-  1.39e-01  <none>
#     prop_binmybin_bin1    0.0000e+00   -1.1638e+00 +/-  2.43e-01  <none>
#    prop_binmybin_bin10    0.0000e+00   -6.4247e-01 +/-  2.81e-01  <none>
#    prop_binmybin_bin11    0.0000e+00   -7.6472e-01 +/-  2.70e-01  <none>
#    prop_binmybin_bin12    0.0000e+00   -4.8691e-01 +/-  3.10e-01  <none>
#    prop_binmybin_bin13    0.0000e+00    7.4573e-01 +/-  4.49e-01  <none>
#    prop_binmybin_bin14    0.0000e+00    2.4190e+00 +/-  5.83e-01  <none>
#    prop_binmybin_bin15    0.0000e+00    1.0434e+00 +/-  5.65e-01  <none>
#    prop_binmybin_bin16    0.0000e+00    2.2816e-01 +/-  4.24e-01  <none>
#    prop_binmybin_bin17    0.0000e+00   -9.3544e-01 +/-  2.58e-01  <none>
#    prop_binmybin_bin18    0.0000e+00   -6.4592e-01 +/-  2.61e-01  <none>
#    prop_binmybin_bin19    0.0000e+00   -2.7276e-01 +/-  2.91e-01  <none>
#     prop_binmybin_bin2    0.0000e+00   -1.5807e+00 +/-  2.14e-01  <none>
#    prop_binmybin_bin20    0.0000e+00   -1.9685e+00 +/-  1.44e-01  <none>
#    prop_binmybin_bin21    0.0000e+00   -1.1566e+00 +/-  2.18e-01  <none>
#    prop_binmybin_bin22    0.0000e+00    1.4200e-01 +/-  3.01e-01  <none>
#    prop_binmybin_bin23    0.0000e+00   -1.3998e+00 +/-  1.76e-01  <none>
#    prop_binmybin_bin24    0.0000e+00   -8.8037e-01 +/-  1.80e-01  <none>
#    prop_binmybin_bin25    0.0000e+00   -1.2551e+00 +/-  1.58e-01  <none>
#    prop_binmybin_bin26    0.0000e+00   -7.5082e-01 +/-  2.00e-01  <none>
#    prop_binmybin_bin27    0.0000e+00   -6.1898e-01 +/-  2.35e-01  <none>
#    prop_binmybin_bin28    0.0000e+00   -2.2217e+00 +/-  6.89e-02  <none>
#    prop_binmybin_bin29    0.0000e+00   -1.2971e+00 +/-  1.69e-01  <none>
#     prop_binmybin_bin3    0.0000e+00   -2.3714e+00 +/-  1.39e-01  <none>
#    prop_binmybin_bin30    0.0000e+00   -1.1387e+00 +/-  1.46e-01  <none>
#    prop_binmybin_bin31    0.0000e+00   -8.4234e-01 +/-  1.88e-01  <none>
#    prop_binmybin_bin32    0.0000e+00   -1.4501e+00 +/-  1.31e-01  <none>
#    prop_binmybin_bin33    0.0000e+00   -1.8551e+00 +/-  9.85e-02  <none>
#    prop_binmybin_bin34    0.0000e+00   -1.0191e+00 +/-  1.31e-01  <none>
#    prop_binmybin_bin35    0.0000e+00   -1.9183e+00 +/-  9.54e-02  <none>
#    prop_binmybin_bin36    0.0000e+00   -2.4861e-01 +/-  7.83e-01  <none>
#    prop_binmybin_bin37    0.0000e+00    4.7286e-02 +/-  5.86e-01  <none>
#    prop_binmybin_bin38    0.0000e+00   -1.7911e+00 +/-  1.46e-01  <none>
#    prop_binmybin_bin39    0.0000e+00   -1.5507e+00 +/-  1.10e-01  <none>
#     prop_binmybin_bin4    0.0000e+00   -2.2975e-01 +/-  3.32e-01  <none>
#     prop_binmybin_bin5    0.0000e+00   -1.5681e+00 +/-  2.03e-01  <none>
#     prop_binmybin_bin6    0.0000e+00    8.3000e-01 +/-  8.92e-01  <none>
#     prop_binmybin_bin7    0.0000e+00   -4.6298e-01 +/-  3.20e-01  <none>
#     prop_binmybin_bin8    0.0000e+00   -1.9466e+00 +/-  1.50e-01  <none>
#     prop_binmybin_bin9    0.0000e+00   -1.8315e+00 +/-  1.74e-01  <none>
#
#
#   RooFitResult: minimized FCN value: -1225.93, estimated distance to minimum: 4.65194e-05
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_binmybin_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_binmybin_bin0_In    0.0000e+00
#   prop_binmybin_bin10_In    0.0000e+00
#   prop_binmybin_bin11_In    0.0000e+00
#   prop_binmybin_bin12_In    0.0000e+00
#   prop_binmybin_bin13_In    0.0000e+00
#   prop_binmybin_bin14_In    0.0000e+00
#   prop_binmybin_bin15_In    0.0000e+00
#   prop_binmybin_bin16_In    0.0000e+00
#   prop_binmybin_bin17_In    0.0000e+00
#   prop_binmybin_bin18_In    0.0000e+00
#   prop_binmybin_bin19_In    0.0000e+00
#   prop_binmybin_bin1_In    0.0000e+00
#   prop_binmybin_bin20_In    0.0000e+00
#   prop_binmybin_bin21_In    0.0000e+00
#   prop_binmybin_bin22_In    0.0000e+00
#   prop_binmybin_bin23_In    0.0000e+00
#   prop_binmybin_bin24_In    0.0000e+00
#   prop_binmybin_bin25_In    0.0000e+00
#   prop_binmybin_bin26_In    0.0000e+00
#   prop_binmybin_bin27_In    0.0000e+00
#   prop_binmybin_bin28_In    0.0000e+00
#   prop_binmybin_bin29_In    0.0000e+00
#   prop_binmybin_bin2_In    0.0000e+00
#   prop_binmybin_bin30_In    0.0000e+00
#   prop_binmybin_bin31_In    0.0000e+00
#   prop_binmybin_bin32_In    0.0000e+00
#   prop_binmybin_bin33_In    0.0000e+00
#   prop_binmybin_bin34_In    0.0000e+00
#   prop_binmybin_bin35_In    0.0000e+00
#   prop_binmybin_bin36_In    0.0000e+00
#   prop_binmybin_bin37_In    0.0000e+00
#   prop_binmybin_bin38_In    0.0000e+00
#   prop_binmybin_bin39_In    0.0000e+00
#   prop_binmybin_bin3_In    0.0000e+00
#   prop_binmybin_bin4_In    0.0000e+00
#   prop_binmybin_bin5_In    0.0000e+00
#   prop_binmybin_bin6_In    0.0000e+00
#   prop_binmybin_bin7_In    0.0000e+00
#   prop_binmybin_bin8_In    0.0000e+00
#   prop_binmybin_bin9_In    0.0000e+00
#                      r    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#      WGammaBkgPhotonSF    0.0000e+00    6.9333e+00 +/-  1.07e+00  <none>
#      ZGammaBkgPhotonSF    0.0000e+00    1.4110e+00 +/-  4.88e-01  <none>
#     prop_binmybin_bin0    0.0000e+00   -2.1922e+00 +/-  1.39e-01  <none>
#     prop_binmybin_bin1    0.0000e+00   -1.1638e+00 +/-  2.43e-01  <none>
#    prop_binmybin_bin10    0.0000e+00   -6.4247e-01 +/-  2.81e-01  <none>
#    prop_binmybin_bin11    0.0000e+00   -7.6472e-01 +/-  2.70e-01  <none>
#    prop_binmybin_bin12    0.0000e+00   -4.8691e-01 +/-  3.10e-01  <none>
#    prop_binmybin_bin13    0.0000e+00    7.4573e-01 +/-  4.49e-01  <none>
#    prop_binmybin_bin14    0.0000e+00    2.4190e+00 +/-  5.83e-01  <none>
#    prop_binmybin_bin15    0.0000e+00    1.0434e+00 +/-  5.65e-01  <none>
#    prop_binmybin_bin16    0.0000e+00    2.2816e-01 +/-  4.24e-01  <none>
#    prop_binmybin_bin17    0.0000e+00   -9.3544e-01 +/-  2.58e-01  <none>
#    prop_binmybin_bin18    0.0000e+00   -6.4592e-01 +/-  2.61e-01  <none>
#    prop_binmybin_bin19    0.0000e+00   -2.7276e-01 +/-  2.91e-01  <none>
#     prop_binmybin_bin2    0.0000e+00   -1.5807e+00 +/-  2.14e-01  <none>
#    prop_binmybin_bin20    0.0000e+00   -1.9685e+00 +/-  1.44e-01  <none>
#    prop_binmybin_bin21    0.0000e+00   -1.1566e+00 +/-  2.18e-01  <none>
#    prop_binmybin_bin22    0.0000e+00    1.4200e-01 +/-  3.01e-01  <none>
#    prop_binmybin_bin23    0.0000e+00   -1.3998e+00 +/-  1.76e-01  <none>
#    prop_binmybin_bin24    0.0000e+00   -8.8037e-01 +/-  1.80e-01  <none>
#    prop_binmybin_bin25    0.0000e+00   -1.2551e+00 +/-  1.58e-01  <none>
#    prop_binmybin_bin26    0.0000e+00   -7.5082e-01 +/-  2.00e-01  <none>
#    prop_binmybin_bin27    0.0000e+00   -6.1898e-01 +/-  2.35e-01  <none>
#    prop_binmybin_bin28    0.0000e+00   -2.2217e+00 +/-  6.89e-02  <none>
#    prop_binmybin_bin29    0.0000e+00   -1.2971e+00 +/-  1.69e-01  <none>
#     prop_binmybin_bin3    0.0000e+00   -2.3714e+00 +/-  1.39e-01  <none>
#    prop_binmybin_bin30    0.0000e+00   -1.1387e+00 +/-  1.46e-01  <none>
#    prop_binmybin_bin31    0.0000e+00   -8.4234e-01 +/-  1.88e-01  <none>
#    prop_binmybin_bin32    0.0000e+00   -1.4501e+00 +/-  1.31e-01  <none>
#    prop_binmybin_bin33    0.0000e+00   -1.8551e+00 +/-  9.85e-02  <none>
#    prop_binmybin_bin34    0.0000e+00   -1.0191e+00 +/-  1.31e-01  <none>
#    prop_binmybin_bin35    0.0000e+00   -1.9183e+00 +/-  9.54e-02  <none>
#    prop_binmybin_bin36    0.0000e+00   -2.4861e-01 +/-  7.83e-01  <none>
#    prop_binmybin_bin37    0.0000e+00    4.7286e-02 +/-  5.86e-01  <none>
#    prop_binmybin_bin38    0.0000e+00   -1.7911e+00 +/-  1.46e-01  <none>
#    prop_binmybin_bin39    0.0000e+00   -1.5507e+00 +/-  1.10e-01  <none>
#     prop_binmybin_bin4    0.0000e+00   -2.2975e-01 +/-  3.32e-01  <none>
#     prop_binmybin_bin5    0.0000e+00   -1.5681e+00 +/-  2.03e-01  <none>
#     prop_binmybin_bin6    0.0000e+00    8.3000e-01 +/-  8.92e-01  <none>
#     prop_binmybin_bin7    0.0000e+00   -4.6298e-01 +/-  3.20e-01  <none>
#     prop_binmybin_bin8    0.0000e+00   -1.9466e+00 +/-  1.50e-01  <none>
#     prop_binmybin_bin9    0.0000e+00   -1.8315e+00 +/-  1.74e-01  <none>
#
#
#   RooFitResult: minimized FCN value: -457.688, estimated distance to minimum: 8.12695e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_binmybin_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_binmybin_bin0_In    0.0000e+00
#   prop_binmybin_bin10_In    0.0000e+00
#   prop_binmybin_bin11_In    0.0000e+00
#   prop_binmybin_bin12_In    0.0000e+00
#   prop_binmybin_bin13_In    0.0000e+00
#   prop_binmybin_bin14_In    0.0000e+00
#   prop_binmybin_bin15_In    0.0000e+00
#   prop_binmybin_bin16_In    0.0000e+00
#   prop_binmybin_bin17_In    0.0000e+00
#   prop_binmybin_bin18_In    0.0000e+00
#   prop_binmybin_bin19_In    0.0000e+00
#   prop_binmybin_bin1_In    0.0000e+00
#   prop_binmybin_bin20_In    0.0000e+00
#   prop_binmybin_bin21_In    0.0000e+00
#   prop_binmybin_bin22_In    0.0000e+00
#   prop_binmybin_bin23_In    0.0000e+00
#   prop_binmybin_bin24_In    0.0000e+00
#   prop_binmybin_bin25_In    0.0000e+00
#   prop_binmybin_bin26_In    0.0000e+00
#   prop_binmybin_bin27_In    0.0000e+00
#   prop_binmybin_bin28_In    0.0000e+00
#   prop_binmybin_bin29_In    0.0000e+00
#   prop_binmybin_bin2_In    0.0000e+00
#   prop_binmybin_bin30_In    0.0000e+00
#   prop_binmybin_bin31_In    0.0000e+00
#   prop_binmybin_bin32_In    0.0000e+00
#   prop_binmybin_bin33_In    0.0000e+00
#   prop_binmybin_bin34_In    0.0000e+00
#   prop_binmybin_bin35_In    0.0000e+00
#   prop_binmybin_bin36_In    0.0000e+00
#   prop_binmybin_bin37_In    0.0000e+00
#   prop_binmybin_bin38_In    0.0000e+00
#   prop_binmybin_bin39_In    0.0000e+00
#   prop_binmybin_bin3_In    0.0000e+00
#   prop_binmybin_bin4_In    0.0000e+00
#   prop_binmybin_bin5_In    0.0000e+00
#   prop_binmybin_bin6_In    0.0000e+00
#   prop_binmybin_bin7_In    0.0000e+00
#   prop_binmybin_bin8_In    0.0000e+00
#   prop_binmybin_bin9_In    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#      WGammaBkgPhotonSF    0.0000e+00    1.3956e+00 +/-  3.53e-01  <none>
#      ZGammaBkgPhotonSF    0.0000e+00    1.3954e+00 +/-  5.60e-01  <none>
#     prop_binmybin_bin0    0.0000e+00   -1.0723e+00 +/-  5.74e-01  <none>
#     prop_binmybin_bin1    0.0000e+00    6.2197e-02 +/-  6.33e-01  <none>
#    prop_binmybin_bin10    0.0000e+00    3.1563e-02 +/-  5.83e-01  <none>
#    prop_binmybin_bin11    0.0000e+00   -1.4180e-01 +/-  5.71e-01  <none>
#    prop_binmybin_bin12    0.0000e+00    4.9965e-01 +/-  5.77e-01  <none>
#    prop_binmybin_bin13    0.0000e+00    6.5403e-01 +/-  6.17e-01  <none>
#    prop_binmybin_bin14    0.0000e+00    1.6840e-01 +/-  6.80e-01  <none>
#    prop_binmybin_bin15    0.0000e+00   -7.9563e-01 +/-  7.05e-01  <none>
#    prop_binmybin_bin16    0.0000e+00    2.2445e-01 +/-  6.08e-01  <none>
#    prop_binmybin_bin17    0.0000e+00   -4.2641e-01 +/-  5.46e-01  <none>
#    prop_binmybin_bin18    0.0000e+00    2.2160e-01 +/-  5.53e-01  <none>
#    prop_binmybin_bin19    0.0000e+00    1.6740e-01 +/-  5.26e-01  <none>
#     prop_binmybin_bin2    0.0000e+00   -4.5966e-01 +/-  6.53e-01  <none>
#    prop_binmybin_bin20    0.0000e+00   -8.2526e-01 +/-  5.46e-01  <none>
#    prop_binmybin_bin21    0.0000e+00    2.2017e-01 +/-  5.77e-01  <none>
#    prop_binmybin_bin22    0.0000e+00    1.3907e+00 +/-  5.44e-01  <none>
#    prop_binmybin_bin23    0.0000e+00    4.8200e-01 +/-  6.45e-01  <none>
#    prop_binmybin_bin24    0.0000e+00    6.6377e-01 +/-  6.21e-01  <none>
#    prop_binmybin_bin25    0.0000e+00   -1.0257e+00 +/-  4.75e-01  <none>
#    prop_binmybin_bin26    0.0000e+00   -1.7634e-01 +/-  5.56e-01  <none>
#    prop_binmybin_bin27    0.0000e+00    1.1759e+00 +/-  6.55e-01  <none>
#    prop_binmybin_bin28    0.0000e+00   -2.0069e+00 +/-  3.89e-01  <none>
#    prop_binmybin_bin29    0.0000e+00   -2.4534e-01 +/-  6.33e-01  <none>
#     prop_binmybin_bin3    0.0000e+00   -1.0575e+00 +/-  5.78e-01  <none>
#    prop_binmybin_bin30    0.0000e+00   -2.3348e-01 +/-  5.29e-01  <none>
#    prop_binmybin_bin31    0.0000e+00    7.1292e-01 +/-  6.32e-01  <none>
#    prop_binmybin_bin32    0.0000e+00   -3.6177e-01 +/-  5.78e-01  <none>
#    prop_binmybin_bin33    0.0000e+00   -1.0438e+00 +/-  5.03e-01  <none>
#    prop_binmybin_bin34    0.0000e+00   -7.3400e-01 +/-  5.75e-01  <none>
#    prop_binmybin_bin35    0.0000e+00   -1.5480e+00 +/-  4.55e-01  <none>
#    prop_binmybin_bin36    0.0000e+00   -2.7144e-01 +/-  7.92e-01  <none>
#    prop_binmybin_bin37    0.0000e+00    1.0625e-01 +/-  5.93e-01  <none>
#    prop_binmybin_bin38    0.0000e+00   -1.8433e+00 +/-  3.99e-01  <none>
#    prop_binmybin_bin39    0.0000e+00   -7.3363e-01 +/-  5.29e-01  <none>
#     prop_binmybin_bin4    0.0000e+00    5.8386e-01 +/-  7.09e-01  <none>
#     prop_binmybin_bin5    0.0000e+00    1.3602e-01 +/-  6.42e-01  <none>
#     prop_binmybin_bin6    0.0000e+00   -8.8512e-02 +/-  7.80e-01  <none>
#     prop_binmybin_bin7    0.0000e+00    1.2719e+00 +/-  7.34e-01  <none>
#     prop_binmybin_bin8    0.0000e+00   -6.2418e-01 +/-  5.85e-01  <none>
#     prop_binmybin_bin9    0.0000e+00   -6.1680e-01 +/-  5.64e-01  <none>
#                      r    1.0000e+00    2.4050e+00 +/-  2.84e-01  <none>
#
# Running Minos for POI
# Run Minos in  Real time 0:00:00, CP time 0.010
#
#
#   RooFitResult: minimized FCN value: -457.688, estimated distance to minimum: 8.12695e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                    ONE    1.0000e+00
#   n_exp_binmybin_proc_OtherSampleBkgPhoton    1.0000e+00
#   prop_binmybin_bin0_In    0.0000e+00
#   prop_binmybin_bin10_In    0.0000e+00
#   prop_binmybin_bin11_In    0.0000e+00
#   prop_binmybin_bin12_In    0.0000e+00
#   prop_binmybin_bin13_In    0.0000e+00
#   prop_binmybin_bin14_In    0.0000e+00
#   prop_binmybin_bin15_In    0.0000e+00
#   prop_binmybin_bin16_In    0.0000e+00
#   prop_binmybin_bin17_In    0.0000e+00
#   prop_binmybin_bin18_In    0.0000e+00
#   prop_binmybin_bin19_In    0.0000e+00
#   prop_binmybin_bin1_In    0.0000e+00
#   prop_binmybin_bin20_In    0.0000e+00
#   prop_binmybin_bin21_In    0.0000e+00
#   prop_binmybin_bin22_In    0.0000e+00
#   prop_binmybin_bin23_In    0.0000e+00
#   prop_binmybin_bin24_In    0.0000e+00
#   prop_binmybin_bin25_In    0.0000e+00
#   prop_binmybin_bin26_In    0.0000e+00
#   prop_binmybin_bin27_In    0.0000e+00
#   prop_binmybin_bin28_In    0.0000e+00
#   prop_binmybin_bin29_In    0.0000e+00
#   prop_binmybin_bin2_In    0.0000e+00
#   prop_binmybin_bin30_In    0.0000e+00
#   prop_binmybin_bin31_In    0.0000e+00
#   prop_binmybin_bin32_In    0.0000e+00
#   prop_binmybin_bin33_In    0.0000e+00
#   prop_binmybin_bin34_In    0.0000e+00
#   prop_binmybin_bin35_In    0.0000e+00
#   prop_binmybin_bin36_In    0.0000e+00
#   prop_binmybin_bin37_In    0.0000e+00
#   prop_binmybin_bin38_In    0.0000e+00
#   prop_binmybin_bin39_In    0.0000e+00
#   prop_binmybin_bin3_In    0.0000e+00
#   prop_binmybin_bin4_In    0.0000e+00
#   prop_binmybin_bin5_In    0.0000e+00
#   prop_binmybin_bin6_In    0.0000e+00
#   prop_binmybin_bin7_In    0.0000e+00
#   prop_binmybin_bin8_In    0.0000e+00
#   prop_binmybin_bin9_In    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue (+HiError,-LoError)    GblCorr.
#   --------------------  ------------  ----------------------------------  --------
#      WGammaBkgPhotonSF    0.0000e+00    1.3956e+00         +/-  3.53e-01  <none>
#      ZGammaBkgPhotonSF    0.0000e+00    1.3954e+00         +/-  5.60e-01  <none>
#     prop_binmybin_bin0    0.0000e+00   -1.0723e+00         +/-  5.74e-01  <none>
#     prop_binmybin_bin1    0.0000e+00    6.2197e-02         +/-  6.33e-01  <none>
#    prop_binmybin_bin10    0.0000e+00    3.1563e-02         +/-  5.83e-01  <none>
#    prop_binmybin_bin11    0.0000e+00   -1.4180e-01         +/-  5.71e-01  <none>
#    prop_binmybin_bin12    0.0000e+00    4.9965e-01         +/-  5.77e-01  <none>
#    prop_binmybin_bin13    0.0000e+00    6.5403e-01         +/-  6.17e-01  <none>
#    prop_binmybin_bin14    0.0000e+00    1.6840e-01         +/-  6.80e-01  <none>
#    prop_binmybin_bin15    0.0000e+00   -7.9563e-01         +/-  7.05e-01  <none>
#    prop_binmybin_bin16    0.0000e+00    2.2445e-01         +/-  6.08e-01  <none>
#    prop_binmybin_bin17    0.0000e+00   -4.2641e-01         +/-  5.46e-01  <none>
#    prop_binmybin_bin18    0.0000e+00    2.2160e-01         +/-  5.53e-01  <none>
#    prop_binmybin_bin19    0.0000e+00    1.6740e-01         +/-  5.26e-01  <none>
#     prop_binmybin_bin2    0.0000e+00   -4.5966e-01         +/-  6.53e-01  <none>
#    prop_binmybin_bin20    0.0000e+00   -8.2526e-01         +/-  5.46e-01  <none>
#    prop_binmybin_bin21    0.0000e+00    2.2017e-01         +/-  5.77e-01  <none>
#    prop_binmybin_bin22    0.0000e+00    1.3907e+00         +/-  5.44e-01  <none>
#    prop_binmybin_bin23    0.0000e+00    4.8200e-01         +/-  6.45e-01  <none>
#    prop_binmybin_bin24    0.0000e+00    6.6377e-01         +/-  6.21e-01  <none>
#    prop_binmybin_bin25    0.0000e+00   -1.0257e+00         +/-  4.75e-01  <none>
#    prop_binmybin_bin26    0.0000e+00   -1.7634e-01         +/-  5.56e-01  <none>
#    prop_binmybin_bin27    0.0000e+00    1.1759e+00         +/-  6.55e-01  <none>
#    prop_binmybin_bin28    0.0000e+00   -2.0069e+00         +/-  3.89e-01  <none>
#    prop_binmybin_bin29    0.0000e+00   -2.4534e-01         +/-  6.33e-01  <none>
#     prop_binmybin_bin3    0.0000e+00   -1.0575e+00         +/-  5.78e-01  <none>
#    prop_binmybin_bin30    0.0000e+00   -2.3348e-01         +/-  5.29e-01  <none>
#    prop_binmybin_bin31    0.0000e+00    7.1292e-01         +/-  6.32e-01  <none>
#    prop_binmybin_bin32    0.0000e+00   -3.6177e-01         +/-  5.78e-01  <none>
#    prop_binmybin_bin33    0.0000e+00   -1.0438e+00         +/-  5.03e-01  <none>
#    prop_binmybin_bin34    0.0000e+00   -7.3400e-01         +/-  5.75e-01  <none>
#    prop_binmybin_bin35    0.0000e+00   -1.5480e+00         +/-  4.55e-01  <none>
#    prop_binmybin_bin36    0.0000e+00   -2.7144e-01         +/-  7.92e-01  <none>
#    prop_binmybin_bin37    0.0000e+00    1.0625e-01         +/-  5.93e-01  <none>
#    prop_binmybin_bin38    0.0000e+00   -1.8433e+00         +/-  3.99e-01  <none>
#    prop_binmybin_bin39    0.0000e+00   -7.3363e-01         +/-  5.29e-01  <none>
#     prop_binmybin_bin4    0.0000e+00    5.8386e-01         +/-  7.09e-01  <none>
#     prop_binmybin_bin5    0.0000e+00    1.3602e-01         +/-  6.42e-01  <none>
#     prop_binmybin_bin6    0.0000e+00   -8.8512e-02         +/-  7.80e-01  <none>
#     prop_binmybin_bin7    0.0000e+00    1.2719e+00         +/-  7.34e-01  <none>
#     prop_binmybin_bin8    0.0000e+00   -6.2418e-01         +/-  5.85e-01  <none>
#     prop_binmybin_bin9    0.0000e+00   -6.1680e-01         +/-  5.64e-01  <none>
#                      r    1.0000e+00    2.4050e+00 (+3.00e-01,-2.71e-01)  <none>
#
#
#  --- FitDiagnostics ---
# Best fit r: 2.40505  -0.271333/+0.299985  (68% CL)
# Done in 0.00 min (cpu), 0.01 min (real)
# Printing Message Summary From ... combine_logger.out
# ----------------------------------------------
# Messages of type INFO : 10
# Messages of type DEBUG : 2
# Messages of type ERROR : 0
# ----------------------------------------------
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# DEBUG: (function: runSpecific) FitDiagnostics.cc: 304 -- Fit B-only, status = 0, numBadNLL = 0, covariance quality = 3
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: doFit) FitterAlgoBase.cc: 318 -- Running Minos for POI r
# DEBUG: (function: runSpecific) FitDiagnostics.cc: 412 -- Fit S+B, status = 0, numBadNLL = 0, covariance quality = 3

# %%
# !combine -M MultiDimFit -n CR4  datacard_CR4.txt --redefineSignalPOIs r,WGammaSF

# %%
# !combine -M MultiDimFit -n CR5  datacard_CR5.txt --redefineSignalPOIs r,WGammaSF

# %%
# !combine -M MultiDimFit -n CR6  datacard_CR6.txt --redefineSignalPOIs r,WGammaSF

# %%
# !combine -M MultiDimFit -n CR7  datacard_CR7.txt --redefineSignalPOIs r,WGammaSF

# %%
# !combine -M MultiDimFit -n SR8  datacard_SR8.txt --redefineSignalPOIs r,WGammaSF

# %%
# f_input_shapes_TH1 = ROOT.TFile("simple-shapes-TH1_input.root","READ")
# f_input_shapes_TH1.ls()

# %%
# h_background = f_input_shapes_TH1.Get("background")
# h_background.SetLineColor(ROOT.kBlack)
# print h_background.Integral(-1,-1)

# h_background_alphaUp = f_input_shapes_TH1.Get("background_alphaUp")
# h_background_alphaUp.SetLineColor(ROOT.kBlue)
# print h_background_alphaUp.Integral(-1,-1)

# h_background_alphaDown = f_input_shapes_TH1.Get("background_alphaDown")
# h_background_alphaDown.SetLineColor(ROOT.kRed)
# print h_background_alphaDown.Integral(-1,-1)

# c = ROOT.TCanvas()
# h_background_alphaDown.Draw()
# h_background.Draw("same")
# h_background_alphaUp.Draw("same")

# c.Draw()

# %%
# h_signal = f_input_shapes_TH1.Get("signal")
# h_signal.SetLineColor(ROOT.kBlack)
# print h_signal.Integral()

# h_signal_sigmaUp = f_input_shapes_TH1.Get("signal_sigmaUp")
# h_signal_sigmaUp.SetLineColor(ROOT.kBlue)
# print h_signal_sigmaUp.Integral()

# h_signal_sigmaDown = f_input_shapes_TH1.Get("signal_sigmaDown")
# h_signal_sigmaDown.SetLineColor(ROOT.kRed)
# print h_signal_sigmaDown.Integral()

# c = ROOT.TCanvas()
# h_signal_sigmaDown.Draw()
# h_signal.Draw("same")
# h_signal_sigmaUp.Draw("same")

# c.Draw()

# %% [markdown]
# The combine tool converts datacards into a RooWorkspace to build the likelihood

# %%
# !text2workspace.py ttgamma_sys.txt

# %%
# f_shapes_TH1 = ROOT.TFile("ttgamma_sys.root","READ")
# w_shapes_TH1 = f_shapes_TH1.Get("w")
# w_shapes_TH1.Print()

# %% [markdown]
# The workspace contains "model_s" i.e. the likelihood function, which is composed of the observable "CMS_th1x" which is split in several channels, the POI "r" and several nuisance parameters. Lets see how combine smoothly morphs the shape of the background as a function of the nuisance parameter alpha:

# %%
# shapeBkg = w_shapes_TH1.pdf("shapeBkg_mybin_background_morph")
# th1x = w_shapes_TH1.var("CMS_th1x")
# plot_th1x = th1x.frame()
# alpha = w_shapes_TH1.var("alpha")
# alpha.setVal(0.0)
# shapeBkg.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kBlack))
# alpha.setVal(0.5)
# shapeBkg.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kGreen))
# alpha.setVal(1.0)
# shapeBkg.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kRed))
# alpha.setVal(2.0)
# shapeBkg.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kOrange))

# c2 = ROOT.TCanvas()
# plot_th1x.Draw()
# c2.Draw()

# %%
# shapeSig = w_shapes_TH1.pdf("shapeSig_mybin_signal_morph")
# th1x = w_shapes_TH1.var("CMS_th1x")
# plot_th1x = th1x.frame()
# sigma = w_shapes_TH1.var("sigma")
# sigma.setVal(0.0)
# shapeSig.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kBlack))
# sigma.setVal(0.5)
# shapeSig.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kGreen))
# sigma.setVal(1.0)
# shapeSig.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kRed))
# sigma.setVal(2.0)
# shapeSig.plotOn(plot_th1x,ROOT.RooFit.LineColor(ROOT.kOrange))

# c2 = ROOT.TCanvas()
# plot_th1x.Draw()
# c2.Draw()

# %% [markdown]
# Prints the workspace normalization

# %%
# !python ../test/printWorkspaceNormalisations.py ttgamma_sys.root

# %% [markdown]
# If we redefine POI then it will be float and can take any values. If we have things in datacard then everything will be used to produce the best r value.
# The option "--run both" tells combine to run both expected and observed limits.You can see we have computed an observed limit on r, and also the nominal expected, and +/- 1 and 2 sigma expected limits. [-s -1 == random seed]

# %%
# !combine -M MultiDimFit -n Nabin ttgamma_sys.txt

# %%
# !combine -n LimitTestNabin -M AsymptoticLimits ttgamma_sys.root --run both

# %%
# asymptoticfile = ROOT.TFile("higgsCombineLimitTestNabin.AsymptoticLimits.mH120.root")
# limit = asymptoticfile.Get("limit")
# for i in xrange(limit.GetEntries()):
#     limit.GetEntry(i)
#     print i,limit.mh,limit.limit

# %% [markdown]
# 1-sigma ==  68%, 2-sigma == 95%, 3-sigma == 99.7%. The higher sigma value means that the discovery is less likely to be accidently a mistake or 'random chance'.
# How do we test hypothesis?
# Null hypothesis  means A and B are not connected. Research hypothesis means A and B are connected. First assume Null hypothesis is true. Then calculate the probability of obtaining data as extreme as the kind they are observing.
# P-value close to zero means Null hypothesis is false, however, larger p-value means Null hypothesis is true. For example, p-value = 5% means that chance that the data sample being tested is drawn from where Null hypothesis is true.
# Next example, the chances of a result being greater than 1-sigma is 15.9%, 2-sigma is 2.3%, 3-sigma is 0.2%.
