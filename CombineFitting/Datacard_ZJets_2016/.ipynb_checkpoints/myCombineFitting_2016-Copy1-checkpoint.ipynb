# %%
import ROOT
import os

# %% [markdown]
# ## Both Channel

# %%
# !combine --help
# !pwd
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# pwd: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# pwd: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
# !combine -M FitDiagnostics -n AR_both  datacard_AR_both.txt --saveWithUncertainties

# %%
# !combine -M FitDiagnostics -n CR123_both  datacard_CR123_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          810.645905      32.862046       total sum
# 0          609.000000      24.677925       Unweighted events, alpha=1.331110
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          971.557785      36.387794       total sum
# 1          713.000000      26.702060       Unweighted events, alpha=1.362634
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1291.278740     42.317277       total sum
# 2          931.000000      30.512293       Unweighted events, alpha=1.386980
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1770.123222     49.725573       total sum
# 3          1267.000000     35.594943       Unweighted events, alpha=1.397098
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          2594.517174     60.400083       total sum
# 4          1845.000000     42.953463       Unweighted events, alpha=1.406242
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          3903.910187     74.346961       total sum
# 5          2757.000000     52.507142       Unweighted events, alpha=1.415999
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          5870.397751     91.150516       total sum
# 6          4148.000000     64.404969       Unweighted events, alpha=1.415236
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          9089.658768     113.771285      total sum
# 7          6383.000000     79.893679       Unweighted events, alpha=1.424042
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          13868.448669    140.739730      total sum
# 8          9710.000000     98.539332       Unweighted events, alpha=1.428265
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          19314.595398    166.121775      total sum
# 9          13518.000000    116.266934      Unweighted events, alpha=1.428806
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         23621.736450    183.739235      total sum
# 10         16528.000000    128.561269      Unweighted events, alpha=1.429195
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         22577.835571    179.769162      total sum
# 11         15774.000000    125.594586      Unweighted events, alpha=1.431332
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         16768.976044    154.733429      total sum
# 12         11745.000000    108.374351      Unweighted events, alpha=1.427754
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         10767.132507    123.885741      total sum
# 13         7554.000000     86.913750       Unweighted events, alpha=1.425355
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         6747.249542     98.062020       total sum
# 14         4734.000000     68.804070       Unweighted events, alpha=1.425275
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         4269.861397     77.907506       total sum
# 15         3004.000000     54.808758       Unweighted events, alpha=1.421392
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         2789.825493     62.575431       total sum
# 16         1988.000000     44.586994       Unweighted events, alpha=1.403333
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         1896.078354     51.432613       total sum
# 17         1359.000000     36.864617       Unweighted events, alpha=1.395201
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         1527.227203     46.148806       total sum
# 18         1095.000000     33.090784       Unweighted events, alpha=1.394728
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         1117.672321     39.387499       total sum
# 19         805.000000      28.372522       Unweighted events, alpha=1.388413
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2920.016357     63.206077       total sum
# 0          2134.000000     46.195238       Unweighted events, alpha=1.368330
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          3390.603790     68.418101       total sum
# 1          2456.000000     49.558047       Unweighted events, alpha=1.380539
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          4340.782959     77.898680       total sum
# 2          3105.000000     55.722527       Unweighted events, alpha=1.397998
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          5492.821960     87.758043       total sum
# 3          3918.000000     62.593929       Unweighted events, alpha=1.401945
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          7157.854645     100.674857      total sum
# 4          5055.000000     71.098523       Unweighted events, alpha=1.415995
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          10052.916962    119.880535      total sum
# 5          7032.000000     83.857021       Unweighted events, alpha=1.429596
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          14790.491180    145.721303      total sum
# 6          10302.000000    101.498768      Unweighted events, alpha=1.435691
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          21963.614075    177.748911      total sum
# 7          15268.000000    123.563749      Unweighted events, alpha=1.438539
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          34798.329346    223.971222      total sum
# 8          24140.000000    155.370525      Unweighted events, alpha=1.441522
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          55055.828735    282.159164      total sum
# 9          38073.000000    195.123038      Unweighted events, alpha=1.446060
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         74781.070679    328.987441      total sum
# 10         51668.000000    227.305961      Unweighted events, alpha=1.447338
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         76250.425537    332.285648      total sum
# 11         52658.000000    229.473310      Unweighted events, alpha=1.448031
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         58006.217163    289.691869      total sum
# 12         40094.000000    200.234862      Unweighted events, alpha=1.446756
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         36522.583008    229.638121      total sum
# 13         25295.000000    159.044019      Unweighted events, alpha=1.443866
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         21593.151978    176.334395      total sum
# 14         14995.000000    122.454073      Unweighted events, alpha=1.440023
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         13804.185730    140.867294      total sum
# 15         9603.000000     97.994898       Unweighted events, alpha=1.437487
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         8796.464172     112.053591      total sum
# 16         6163.000000     78.504777       Unweighted events, alpha=1.427302
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         6383.161942     95.215590       total sum
# 17         4494.000000     67.037303       Unweighted events, alpha=1.420374
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         4690.158920     81.621943       total sum
# 18         3302.000000     57.463032       Unweighted events, alpha=1.420399
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         3834.493164     73.522370       total sum
# 19         2720.000000     52.153619       Unweighted events, alpha=1.409740
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-ef13pi.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8cafcc0
#   Clients:
#     (0x8df86e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8cb11e0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8bdccf0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 151569
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8cbf020
#   Clients:
#     (0x8df86e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8cbe2e0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8cc0010,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 464625
# Error in <TList::Clear>: A list is accessing an object (0x8e29364) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8e2960c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9073640
#   Clients:
#     (0x9072020,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x909b4c0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x8bdccf0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 18954.8
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x90a6150
#   Clients:
#     (0x9072020,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x90d2a40,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x8cc0010,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 54978.9
# Error in <TList::Clear>: A list is accessing an object (0x8e29e04) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8e2a0ac) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8cafcc0
#   Clients:
#     (0x8df86e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8cb11e0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8bdccf0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 183773
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8cbf020
#   Clients:
#     (0x8df86e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8cbe2e0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8cc0010,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 567548
# Error in <TList::Clear>: A list is accessing an object (0x8e2a354) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8e2a5fc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.22588  -0.00237051/+0.00240551  (68% CL)
# Done in 0.05 min (cpu), 0.15 min (real)

# %%
# !combine -M FitDiagnostics -n CR1_both  datacard_CR1_both.txt --saveWithUncertainties

# %%
# !combine -M FitDiagnostics -n CR2_both  datacard_CR2_both.txt --saveWithUncertainties

# %%
# !combine -M FitDiagnostics -n CR3_both  datacard_CR3_both.txt --saveWithUncertainties

# %%
# !combine -M FitDiagnostics -n CR4_both  datacard_CR4_both.txt --saveWithUncertainties

# %%
# !combine -M FitDiagnostics -n CR5_both  datacard_CR5_both.txt --saveWithUncertainties

# %%
# !combine -M FitDiagnostics -n CR6_both  datacard_CR6_both.txt --saveWithUncertainties

# %%
# !combine -M FitDiagnostics -n CR7_both  datacard_CR7_both.txt --saveWithUncertainties

# %%
# !combine -M FitDiagnostics -n SR8_both  datacard_SR8_both.txt --saveWithUncertainties
