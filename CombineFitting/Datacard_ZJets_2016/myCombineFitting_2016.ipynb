# %%
import ROOT
import os

# %% [markdown]
# ## Both Channel

# %%
# !combine --help
# !pwd
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/TTGammaSemiLep_13TeV/Plotting/CombineFitting/Datacard_ZJets_2016

# %%
# !combine -M FitDiagnostics -n AR_both  datacard_AR_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          799.499100      32.727448       total sum
# 0          597.000000      24.433583       Unweighted events, alpha=1.339194
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          962.825142      36.301886       total sum
# 1          703.000000      26.514147       Unweighted events, alpha=1.369595
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1281.071777     42.239504       total sum
# 2          920.000000      30.331502       Unweighted events, alpha=1.392469
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1761.249390     49.642664       total sum
# 3          1259.000000     35.482390       Unweighted events, alpha=1.398927
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          2587.356773     60.352795       total sum
# 4          1838.000000     42.871902       Unweighted events, alpha=1.407702
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          3896.968903     74.318910       total sum
# 5          2750.000000     52.440442       Unweighted events, alpha=1.417080
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          5862.432388     91.104548       total sum
# 6          4141.000000     64.350602       Unweighted events, alpha=1.415705
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          9070.176559     113.692913      total sum
# 7          6365.000000     79.780950       Unweighted events, alpha=1.425008
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          13830.470276    140.624524      total sum
# 8          9673.000000     98.351411       Unweighted events, alpha=1.429802
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          19274.556122    166.027746      total sum
# 9          13477.000000    116.090482      Unweighted events, alpha=1.430182
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         23575.708984    183.624836      total sum
# 10         16484.000000    128.390031      Unweighted events, alpha=1.430218
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         22520.532990    179.638295      total sum
# 11         15717.000000    125.367460      Unweighted events, alpha=1.432877
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         16727.272095    154.632999      total sum
# 12         11702.000000    108.175783      Unweighted events, alpha=1.429437
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         10739.744659    123.812365      total sum
# 13         7524.000000     86.740994       Unweighted events, alpha=1.427398
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         6729.253372     97.990286       total sum
# 14         4716.000000     68.673139       Unweighted events, alpha=1.426899
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         4259.173943     77.860945       total sum
# 15         2992.000000     54.699177       Unweighted events, alpha=1.423521
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         2783.415802     62.541035       total sum
# 16         1981.000000     44.508426       Unweighted events, alpha=1.405056
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         1886.318573     51.333245       total sum
# 17         1350.000000     36.742346       Unweighted events, alpha=1.397273
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         1523.825951     46.121456       total sum
# 18         1092.000000     33.045423       Unweighted events, alpha=1.395445
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         1114.958263     39.374670       total sum
# 19         802.000000      28.319605       Unweighted events, alpha=1.390222
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2900.065933     63.084436       total sum
# 0          2113.000000     45.967380       Unweighted events, alpha=1.372487
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          3366.168854     68.274398       total sum
# 1          2431.000000     49.305172       Unweighted events, alpha=1.384685
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          4326.779572     77.802930       total sum
# 2          3093.000000     55.614746       Unweighted events, alpha=1.398894
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          5478.427185     87.705503       total sum
# 3          3902.000000     62.465991       Unweighted events, alpha=1.404005
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          7134.691437     100.604971      total sum
# 4          5029.000000     70.915443       Unweighted events, alpha=1.418710
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          10029.185669    119.799397      total sum
# 5          7008.000000     83.713798       Unweighted events, alpha=1.431105
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          14762.232178    145.633398      total sum
# 6          10275.000000    101.365675      Unweighted events, alpha=1.436714
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          21916.082092    177.640852      total sum
# 7          15221.000000    123.373417      Unweighted events, alpha=1.439858
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          34727.924683    223.832572      total sum
# 8          24072.000000    155.151539      Unweighted events, alpha=1.442669
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          54970.175415    282.016573      total sum
# 9          37993.000000    194.917931      Unweighted events, alpha=1.446850
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         74643.233521    328.829907      total sum
# 10         51527.000000    226.995595      Unweighted events, alpha=1.448624
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         76108.761108    332.106912      total sum
# 11         52519.000000    229.170242      Unweighted events, alpha=1.449166
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         57897.571106    289.543738      total sum
# 12         39985.000000    199.962496      Unweighted events, alpha=1.447982
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         36450.396057    229.499571      total sum
# 13         25226.000000    158.826950      Unweighted events, alpha=1.444953
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         21544.993073    176.219089      total sum
# 14         14948.000000    122.262014      Unweighted events, alpha=1.441329
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         13776.860596    140.780606      total sum
# 15         9577.000000     97.862148       Unweighted events, alpha=1.438536
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         8775.245544     111.987038      total sum
# 16         6140.000000     78.358152       Unweighted events, alpha=1.429193
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         6365.348740     95.126289       total sum
# 17         4478.000000     66.917860       Unweighted events, alpha=1.421471
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         4681.312149     81.575495       total sum
# 18         3293.000000     57.384667       Unweighted events, alpha=1.421595
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         3824.144150     73.456783       total sum
# 19         2710.000000     52.057660       Unweighted events, alpha=1.411123
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-0OdVpN.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x90a0b40
#   Clients:
#     (0x91e9590,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x90a2060,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8fcdb70,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 151187
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x90afed0
#   Clients:
#     (0x91e9590,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x90af190,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x90b0ec0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 463680
# Error in <TList::Clear>: A list is accessing an object (0x921a264) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x921a50c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9464b70
#   Clients:
#     (0x9463550,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x948c700,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x8fcdb70,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 17857.7
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9497390
#   Clients:
#     (0x9463550,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x94c3c30,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x90b0ec0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 52037.7
# Error in <TList::Clear>: A list is accessing an object (0x921ad04) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x921afac) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x90a0b40
#   Clients:
#     (0x91e9590,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x90a2060,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8fcdb70,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 183409
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x90afed0
#   Clients:
#     (0x91e9590,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x90af190,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x90b0ec0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 566490
# Error in <TList::Clear>: A list is accessing an object (0x921b254) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x921b4fc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.22582  -0.00236992/+0.00240502  (68% CL)
# Done in 0.04 min (cpu), 0.04 min (real)

# %%
# !combine -M FitDiagnostics -n CR123_both  datacard_CR123_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1023.360703     34.495345       total sum
# 0          880.000000      29.664794       Unweighted events, alpha=1.162910
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1218.017670     38.254215       total sum
# 1          1014.000000     31.843367       Unweighted events, alpha=1.201201
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1593.242813     44.808558       total sum
# 2          1264.000000     35.552778       Unweighted events, alpha=1.260477
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          2137.942596     52.729655       total sum
# 3          1644.000000     40.546270       Unweighted events, alpha=1.300452
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          3005.148254     63.366460       total sum
# 4          2249.000000     47.423623       Unweighted events, alpha=1.336215
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          4469.135590     78.207170       total sum
# 5          3266.000000     57.148928       Unweighted events, alpha=1.368382
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          6674.901093     96.103855       total sum
# 6          4824.000000     69.455021       Unweighted events, alpha=1.383686
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          10272.923615    120.031246      total sum
# 7          7325.000000     85.586214       Unweighted events, alpha=1.402447
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          15499.145996    148.098700      total sum
# 8          10952.000000    104.651804      Unweighted events, alpha=1.415189
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          21701.658813    175.428845      total sum
# 9          15303.000000    123.705295      Unweighted events, alpha=1.418131
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         26328.543640    193.366580      total sum
# 10         18539.000000    136.157996      Unweighted events, alpha=1.420171
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         25203.330994    189.332200      total sum
# 11         17720.000000    133.116490      Unweighted events, alpha=1.422310
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         18734.061218    162.867485      total sum
# 12         13231.000000    115.026084      Unweighted events, alpha=1.415922
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         12034.076447    130.071680      total sum
# 13         8560.000000     92.520268       Unweighted events, alpha=1.405850
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         7677.859436     103.489269      total sum
# 14         5504.000000     74.188948       Unweighted events, alpha=1.394960
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         4911.248535     82.081017       total sum
# 15         3580.000000     59.833101       Unweighted events, alpha=1.371857
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         3267.455017     65.901897       total sum
# 16         2458.000000     49.578221       Unweighted events, alpha=1.329314
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         2274.985260     54.162925       total sum
# 17         1764.000000     42.000000       Unweighted events, alpha=1.289674
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         1878.187439     48.574297       total sum
# 18         1495.000000     38.665230       Unweighted events, alpha=1.256313
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         1416.968658     41.548888       total sum
# 19         1163.000000     34.102786       Unweighted events, alpha=1.218374
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          3693.206177     66.691966       total sum
# 0          3067.000000     55.380502       Unweighted events, alpha=1.204175
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          4206.232361     72.139038       total sum
# 1          3400.000000     58.309519       Unweighted events, alpha=1.237127
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          5279.715576     82.037779       total sum
# 2          4142.000000     64.358372       Unweighted events, alpha=1.274678
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          6556.319153     92.475850       total sum
# 3          5026.000000     70.894287       Unweighted events, alpha=1.304481
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          8443.869812     106.294647      total sum
# 4          6310.000000     79.435508       Unweighted events, alpha=1.338173
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          11520.953491    125.699507      total sum
# 5          8401.000000     91.656969       Unweighted events, alpha=1.371379
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          16817.102051    153.210991      total sum
# 6          12048.000000    109.763382      Unweighted events, alpha=1.395842
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          24751.688232    186.898691      total sum
# 7          17539.000000    132.434890      Unweighted events, alpha=1.411237
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          38936.651611    235.544505      total sum
# 8          27326.000000    165.305777      Unweighted events, alpha=1.424894
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          61354.461426    296.716997      total sum
# 9          42757.000000    206.777658      Unweighted events, alpha=1.434957
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         83130.518799    345.967268      total sum
# 10         57737.000000    240.285247      Unweighted events, alpha=1.439814
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         84917.739990    349.736781      total sum
# 11         58954.000000    242.804448      Unweighted events, alpha=1.440407
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         64554.882812    304.498872      total sum
# 12         44946.000000    212.004717      Unweighted events, alpha=1.436276
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         40862.159912    241.464939      total sum
# 13         28637.000000    169.224703      Unweighted events, alpha=1.426901
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         24316.717773    185.268546      total sum
# 14         17227.000000    131.251667      Unweighted events, alpha=1.411547
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         15666.478882    147.702085      total sum
# 15         11250.000000    106.066017      Unweighted events, alpha=1.392576
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         10236.097168    117.954127      total sum
# 16         7531.000000     86.781334       Unweighted events, alpha=1.359195
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         7559.921326     100.154599      total sum
# 17         5698.000000     75.485098       Unweighted events, alpha=1.326768
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         5703.557190     86.002953       total sum
# 18         4398.000000     66.317419       Unweighted events, alpha=1.296852
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         4723.468689     77.335436       total sum
# 19         3730.000000     61.073726       Unweighted events, alpha=1.266345
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-UQKaqh.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x817c6c0
#   Clients:
#     (0x82c5110,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x817dbe0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x80a96f0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 171322
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x818ba50
#   Clients:
#     (0x82c5110,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x818ad10,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x818ca40,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 523232
# Error in <TList::Clear>: A list is accessing an object (0x82f5d74) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x82f601c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8540e70
#   Clients:
#     (0x853f850,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8568ac0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x80a96f0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 23181.6
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x85736f0
#   Clients:
#     (0x853f850,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x859ff20,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x818ca40,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 67350.9
# Error in <TList::Clear>: A list is accessing an object (0x82f6814) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x82f6abc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x817c6c0
#   Clients:
#     (0x82c5110,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x817dbe0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x80a96f0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 207955
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x818ba50
#   Clients:
#     (0x82c5110,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x818ad10,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x818ca40,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 638696
# Error in <TList::Clear>: A list is accessing an object (0x82f6d64) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x82f700c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.22982  -0.00226688/+0.00229993  (68% CL)
# Done in 0.03 min (cpu), 0.03 min (real)

# %%
# !combine -M FitDiagnostics -n CR1_both  datacard_CR1_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          589.352192      28.223390       total sum
# 0          436.000000      20.880613       Unweighted events, alpha=1.351725
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          730.490913      31.800889       total sum
# 1          528.000000      22.978251       Unweighted events, alpha=1.383506
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          986.672012      37.125064       total sum
# 2          706.000000      26.570661       Unweighted events, alpha=1.397552
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1356.452858     43.665230       total sum
# 3          965.000000      31.064449       Unweighted events, alpha=1.405651
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          2048.807331     53.842253       total sum
# 4          1448.000000     38.052595       Unweighted events, alpha=1.414922
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          2988.902527     65.062371       total sum
# 5          2110.000000     45.934736       Unweighted events, alpha=1.416541
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          4449.694077     79.407846       total sum
# 6          3140.000000     56.035703       Unweighted events, alpha=1.417100
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          7009.523209     99.985949       total sum
# 7          4915.000000     70.107061       Unweighted events, alpha=1.426149
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          10690.624176    123.574104      total sum
# 8          7484.000000     86.510115       Unweighted events, alpha=1.428464
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          14878.765900    145.882647      total sum
# 9          10402.000000    101.990196      Unweighted events, alpha=1.430375
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         18095.658295    160.878392      total sum
# 10         12652.000000    112.481110      Unweighted events, alpha=1.430261
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         17159.430634    156.785706      total sum
# 11         11978.000000    109.444050      Unweighted events, alpha=1.432579
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         12723.925400    134.740995      total sum
# 12         8917.000000     94.429868       Unweighted events, alpha=1.426929
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         8221.171204     108.292911      total sum
# 13         5763.000000     75.914426       Unweighted events, alpha=1.426544
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         5203.709885     86.229019       total sum
# 14         3642.000000     60.348985       Unweighted events, alpha=1.428806
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         3238.454819     67.979491       total sum
# 15         2269.000000     47.634021       Unweighted events, alpha=1.427261
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         2168.485775     55.319396       total sum
# 16         1537.000000     39.204592       Unweighted events, alpha=1.410856
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         1449.240177     45.075769       total sum
# 17         1034.000000     32.155870       Unweighted events, alpha=1.401586
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         1194.594742     40.878423       total sum
# 18         854.000000      29.223278       Unweighted events, alpha=1.398823
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         840.358837      34.311571       total sum
# 19         600.000000      24.494897       Unweighted events, alpha=1.400598
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2232.094543     55.551490       total sum
# 0          1614.000000     40.174619       Unweighted events, alpha=1.382958
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          2601.852020     60.311183       total sum
# 1          1861.000000     43.139309       Unweighted events, alpha=1.398094
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          3385.193207     69.049078       total sum
# 2          2404.000000     49.030603       Unweighted events, alpha=1.408150
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          4252.029449     77.456567       total sum
# 3          3014.000000     54.899909       Unweighted events, alpha=1.410760
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          5528.027191     88.671746       total sum
# 4          3887.000000     62.345810       Unweighted events, alpha=1.422183
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          7793.488358     105.780557      total sum
# 5          5428.000000     73.674962       Unweighted events, alpha=1.435794
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          11416.070435    128.256761      total sum
# 6          7923.000000     89.011235       Unweighted events, alpha=1.440877
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          16994.325287    156.604953      total sum
# 7          11776.000000    108.517280      Unweighted events, alpha=1.443132
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          27013.672119    197.543068      total sum
# 8          18700.000000    136.747943      Unweighted events, alpha=1.444581
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          42860.287781    249.142301      total sum
# 9          29595.000000    172.031974      Unweighted events, alpha=1.448227
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         59151.936401    292.897458      total sum
# 10         40786.000000    201.955441      Unweighted events, alpha=1.450300
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         60167.900085    295.417825      total sum
# 11         41482.000000    203.671304      Unweighted events, alpha=1.450458
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         45521.843323    256.984829      total sum
# 12         31378.000000    177.138364      Unweighted events, alpha=1.450757
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         28437.758728    202.802092      total sum
# 13         19663.000000    140.224819      Unweighted events, alpha=1.446257
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         16771.560669    155.721845      total sum
# 14         11600.000000    107.703296      Unweighted events, alpha=1.445824
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         10681.368057    124.127276      total sum
# 15         7405.000000     86.052310       Unweighted events, alpha=1.442453
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         6814.164780     98.823133       total sum
# 16         4755.000000     68.956508       Unweighted events, alpha=1.433053
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         4992.834778     84.429075       total sum
# 17         3497.000000     59.135438       Unweighted events, alpha=1.427748
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         3660.026398     72.411723       total sum
# 18         2555.000000     50.547008       Unweighted events, alpha=1.432496
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         2965.432487     64.945049       total sum
# 19         2085.000000     45.661800       Unweighted events, alpha=1.422270
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-asbADW.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x88b96b0
#   Clients:
#     (0x8a02100,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x88babd0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x87e66c0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 116024
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x88c8a40
#   Clients:
#     (0x8a02100,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x88c7d00,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x88c9a30,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 363242
# Error in <TList::Clear>: A list is accessing an object (0x8a32d64) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a3300c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8c7dcb0
#   Clients:
#     (0x8c7c690,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8ca5860,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x87e66c0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 13364.2
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8cb0490
#   Clients:
#     (0x8c7c690,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8cdcdf0,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x88c9a30,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 39627.2
# Error in <TList::Clear>: A list is accessing an object (0x8a33804) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a33aac) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x88b96b0
#   Clients:
#     (0x8a02100,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x88babd0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x87e66c0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 141028
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x88c8a40
#   Clients:
#     (0x8a02100,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x88c7d00,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x88c9a30,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 444312
# Error in <TList::Clear>: A list is accessing an object (0x8a33d54) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a33ffc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.22719  -0.00268317/+0.00272163  (68% CL)
# Done in 0.04 min (cpu), 0.04 min (real)

# %%
# !combine -M FitDiagnostics -n CR2_both  datacard_CR2_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          144.114767      13.741118       total sum
# 0          110.000000      10.488088       Unweighted events, alpha=1.310134
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          166.162270      14.761290       total sum
# 1          127.000000      11.269428       Unweighted events, alpha=1.308364
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          224.818234      17.689204       total sum
# 2          162.000000      12.727922       Unweighted events, alpha=1.387767
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          308.662790      20.578340       total sum
# 3          225.000000      15.000000       Unweighted events, alpha=1.371835
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          421.792513      24.143162       total sum
# 4          305.000000      17.464249       Unweighted events, alpha=1.382926
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          678.905846      31.032666       total sum
# 5          479.000000      21.886069       Unweighted events, alpha=1.417340
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1079.033745     39.014473       total sum
# 6          765.000000      27.658633       Unweighted events, alpha=1.410502
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1513.677017     46.404851       total sum
# 7          1064.000000     32.619013       Unweighted events, alpha=1.422629
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          2346.965031     58.077370       total sum
# 8          1633.000000     40.410395       Unweighted events, alpha=1.437211
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          3321.718544     68.964176       total sum
# 9          2320.000000     48.166378       Unweighted events, alpha=1.431775
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         4027.778687     75.794699       total sum
# 10         2824.000000     53.141321       Unweighted events, alpha=1.426267
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         3977.508766     75.477987       total sum
# 11         2777.000000     52.697249       Unweighted events, alpha=1.432304
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         2993.254448     65.589397       total sum
# 12         2083.000000     45.639895       Unweighted events, alpha=1.436992
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         1892.630299     51.988109       total sum
# 13         1325.000000     36.400549       Unweighted events, alpha=1.428400
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1173.404076     40.818912       total sum
# 14         826.000000      28.740216       Unweighted events, alpha=1.420586
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         764.135344      32.809429       total sum
# 15         542.000000      23.280893       Unweighted events, alpha=1.409844
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         471.890148      25.658150       total sum
# 16         338.000000      18.384776       Unweighted events, alpha=1.396125
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         331.735704      21.453078       total sum
# 17         239.000000      15.459625       Unweighted events, alpha=1.388015
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         241.403082      18.356491       total sum
# 18         173.000000      13.152946       Unweighted events, alpha=1.395394
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         193.051435      16.076385       total sum
# 19         144.000000      12.000000       Unweighted events, alpha=1.340635
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          482.807804      25.382559       total sum
# 0          362.000000      19.026298       Unweighted events, alpha=1.333723
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          570.686073      27.689774       total sum
# 1          425.000000      20.615528       Unweighted events, alpha=1.342791
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          726.299191      31.560550       total sum
# 2          530.000000      23.021729       Unweighted events, alpha=1.370376
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          917.909424      35.672864       total sum
# 3          662.000000      25.729361       Unweighted events, alpha=1.386570
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1204.736237     41.247372       total sum
# 4          853.000000      29.206164       Unweighted events, alpha=1.412352
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1695.403435     49.018649       total sum
# 5          1196.000000     34.583233       Unweighted events, alpha=1.417561
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          2497.711372     59.594107       total sum
# 6          1757.000000     41.916584       Unweighted events, alpha=1.421577
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          3713.263817     72.847249       total sum
# 7          2598.000000     50.970580       Unweighted events, alpha=1.429278
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          5848.518539     91.634534       total sum
# 8          4074.000000     63.827894       Unweighted events, alpha=1.435572
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          9269.083115     115.667172      total sum
# 9          6422.000000     80.137382       Unweighted events, alpha=1.443333
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         11882.291840    130.892743      total sum
# 10         8241.000000     90.779954       Unweighted events, alpha=1.441851
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         12172.962677    132.641108      total sum
# 11         8422.000000     91.771455       Unweighted events, alpha=1.445377
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         9411.472488     116.349443      total sum
# 12         6543.000000     80.888813       Unweighted events, alpha=1.438403
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         6040.598785     93.289984       total sum
# 13         4193.000000     64.753378       Unweighted events, alpha=1.440639
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         3580.925980     71.475746       total sum
# 14         2510.000000     50.099900       Unweighted events, alpha=1.426664
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         2359.974693     58.013118       total sum
# 15         1655.000000     40.681691       Unweighted events, alpha=1.425967
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         1485.991581     45.841479       total sum
# 16         1051.000000     32.419130       Unweighted events, alpha=1.413884
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         1027.728107     38.007724       total sum
# 17         731.000000      27.037012       Unweighted events, alpha=1.405921
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         768.517994      32.711988       total sum
# 18         552.000000      23.494680       Unweighted events, alpha=1.392243
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         663.153065      30.340984       total sum
# 19         478.000000      21.863211       Unweighted events, alpha=1.387350
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-Cypmu6.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8e35cc0
#   Clients:
#     (0x8f7e6e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8e371e0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8d62cf0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 26272.6
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8e45020
#   Clients:
#     (0x8f7e6e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8e442e0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8e46010,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 76320
# Error in <TList::Clear>: A list is accessing an object (0x8faf364) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8faf60c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x91f9a30
#   Clients:
#     (0x91f8410,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9221620,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x8d62cf0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 3420.47
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x922c1f0
#   Clients:
#     (0x91f8410,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9258c00,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x8e46010,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 9576.65
# Error in <TList::Clear>: A list is accessing an object (0x8fafe04) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8fb00ac) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8e35cc0
#   Clients:
#     (0x8f7e6e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8e371e0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8d62cf0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 32509.8
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8e45020
#   Clients:
#     (0x8f7e6e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8e442e0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8e46010,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 95170.7
# Error in <TList::Clear>: A list is accessing an object (0x8fb0354) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8fb05fc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.25307  -0.00594195/+0.00602057  (68% CL)
# Done in 0.04 min (cpu), 0.04 min (real)

# %%
# !combine -M FitDiagnostics -n CR3_both  datacard_CR3_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          66.031909       9.257849        total sum
# 0          51.000000       7.141428        Unweighted events, alpha=1.294743
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          66.172189       9.414600        total sum
# 1          49.000000       7.000000        Unweighted events, alpha=1.350453
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          69.582237       9.643515        total sum
# 2          52.000000       7.211103        Unweighted events, alpha=1.338120
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          96.133203       11.587655       total sum
# 3          69.000000       8.306624        Unweighted events, alpha=1.393235
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          116.752975      12.671993       total sum
# 4          85.000000       9.219544        Unweighted events, alpha=1.373564
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          229.155352      18.087617       total sum
# 5          161.000000      12.688578       Unweighted events, alpha=1.423325
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          333.711500      21.732544       total sum
# 6          236.000000      15.362291       Unweighted events, alpha=1.414032
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          546.970358      27.847411       total sum
# 7          386.000000      19.646883       Unweighted events, alpha=1.417022
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          792.899435      33.640998       total sum
# 8          556.000000      23.579652       Unweighted events, alpha=1.426078
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1074.121622     39.082072       total sum
# 9          755.000000      27.477263       Unweighted events, alpha=1.422678
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1452.414354     45.731683       total sum
# 10         1009.000000     31.764760       Unweighted events, alpha=1.439459
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         1383.766140     44.623231       total sum
# 11         962.000000      31.016125       Unweighted events, alpha=1.438426
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1010.106558     38.134759       total sum
# 12         702.000000      26.495283       Unweighted events, alpha=1.438898
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         625.944893      29.989727       total sum
# 13         436.000000      20.880613       Unweighted events, alpha=1.435653
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         352.132761      22.371163       total sum
# 14         248.000000      15.748016       Unweighted events, alpha=1.419890
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         256.582683      19.095992       total sum
# 15         181.000000      13.453624       Unweighted events, alpha=1.417584
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         143.037863      13.885419       total sum
# 16         106.000000      10.295630       Unweighted events, alpha=1.349414
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         105.343035      11.960038       total sum
# 17         78.000000       8.831761        Unweighted events, alpha=1.350552
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         87.826086       10.917074       total sum
# 18         65.000000       8.062258        Unweighted events, alpha=1.351171
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         81.547492       10.706567       total sum
# 19         58.000000       7.615773        Unweighted events, alpha=1.405991
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          185.162577      15.792521       total sum
# 0          137.000000      11.704700       Unweighted events, alpha=1.351552
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          193.630886      16.038424       total sum
# 1          146.000000      12.083046       Unweighted events, alpha=1.326239
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          215.287424      17.013303       total sum
# 2          160.000000      12.649111       Unweighted events, alpha=1.345546
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          308.484154      20.498350       total sum
# 3          226.000000      15.033296       Unweighted events, alpha=1.364974
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          401.935501      23.607963       total sum
# 4          290.000000      17.029386       Unweighted events, alpha=1.385984
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          540.287537      27.559778       total sum
# 5          384.000000      19.595918       Unweighted events, alpha=1.406999
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          848.468697      34.753880       total sum
# 6          596.000000      24.413111       Unweighted events, alpha=1.423605
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1208.400124     41.526368       total sum
# 7          847.000000      29.103264       Unweighted events, alpha=1.426683
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1865.646271     51.777107       total sum
# 8          1298.000000     36.027767       Unweighted events, alpha=1.437324
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          2840.365540     63.894967       total sum
# 9          1976.000000     44.452222       Unweighted events, alpha=1.437432
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         3608.452278     72.161462       total sum
# 10         2501.000000     50.009999       Unweighted events, alpha=1.442804
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         3767.585152     73.686133       total sum
# 11         2614.000000     51.127292       Unweighted events, alpha=1.441310
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         2963.888435     65.247077       total sum
# 12         2063.000000     45.420260       Unweighted events, alpha=1.436689
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         1971.907429     53.276102       total sum
# 13         1370.000000     37.013511       Unweighted events, alpha=1.439348
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1192.505474     41.171494       total sum
# 14         839.000000      28.965497       Unweighted events, alpha=1.421341
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         735.522564      32.343104       total sum
# 15         517.000000      22.737634       Unweighted events, alpha=1.422674
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         475.092278      25.954647       total sum
# 16         335.000000      18.303005       Unweighted events, alpha=1.418186
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         344.793985      21.820980       total sum
# 17         250.000000      15.811388       Unweighted events, alpha=1.379176
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         252.770300      18.466985       total sum
# 18         187.000000      13.674794       Unweighted events, alpha=1.351713
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         195.556692      16.045691       total sum
# 19         149.000000      12.206556       Unweighted events, alpha=1.312461
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-SNPzav.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8af5620
#   Clients:
#     (0x8c3e070,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8af6b40,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8a22650,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 8890.23
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8b049b0
#   Clients:
#     (0x8c3e070,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8b03c70,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8b059a0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 24115.7
# Error in <TList::Clear>: A list is accessing an object (0x8c6ecd4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c6ef7c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8eb9c40
#   Clients:
#     (0x8eb8620,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8ee1900,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x8a22650,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 1061.45
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8eec530
#   Clients:
#     (0x8eb8620,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8f18ee0,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x8b059a0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 2792.14
# Error in <TList::Clear>: A list is accessing an object (0x8c6f774) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c6fa1c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8af5620
#   Clients:
#     (0x8c3e070,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8af6b40,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8a22650,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 9845.43
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8b049b0
#   Clients:
#     (0x8c3e070,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8b03c70,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8b059a0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 27032.5
# Error in <TList::Clear>: A list is accessing an object (0x8c6fcc4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c6ff6c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.12318  -0.00963512/+0.00974287  (68% CL)
# Done in 0.04 min (cpu), 0.06 min (real)

# %%
# !combine -M FitDiagnostics -n CR4_both  datacard_CR4_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          102.135937      8.804265        total sum
# 0          135.000000      11.618950       Unweighted events, alpha=0.756562
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          108.343643      8.909373        total sum
# 1          148.000000      12.165525       Unweighted events, alpha=0.732052
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          137.057732      10.650139       total sum
# 2          166.000000      12.884099       Unweighted events, alpha=0.825649
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          195.321072      14.074803       total sum
# 3          193.000000      13.892444       Unweighted events, alpha=1.012026
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          227.889828      15.560618       total sum
# 4          214.000000      14.628739       Unweighted events, alpha=1.064906
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          351.138874      20.378206       total sum
# 5          297.000000      17.233688       Unweighted events, alpha=1.182286
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          482.678162      24.482618       total sum
# 6          389.000000      19.723083       Unweighted events, alpha=1.240818
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          732.180984      30.675733       total sum
# 7          570.000000      23.874673       Unweighted events, alpha=1.284528
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1062.212410     37.457702       total sum
# 8          804.000000      28.354894       Unweighted events, alpha=1.321160
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1521.605766     44.998926       total sum
# 9          1143.000000     33.808283       Unweighted events, alpha=1.331239
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1768.883492     48.725307       total sum
# 10         1318.000000     36.304270       Unweighted events, alpha=1.342097
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         1686.596985     47.682875       total sum
# 11         1251.000000     35.369478       Unweighted events, alpha=1.348199
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1277.542351     41.274127       total sum
# 12         958.000000      30.951575       Unweighted events, alpha=1.333552
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         822.574532      32.579235       total sum
# 13         637.000000      25.238859       Unweighted events, alpha=1.291326
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         602.799568      27.787721       total sum
# 14         471.000000      21.702534       Unweighted events, alpha=1.279829
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         381.024078      21.266188       total sum
# 15         321.000000      17.916473       Unweighted events, alpha=1.186991
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         261.614929      16.646056       total sum
# 16         247.000000      15.716234       Unweighted events, alpha=1.059170
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         191.996010      13.521747       total sum
# 17         202.000000      14.212670       Unweighted events, alpha=0.950475
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         166.226692      11.800236       total sum
# 18         198.000000      14.071247       Unweighted events, alpha=0.839529
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         147.380890      11.046091       total sum
# 19         178.000000      13.341664       Unweighted events, alpha=0.827983
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          378.399582      17.444436       total sum
# 0          471.000000      21.702534       Unweighted events, alpha=0.803396
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          434.583435      20.111571       total sum
# 1          467.000000      21.610183       Unweighted events, alpha=0.930586
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          487.229858      21.232536       total sum
# 2          527.000000      22.956481       Unweighted events, alpha=0.924535
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          534.625198      22.772473       total sum
# 3          551.000000      23.473389       Unweighted events, alpha=0.970282
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          710.783691      27.632945       total sum
# 4          662.000000      25.729361       Unweighted events, alpha=1.073691
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          863.598587      31.312483       total sum
# 5          761.000000      27.586228       Unweighted events, alpha=1.134821
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1240.115952     39.045747       total sum
# 6          1009.000000     31.764760       Unweighted events, alpha=1.229054
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1798.356430     47.982744       total sum
# 7          1405.000000     37.483330       Unweighted events, alpha=1.279969
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          2766.175583     60.724167       total sum
# 8          2075.000000     45.552168       Unweighted events, alpha=1.333097
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          4203.861755     75.604564       total sum
# 9          3092.000000     55.605755       Unweighted events, alpha=1.359593
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         5668.813019     88.221808       total sum
# 10         4129.000000     64.257295       Unweighted events, alpha=1.372926
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         5895.883575     90.085499       total sum
# 11         4283.000000     65.444633       Unweighted events, alpha=1.376578
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         4434.585419     77.654065       total sum
# 12         3261.000000     57.105166       Unweighted events, alpha=1.359885
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         2872.307907     61.713784       total sum
# 13         2166.000000     46.540305       Unweighted events, alpha=1.326089
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1699.209106     46.431139       total sum
# 14         1339.000000     36.592349       Unweighted events, alpha=1.269014
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         1117.826935     36.544426       total sum
# 15         936.000000      30.594117       Unweighted events, alpha=1.194260
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         838.785324      30.662038       total sum
# 16         748.000000      27.349589       Unweighted events, alpha=1.121371
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         640.166687      25.448464       total sum
# 17         633.000000      25.159491       Unweighted events, alpha=1.011322
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         523.067093      21.874815       total sum
# 18         572.000000      23.916521       Unweighted events, alpha=0.914453
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         436.690475      19.245910       total sum
# 19         515.000000      22.693611       Unweighted events, alpha=0.847943
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-tP5DsR.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x81fac10
#   Clients:
#     (0x8343660,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x81fc130,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8127c50,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 12227.2
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8209fa0
#   Clients:
#     (0x8343660,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8209260,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x820af90,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 37545.1
# Error in <TList::Clear>: A list is accessing an object (0x8374334) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x83745dc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x85be730
#   Clients:
#     (0x85bd110,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x85e6690,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x8127c50,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 2287.64
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x85f1320
#   Clients:
#     (0x85bd110,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x861dcd0,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x820af90,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 6781.76
# Error in <TList::Clear>: A list is accessing an object (0x8374dd4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x837507c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x81fac10
#   Clients:
#     (0x8343660,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x81fc130,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8127c50,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 14863.2
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8209fa0
#   Clients:
#     (0x8343660,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8209260,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x820af90,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 45280.7
# Error in <TList::Clear>: A list is accessing an object (0x8375324) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x83755cc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.23597  -0.00886074/+0.00898217  (68% CL)
# Done in 0.04 min (cpu), 0.04 min (real)

# %%
# !combine -M FitDiagnostics -n CR5_both  datacard_CR5_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          37.080747       4.145574        total sum
# 0          80.000000       8.944272        Unweighted events, alpha=0.463509
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          52.101019       6.071456        total sum
# 1          74.000000       8.602325        Unweighted events, alpha=0.704068
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          68.512794       7.548071        total sum
# 2          82.000000       9.055385        Unweighted events, alpha=0.835522
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          51.419420       6.160902        total sum
# 3          70.000000       8.366600        Unweighted events, alpha=0.734563
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          89.646358       9.415744        total sum
# 4          91.000000       9.539392        Unweighted events, alpha=0.985125
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          93.249210       9.403137        total sum
# 5          98.000000       9.899495        Unweighted events, alpha=0.951523
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          170.874809      14.334017       total sum
# 6          142.000000      11.916375       Unweighted events, alpha=1.203344
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          257.970055      18.058409       total sum
# 7          204.000000      14.282857       Unweighted events, alpha=1.264559
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          370.675735      22.061432       total sum
# 8          282.000000      16.792856       Unweighted events, alpha=1.314453
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          546.076420      27.042919       total sum
# 9          408.000000      20.199010       Unweighted events, alpha=1.338423
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         551.292973      27.161892       total sum
# 10         412.000000      20.297783       Unweighted events, alpha=1.338090
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         613.311272      28.726154       total sum
# 11         456.000000      21.354157       Unweighted events, alpha=1.344981
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         428.793591      23.493896       total sum
# 12         333.000000      18.248288       Unweighted events, alpha=1.287668
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         255.054447      17.749461       total sum
# 13         206.000000      14.352700       Unweighted events, alpha=1.238128
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         194.961758      15.122937       total sum
# 14         166.000000      12.884099       Unweighted events, alpha=1.174468
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         149.767685      13.042280       total sum
# 15         132.000000      11.489125       Unweighted events, alpha=1.134604
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         97.161674       9.898795        total sum
# 16         96.000000       9.797959        Unweighted events, alpha=1.012101
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         72.734322       7.638798        total sum
# 17         91.000000       9.539392        Unweighted events, alpha=0.799278
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         70.030552       7.182696        total sum
# 18         95.000000       9.746794        Unweighted events, alpha=0.737164
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         52.085941       5.405448        total sum
# 19         93.000000       9.643651        Unweighted events, alpha=0.560064
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          154.216522      10.171607       total sum
# 0          230.000000      15.165751       Unweighted events, alpha=0.670507
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          117.774746      7.328988        total sum
# 1          258.000000      16.062378       Unweighted events, alpha=0.456491
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          175.206947      11.413155       total sum
# 2          236.000000      15.362291       Unweighted events, alpha=0.742402
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          211.749619      13.564260       total sum
# 3          244.000000      15.620499       Unweighted events, alpha=0.867826
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          250.385231      15.390660       total sum
# 4          265.000000      16.278821       Unweighted events, alpha=0.944850
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          290.808502      17.284048       total sum
# 5          283.000000      16.822604       Unweighted events, alpha=1.027592
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          405.069771      21.408451       total sum
# 6          358.000000      18.920888       Unweighted events, alpha=1.131480
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          523.985817      24.799668       total sum
# 7          446.000000      21.118712       Unweighted events, alpha=1.174856
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          833.213837      32.524172       total sum
# 8          656.000000      25.612497       Unweighted events, alpha=1.270143
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1310.082298     41.608387       total sum
# 9          991.000000      31.480152       Unweighted events, alpha=1.321980
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1730.013084     48.213929       total sum
# 10         1288.000000     35.888717       Unweighted events, alpha=1.343178
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         1785.614449     49.136994       total sum
# 11         1321.000000     36.345564       Unweighted events, alpha=1.351714
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1386.796707     42.816456       total sum
# 12         1049.000000     32.388269       Unweighted events, alpha=1.322018
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         902.676430      34.030307       total sum
# 13         704.000000      26.532998       Unweighted events, alpha=1.282211
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         590.376869      26.845822       total sum
# 14         484.000000      22.000000       Unweighted events, alpha=1.219787
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         360.623222      19.743902       total sum
# 15         334.000000      18.275667       Unweighted events, alpha=1.079710
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         270.210899      16.138085       total sum
# 16         280.000000      16.733201       Unweighted events, alpha=0.965039
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         226.323418      14.054753       total sum
# 17         259.000000      16.093477       Unweighted events, alpha=0.873836
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         190.920334      12.160300       total sum
# 18         246.000000      15.684387       Unweighted events, alpha=0.776099
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         167.354729      10.808159       total sum
# 19         240.000000      15.491933       Unweighted events, alpha=0.697311
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-A9CNGI.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x86fd0a0
#   Clients:
#     (0x8845ae0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x86fe5c0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x862a0d0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 4222.8
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x870c420
#   Clients:
#     (0x8845ae0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x870b6e0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x870d410,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 11883.4
# Error in <TList::Clear>: A list is accessing an object (0x8876764) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8876a0c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8ac0ad0
#   Clients:
#     (0x8abf4b0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8ae87d0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x862a0d0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 949.453
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8af3340
#   Clients:
#     (0x8abf4b0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8b1fc90,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x870d410,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 2772.86
# Error in <TList::Clear>: A list is accessing an object (0x8877204) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x88774ac) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x86fd0a0
#   Clients:
#     (0x8845ae0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x86fe5c0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x862a0d0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 5104.12
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x870c420
#   Clients:
#     (0x8845ae0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x870b6e0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x870d410,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 14455.7
# Error in <TList::Clear>: A list is accessing an object (0x8877754) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x88779fc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.26357  -0.0165981/+0.0168888  (68% CL)
# Done in 0.04 min (cpu), 0.08 min (real)

# %%
# !combine -M FitDiagnostics -n CR6_both  datacard_CR6_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          42.975005       4.021254        total sum
# 0          114.000000      10.677078       Unweighted events, alpha=0.376974
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          39.233063       2.786226        total sum
# 1          198.000000      14.071247       Unweighted events, alpha=0.198147
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          44.187107       4.024913        total sum
# 2          121.000000      11.000000       Unweighted events, alpha=0.365183
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          50.311063       4.579959        total sum
# 3          121.000000      11.000000       Unweighted events, alpha=0.415794
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          46.914209       4.151151        total sum
# 4          128.000000      11.313708       Unweighted events, alpha=0.366517
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          56.922583       5.613934        total sum
# 5          103.000000      10.148892       Unweighted events, alpha=0.552646
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          72.227280       6.880532        total sum
# 6          110.000000      10.488088       Unweighted events, alpha=0.656612
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          98.558453       8.793603        total sum
# 7          126.000000      11.224972       Unweighted events, alpha=0.782210
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          128.863674      11.096527       total sum
# 8          135.000000      11.618950       Unweighted events, alpha=0.954546
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          189.306808      14.122500       total sum
# 9          180.000000      13.416408       Unweighted events, alpha=1.051704
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         216.480717      15.325651       total sum
# 10         200.000000      14.142136       Unweighted events, alpha=1.082404
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         214.583786      15.515852       total sum
# 11         191.000000      13.820275       Unweighted events, alpha=1.123475
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         152.831631      12.333454       total sum
# 12         154.000000      12.409674       Unweighted events, alpha=0.992413
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         120.429768      10.193849       total sum
# 13         140.000000      11.832160       Unweighted events, alpha=0.860213
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         87.893272       8.115498        total sum
# 14         117.000000      10.816654       Unweighted events, alpha=0.751225
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         63.960606       5.713830        total sum
# 15         125.000000      11.180340       Unweighted events, alpha=0.511685
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         57.415330       4.788906        total sum
# 16         144.000000      12.000000       Unweighted events, alpha=0.398718
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         51.182573       3.613974        total sum
# 17         201.000000      14.177447       Unweighted events, alpha=0.254640
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         55.356764       4.184122        total sum
# 18         175.000000      13.228757       Unweighted events, alpha=0.316324
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         48.436479       3.110964        total sum
# 19         242.000000      15.556349       Unweighted events, alpha=0.200151
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          125.190741      5.224719        total sum
# 0          574.000000      23.958297       Unweighted events, alpha=0.218102
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          133.937048      6.138903        total sum
# 1          476.000000      21.817424       Unweighted events, alpha=0.281380
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          138.452608      6.536226        total sum
# 2          449.000000      21.189620       Unweighted events, alpha=0.308358
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          150.501743      7.866071        total sum
# 3          366.000000      19.131126       Unweighted events, alpha=0.411207
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          152.185665      7.741968        total sum
# 4          386.000000      19.646883       Unweighted events, alpha=0.394263
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          177.842682      9.863770        total sum
# 5          325.000000      18.027756       Unweighted events, alpha=0.547208
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          202.689590      11.228823       total sum
# 6          326.000000      18.055470       Unweighted events, alpha=0.621747
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          244.680771      13.459320       total sum
# 7          330.000000      18.165902       Unweighted events, alpha=0.741457
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          374.681175      19.073893       total sum
# 8          386.000000      19.646883       Unweighted events, alpha=0.970677
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          491.978577      22.625675       total sum
# 9          473.000000      21.748563       Unweighted events, alpha=1.040124
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         654.455338      27.114471       total sum
# 10         583.000000      24.145393       Unweighted events, alpha=1.122565
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         668.914383      27.399742       total sum
# 11         596.000000      24.413111       Unweighted events, alpha=1.122340
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         505.093933      22.959639       total sum
# 12         484.000000      22.000000       Unweighted events, alpha=1.043583
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         389.201874      19.186011       total sum
# 13         412.000000      20.297783       Unweighted events, alpha=0.944665
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         261.230545      14.229440       total sum
# 14         337.000000      18.357560       Unweighted events, alpha=0.775165
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         210.798386      11.429883       total sum
# 15         340.000000      18.439089       Unweighted events, alpha=0.619995
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         181.520447      9.630975        total sum
# 16         355.000000      18.841444       Unweighted events, alpha=0.511325
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         154.154438      7.506483        total sum
# 17         422.000000      20.542639       Unweighted events, alpha=0.365295
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         147.251188      6.673416        total sum
# 18         487.000000      22.068076       Unweighted events, alpha=0.302364
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         134.007820      5.912693        total sum
# 19         514.000000      22.671568       Unweighted events, alpha=0.260716
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-xFJYXV.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x91bdb50
#   Clients:
#     (0x93065a0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x91bf070,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x90eab80,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 1838.07
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x91ccee0
#   Clients:
#     (0x93065a0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x91cc1a0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x91cded0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 5498.77
# Error in <TList::Clear>: A list is accessing an object (0x9337274) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x933751c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x95817b0
#   Clients:
#     (0x9580190,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x95a9590,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x90eab80,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 878.45
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x95b41c0
#   Clients:
#     (0x9580190,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x95e0990,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x91cded0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 2589.84
# Error in <TList::Clear>: A list is accessing an object (0x9337d14) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9337fbc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x91bdb50
#   Clients:
#     (0x93065a0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x91bf070,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x90eab80,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 2091.13
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x91ccee0
#   Clients:
#     (0x93065a0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x91cc1a0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x91cded0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 6259.82
# Error in <TList::Clear>: A list is accessing an object (0x9338264) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x933850c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.25039  -0.030678/+0.0317249  (68% CL)
# Done in 0.05 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR7_both  datacard_CR7_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          23.577398       1.793513        total sum
# 0          173.000000      13.152946       Unweighted events, alpha=0.136286
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          25.123806       2.592683        total sum
# 1          94.000000       9.695360        Unweighted events, alpha=0.267275
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          28.965848       3.420029        total sum
# 2          72.000000       8.485281        Unweighted events, alpha=0.402303
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          35.820408       4.283967        total sum
# 3          70.000000       8.366600        Unweighted events, alpha=0.511720
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          29.779694       3.456625        total sum
# 4          74.000000       8.602325        Unweighted events, alpha=0.402428
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          37.510685       4.743623        total sum
# 5          63.000000       7.937254        Unweighted events, alpha=0.595408
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          55.772955       6.692046        total sum
# 6          69.000000       8.306624        Unweighted events, alpha=0.808304
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          48.867374       6.055432        total sum
# 7          65.000000       8.062258        Unweighted events, alpha=0.751806
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          73.045475       8.228156        total sum
# 8          79.000000       8.888194        Unweighted events, alpha=0.924626
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          86.238358       9.370135        total sum
# 9          85.000000       9.219544        Unweighted events, alpha=1.014569
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         99.399729       10.038516       total sum
# 10         98.000000       9.899495        Unweighted events, alpha=1.014283
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         105.533522      10.271637       total sum
# 11         106.000000      10.295630       Unweighted events, alpha=0.995599
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         84.645540       9.068490        total sum
# 12         87.000000       9.327379        Unweighted events, alpha=0.972937
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         56.071981       6.641041        total sum
# 13         71.000000       8.426150        Unweighted events, alpha=0.789746
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         59.808254       7.005981        total sum
# 14         73.000000       8.544004        Unweighted events, alpha=0.819291
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         39.854720       4.576559        total sum
# 15         76.000000       8.717798        Unweighted events, alpha=0.524404
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         39.973505       4.343931        total sum
# 16         85.000000       9.219544        Unweighted events, alpha=0.470277
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         27.962539       2.357150        total sum
# 17         141.000000      11.874342       Unweighted events, alpha=0.198316
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         34.296346       3.716330        total sum
# 18         85.000000       9.219544        Unweighted events, alpha=0.403486
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         31.657104       3.444581        total sum
# 19         84.000000       9.165151        Unweighted events, alpha=0.376870
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          74.357033       3.755314        total sum
# 0          392.000000      19.798990       Unweighted events, alpha=0.189686
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          70.900490       3.158431        total sum
# 1          504.000000      22.449944       Unweighted events, alpha=0.140676
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          90.080212       6.256031        total sum
# 2          207.000000      14.387495       Unweighted events, alpha=0.435170
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          93.231054       6.417862        total sum
# 3          211.000000      14.525839       Unweighted events, alpha=0.441853
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          95.848978       6.366085        total sum
# 4          227.000000      15.066519       Unweighted events, alpha=0.422242
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          97.933239       6.771668        total sum
# 5          209.000000      14.456832       Unweighted events, alpha=0.468580
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          123.032539      8.933843        total sum
# 6          190.000000      13.784049       Unweighted events, alpha=0.647540
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          146.478813      10.369669       total sum
# 7          200.000000      14.142136       Unweighted events, alpha=0.732394
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          169.516960      11.779856       total sum
# 8          207.000000      14.387495       Unweighted events, alpha=0.818923
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          254.259933      15.905739       total sum
# 9          256.000000      16.000000       Unweighted events, alpha=0.993203
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         348.337135      19.515179       total sum
# 10         319.000000      17.860571       Unweighted events, alpha=1.091966
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         292.899834      17.390638       total sum
# 11         284.000000      16.852300       Unweighted events, alpha=1.031337
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         258.261238      16.155827       total sum
# 12         256.000000      16.000000       Unweighted events, alpha=1.008833
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         204.228020      13.565739       total sum
# 13         227.000000      15.066519       Unweighted events, alpha=0.899683
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         138.621948      10.140039       total sum
# 14         187.000000      13.674794       Unweighted events, alpha=0.741294
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         109.064072      7.441012        total sum
# 15         215.000000      14.662878       Unweighted events, alpha=0.507275
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         94.896767       5.959581        total sum
# 16         254.000000      15.937377       Unweighted events, alpha=0.373609
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         99.313879       6.127791        total sum
# 17         263.000000      16.217275       Unweighted events, alpha=0.377619
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         86.171982       5.225567        total sum
# 18         272.000000      16.492423       Unweighted events, alpha=0.316809
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         83.558856       4.730217        total sum
# 19         312.000000      17.663522       Unweighted events, alpha=0.267817
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-uIXoNW.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x835dcb0
#   Clients:
#     (0x84a66d0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x835f1d0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x828ace0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 1023.91
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x836d010
#   Clients:
#     (0x84a66d0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x836c2d0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x836e000,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 2930.99
# Error in <TList::Clear>: A list is accessing an object (0x84d7354) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x84d75fc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8721950
#   Clients:
#     (0x8720330,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8749650,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x828ace0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 530.095
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8754280
#   Clients:
#     (0x8720330,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8780b10,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x836e000,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 1523.37
# Error in <TList::Clear>: A list is accessing an object (0x84d7df4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x84d809c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x835dcb0
#   Clients:
#     (0x84a66d0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x835f1d0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x828ace0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 1175.19
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x836d010
#   Clients:
#     (0x84a66d0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x836c2d0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x836e000,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 3358.37
# Error in <TList::Clear>: A list is accessing an object (0x84d8344) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x84d85ec) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.30465  -0.0459261/+0.0482549  (68% CL)
# Done in 0.04 min (cpu), 0.09 min (real)

# %%
# !combine -M FitDiagnostics -n SR8_both  datacard_SR8_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          33.543782       4.119515        total sum
# 0          66.000000       8.124038        Unweighted events, alpha=0.508239
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          45.896170       4.922863        total sum
# 1          87.000000       9.327379        Unweighted events, alpha=0.527542
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          44.842880       5.087940        total sum
# 2          78.000000       8.831761        Unweighted events, alpha=0.574909
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          59.261915       6.742597        total sum
# 3          77.000000       8.774964        Unweighted events, alpha=0.769635
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          64.646742       7.293069        total sum
# 4          79.000000       8.888194        Unweighted events, alpha=0.818313
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          83.402679       8.968563        total sum
# 5          86.000000       9.273618        Unweighted events, alpha=0.969799
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          103.759266      10.335505       total sum
# 6          101.000000      10.049876       Unweighted events, alpha=1.027319
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          180.045017      14.524149       total sum
# 7          154.000000      12.409674       Unweighted events, alpha=1.169123
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          183.906155      14.672158       total sum
# 8          157.000000      12.529964       Unweighted events, alpha=1.171377
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          294.504086      18.957160       total sum
# 9          241.000000      15.524175       Unweighted events, alpha=1.222009
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         381.291954      21.989423       total sum
# 10         301.000000      17.349352       Unweighted events, alpha=1.266751
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         323.726654      20.259690       total sum
# 11         255.000000      15.968719       Unweighted events, alpha=1.269516
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         258.303986      17.783996       total sum
# 12         211.000000      14.525839       Unweighted events, alpha=1.224190
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         160.667255      13.518334       total sum
# 13         141.000000      11.874342       Unweighted events, alpha=1.139484
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         107.707169      10.304571       total sum
# 14         109.000000      10.440307       Unweighted events, alpha=0.988139
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         79.040527       8.002447        total sum
# 15         98.000000       9.899495        Unweighted events, alpha=0.806536
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         66.450302       7.092198        total sum
# 16         88.000000       9.380832        Unweighted events, alpha=0.755117
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         58.348503       6.424458        total sum
# 17         82.000000       9.055385        Unweighted events, alpha=0.711567
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         50.795017       5.088313        total sum
# 18         100.000000      10.000000       Unweighted events, alpha=0.507950
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         45.142448       4.683859        total sum
# 19         93.000000       9.643651        Unweighted events, alpha=0.485403
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          106.225132      6.719724        total sum
# 0          250.000000      15.811388       Unweighted events, alpha=0.424901
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          116.360092      7.077906        total sum
# 1          270.000000      16.431677       Unweighted events, alpha=0.430963
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          124.906837      7.785734        total sum
# 2          257.000000      16.031220       Unweighted events, alpha=0.486019
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          149.864098      10.026471       total sum
# 3          223.000000      14.933185       Unweighted events, alpha=0.672036
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          177.323631      11.851882       total sum
# 4          224.000000      14.966630       Unweighted events, alpha=0.791623
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          202.965828      13.386494       total sum
# 5          230.000000      15.165751       Unweighted events, alpha=0.882460
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          259.013634      15.843668       total sum
# 6          267.000000      16.340135       Unweighted events, alpha=0.970089
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          356.559341      19.795110       total sum
# 7          324.000000      18.000000       Unweighted events, alpha=1.100492
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          450.348366      22.732033       total sum
# 8          392.000000      19.798990       Unweighted events, alpha=1.148848
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          701.120270      29.600351       total sum
# 9          561.000000      23.685439       Unweighted events, alpha=1.249769
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         958.343948      35.210911       total sum
# 10         741.000000      27.221315       Unweighted events, alpha=1.293312
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         947.786430      34.744385       total sum
# 11         744.000000      27.276363       Unweighted events, alpha=1.273906
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         756.369232      30.675416       total sum
# 12         608.000000      24.657656       Unweighted events, alpha=1.244028
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         499.437637      24.265311       total sum
# 13         424.000000      20.591260       Unweighted events, alpha=1.177919
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         329.142227      18.195272       total sum
# 14         327.000000      18.083141       Unweighted events, alpha=1.006551
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         248.678268      15.145071       total sum
# 15         270.000000      16.431677       Unweighted events, alpha=0.921031
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         181.039238      11.732355       total sum
# 16         238.000000      15.427249       Unweighted events, alpha=0.760669
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         157.290047      10.346677       total sum
# 17         231.000000      15.198684       Unweighted events, alpha=0.680909
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         145.897285      9.859397        total sum
# 18         219.000000      14.798649       Unweighted events, alpha=0.666198
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         125.522648      8.222577        total sum
# 19         233.000000      15.264338       Unweighted events, alpha=0.538724
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-lBARBO.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9707990
#   Clients:
#     (0x98503e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9708eb0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x96349c0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 2625.28
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9716d20
#   Clients:
#     (0x98503e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9715fe0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x9717d10,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 6994.19
# Error in <TList::Clear>: A list is accessing an object (0x9881094) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x988133c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9acbd10
#   Clients:
#     (0x9aca6f0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9af3c70,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x96349c0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 830.955
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9afe900
#   Clients:
#     (0x9aca6f0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9b2b130,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x9717d10,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 2240.58
# Error in <TList::Clear>: A list is accessing an object (0x9881b34) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9881ddc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9707990
#   Clients:
#     (0x98503e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9708eb0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x96349c0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 3031.7
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9716d20
#   Clients:
#     (0x98503e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9715fe0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x9717d10,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 8066.92
# Error in <TList::Clear>: A list is accessing an object (0x9882084) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x988232c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.22  -0.0228247/+0.0233815  (68% CL)
# Done in 0.04 min (cpu), 0.04 min (real)
