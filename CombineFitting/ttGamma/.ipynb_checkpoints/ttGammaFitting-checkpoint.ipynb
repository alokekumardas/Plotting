# %%
import ROOT
import os
# Out:
# Welcome to JupyROOT 6.12/07

# %%
# !combine -M FitDiagnostics -n SR datacard_SR.txt  --redefineSignalPOIs r,nonPromptTTGammaSF --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel M3 will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binM3
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          6.373408        3.297555        total sum
# 0          4.000000        2.000000        Unweighted events, alpha=1.593352
#   => Total parameter prop_binM3_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          18.593060       5.752703        total sum
# 1          10.000000       3.162278        Unweighted events, alpha=1.859306
#   => Total parameter prop_binM3_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          35.377380       8.230783        total sum
# ...
