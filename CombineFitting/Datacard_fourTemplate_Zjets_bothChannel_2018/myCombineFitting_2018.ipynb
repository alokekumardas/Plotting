# %%
import ROOT
import os
# !pwd
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/TTGammaSemiLep_13TeV/Plotting/CombineFitting/Datacard_fourTemplate_Zjets_bothChannel_2018

# %%
# !combine -M FitDiagnostics -n CR123  datacard_CR123.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          607.153191      53.142955       total sum
# 0          131.000000      11.445523       Unweighted events, alpha=4.634757
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          946.523270      101.401051      total sum
# 1          87.000000       9.327379        Unweighted events, alpha=10.879578
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1083.805344     83.979133       total sum
# 2          167.000000      12.922848       Unweighted events, alpha=6.489852
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1464.116516     160.834004      total sum
# 3          83.000000       9.110434        Unweighted events, alpha=17.639958
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          642.474670      97.702639       total sum
# 4          43.000000       6.557439        Unweighted events, alpha=14.941271
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          785.449402      57.253213       total sum
# 5          188.000000      13.711309       Unweighted events, alpha=4.177922
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1232.076981     72.665731       total sum
# 6          287.000000      16.941074       Unweighted events, alpha=4.292951
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          2202.720779     97.263787       total sum
# 7          513.000000      22.649503       Unweighted events, alpha=4.293803
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          3834.562500     150.731844      total sum
# 8          647.000000      25.436195       Unweighted events, alpha=5.926681
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          6421.819824     2714.850524     total sum
# 9          6.000000        2.449490        Unweighted events, alpha=1070.303304
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         2265.173462     98.310632       total sum
# 10         531.000000      23.043437       Unweighted events, alpha=4.265863
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         882.709717      61.725465       total sum
# 11         205.000000      14.317821       Unweighted events, alpha=4.305901
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         857.736145      349.409927      total sum
# 12         6.000000        2.449490        Unweighted events, alpha=142.956024
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         280.654297      35.290415       total sum
# 13         63.000000       7.937254        Unweighted events, alpha=4.454830
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1043.269562     125.943805      total sum
# 14         69.000000       8.306624        Unweighted events, alpha=15.119849
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         901.276871      154.104857      total sum
# 15         34.000000       5.830952        Unweighted events, alpha=26.508143
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         678.517464      141.042011      total sum
# 16         23.000000       4.795832        Unweighted events, alpha=29.500759
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         553.641281      94.259965       total sum
# 17         34.000000       5.830952        Unweighted events, alpha=16.283567
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         381.355476      40.779250       total sum
# 18         87.000000       9.327379        Unweighted events, alpha=4.383396
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         307.908928      34.567187       total sum
# 19         79.000000       8.888194        Unweighted events, alpha=3.897581
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1421.876083     348.273353      total sum
# 0          17.000000       4.123106        Unweighted events, alpha=83.639770
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1524.356010     118.176608      total sum
# 1          166.000000      12.884099       Unweighted events, alpha=9.182868
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          3656.609337     1665.048444     total sum
# 2          5.000000        2.236068        Unweighted events, alpha=731.321867
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          3345.488483     1329.941718     total sum
# 3          6.000000        2.449490        Unweighted events, alpha=557.581414
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1214.227859     71.388722       total sum
# 4          289.000000      17.000000       Unweighted events, alpha=4.201480
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1089.669548     224.589752      total sum
# 5          24.000000       4.898979        Unweighted events, alpha=45.402898
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          794.139660      56.053415       total sum
# 6          201.000000      14.177447       Unweighted events, alpha=3.950944
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          932.389854      208.746304      total sum
# 7          20.000000       4.472136        Unweighted events, alpha=46.619493
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          559.868755      59.895987       total sum
# 8          87.000000       9.327379        Unweighted events, alpha=6.435273
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          455.947348      59.721814       total sum
# 9          58.000000       7.615773        Unweighted events, alpha=7.861161
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         410.211082      40.265321       total sum
# 10         104.000000      10.198039       Unweighted events, alpha=3.944337
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         266.389819      27.682183       total sum
# 11         93.000000       9.643651        Unweighted events, alpha=2.864407
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-VCs0hA.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.59838  -0.0388418/+0.0401408  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)

# %%
# !combine -M FitDiagnostics -n CR1  datacard_CR1.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          404.380249      47.400131       total sum
# 0          73.000000       8.544004        Unweighted events, alpha=5.539455
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          676.265549      92.354790       total sum
# 1          54.000000       7.348469        Unweighted events, alpha=12.523436
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          716.750000      68.139083       total sum
# 2          111.000000      10.535654       Unweighted events, alpha=6.457207
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1185.496826     90.269251       total sum
# 3          172.000000      13.114877       Unweighted events, alpha=6.892423
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          523.827042      95.637852       total sum
# 4          30.000000       5.477226        Unweighted events, alpha=17.460901
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          620.332336      51.977583       total sum
# 5          142.000000      11.916375       Unweighted events, alpha=4.368538
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          936.678314      64.357540       total sum
# 6          212.000000      14.560220       Unweighted events, alpha=4.418294
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1762.893036     87.699810       total sum
# 7          404.000000      20.099751       Unweighted events, alpha=4.363597
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          3026.575623     137.768755      total sum
# 8          483.000000      21.977261       Unweighted events, alpha=6.266202
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          2879.980225     109.466275      total sum
# 9          692.000000      26.305893       Unweighted events, alpha=4.161821
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1824.962250     88.612667       total sum
# 10         424.000000      20.591260       Unweighted events, alpha=4.304156
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         596.383873      50.968412       total sum
# 11         137.000000      11.704700       Unweighted events, alpha=4.353167
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         386.699722      40.834171       total sum
# 12         90.000000       9.486833        Unweighted events, alpha=4.296664
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         210.943130      31.402630       total sum
# 13         45.000000       6.708204        Unweighted events, alpha=4.687625
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         579.859772      85.114358       total sum
# 14         46.000000       6.782330        Unweighted events, alpha=12.605647
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         655.975586      151.192173      total sum
# 15         19.000000       4.358899        Unweighted events, alpha=34.525031
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         461.442017      128.301928      total sum
# 16         13.000000       3.605551        Unweighted events, alpha=35.495540
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         352.251091      90.231682       total sum
# 17         15.000000       3.872983        Unweighted events, alpha=23.483406
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         237.751293      32.450678       total sum
# 18         54.000000       7.348469        Unweighted events, alpha=4.402802
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         205.989449      30.394184       total sum
# 19         46.000000       6.782330        Unweighted events, alpha=4.478031
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          748.447716      66.929834       total sum
# 0          125.000000      11.180340       Unweighted events, alpha=5.987582
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1084.448568     107.709079      total sum
# 1          101.000000      10.049876       Unweighted events, alpha=10.737115
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          3076.936344     1662.555326     total sum
# 2          3.000000        1.732051        Unweighted events, alpha=1025.645448
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          2747.262699     1327.370517     total sum
# 3          4.000000        2.000000        Unweighted events, alpha=686.815675
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          762.722412      59.965051       total sum
# 4          162.000000      12.727922       Unweighted events, alpha=4.708163
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          768.764017      222.536325      total sum
# 5          12.000000       3.464102        Unweighted events, alpha=64.063668
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          475.085695      47.288545       total sum
# 6          101.000000      10.049876       Unweighted events, alpha=4.703819
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          711.742151      207.620341      total sum
# 7          12.000000       3.464102        Unweighted events, alpha=59.311846
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          326.192726      54.062128       total sum
# 8          36.000000       6.000000        Unweighted events, alpha=9.060909
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          300.282995      57.429588       total sum
# 9          27.000000       5.196152        Unweighted events, alpha=11.121592
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         248.715348      33.578029       total sum
# 10         55.000000       7.416198        Unweighted events, alpha=4.522097
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         160.865992      25.422442       total sum
# 11         40.000000       6.324555        Unweighted events, alpha=4.021650
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-8ZXQkO.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.61173  -0.0367322/+0.037969  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)

# %%
# !combine -M FitDiagnostics -n CR2  datacard_CR2.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          138.038018      21.000224       total sum
# 0          43.000000       6.557439        Unweighted events, alpha=3.210186
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          193.718741      40.612661       total sum
# 1          23.000000       4.795832        Unweighted events, alpha=8.422554
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          274.290596      48.088983       total sum
# 2          33.000000       5.744563        Unweighted events, alpha=8.311836
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          155.791840      131.973504      total sum
# 3          1.000000        1.000000        Unweighted events, alpha=155.791840
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          92.651405       18.763301       total sum
# 4          24.000000       4.898979        Unweighted events, alpha=3.860475
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          122.533106      20.941011       total sum
# 5          34.000000       5.830952        Unweighted events, alpha=3.603915
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          239.230484      30.554936       total sum
# 6          61.000000       7.810250        Unweighted events, alpha=3.921811
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          351.621502      38.370773       total sum
# 7          84.000000       9.165151        Unweighted events, alpha=4.185970
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          655.724495      56.179711       total sum
# 8          136.000000      11.661904       Unweighted events, alpha=4.821504
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          3389.274597     2712.539186     total sum
# 9          2.000000        1.414214        Unweighted events, alpha=1694.637299
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         324.820457      37.468148       total sum
# 10         75.000000       8.660254        Unweighted events, alpha=4.330939
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         230.207962      31.961487       total sum
# 11         52.000000       7.211103        Unweighted events, alpha=4.427076
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         444.699684      346.920140      total sum
# 12         2.000000        1.414214        Unweighted events, alpha=222.349842
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         46.677055       14.471476       total sum
# 13         10.000000       3.162278        Unweighted events, alpha=4.667706
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         360.606857      90.932771       total sum
# 14         16.000000       4.000000        Unweighted events, alpha=22.537929
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         162.744549      26.042255       total sum
# 15         39.000000       6.244998        Unweighted events, alpha=4.172937
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         150.451580      56.808107       total sum
# 16         7.000000        2.645751        Unweighted events, alpha=21.493083
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         128.994807      22.718540       total sum
# 17         32.000000       5.656854        Unweighted events, alpha=4.031088
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         84.573729       21.880208       total sum
# 18         15.000000       3.872983        Unweighted events, alpha=5.638249
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         47.598072       8.842270        total sum
# 19         29.000000       5.385165        Unweighted events, alpha=1.641313
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          561.236193      341.498703      total sum
# 0          3.000000        1.732051        Unweighted events, alpha=187.078731
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          294.915520      31.990038       total sum
# 1          85.000000       9.219544        Unweighted events, alpha=3.469594
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          353.939961      35.209031       total sum
# 2          101.000000      10.049876       Unweighted events, alpha=3.504356
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          447.361399      81.181417       total sum
# 3          30.000000       5.477226        Unweighted events, alpha=14.912047
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          315.502861      33.855743       total sum
# 4          87.000000       9.327379        Unweighted events, alpha=3.626470
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          221.319976      27.885514       total sum
# 5          63.000000       7.937254        Unweighted events, alpha=3.513015
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          219.874002      27.973772       total sum
# 6          62.000000       7.874008        Unweighted events, alpha=3.546355
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          123.972578      13.060710       total sum
# 7          90.000000       9.486833        Unweighted events, alpha=1.377473
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          153.295550      22.439025       total sum
# 8          47.000000       6.855655        Unweighted events, alpha=3.261607
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          102.868727      14.236745       total sum
# 9          52.000000       7.211103        Unweighted events, alpha=1.978245
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         100.065708      16.512338       total sum
# 10         37.000000       6.082763        Unweighted events, alpha=2.704479
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         70.038812       10.073778       total sum
# 11         48.000000       6.928203        Unweighted events, alpha=1.459142
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-QGEtGV.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.62069  -0.0948472/+0.102021  (68% CL)
# Done in 0.01 min (cpu), 0.02 min (real)

# %%
# !combine -M FitDiagnostics -n CR3  datacard_CR3.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          64.839905       11.762042       total sum
# 0          30.000000       5.477226        Unweighted events, alpha=2.161330
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          76.753085       10.304469       total sum
# 1          55.000000       7.416198        Unweighted events, alpha=1.395511
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          92.938308       9.944485        total sum
# 2          87.000000       9.327379        Unweighted events, alpha=1.068256
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          123.444227      17.532459       total sum
# 3          50.000000       7.071068        Unweighted events, alpha=2.468885
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          26.266424       7.029811        total sum
# 4          14.000000       3.741657        Unweighted events, alpha=1.876173
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          42.825203       11.812984       total sum
# 5          13.000000       3.605551        Unweighted events, alpha=3.294246
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          56.588604       14.421423       total sum
# 6          15.000000       3.872983        Unweighted events, alpha=3.772574
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          89.273426       17.495368       total sum
# 7          26.000000       5.099020        Unweighted events, alpha=3.433593
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          153.798218      24.400254       total sum
# 8          40.000000       6.324555        Unweighted events, alpha=3.844955
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          153.997431      23.971406       total sum
# 9          41.000000       6.403124        Unweighted events, alpha=3.756035
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         116.293736      20.451907       total sum
# 10         32.000000       5.656854        Unweighted events, alpha=3.634179
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         56.022441       13.757925       total sum
# 11         17.000000       4.123106        Unweighted events, alpha=3.295438
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         26.524261       8.244614        total sum
# 12         10.000000       3.162278        Unweighted events, alpha=2.652426
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         23.194758       7.197636        total sum
# 13         10.000000       3.162278        Unweighted events, alpha=2.319476
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         102.806637      18.671026       total sum
# 14         30.000000       5.477226        Unweighted events, alpha=3.426888
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         82.691600       14.570451       total sum
# 15         32.000000       5.656854        Unweighted events, alpha=2.584113
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         66.710415       14.319443       total sum
# 16         22.000000       4.690416        Unweighted events, alpha=3.032292
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         72.434769       15.089331       total sum
# 17         23.000000       4.795832        Unweighted events, alpha=3.149338
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         58.912789       11.400265       total sum
# 18         27.000000       5.196152        Unweighted events, alpha=2.181955
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         54.341915       13.897699       total sum
# 19         15.000000       3.872983        Unweighted events, alpha=3.622794
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          112.103037      13.958498       total sum
# 0          64.000000       8.000000        Unweighted events, alpha=1.751610
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          145.184649      36.663438       total sum
# 1          16.000000       4.000000        Unweighted events, alpha=9.074041
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          226.133443      84.007868       total sum
# 2          7.000000        2.645751        Unweighted events, alpha=32.304778
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          151.006667      15.621960       total sum
# 3          93.000000       9.643651        Unweighted events, alpha=1.623728
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          135.881691      18.796281       total sum
# 4          52.000000       7.211103        Unweighted events, alpha=2.613109
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          99.618620       11.866509       total sum
# 5          70.000000       8.366600        Unweighted events, alpha=1.423123
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          99.004717       11.022490       total sum
# 6          81.000000       9.000000        Unweighted events, alpha=1.222280
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          96.672694       17.276983       total sum
# 7          31.000000       5.567764        Unweighted events, alpha=3.118474
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          80.357780       12.693441       total sum
# 8          40.000000       6.324555        Unweighted events, alpha=2.008945
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          52.755789       8.092062        total sum
# 9          43.000000       6.557439        Unweighted events, alpha=1.226879
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         61.439078       14.872826       total sum
# 10         17.000000       4.123106        Unweighted events, alpha=3.614063
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         35.466262       4.293818        total sum
# 11         68.000000       8.246211        Unweighted events, alpha=0.521563
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-qUNtXe.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.70085  -0.165172/+0.189033  (68% CL)
# Done in 0.00 min (cpu), 0.01 min (real)

# %%
# !combine -M FitDiagnostics -n CR4  datacard_CR4.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          207.078747      16.721468       total sum
# 0          153.000000      12.369317       Unweighted events, alpha=1.353456
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          232.661366      18.399713       total sum
# 1          160.000000      12.649111       Unweighted events, alpha=1.454134
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          326.994301      23.961170       total sum
# 2          186.000000      13.638182       Unweighted events, alpha=1.758034
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          366.275841      21.016283       total sum
# 3          304.000000      17.435596       Unweighted events, alpha=1.204855
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          103.561050      15.967028       total sum
# 4          42.000000       6.480741        Unweighted events, alpha=2.465739
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          167.213791      59.400986       total sum
# 5          8.000000        2.828427        Unweighted events, alpha=20.901724
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          165.705547      23.321549       total sum
# 6          50.000000       7.071068        Unweighted events, alpha=3.314111
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          221.050087      27.940905       total sum
# 7          63.000000       7.937254        Unweighted events, alpha=3.508732
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          303.861732      34.149959       total sum
# 8          79.000000       8.888194        Unweighted events, alpha=3.846351
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          353.594833      37.325892       total sum
# 9          90.000000       9.486833        Unweighted events, alpha=3.928831
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         182.215263      25.085749       total sum
# 10         53.000000       7.280110        Unweighted events, alpha=3.438024
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         111.973087      17.741243       total sum
# 11         40.000000       6.324555        Unweighted events, alpha=2.799327
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         98.727856       19.031513       total sum
# 12         27.000000       5.196152        Unweighted events, alpha=3.656587
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         68.930120       10.191533       total sum
# 13         46.000000       6.782330        Unweighted events, alpha=1.498481
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         440.264275      159.072680      total sum
# 14         8.000000        2.828427        Unweighted events, alpha=55.033034
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         222.182522      19.092860       total sum
# 15         135.000000      11.618950       Unweighted events, alpha=1.645796
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         178.608475      15.323419       total sum
# 16         136.000000      11.661904       Unweighted events, alpha=1.313298
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         130.797932      5.658567        total sum
# 17         534.000000      23.108440       Unweighted events, alpha=0.244940
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         119.908772      9.950695        total sum
# 18         145.000000      12.041595       Unweighted events, alpha=0.826957
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         99.493427       8.498853        total sum
# 19         137.000000      11.704700       Unweighted events, alpha=0.726229
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          394.137527      35.654482       total sum
# 0          122.000000      11.045361       Unweighted events, alpha=3.230635
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          459.664089      70.827153       total sum
# 1          42.000000       6.480741        Unweighted events, alpha=10.944383
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          474.231583      23.042178       total sum
# 2          424.000000      20.591260       Unweighted events, alpha=1.118471
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          525.018906      27.213830       total sum
# 3          372.000000      19.287302       Unweighted events, alpha=1.411341
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          491.965050      25.220452       total sum
# 4          381.000000      19.519221       Unweighted events, alpha=1.291247
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          391.350815      19.038681       total sum
# 5          423.000000      20.566964       Unweighted events, alpha=0.925179
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          381.962959      28.174717       total sum
# 6          184.000000      13.564660       Unweighted events, alpha=2.075886
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          285.668957      8.702362        total sum
# 7          1078.000000     32.832910       Unweighted events, alpha=0.264999
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          285.871746      26.434666       total sum
# 8          117.000000      10.816654       Unweighted events, alpha=2.443348
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          207.602928      9.727148        total sum
# 9          456.000000      21.354157       Unweighted events, alpha=0.455270
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         159.917496      9.736981        total sum
# 10         270.000000      16.431677       Unweighted events, alpha=0.592287
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         150.105576      12.111500       total sum
# 11         154.000000      12.409674       Unweighted events, alpha=0.974712
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-uHAJ1T.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.82696  -0.134001/+0.149477  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)
