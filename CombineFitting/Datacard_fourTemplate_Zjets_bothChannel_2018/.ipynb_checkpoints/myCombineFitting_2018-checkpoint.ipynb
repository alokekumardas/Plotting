# %%
import ROOT
import os
# !pwd
# Out:
# Welcome to JupyROOT 6.12/07
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/ttgammaCombineFitting/Datacard_fourTemplate_Zjets_bothChannel_2018

# %%
# !combine -M FitDiagnostics -n CR123  datacard_CR123.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          168.732595      21.134845       total sum
# 0          64.000000       8.000000        Unweighted events, alpha=2.636447
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          221.189995      30.712211       total sum
# 1          52.000000       7.211103        Unweighted events, alpha=4.253654
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          213.972126      31.795007       total sum
# 2          45.000000       6.708204        Unweighted events, alpha=4.754936
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          214.369808      46.943132       total sum
# 3          21.000000       4.582576        Unweighted events, alpha=10.208086
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          219.815556      44.525870       total sum
# 4          24.000000       4.898979        Unweighted events, alpha=9.158981
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          202.648972      25.832910       total sum
# 5          62.000000       7.874008        Unweighted events, alpha=3.268532
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          87.356514       131.124523      total sum
# 6          0.000000        0.000000        Unweighted events, alpha=inf
#   => Number of weighted events is below poisson threshold
#     MisIDEle             65.131714       13.371802
#                          24.000000       4.898979        Unweighted events, alpha=2.713821
#       => Parameter prop_bineleJets_bin6_MisIDEle[0.00,-7.00,7.00] to be gaussian constrained
#   ----------------------------------------------------------
#     WGammaBkgPhoton      193.865967      30.238014
#                          41.000000       6.403124        Unweighted events, alpha=4.728438
#       => Parameter prop_bineleJets_bin6_WGammaBkgPhoton[0.00,-7.00,7.00] to be gaussian constrained
#   ----------------------------------------------------------
#     OtherSampleBkgPhoton 22.224800       130.440927
#       => Poisson not viable, prop_bineleJets_bin6_OtherSampleBkgPhoton[0.00,-7.00,7.00] to be gaussian constrained
#   ----------------------------------------------------------
#     ZGammaBkgPhoton      262.989899      17.310397
#                          231.000000      15.198684       Unweighted events, alpha=1.138484
#       => Parameter prop_bineleJets_bin6_ZGammaBkgPhoton[0.00,-7.00,7.00] to be gaussian constrained
#   ----------------------------------------------------------
# ------------------------------------------------------------
# 7          310.440964      35.448402       total sum
# 7          77.000000       8.774964        Unweighted events, alpha=4.031701
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          235.469803      28.628870       total sum
# 8          68.000000       8.246211        Unweighted events, alpha=3.462791
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          495.326004      70.084665       total sum
# 9          50.000000       7.071068        Unweighted events, alpha=9.906520
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         562.067291      94.299148       total sum
# 10         36.000000       6.000000        Unweighted events, alpha=15.612980
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         655.395599      47.614171       total sum
# 11         189.000000      13.747727       Unweighted events, alpha=3.467702
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1011.860657     59.443775       total sum
# 12         290.000000      17.029386       Unweighted events, alpha=3.489175
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         1794.312500     79.459045       total sum
# 13         510.000000      22.583180       Unweighted events, alpha=3.518260
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         3107.873962     130.675428      total sum
# 14         566.000000      23.790755       Unweighted events, alpha=5.490943
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         5686.017090     2713.818069     total sum
# 15         4.000000        2.000000        Unweighted events, alpha=1421.504272
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         1823.088867     78.588624       total sum
# 16         538.000000      23.194827       Unweighted events, alpha=3.388641
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         728.853210      51.025868       total sum
# 17         204.000000      14.282857       Unweighted events, alpha=3.572810
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         776.063446      348.479731      total sum
# 18         5.000000        2.236068        Unweighted events, alpha=155.212689
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         244.239861      30.142836       total sum
# 19         66.000000       8.124038        Unweighted events, alpha=3.700604
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         260.483475      43.592526       total sum
# 20         36.000000       6.000000        Unweighted events, alpha=7.235652
#   => Total parameter prop_bineleJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         184.483749      31.258903       total sum
# 21         35.000000       5.916080        Unweighted events, alpha=5.270964
#   => Total parameter prop_bineleJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         233.350838      63.797937       total sum
# 22         13.000000       3.605551        Unweighted events, alpha=17.950064
#   => Total parameter prop_bineleJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         140.103333      87.259750       total sum
# 23         3.000000        1.732051        Unweighted events, alpha=46.701111
#   => Total parameter prop_bineleJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         138.929569      22.576582       total sum
# 24         38.000000       6.164414        Unweighted events, alpha=3.656041
#   => Total parameter prop_bineleJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         305.222824      144.011695      total sum
# 25         4.000000        2.000000        Unweighted events, alpha=76.305706
#   => Total parameter prop_bineleJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         152.309639      27.621445       total sum
# 26         30.000000       5.477226        Unweighted events, alpha=5.076988
#   => Total parameter prop_bineleJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         175.207954      32.503790       total sum
# 27         29.000000       5.385165        Unweighted events, alpha=6.041654
#   => Total parameter prop_bineleJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         118.386038      21.246244       total sum
# 28         31.000000       5.567764        Unweighted events, alpha=3.818904
#   => Total parameter prop_bineleJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         109.086428      20.021820       total sum
# 29         30.000000       5.477226        Unweighted events, alpha=3.636214
#   => Total parameter prop_bineleJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         166.434259      58.979544       total sum
# 30         8.000000        2.828427        Unweighted events, alpha=20.804282
#   => Total parameter prop_bineleJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         217.473381      122.539024      total sum
# 31         3.000000        1.732051        Unweighted events, alpha=72.491127
#   => Total parameter prop_bineleJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         85.523897       14.727863       total sum
# 32         34.000000       5.830952        Unweighted events, alpha=2.515409
#   => Total parameter prop_bineleJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         87.500343       21.465011       total sum
# 33         17.000000       4.123106        Unweighted events, alpha=5.147079
#   => Total parameter prop_bineleJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         103.340511      24.101608       total sum
# 34         18.000000       4.242641        Unweighted events, alpha=5.741140
#   => Total parameter prop_bineleJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         109.551099      22.319659       total sum
# 35         24.000000       4.898979        Unweighted events, alpha=4.564629
#   => Total parameter prop_bineleJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         114.694206      21.087017       total sum
# 36         30.000000       5.477226        Unweighted events, alpha=3.823140
#   => Total parameter prop_bineleJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         72.317211       19.329368       total sum
# 37         14.000000       3.741657        Unweighted events, alpha=5.165515
#   => Total parameter prop_bineleJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         99.939806       22.435750       total sum
# 38         20.000000       4.472136        Unweighted events, alpha=4.996990
#   => Total parameter prop_bineleJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         137.597071      83.018531       total sum
# 39         3.000000        1.732051        Unweighted events, alpha=45.865690
#   => Total parameter prop_bineleJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          314.069785      39.295468       total sum
# 0          64.000000       8.000000        Unweighted events, alpha=4.907340
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          402.846379      69.667896       total sum
# 1          33.000000       5.744563        Unweighted events, alpha=12.207466
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          389.614153      90.385949       total sum
# 2          19.000000       4.358899        Unweighted events, alpha=20.506008
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1950.719461     1657.331310     total sum
# 3          1.000000        1.000000        Unweighted events, alpha=1950.719461
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          485.105877      99.475656       total sum
# 4          24.000000       4.898979        Unweighted events, alpha=20.212745
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          330.558182      35.193969       total sum
# 5          88.000000       9.380832        Unweighted events, alpha=3.756343
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          409.219987      69.292401       total sum
# 6          35.000000       5.916080        Unweighted events, alpha=11.692000
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          389.539413      76.921114       total sum
# 7          26.000000       5.099020        Unweighted events, alpha=14.982285
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1775.411935     1323.103155     total sum
# 8          2.000000        1.414214        Unweighted events, alpha=887.705968
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          339.163763      72.418916       total sum
# 9          22.000000       4.690416        Unweighted events, alpha=15.416535
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         217.372983      22.014811       total sum
# 10         97.000000       9.848858        Unweighted events, alpha=2.240959
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         317.967406      42.990830       total sum
# 11         55.000000       7.416198        Unweighted events, alpha=5.781226
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         247.588412      33.090245       total sum
# 12         56.000000       7.483315        Unweighted events, alpha=4.421222
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         201.359989      27.185110       total sum
# 13         55.000000       7.416198        Unweighted events, alpha=3.661091
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         171.538773      21.201152       total sum
# 14         65.000000       8.062258        Unweighted events, alpha=2.639058
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         174.784197      24.235928       total sum
# 15         52.000000       7.211103        Unweighted events, alpha=3.361235
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         136.298180      17.021494       total sum
# 16         64.000000       8.000000        Unweighted events, alpha=2.129659
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         189.583935      27.616153       total sum
# 17         47.000000       6.855655        Unweighted events, alpha=4.033701
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         183.395947      27.245282       total sum
# 18         45.000000       6.708204        Unweighted events, alpha=4.075465
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         400.597583      219.036537      total sum
# 19         3.000000        1.732051        Unweighted events, alpha=133.532528
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         179.944809      31.058737       total sum
# 20         34.000000       5.830952        Unweighted events, alpha=5.292494
#   => Total parameter prop_binmuJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         204.066540      29.928525       total sum
# 21         46.000000       6.782330        Unweighted events, alpha=4.436229
#   => Total parameter prop_binmuJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         123.575679      16.876482       total sum
# 22         54.000000       7.348469        Unweighted events, alpha=2.288438
#   => Total parameter prop_binmuJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         156.016406      22.888514       total sum
# 23         46.000000       6.782330        Unweighted events, alpha=3.391661
#   => Total parameter prop_binmuJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         122.775131      19.748355       total sum
# 24         39.000000       6.244998        Unweighted events, alpha=3.148080
#   => Total parameter prop_binmuJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         321.120000      182.255513      total sum
# 25         3.000000        1.732051        Unweighted events, alpha=107.040000
#   => Total parameter prop_binmuJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         135.670553      22.269980       total sum
# 26         37.000000       6.082763        Unweighted events, alpha=3.666772
#   => Total parameter prop_binmuJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         119.611100      17.952483       total sum
# 27         44.000000       6.633250        Unweighted events, alpha=2.718434
#   => Total parameter prop_binmuJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         100.377569      18.442979       total sum
# 28         30.000000       5.477226        Unweighted events, alpha=3.345919
#   => Total parameter prop_binmuJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         243.245594      95.226882       total sum
# 29         7.000000        2.645751        Unweighted events, alpha=34.749371
#   => Total parameter prop_binmuJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         114.087968      46.713055       total sum
# 30         6.000000        2.449490        Unweighted events, alpha=19.014661
#   => Total parameter prop_binmuJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         97.635978       15.166324       total sum
# 31         41.000000       6.403124        Unweighted events, alpha=2.381365
#   => Total parameter prop_binmuJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         104.341007      16.774357       total sum
# 32         39.000000       6.244998        Unweighted events, alpha=2.675410
#   => Total parameter prop_binmuJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         131.284037      23.245345       total sum
# 33         32.000000       5.656854        Unweighted events, alpha=4.102626
#   => Total parameter prop_binmuJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         108.767918      17.481722       total sum
# 34         39.000000       6.244998        Unweighted events, alpha=2.788921
#   => Total parameter prop_binmuJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         86.621043       15.561362       total sum
# 35         31.000000       5.567764        Unweighted events, alpha=2.794227
#   => Total parameter prop_binmuJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         105.607513      22.669468       total sum
# 36         22.000000       4.690416        Unweighted events, alpha=4.800341
#   => Total parameter prop_binmuJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         121.868923      49.881082       total sum
# 37         6.000000        2.449490        Unweighted events, alpha=20.311487
#   => Total parameter prop_binmuJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         78.481110       13.040018       total sum
# 38         36.000000       6.000000        Unweighted events, alpha=2.180031
#   => Total parameter prop_binmuJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         58.544506       9.702073        total sum
# 39         36.000000       6.000000        Unweighted events, alpha=1.626236
#   => Total parameter prop_binmuJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-CTDiFf.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 2.04385  -0.0507268/+0.0524484  (68% CL)
# Done in 0.01 min (cpu), 0.02 min (real)

# %%
# !combine -M FitDiagnostics -n CR1  datacard_CR1.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          112.203312      18.397591       total sum
# 0          37.000000       6.082763        Unweighted events, alpha=3.032522
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          144.712074      25.976488       total sum
# 1          31.000000       5.567764        Unweighted events, alpha=4.668131
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          152.492691      29.871805       total sum
# 2          26.000000       5.099020        Unweighted events, alpha=5.865104
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          126.850172      24.086075       total sum
# 3          28.000000       5.291503        Unweighted events, alpha=4.530363
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          145.545128      42.335318       total sum
# 4          12.000000       3.464102        Unweighted events, alpha=12.128761
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          139.478159      22.583875       total sum
# 5          38.000000       6.164414        Unweighted events, alpha=3.670478
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          157.655876      24.272247       total sum
# 6          42.000000       6.480741        Unweighted events, alpha=3.753711
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          189.225773      28.373086       total sum
# 7          44.000000       6.633250        Unweighted events, alpha=4.300586
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          192.733566      27.921612       total sum
# 8          48.000000       6.928203        Unweighted events, alpha=4.015283
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          382.182480      67.027062       total sum
# 9          33.000000       5.744563        Unweighted events, alpha=11.581287
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         458.354736      92.845471       total sum
# 10         24.000000       4.898979        Unweighted events, alpha=19.098114
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         516.767426      43.497791       total sum
# 11         141.000000      11.874342       Unweighted events, alpha=3.665017
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         765.552200      52.781105       total sum
# 12         210.000000      14.491377       Unweighted events, alpha=3.645487
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         1430.233429     71.511430       total sum
# 13         400.000000      20.000000       Unweighted events, alpha=3.575584
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         2444.714996     120.799588      total sum
# 14         410.000000      20.248457       Unweighted events, alpha=5.962720
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         2299.001495     86.886706       total sum
# 15         700.000000      26.457513       Unweighted events, alpha=3.284288
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         1460.887253     70.557347       total sum
# 16         429.000000      20.712315       Unweighted events, alpha=3.405332
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         490.237129      42.310050       total sum
# 17         134.000000      11.575837       Unweighted events, alpha=3.658486
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         322.354988      33.940773       total sum
# 18         90.000000       9.486833        Unweighted events, alpha=3.581722
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         178.642860      26.108452       total sum
# 19         47.000000       6.855655        Unweighted events, alpha=3.800912
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         172.142227      39.687563       total sum
# 20         19.000000       4.358899        Unweighted events, alpha=9.060117
#   => Total parameter prop_bineleJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         130.043556      27.445122       total sum
# 21         22.000000       4.690416        Unweighted events, alpha=5.911071
#   => Total parameter prop_bineleJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         107.489483      21.880631       total sum
# 22         24.000000       4.898979        Unweighted events, alpha=4.478728
#   => Total parameter prop_bineleJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         34.646919       60.322044       total sum
# 23         0.000000        0.000000        Unweighted events, alpha=inf
#   => Number of weighted events is below poisson threshold
#     MisIDEle             34.646919       10.120678
#                          12.000000       3.464102        Unweighted events, alpha=2.887243
#       => Parameter prop_bineleJets_bin23_MisIDEle[0.00,-7.00,7.00] to be gaussian constrained
#   ----------------------------------------------------------
#     WGammaBkgPhoton      86.304779       19.390771
#                          20.000000       4.472136        Unweighted events, alpha=4.315239
#       => Parameter prop_bineleJets_bin23_WGammaBkgPhoton[0.00,-7.00,7.00] to be gaussian constrained
#   ----------------------------------------------------------
#     OtherSampleBkgPhoton 0.000000        59.466973
#       => Poisson not viable, prop_bineleJets_bin23_OtherSampleBkgPhoton[0.00,-7.00,7.00] to be gaussian constrained
#   ----------------------------------------------------------
#     ZGammaBkgPhoton      22.800268       5.488190
#                          17.000000       4.123106        Unweighted events, alpha=1.341192
#       => Parameter prop_bineleJets_bin23_ZGammaBkgPhoton[0.00,-7.00,7.00] to be gaussian constrained
#   ----------------------------------------------------------
# ------------------------------------------------------------
# 24         78.355118       16.836225       total sum
# 24         22.000000       4.690416        Unweighted events, alpha=3.561596
#   => Total parameter prop_bineleJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         237.425396      143.071871      total sum
# 25         3.000000        1.732051        Unweighted events, alpha=79.141799
#   => Total parameter prop_bineleJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         113.771036      26.497291       total sum
# 26         18.000000       4.242641        Unweighted events, alpha=6.320613
#   => Total parameter prop_bineleJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         129.007652      29.537807       total sum
# 27         19.000000       4.358899        Unweighted events, alpha=6.789876
#   => Total parameter prop_bineleJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         60.440006       12.556992       total sum
# 28         23.000000       4.795832        Unweighted events, alpha=2.627826
#   => Total parameter prop_bineleJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         79.384634       19.048581       total sum
# 29         17.000000       4.123106        Unweighted events, alpha=4.669684
#   => Total parameter prop_bineleJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         85.593367       22.083578       total sum
# 30         15.000000       3.872983        Unweighted events, alpha=5.706224
#   => Total parameter prop_bineleJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         178.815133      122.152580      total sum
# 31         2.000000        1.414214        Unweighted events, alpha=89.407567
#   => Total parameter prop_bineleJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         49.932132       9.822817        total sum
# 32         26.000000       5.099020        Unweighted events, alpha=1.920467
#   => Total parameter prop_bineleJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         60.463725       19.704844       total sum
# 33         9.000000        3.000000        Unweighted events, alpha=6.718192
#   => Total parameter prop_bineleJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         71.462699       21.288346       total sum
# 34         11.000000       3.316625        Unweighted events, alpha=6.496609
#   => Total parameter prop_bineleJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         56.655129       17.643827       total sum
# 35         10.000000       3.162278        Unweighted events, alpha=5.665513
#   => Total parameter prop_bineleJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         55.587780       13.550609       total sum
# 36         17.000000       4.123106        Unweighted events, alpha=3.269869
#   => Total parameter prop_bineleJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         47.653581       17.709547       total sum
# 37         7.000000        2.645751        Unweighted events, alpha=6.807654
#   => Total parameter prop_bineleJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         71.470993       20.526788       total sum
# 38         12.000000       3.464102        Unweighted events, alpha=5.955916
#   => Total parameter prop_bineleJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         105.281565      82.290789       total sum
# 39         2.000000        1.414214        Unweighted events, alpha=52.640782
#   => Total parameter prop_bineleJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          223.286999      34.613296       total sum
# 0          42.000000       6.480741        Unweighted events, alpha=5.316357
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          286.422124      67.428405       total sum
# 1          18.000000       4.242641        Unweighted events, alpha=15.912340
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          221.770617      35.782252       total sum
# 2          38.000000       6.164414        Unweighted events, alpha=5.836069
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1876.142643     1657.307057     total sum
# 3          1.000000        1.000000        Unweighted events, alpha=1876.142643
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          373.835959      97.164496       total sum
# 4          15.000000       3.872983        Unweighted events, alpha=24.922397
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          230.593997      30.938732       total sum
# 5          56.000000       7.483315        Unweighted events, alpha=4.117750
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          324.958006      67.111818       total sum
# 6          23.000000       4.795832        Unweighted events, alpha=14.128609
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          281.096725      74.194626       total sum
# 7          14.000000       3.741657        Unweighted events, alpha=20.078337
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1595.444406     1321.094432     total sum
# 8          1.000000        1.000000        Unweighted events, alpha=1595.444406
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          234.463211      69.946506       total sum
# 9          11.000000       3.316625        Unweighted events, alpha=21.314837
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         126.852345      17.570630       total sum
# 10         52.000000       7.211103        Unweighted events, alpha=2.439468
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         221.538430      37.448640       total sum
# 11         35.000000       5.916080        Unweighted events, alpha=6.329669
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         148.758395      26.255710       total sum
# 12         32.000000       5.656854        Unweighted events, alpha=4.648700
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         128.805887      25.332298       total sum
# 13         26.000000       5.099020        Unweighted events, alpha=4.954073
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         94.453871       14.511451       total sum
# 14         42.000000       6.480741        Unweighted events, alpha=2.248902
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         112.343803      22.284434       total sum
# 15         25.000000       5.000000        Unweighted events, alpha=4.493752
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         72.770533       13.577450       total sum
# 16         29.000000       5.385165        Unweighted events, alpha=2.509329
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         139.477514      26.683689       total sum
# 17         27.000000       5.196152        Unweighted events, alpha=5.165834
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         114.852736      20.694502       total sum
# 18         31.000000       5.567764        Unweighted events, alpha=3.704927
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         326.029478      218.292188      total sum
# 19         2.000000        1.414214        Unweighted events, alpha=163.014739
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         114.320623      26.340263       total sum
# 20         19.000000       4.358899        Unweighted events, alpha=6.016875
#   => Total parameter prop_binmuJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         124.358459      25.603941       total sum
# 21         24.000000       4.898979        Unweighted events, alpha=5.181602
#   => Total parameter prop_binmuJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         56.439636       10.670880       total sum
# 22         28.000000       5.291503        Unweighted events, alpha=2.015701
#   => Total parameter prop_binmuJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         94.887828       19.025239       total sum
# 23         25.000000       5.000000        Unweighted events, alpha=3.795513
#   => Total parameter prop_binmuJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         81.584703       19.322620       total sum
# 24         18.000000       4.242641        Unweighted events, alpha=4.532484
#   => Total parameter prop_binmuJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         282.210832      182.187795      total sum
# 25         2.000000        1.414214        Unweighted events, alpha=141.105416
#   => Total parameter prop_binmuJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         87.569456       20.788964       total sum
# 26         18.000000       4.242641        Unweighted events, alpha=4.864970
#   => Total parameter prop_binmuJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         75.229666       15.305646       total sum
# 27         24.000000       4.898979        Unweighted events, alpha=3.134569
#   => Total parameter prop_binmuJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         63.024920       17.386303       total sum
# 28         13.000000       3.605551        Unweighted events, alpha=4.848071
#   => Total parameter prop_binmuJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         190.457502      93.909324       total sum
# 29         4.000000        2.000000        Unweighted events, alpha=47.614376
#   => Total parameter prop_binmuJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         75.999580       45.818207       total sum
# 30         3.000000        1.732051        Unweighted events, alpha=25.333193
#   => Total parameter prop_binmuJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         54.319023       13.027790       total sum
# 31         17.000000       4.123106        Unweighted events, alpha=3.195237
#   => Total parameter prop_binmuJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         61.228755       14.179082       total sum
# 32         19.000000       4.358899        Unweighted events, alpha=3.222566
#   => Total parameter prop_binmuJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         71.180186       14.968211       total sum
# 33         23.000000       4.795832        Unweighted events, alpha=3.094791
#   => Total parameter prop_binmuJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         59.089787       13.666473       total sum
# 34         19.000000       4.358899        Unweighted events, alpha=3.109989
#   => Total parameter prop_binmuJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         52.794689       12.982517       total sum
# 35         17.000000       4.123106        Unweighted events, alpha=3.105570
#   => Total parameter prop_binmuJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         71.355427       21.223292       total sum
# 36         11.000000       3.316625        Unweighted events, alpha=6.486857
#   => Total parameter prop_binmuJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         96.427827       49.480400       total sum
# 37         4.000000        2.000000        Unweighted events, alpha=24.106957
#   => Total parameter prop_binmuJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         49.749441       12.092281       total sum
# 38         17.000000       4.123106        Unweighted events, alpha=2.926438
#   => Total parameter prop_binmuJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         26.031742       6.526149        total sum
# 39         16.000000       4.000000        Unweighted events, alpha=1.626984
#   => Total parameter prop_binmuJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-KMnDTI.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 2.07074  -0.048167/+0.0497109  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)

# %%
# !combine -M FitDiagnostics -n CR2  datacard_CR2.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          39.374788       9.844117        total sum
# 0          16.000000       4.000000        Unweighted events, alpha=2.460924
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          54.092799       15.518749       total sum
# 1          12.000000       3.464102        Unweighted events, alpha=4.507733
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          46.064897       10.320309       total sum
# 2          20.000000       4.472136        Unweighted events, alpha=2.303245
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          71.774829       40.100882       total sum
# 3          3.000000        1.732051        Unweighted events, alpha=23.924943
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          52.196655       12.792307       total sum
# 4          17.000000       4.123106        Unweighted events, alpha=3.070391
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          48.356290       12.195841       total sum
# 5          16.000000       4.000000        Unweighted events, alpha=3.022268
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          11.384122       128.789758      total sum
# 6          0.000000        0.000000        Unweighted events, alpha=inf
#   => Number of weighted events is below poisson threshold
#     MisIDEle             11.384122       5.367581
#                          4.000000        2.000000        Unweighted events, alpha=2.846030
#       => Parameter prop_bineleJets_bin6_MisIDEle[0.00,-7.00,7.00] to be gaussian constrained
#   ----------------------------------------------------------
#     WGammaBkgPhoton      30.907188       12.736190
#                          6.000000        2.449490        Unweighted events, alpha=5.151198
#       => Parameter prop_bineleJets_bin6_WGammaBkgPhoton[0.00,-7.00,7.00] to be gaussian constrained
#   ----------------------------------------------------------
#     OtherSampleBkgPhoton 0.000000        128.677857
#       => Poisson not viable, prop_bineleJets_bin6_OtherSampleBkgPhoton[0.00,-7.00,7.00] to be gaussian constrained
#   ----------------------------------------------------------
#     ZGammaBkgPhoton      42.039536       6.937384
#                          37.000000       6.082763        Unweighted events, alpha=1.136204
#       => Parameter prop_bineleJets_bin6_ZGammaBkgPhoton[0.00,-7.00,7.00] to be gaussian constrained
#   ----------------------------------------------------------
# ------------------------------------------------------------
# 7          81.677635       17.827455       total sum
# 7          21.000000       4.582576        Unweighted events, alpha=3.889411
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          22.397938       3.669601        total sum
# 8          37.000000       6.082763        Unweighted events, alpha=0.605350
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          82.928108       17.752775       total sum
# 9          22.000000       4.690416        Unweighted events, alpha=3.769459
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         79.216713       15.404392       total sum
# 10         26.000000       5.099020        Unweighted events, alpha=3.046797
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         101.721523      16.852408       total sum
# 11         36.000000       6.000000        Unweighted events, alpha=2.825598
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         197.362537      24.630596       total sum
# 12         64.000000       8.000000        Unweighted events, alpha=3.083790
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         289.682148      31.617804       total sum
# 13         84.000000       9.165151        Unweighted events, alpha=3.448597
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         534.855461      45.676945       total sum
# 14         137.000000      11.704700       Unweighted events, alpha=3.904054
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         3259.960663     2712.356923     total sum
# 15         1.000000        1.000000        Unweighted events, alpha=3259.960663
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         265.012222      30.169679       total sum
# 16         77.000000       8.774964        Unweighted events, alpha=3.441717
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         190.665539      26.264021       total sum
# 17         53.000000       7.280110        Unweighted events, alpha=3.597463
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         429.720116      346.754587      total sum
# 18         2.000000        1.414214        Unweighted events, alpha=214.860058
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         42.962268       13.413678       total sum
# 19         10.000000       3.162278        Unweighted events, alpha=4.296227
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         59.001183       15.462628       total sum
# 20         15.000000       3.872983        Unweighted events, alpha=3.933412
#   => Total parameter prop_bineleJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         44.517806       14.922744       total sum
# 21         9.000000        3.000000        Unweighted events, alpha=4.946423
#   => Total parameter prop_bineleJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         98.003754       58.878192       total sum
# 22         3.000000        1.732051        Unweighted events, alpha=32.667918
#   => Total parameter prop_bineleJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         99.887443       63.026095       total sum
# 23         3.000000        1.732051        Unweighted events, alpha=33.295814
#   => Total parameter prop_bineleJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         38.574080       10.923836       total sum
# 24         12.000000       3.464102        Unweighted events, alpha=3.214507
#   => Total parameter prop_bineleJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         50.383770       14.440826       total sum
# 25         12.000000       3.464102        Unweighted events, alpha=4.198647
#   => Total parameter prop_bineleJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         24.264604       6.389614        total sum
# 26         14.000000       3.741657        Unweighted events, alpha=1.733186
#   => Total parameter prop_bineleJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         25.331853       10.390132       total sum
# 27         6.000000        2.449490        Unweighted events, alpha=4.221975
#   => Total parameter prop_bineleJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         46.282394       16.800940       total sum
# 28         8.000000        2.828427        Unweighted events, alpha=5.785299
#   => Total parameter prop_bineleJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         12.629848       2.465251        total sum
# 29         26.000000       5.099020        Unweighted events, alpha=0.485763
#   => Total parameter prop_bineleJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         73.122512       54.362314       total sum
# 30         2.000000        1.414214        Unweighted events, alpha=36.561256
#   => Total parameter prop_bineleJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         25.518044       8.383093        total sum
# 31         9.000000        3.000000        Unweighted events, alpha=2.835338
#   => Total parameter prop_bineleJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         8.996992        1.358482        total sum
# 32         44.000000       6.633250        Unweighted events, alpha=0.204477
#   => Total parameter prop_bineleJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         17.924832       7.530767        total sum
# 33         6.000000        2.449490        Unweighted events, alpha=2.987472
#   => Total parameter prop_bineleJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         21.574085       10.814603       total sum
# 34         4.000000        2.000000        Unweighted events, alpha=5.393521
#   => Total parameter prop_bineleJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         30.408213       9.472952        total sum
# 35         10.000000       3.162278        Unweighted events, alpha=3.040821
#   => Total parameter prop_bineleJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         43.175911       14.503167       total sum
# 36         9.000000        3.000000        Unweighted events, alpha=4.797323
#   => Total parameter prop_bineleJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         16.083652       7.189289        total sum
# 37         5.000000        2.236068        Unweighted events, alpha=3.216730
#   => Total parameter prop_bineleJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         12.375973       4.615079        total sum
# 38         7.000000        2.645751        Unweighted events, alpha=1.767996
#   => Total parameter prop_bineleJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         23.511315       10.636474       total sum
# 39         5.000000        2.236068        Unweighted events, alpha=4.702263
#   => Total parameter prop_bineleJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          67.292095       15.712791       total sum
# 0          18.000000       4.242641        Unweighted events, alpha=3.738450
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          80.183207       15.262232       total sum
# 1          28.000000       5.291503        Unweighted events, alpha=2.863686
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          60.795174       11.340216       total sum
# 2          29.000000       5.385165        Unweighted events, alpha=2.096385
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          44.180467       6.932974        total sum
# 3          41.000000       6.403124        Unweighted events, alpha=1.077572
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          84.572350       20.877901       total sum
# 4          16.000000       4.000000        Unweighted events, alpha=5.285772
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          69.069151       15.514342       total sum
# 5          20.000000       4.472136        Unweighted events, alpha=3.453458
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          58.415967       16.388932       total sum
# 6          13.000000       3.605551        Unweighted events, alpha=4.493536
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          84.776852       19.645338       total sum
# 7          19.000000       4.358899        Unweighted events, alpha=4.461940
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          134.100924      72.165041       total sum
# 8          3.000000        1.732051        Unweighted events, alpha=44.700308
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          83.924899       18.627701       total sum
# 9          20.000000       4.472136        Unweighted events, alpha=4.196245
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         62.717768       12.155813       total sum
# 10         27.000000       5.196152        Unweighted events, alpha=2.322880
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         71.570036       20.306620       total sum
# 11         12.000000       3.464102        Unweighted events, alpha=5.964170
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         58.943849       12.702358       total sum
# 12         22.000000       4.690416        Unweighted events, alpha=2.679266
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         54.784476       9.739309        total sum
# 13         32.000000       5.656854        Unweighted events, alpha=1.712015
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         55.878082       15.203464       total sum
# 14         14.000000       3.741657        Unweighted events, alpha=3.991292
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         45.485190       9.389252        total sum
# 15         23.000000       4.795832        Unweighted events, alpha=1.977617
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         36.660606       7.079189        total sum
# 16         27.000000       5.196152        Unweighted events, alpha=1.357800
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         29.167995       5.846275        total sum
# 17         25.000000       5.000000        Unweighted events, alpha=1.166720
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         46.045485       16.019338       total sum
# 18         8.000000        2.828427        Unweighted events, alpha=5.755686
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         61.638771       17.789412       total sum
# 19         12.000000       3.464102        Unweighted events, alpha=5.136564
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         43.654626       15.676858       total sum
# 20         8.000000        2.828427        Unweighted events, alpha=5.456828
#   => Total parameter prop_binmuJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         57.558824       14.577494       total sum
# 21         16.000000       4.000000        Unweighted events, alpha=3.597426
#   => Total parameter prop_binmuJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         50.946781       12.902496       total sum
# 22         16.000000       4.000000        Unweighted events, alpha=3.184174
#   => Total parameter prop_binmuJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         43.318106       11.415764       total sum
# 23         14.000000       3.741657        Unweighted events, alpha=3.094150
#   => Total parameter prop_binmuJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         22.566239       2.674050        total sum
# 24         71.000000       8.426150        Unweighted events, alpha=0.317834
#   => Total parameter prop_binmuJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         26.300969       4.769370        total sum
# 25         30.000000       5.477226        Unweighted events, alpha=0.876699
#   => Total parameter prop_binmuJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         31.264295       7.439521        total sum
# 26         18.000000       4.242641        Unweighted events, alpha=1.736905
#   => Total parameter prop_binmuJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         21.565682       4.894259        total sum
# 27         19.000000       4.358899        Unweighted events, alpha=1.135036
#   => Total parameter prop_binmuJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         24.428344       5.997523        total sum
# 28         17.000000       4.123106        Unweighted events, alpha=1.436961
#   => Total parameter prop_binmuJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         21.747926       5.742756        total sum
# 29         14.000000       3.741657        Unweighted events, alpha=1.553423
#   => Total parameter prop_binmuJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         28.042043       8.982287        total sum
# 30         10.000000       3.162278        Unweighted events, alpha=2.804204
#   => Total parameter prop_binmuJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         30.294117       6.887350        total sum
# 31         19.000000       4.358899        Unweighted events, alpha=1.594427
#   => Total parameter prop_binmuJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         24.202164       6.252496        total sum
# 32         15.000000       3.872983        Unweighted events, alpha=1.613478
#   => Total parameter prop_binmuJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         39.249373       15.651172       total sum
# 33         6.000000        2.449490        Unweighted events, alpha=6.541562
#   => Total parameter prop_binmuJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         32.632721       9.578266        total sum
# 34         12.000000       3.464102        Unweighted events, alpha=2.719393
#   => Total parameter prop_binmuJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         25.042741       8.475811        total sum
# 35         9.000000        3.000000        Unweighted events, alpha=2.782527
#   => Total parameter prop_binmuJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         23.869117       6.982467        total sum
# 36         12.000000       3.464102        Unweighted events, alpha=1.989093
#   => Total parameter prop_binmuJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         15.514432       4.449420        total sum
# 37         12.000000       3.464102        Unweighted events, alpha=1.292869
#   => Total parameter prop_binmuJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         17.757846       4.280874        total sum
# 38         17.000000       4.123106        Unweighted events, alpha=1.044579
#   => Total parameter prop_binmuJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         20.406678       5.999453        total sum
# 39         12.000000       3.464102        Unweighted events, alpha=1.700556
#   => Total parameter prop_binmuJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-ZLv4wN.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 2.06551  -0.124083/+0.135176  (68% CL)
# Done in 0.02 min (cpu), 0.02 min (real)

# %%
# !combine -M FitDiagnostics -n CR3  datacard_CR3.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          17.154492       3.362095        total sum
# 0          26.000000       5.099020        Unweighted events, alpha=0.659788
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          22.385113       5.256467        total sum
# 1          18.000000       4.242641        Unweighted events, alpha=1.243617
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          15.414537       3.476917        total sum
# 2          20.000000       4.472136        Unweighted events, alpha=0.770727
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          15.744826       3.929106        total sum
# 3          16.000000       4.000000        Unweighted events, alpha=0.984052
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          22.073772       5.160506        total sum
# 4          18.000000       4.242641        Unweighted events, alpha=1.226321
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          14.814537       2.927335        total sum
# 5          26.000000       5.099020        Unweighted events, alpha=0.569790
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          16.378532       4.206764        total sum
# 6          15.000000       3.872983        Unweighted events, alpha=1.091902
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          39.537591       11.564559       total sum
# 7          12.000000       3.464102        Unweighted events, alpha=3.294799
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          20.338297       5.150711        total sum
# 8          16.000000       4.000000        Unweighted events, alpha=1.271144
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          30.215415       10.201580       total sum
# 9          9.000000        3.000000        Unweighted events, alpha=3.357268
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         24.495882       5.895131        total sum
# 10         17.000000       4.123106        Unweighted events, alpha=1.440934
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         36.906739       9.541895        total sum
# 11         15.000000       3.872983        Unweighted events, alpha=2.460449
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         48.945969       11.876493       total sum
# 12         17.000000       4.123106        Unweighted events, alpha=2.879175
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         74.396877       14.148131       total sum
# 13         28.000000       5.291503        Unweighted events, alpha=2.657031
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         128.303463      19.928470       total sum
# 14         41.000000       6.403124        Unweighted events, alpha=3.129353
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         127.055222      19.471486       total sum
# 15         43.000000       6.557439        Unweighted events, alpha=2.954773
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         97.189270       16.959453       total sum
# 16         33.000000       5.744563        Unweighted events, alpha=2.945129
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         47.950470       11.122049       total sum
# 17         19.000000       4.358899        Unweighted events, alpha=2.523709
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         23.988320       6.885001        total sum
# 18         12.000000       3.464102        Unweighted events, alpha=1.999027
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         22.634733       6.856570        total sum
# 19         11.000000       3.316625        Unweighted events, alpha=2.057703
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         29.340051       9.279694        total sum
# 20         10.000000       3.162278        Unweighted events, alpha=2.934005
#   => Total parameter prop_bineleJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         9.922397        1.093602        total sum
# 21         82.000000       9.055385        Unweighted events, alpha=0.121005
#   => Total parameter prop_bineleJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         27.857594       11.170195       total sum
# 22         6.000000        2.449490        Unweighted events, alpha=4.642932
#   => Total parameter prop_bineleJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         10.682046       1.796183        total sum
# 23         35.000000       5.916080        Unweighted events, alpha=0.305201
#   => Total parameter prop_bineleJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         22.000392       10.339893       total sum
# 24         5.000000        2.236068        Unweighted events, alpha=4.400078
#   => Total parameter prop_bineleJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         17.413666       7.827560        total sum
# 25         5.000000        2.236068        Unweighted events, alpha=3.482733
#   => Total parameter prop_bineleJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         14.273990       4.473324        total sum
# 26         10.000000       3.162278        Unweighted events, alpha=1.427399
#   => Total parameter prop_bineleJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         20.868447       8.721211        total sum
# 27         6.000000        2.449490        Unweighted events, alpha=3.478074
#   => Total parameter prop_bineleJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         11.663630       3.384259        total sum
# 28         12.000000       3.464102        Unweighted events, alpha=0.971969
#   => Total parameter prop_bineleJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         17.071960       5.652201        total sum
# 29         9.000000        3.000000        Unweighted events, alpha=1.896884
#   => Total parameter prop_bineleJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         7.718380        5.970012        total sum
# 30         2.000000        1.414214        Unweighted events, alpha=3.859190
#   => Total parameter prop_bineleJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         13.140193       4.927805        total sum
# 31         7.000000        2.645751        Unweighted events, alpha=1.877170
#   => Total parameter prop_bineleJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         26.594755       10.889295       total sum
# 32         6.000000        2.449490        Unweighted events, alpha=4.432459
#   => Total parameter prop_bineleJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         9.111786        3.969053        total sum
# 33         5.000000        2.236068        Unweighted events, alpha=1.822357
#   => Total parameter prop_bineleJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         10.303736       3.276918        total sum
# 34         10.000000       3.162278        Unweighted events, alpha=1.030374
#   => Total parameter prop_bineleJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         22.487753       9.855240        total sum
# 35         5.000000        2.236068        Unweighted events, alpha=4.497551
#   => Total parameter prop_bineleJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         15.930505       7.120492        total sum
# 36         5.000000        2.236068        Unweighted events, alpha=3.186101
#   => Total parameter prop_bineleJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         8.579991        2.882797        total sum
# 37         9.000000        3.000000        Unweighted events, alpha=0.953332
#   => Total parameter prop_bineleJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         16.092845       7.791977        total sum
# 38         4.000000        2.000000        Unweighted events, alpha=4.023211
#   => Total parameter prop_bineleJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         8.804202        2.677295        total sum
# 39         11.000000       3.316625        Unweighted events, alpha=0.800382
#   => Total parameter prop_bineleJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          23.490693       9.957998        total sum
# 0          6.000000        2.449490        Unweighted events, alpha=3.915116
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          36.240975       8.607562        total sum
# 1          18.000000       4.242641        Unweighted events, alpha=2.013388
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          107.868759      82.223170       total sum
# 2          2.000000        1.414214        Unweighted events, alpha=53.934380
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          30.396330       5.685335        total sum
# 3          29.000000       5.385165        Unweighted events, alpha=1.048149
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          26.697517       4.310470        total sum
# 4          38.000000       6.164414        Unweighted events, alpha=0.702566
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          30.894990       6.380871        total sum
# 5          23.000000       4.795832        Unweighted events, alpha=1.343260
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          25.845979       5.370632        total sum
# 6          23.000000       4.795832        Unweighted events, alpha=1.123738
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          23.665765       5.106464        total sum
# 7          21.000000       4.582576        Unweighted events, alpha=1.126941
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          45.866596       10.181758       total sum
# 8          20.000000       4.472136        Unweighted events, alpha=2.293330
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          20.775668       2.234833        total sum
# 9          86.000000       9.273618        Unweighted events, alpha=0.241578
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         27.802856       5.306700        total sum
# 10         27.000000       5.196152        Unweighted events, alpha=1.029735
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         24.858941       5.783773        total sum
# 11         18.000000       4.242641        Unweighted events, alpha=1.381052
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         39.886156       15.628566       total sum
# 12         7.000000        2.645751        Unweighted events, alpha=5.698022
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         17.769659       1.565493        total sum
# 13         129.000000      11.357817       Unweighted events, alpha=0.137749
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         21.206819       2.785911        total sum
# 14         58.000000       7.615773        Unweighted events, alpha=0.365635
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         16.955220       1.620548        total sum
# 15         109.000000      10.440307       Unweighted events, alpha=0.155552
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         26.867001       7.434327        total sum
# 16         13.000000       3.605551        Unweighted events, alpha=2.066692
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         20.938413       4.056318        total sum
# 17         27.000000       5.196152        Unweighted events, alpha=0.775497
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         22.497738       7.577848        total sum
# 18         9.000000        3.000000        Unweighted events, alpha=2.499749
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         12.929326       3.010360        total sum
# 19         18.000000       4.242641        Unweighted events, alpha=0.718296
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         21.969556       5.007177        total sum
# 20         19.000000       4.358899        Unweighted events, alpha=1.156292
#   => Total parameter prop_binmuJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         22.149292       5.258468        total sum
# 21         18.000000       4.242641        Unweighted events, alpha=1.230516
#   => Total parameter prop_binmuJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         16.189270       2.115080        total sum
# 22         59.000000       7.681146        Unweighted events, alpha=0.274394
#   => Total parameter prop_binmuJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         17.810492       5.621803        total sum
# 23         10.000000       3.162278        Unweighted events, alpha=1.781049
#   => Total parameter prop_binmuJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         18.624197       3.079507        total sum
# 24         37.000000       6.082763        Unweighted events, alpha=0.503357
#   => Total parameter prop_binmuJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         12.608245       1.390127        total sum
# 25         82.000000       9.055385        Unweighted events, alpha=0.153759
#   => Total parameter prop_binmuJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         16.836843       2.902500        total sum
# 26         34.000000       5.830952        Unweighted events, alpha=0.495201
#   => Total parameter prop_binmuJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         22.815745       8.004692        total sum
# 27         8.000000        2.828427        Unweighted events, alpha=2.851968
#   => Total parameter prop_binmuJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         12.924319       1.374656        total sum
# 28         88.000000       9.380832        Unweighted events, alpha=0.146867
#   => Total parameter prop_binmuJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         31.040196       14.704373       total sum
# 29         4.000000        2.000000        Unweighted events, alpha=7.760049
#   => Total parameter prop_binmuJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         10.046329       1.455995        total sum
# 30         48.000000       6.928203        Unweighted events, alpha=0.209299
#   => Total parameter prop_binmuJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         13.022836       3.585872        total sum
# 31         13.000000       3.605551        Unweighted events, alpha=1.001757
#   => Total parameter prop_binmuJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         18.910092       6.421758        total sum
# 32         9.000000        3.000000        Unweighted events, alpha=2.101121
#   => Total parameter prop_binmuJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         20.854479       8.446274        total sum
# 33         6.000000        2.449490        Unweighted events, alpha=3.475747
#   => Total parameter prop_binmuJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         17.045417       5.205280        total sum
# 34         11.000000       3.316625        Unweighted events, alpha=1.549583
#   => Total parameter prop_binmuJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         8.783625        1.330744        total sum
# 35         44.000000       6.633250        Unweighted events, alpha=0.199628
#   => Total parameter prop_binmuJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         10.382988       3.836897        total sum
# 36         7.000000        2.645751        Unweighted events, alpha=1.483284
#   => Total parameter prop_binmuJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         9.926655        4.473808        total sum
# 37         5.000000        2.236068        Unweighted events, alpha=1.985331
#   => Total parameter prop_binmuJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         10.973817       2.343701        total sum
# 38         22.000000       4.690416        Unweighted events, alpha=0.498810
#   => Total parameter prop_binmuJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         12.106093       3.942863        total sum
# 39         9.000000        3.000000        Unweighted events, alpha=1.345121
#   => Total parameter prop_binmuJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-MKjXfL.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 2.17106  -0.224525/+0.260816  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)

# %%
# !combine -M FitDiagnostics -n CR4  datacard_CR4.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          63.583902       14.555634       total sum
# 0          19.000000       4.358899        Unweighted events, alpha=3.346521
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          56.416481       6.353635        total sum
# 1          79.000000       8.888194        Unweighted events, alpha=0.714133
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          66.521660       7.225427        total sum
# 2          85.000000       9.219544        Unweighted events, alpha=0.782608
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          72.572132       9.462496        total sum
# 3          59.000000       7.681146        Unweighted events, alpha=1.230036
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          60.779005       9.603490        total sum
# 4          40.000000       6.324555        Unweighted events, alpha=1.519475
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          65.595305       5.207614        total sum
# 5          159.000000      12.609520       Unweighted events, alpha=0.412549
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          69.749210       7.021732        total sum
# 6          99.000000       9.949874        Unweighted events, alpha=0.704537
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          64.676697       5.895627        total sum
# 7          120.000000      10.954451       Unweighted events, alpha=0.538972
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          71.501091       10.375134       total sum
# 8          47.000000       6.855655        Unweighted events, alpha=1.521300
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          83.182207       10.612092       total sum
# 9          61.000000       7.810250        Unweighted events, alpha=1.363643
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         92.903858       12.621396       total sum
# 10         54.000000       7.348469        Unweighted events, alpha=1.720442
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         152.524330      58.349007       total sum
# 11         7.000000        2.645751        Unweighted events, alpha=21.789190
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         139.349014      17.741763       total sum
# 12         62.000000       7.874008        Unweighted events, alpha=2.247565
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         184.110092      21.651302       total sum
# 13         72.000000       8.485281        Unweighted events, alpha=2.557085
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         251.424210      26.849437       total sum
# 14         88.000000       9.380832        Unweighted events, alpha=2.857093
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         282.327370      28.406727       total sum
# 15         99.000000       9.949874        Unweighted events, alpha=2.851792
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         149.969719      19.014957       total sum
# 16         62.000000       7.874008        Unweighted events, alpha=2.418866
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         96.666470       13.574864       total sum
# 17         51.000000       7.141428        Unweighted events, alpha=1.895421
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         90.301125       16.713269       total sum
# 18         29.000000       5.385165        Unweighted events, alpha=3.113832
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         65.396582       8.360136        total sum
# 19         61.000000       7.810250        Unweighted events, alpha=1.072075
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         62.552479       10.965759       total sum
# 20         33.000000       5.744563        Unweighted events, alpha=1.895530
#   => Total parameter prop_bineleJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         49.311666       5.877912        total sum
# 21         70.000000       8.366600        Unweighted events, alpha=0.704452
#   => Total parameter prop_bineleJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         55.492796       6.522926        total sum
# 22         72.000000       8.485281        Unweighted events, alpha=0.770733
#   => Total parameter prop_bineleJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         215.323778      157.887410      total sum
# 23         2.000000        1.414214        Unweighted events, alpha=107.661889
#   => Total parameter prop_bineleJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         50.930880       10.371928       total sum
# 24         24.000000       4.898979        Unweighted events, alpha=2.122120
#   => Total parameter prop_bineleJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         44.854134       6.482965        total sum
# 25         48.000000       6.928203        Unweighted events, alpha=0.934461
#   => Total parameter prop_bineleJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         43.451670       6.535591        total sum
# 26         44.000000       6.633250        Unweighted events, alpha=0.987538
#   => Total parameter prop_bineleJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         57.658719       15.240344       total sum
# 27         14.000000       3.741657        Unweighted events, alpha=4.118480
#   => Total parameter prop_bineleJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         32.949761       2.497584        total sum
# 28         174.000000      13.190906       Unweighted events, alpha=0.189366
#   => Total parameter prop_bineleJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         40.440027       4.148068        total sum
# 29         95.000000       9.746794        Unweighted events, alpha=0.425684
#   => Total parameter prop_bineleJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         36.960361       3.486978        total sum
# 30         112.000000      10.583005       Unweighted events, alpha=0.330003
#   => Total parameter prop_bineleJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         35.019888       4.454825        total sum
# 31         62.000000       7.874008        Unweighted events, alpha=0.564837
#   => Total parameter prop_bineleJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         34.220113       4.278287        total sum
# 32         64.000000       8.000000        Unweighted events, alpha=0.534689
#   => Total parameter prop_bineleJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         31.644556       6.638071        total sum
# 33         23.000000       4.795832        Unweighted events, alpha=1.375850
#   => Total parameter prop_bineleJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         38.815000       11.106024       total sum
# 34         12.000000       3.464102        Unweighted events, alpha=3.234583
#   => Total parameter prop_bineleJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         28.743083       2.439357        total sum
# 35         139.000000      11.789826       Unweighted events, alpha=0.206785
#   => Total parameter prop_bineleJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         32.241979       2.730061        total sum
# 36         139.000000      11.789826       Unweighted events, alpha=0.231957
#   => Total parameter prop_bineleJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         24.056272       2.973208        total sum
# 37         65.000000       8.062258        Unweighted events, alpha=0.370096
#   => Total parameter prop_bineleJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         24.077982       2.155011        total sum
# 38         125.000000      11.180340       Unweighted events, alpha=0.192624
#   => Total parameter prop_bineleJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         22.258737       2.269070        total sum
# 39         96.000000       9.797959        Unweighted events, alpha=0.231862
#   => Total parameter prop_bineleJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          85.827273       5.970272        total sum
# 0          207.000000      14.387495       Unweighted events, alpha=0.414625
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          94.137482       15.916793       total sum
# 1          35.000000       5.916080        Unweighted events, alpha=2.689642
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          105.327526      11.120024       total sum
# 2          90.000000       9.486833        Unweighted events, alpha=1.170306
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          89.816938       7.170367        total sum
# 3          157.000000      12.529964       Unweighted events, alpha=0.572082
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          96.645304       5.799939        total sum
# 4          278.000000      16.673332       Unweighted events, alpha=0.347645
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          102.334759      8.491224        total sum
# 5          145.000000      12.041595       Unweighted events, alpha=0.705757
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          91.113779       10.862898       total sum
# 6          70.000000       8.366600        Unweighted events, alpha=1.301625
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          112.092731      10.923663       total sum
# 7          105.000000      10.246951       Unweighted events, alpha=1.067550
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          110.529590      16.344980       total sum
# 8          46.000000       6.782330        Unweighted events, alpha=2.402817
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          102.285620      9.448064        total sum
# 9          117.000000      10.816654       Unweighted events, alpha=0.874236
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         93.870178       13.706628       total sum
# 10         47.000000       6.855655        Unweighted events, alpha=1.997238
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         83.802749       5.059210        total sum
# 11         274.000000      16.552945       Unweighted events, alpha=0.305849
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         100.559025      8.870370        total sum
# 12         129.000000      11.357817       Unweighted events, alpha=0.779527
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         122.119528      16.170963       total sum
# 13         57.000000       7.549834        Unweighted events, alpha=2.142448
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         85.951115       5.690242        total sum
# 14         228.000000      15.099669       Unweighted events, alpha=0.376979
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         89.890508       10.520981       total sum
# 15         73.000000       8.544004        Unweighted events, alpha=1.231377
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         77.682613       5.711165        total sum
# 16         185.000000      13.601471       Unweighted events, alpha=0.419906
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         85.069899       12.243818       total sum
# 17         48.000000       6.928203        Unweighted events, alpha=1.772290
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         76.644013       5.718703        total sum
# 18         180.000000      13.416408       Unweighted events, alpha=0.425800
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         61.502696       4.533060        total sum
# 19         184.000000      13.564660       Unweighted events, alpha=0.334254
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         93.313005       13.691029       total sum
# 20         46.000000       6.782330        Unweighted events, alpha=2.028544
#   => Total parameter prop_binmuJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         74.603999       4.874979        total sum
# 21         234.000000      15.297059       Unweighted events, alpha=0.318821
#   => Total parameter prop_binmuJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         64.618116       4.301642        total sum
# 22         226.000000      15.033296       Unweighted events, alpha=0.285921
#   => Total parameter prop_binmuJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         65.062674       5.007479        total sum
# 23         169.000000      13.000000       Unweighted events, alpha=0.384986
#   => Total parameter prop_binmuJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         85.739613       23.217967       total sum
# 24         14.000000       3.741657        Unweighted events, alpha=6.124258
#   => Total parameter prop_binmuJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         57.953415       3.832859        total sum
# 25         229.000000      15.132746       Unweighted events, alpha=0.253072
#   => Total parameter prop_binmuJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         54.310631       3.877777        total sum
# 26         196.000000      14.000000       Unweighted events, alpha=0.277095
#   => Total parameter prop_binmuJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         60.184237       3.942815        total sum
# 27         233.000000      15.264338       Unweighted events, alpha=0.258301
#   => Total parameter prop_binmuJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         57.983110       3.914647        total sum
# 28         219.000000      14.798649       Unweighted events, alpha=0.264763
#   => Total parameter prop_binmuJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         57.416492       3.928315        total sum
# 29         214.000000      14.628739       Unweighted events, alpha=0.268301
#   => Total parameter prop_binmuJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         61.508498       8.924357        total sum
# 30         48.000000       6.928203        Unweighted events, alpha=1.281427
#   => Total parameter prop_binmuJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         56.534847       13.596236       total sum
# 31         17.000000       4.123106        Unweighted events, alpha=3.325579
#   => Total parameter prop_binmuJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         44.811586       3.247048        total sum
# 32         190.000000      13.784049       Unweighted events, alpha=0.235850
#   => Total parameter prop_binmuJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         68.675760       19.537091       total sum
# 33         12.000000       3.464102        Unweighted events, alpha=5.722980
#   => Total parameter prop_binmuJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         55.447531       6.486848        total sum
# 34         73.000000       8.544004        Unweighted events, alpha=0.759555
#   => Total parameter prop_binmuJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         50.329994       5.887875        total sum
# 35         73.000000       8.544004        Unweighted events, alpha=0.689452
#   => Total parameter prop_binmuJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         38.844219       4.504571        total sum
# 36         74.000000       8.602325        Unweighted events, alpha=0.524922
#   => Total parameter prop_binmuJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         37.437613       3.110118        total sum
# 37         145.000000      12.041595       Unweighted events, alpha=0.258190
#   => Total parameter prop_binmuJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         42.502245       3.506787        total sum
# 38         147.000000      12.124356       Unweighted events, alpha=0.289131
#   => Total parameter prop_binmuJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         39.258818       3.374921        total sum
# 39         135.000000      11.618950       Unweighted events, alpha=0.290806
#   => Total parameter prop_binmuJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-K8ipqo.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 2.45437  -0.178603/+0.199167  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)
