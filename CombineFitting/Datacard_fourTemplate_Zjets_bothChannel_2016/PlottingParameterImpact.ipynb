# %%
# !text2workspace.py datacard_CR123.txt
# Out:
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          634.251820      171.618982      total sum
# 0          14.000000       3.741657        Unweighted events, alpha=45.303701
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          731.023079      196.776296      total sum
# 1          14.000000       3.741657        Unweighted events, alpha=52.215934
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          716.040710      89.075660       total sum
# 2          65.000000       8.062258        Unweighted events, alpha=11.016011
# ...

# %%
# !combineTool.py -M Impacts -d datacard_CR123.root -m 125 --doInitialFit --robustFit 1
# Out:
# Have POIs: ['r']
# >> combine -M MultiDimFit -n _initialFit_Test --algo singles --redefineSignalPOIs r --robustFit 1 -m 125 -d datacard_CR123.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
#
#  --- MultiDimFit ---
# best fit parameter values and profile-likelihood uncertainties:
#    r :    +2.208   -0.048/+0.050 (68%)
# Done in 0.00 min (cpu), 0.01 min (real)

# %%
# !combineTool.py -M Impacts -d datacard_CR123.root -m 125 --robustFit 1 --doFits
# Out:
# Have POIs: ['r']
# Have parameters: 34
# >> combine -M MultiDimFit -n _paramFit_Test_WGammaBkgPhotonSF --algo impact --redefineSignalPOIs r -P WGammaBkgPhotonSF --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123.root
#  <<< Combine >>>
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is MultiDimFit
# >>> random number generator seed is 123456
# Error: minimization failed at WGammaBkgPhotonSF = 6.25e+27
# Error: minimization failed at WGammaBkgPhotonSF = -6.25e+27
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter         :   Best-fit               r
#   WGammaBkgPhotonSF :   +1.282  +0.000/+0.000  +0.000/+0.000
# Done in 0.01 min (cpu), 0.01 min (real)
# >> combine -M MultiDimFit -n _paramFit_Test_ZGammaBkgPhotonSF --algo impact --redefineSignalPOIs r -P ZGammaBkgPhotonSF --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -m 125 -d datacard_CR123.root
# ...

# %%
# !combineTool.py -M Impacts -d datacard_CR123.root -m 125 -o impacts.json
# Out:
# Have POIs: ['r']
# Have parameters: 34

# %%
# !plotImpacts.py -i impacts.json -o impacts
# Out:
# >> Doing page 0, have 30 parameters
# Info in <TCanvas::Print>: pdf file ./impacts.pdf has been created using the current canvas
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: impacts
# >> Doing page 1, have 4 parameters
# Info in <TCanvas::Print>: Current canvas added to pdf file ./impacts.pdf and file closed

# %%
from IPython.display import IFrame
IFrame("impacts.pdf", width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="impacts.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
