# %%
import ROOT
import os
# !pwd
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/TTGammaSemiLep_13TeV/Plotting/CombineFitting/Datacard_fourTemplate_Zjets_bothChannel_2017

# %%
# !combine -M FitDiagnostics -n CR123  datacard_CR123.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          481.428032      46.915465       total sum
# 0          105.000000      10.246951       Unweighted events, alpha=4.585029
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          731.180267      78.271006       total sum
# 1          87.000000       9.327379        Unweighted events, alpha=8.404371
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          781.933334      56.168660       total sum
# 2          194.000000      13.928388       Unweighted events, alpha=4.030584
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1132.581177     88.673226       total sum
# 3          163.000000      12.767145       Unweighted events, alpha=6.948351
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          332.490387      40.226130       total sum
# 4          68.000000       8.246211        Unweighted events, alpha=4.889565
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          404.474503      61.879533       total sum
# 5          43.000000       6.557439        Unweighted events, alpha=9.406384
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1108.088684     391.514724      total sum
# 6          8.000000        2.828427        Unweighted events, alpha=138.511086
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1199.201477     80.317070       total sum
# 7          223.000000      14.933185       Unweighted events, alpha=5.377585
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1880.880859     86.068044       total sum
# 8          478.000000      21.863211       Unweighted events, alpha=3.934897
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          2108.645813     104.206895      total sum
# 9          409.000000      20.223748       Unweighted events, alpha=5.155613
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1308.436966     65.754148       total sum
# 10         396.000000      19.899749       Unweighted events, alpha=3.304134
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         631.853714      45.046780       total sum
# 11         197.000000      14.035669       Unweighted events, alpha=3.207379
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         614.339584      232.715634      total sum
# 12         7.000000        2.645751        Unweighted events, alpha=87.762798
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         355.966751      69.552367       total sum
# 13         26.000000       5.099020        Unweighted events, alpha=13.691029
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         796.603607      73.500285       total sum
# 14         117.000000      10.816654       Unweighted events, alpha=6.808578
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         436.433815      35.271125       total sum
# 15         153.000000      12.369317       Unweighted events, alpha=2.852509
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         455.548347      70.573799       total sum
# 16         42.000000       6.480741        Unweighted events, alpha=10.846389
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         336.090416      57.476474       total sum
# 17         34.000000       5.830952        Unweighted events, alpha=9.885012
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         266.931612      32.386428       total sum
# 18         68.000000       8.246211        Unweighted events, alpha=3.925465
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         198.678528      36.379055       total sum
# 19         30.000000       5.477226        Unweighted events, alpha=6.622618
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1129.252630     204.716941      total sum
# 0          30.000000       5.477226        Unweighted events, alpha=37.641754
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1474.736546     199.193058      total sum
# 1          55.000000       7.416198        Unweighted events, alpha=26.813392
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          2835.851191     1068.262078     total sum
# 2          7.000000        2.645751        Unweighted events, alpha=405.121599
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1444.669838     120.193015      total sum
# 3          144.000000      12.000000       Unweighted events, alpha=10.032429
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1335.481892     108.004232      total sum
# 4          153.000000      12.369317       Unweighted events, alpha=8.728640
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          2251.557457     1214.089423     total sum
# 5          3.000000        1.732051        Unweighted events, alpha=750.519152
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          976.277437      255.019375      total sum
# 6          15.000000       3.872983        Unweighted events, alpha=65.085162
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          764.769612      154.808855      total sum
# 7          24.000000       4.898979        Unweighted events, alpha=31.865401
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          475.660814      61.391169       total sum
# 8          60.000000       7.745967        Unweighted events, alpha=7.927680
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          300.090840      24.292034       total sum
# 9          153.000000      12.369317       Unweighted events, alpha=1.961378
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         419.721027      84.753625       total sum
# 10         25.000000       5.000000        Unweighted events, alpha=16.788841
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         326.646773      58.030131       total sum
# 11         32.000000       5.656854        Unweighted events, alpha=10.207712
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-D4HynQ.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 2.39128  -0.0595402/+0.0619719  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)

# %%
# !combine -M FitDiagnostics -n CR1  datacard_CR1.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          293.473699      40.348225       total sum
# 0          53.000000       7.280110        Unweighted events, alpha=5.537240
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          458.553825      56.955940       total sum
# 1          65.000000       8.062258        Unweighted events, alpha=7.054674
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          491.781128      45.649862       total sum
# 2          116.000000      10.770330       Unweighted events, alpha=4.239492
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          721.205048      53.440493       total sum
# 3          182.000000      13.490738       Unweighted events, alpha=3.962665
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          254.294907      38.166516       total sum
# 4          44.000000       6.633250        Unweighted events, alpha=5.779430
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          301.635101      60.017607       total sum
# 5          25.000000       5.000000        Unweighted events, alpha=12.065404
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          978.564758      391.076917      total sum
# 6          6.000000        2.449490        Unweighted events, alpha=163.094126
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          930.685165      73.966800       total sum
# 7          158.000000      12.569805       Unweighted events, alpha=5.890412
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1436.136703     71.940682       total sum
# 8          399.000000      19.974984       Unweighted events, alpha=3.599340
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1665.544891     97.013706       total sum
# 9          295.000000      17.175564       Unweighted events, alpha=5.645915
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1015.856262     58.592918       total sum
# 10         301.000000      17.349352       Unweighted events, alpha=3.374938
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         487.198769      40.463567       total sum
# 11         145.000000      12.041595       Unweighted events, alpha=3.359992
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         274.474045      52.820257       total sum
# 12         27.000000       5.196152        Unweighted events, alpha=10.165705
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         242.326790      63.950118       total sum
# 13         14.000000       3.741657        Unweighted events, alpha=17.309056
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         538.389374      68.616748       total sum
# 14         62.000000       7.874008        Unweighted events, alpha=8.683700
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         257.979515      25.955935       total sum
# 15         99.000000       9.949874        Unweighted events, alpha=2.605854
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         295.453062      62.339953       total sum
# 16         22.000000       4.690416        Unweighted events, alpha=13.429685
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         218.183105      55.027183       total sum
# 17         16.000000       4.000000        Unweighted events, alpha=13.636444
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         160.851147      27.877212       total sum
# 18         33.000000       5.744563        Unweighted events, alpha=4.874277
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         132.340437      34.378821       total sum
# 19         15.000000       3.872983        Unweighted events, alpha=8.822696
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          650.673635      97.355996       total sum
# 0          45.000000       6.708204        Unweighted events, alpha=14.459414
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1067.103731     195.983395      total sum
# 1          30.000000       5.477226        Unweighted events, alpha=35.570124
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          2141.186884     1027.998064     total sum
# 2          4.000000        2.000000        Unweighted events, alpha=535.296721
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          935.056010      94.128442       total sum
# 3          99.000000       9.949874        Unweighted events, alpha=9.445010
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          881.192428      96.215073       total sum
# 4          84.000000       9.165151        Unweighted events, alpha=10.490386
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1865.526476     1210.704502     total sum
# 5          2.000000        1.414214        Unweighted events, alpha=932.763238
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          691.991488      245.564750      total sum
# 6          8.000000        2.828427        Unweighted events, alpha=86.498936
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          517.534158      145.107033      total sum
# 7          13.000000       3.605551        Unweighted events, alpha=39.810320
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          314.791955      59.052628       total sum
# 8          28.000000       5.291503        Unweighted events, alpha=11.242570
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          176.154163      21.018382       total sum
# 9          70.000000       8.366600        Unweighted events, alpha=2.516488
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         249.737942      70.878000       total sum
# 10         12.000000       3.464102        Unweighted events, alpha=20.811495
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         194.758915      38.383505       total sum
# 11         26.000000       5.099020        Unweighted events, alpha=7.490728
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-25yUe8.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 2.37854  -0.0659896/+0.0692451  (68% CL)
# Done in 0.00 min (cpu), 0.01 min (real)

# %%
# !combine -M FitDiagnostics -n CR2  datacard_CR2.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          141.174889      23.515725       total sum
# 0          36.000000       6.000000        Unweighted events, alpha=3.921525
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          204.204727      53.095069       total sum
# 1          15.000000       3.872983        Unweighted events, alpha=13.613648
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          215.044449      31.571145       total sum
# 2          46.000000       6.782330        Unweighted events, alpha=4.674879
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          266.386276      57.570833       total sum
# 3          21.000000       4.582576        Unweighted events, alpha=12.685061
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          54.884428       11.813635       total sum
# 4          22.000000       4.690416        Unweighted events, alpha=2.494747
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          67.382912       12.622967       total sum
# 5          28.000000       5.291503        Unweighted events, alpha=2.406533
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          99.807972       16.447408       total sum
# 6          37.000000       6.082763        Unweighted events, alpha=2.697513
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          191.257820      25.813605       total sum
# 7          55.000000       7.416198        Unweighted events, alpha=3.477415
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          351.328796      35.784925       total sum
# 8          96.000000       9.797959        Unweighted events, alpha=3.659675
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          359.395885      34.884128       total sum
# 9          106.000000      10.295630       Unweighted events, alpha=3.390527
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         235.978226      27.286985       total sum
# 10         75.000000       8.660254        Unweighted events, alpha=3.146376
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         102.728424      17.133643       total sum
# 11         36.000000       6.000000        Unweighted events, alpha=2.853567
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         297.082436      226.203397      total sum
# 12         2.000000        1.414214        Unweighted events, alpha=148.541218
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         88.355145       24.782187       total sum
# 13         13.000000       3.605551        Unweighted events, alpha=6.796550
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         171.218712      22.866837       total sum
# 14         56.000000       7.483315        Unweighted events, alpha=3.057477
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         99.790535       17.393401       total sum
# 15         33.000000       5.744563        Unweighted events, alpha=3.023956
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         118.119488      32.669028       total sum
# 16         13.000000       3.605551        Unweighted events, alpha=9.086114
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         71.816906       10.565633       total sum
# 17         46.000000       6.782330        Unweighted events, alpha=1.561237
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         68.665607       15.022682       total sum
# 18         21.000000       4.582576        Unweighted events, alpha=3.269791
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         43.581726       10.988855       total sum
# 19         16.000000       4.000000        Unweighted events, alpha=2.723858
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          378.686870      179.653854      total sum
# 0          4.000000        2.000000        Unweighted events, alpha=94.671718
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          279.524464      32.302037       total sum
# 1          75.000000       8.660254        Unweighted events, alpha=3.726993
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          594.557056      290.390159      total sum
# 2          4.000000        2.000000        Unweighted events, alpha=148.639264
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          346.991849      42.565414       total sum
# 3          66.000000       8.124038        Unweighted events, alpha=5.257452
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          320.468203      45.814728       total sum
# 4          49.000000       7.000000        Unweighted events, alpha=6.540167
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          218.774247      48.258049       total sum
# 5          21.000000       4.582576        Unweighted events, alpha=10.417821
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          146.829120      16.736542       total sum
# 6          77.000000       8.774964        Unweighted events, alpha=1.906872
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          139.212149      17.057119       total sum
# 7          67.000000       8.185353        Unweighted events, alpha=2.077793
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          112.269044      15.951775       total sum
# 8          50.000000       7.071068        Unweighted events, alpha=2.245381
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          79.330396       10.714216       total sum
# 9          55.000000       7.416198        Unweighted events, alpha=1.442371
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         128.259502      46.018755       total sum
# 10         8.000000        2.828427        Unweighted events, alpha=16.032438
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         95.426769       42.674844       total sum
# 11         5.000000        2.236068        Unweighted events, alpha=19.085354
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-twZHbD.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 2.4272  -0.140141/+0.153758  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)

# %%
# !combine -M FitDiagnostics -n CR3  datacard_CR3.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          46.988879       4.846277        total sum
# 0          94.000000       9.695360        Unweighted events, alpha=0.499882
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          68.591276       8.226988        total sum
# 1          70.000000       8.366600        Unweighted events, alpha=0.979875
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          75.171493       8.651709        total sum
# 2          75.000000       8.660254        Unweighted events, alpha=1.002287
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          144.973862      41.132906       total sum
# 3          12.000000       3.464102        Unweighted events, alpha=12.081155
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          23.326928       4.712410        total sum
# 4          25.000000       5.000000        Unweighted events, alpha=0.933077
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          35.372427       8.194524        total sum
# 5          19.000000       4.358899        Unweighted events, alpha=1.861707
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          29.697916       8.474165        total sum
# 6          12.000000       3.464102        Unweighted events, alpha=2.474826
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          77.242157       17.689783       total sum
# 7          19.000000       4.358899        Unweighted events, alpha=4.065377
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          94.059566       30.921181       total sum
# 8          9.000000        3.000000        Unweighted events, alpha=10.451063
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          84.234591       15.325345       total sum
# 9          30.000000       5.477226        Unweighted events, alpha=2.807820
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         56.878364       12.161531       total sum
# 10         22.000000       4.690416        Unweighted events, alpha=2.585380
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         41.898048       9.908068        total sum
# 11         18.000000       4.242641        Unweighted events, alpha=2.327669
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         42.857943       14.119989       total sum
# 12         9.000000        3.000000        Unweighted events, alpha=4.761994
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         25.420097       11.607589       total sum
# 13         5.000000        2.236068        Unweighted events, alpha=5.084019
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         86.876938       13.036011       total sum
# 14         44.000000       6.633250        Unweighted events, alpha=1.974476
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         78.619021       16.360450       total sum
# 15         23.000000       4.795832        Unweighted events, alpha=3.418218
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         41.976180       5.209508        total sum
# 16         65.000000       8.062258        Unweighted events, alpha=0.645787
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         46.123476       12.809263       total sum
# 17         13.000000       3.605551        Unweighted events, alpha=3.547960
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         37.385361       6.772339        total sum
# 18         30.000000       5.477226        Unweighted events, alpha=1.246179
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         22.736604       4.541993        total sum
# 19         25.000000       5.000000        Unweighted events, alpha=0.909464
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          99.903569       12.455020       total sum
# 0          64.000000       8.000000        Unweighted events, alpha=1.560993
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          128.198064      15.004698       total sum
# 1          73.000000       8.544004        Unweighted events, alpha=1.756138
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          100.162375      8.823471        total sum
# 2          129.000000      11.357817       Unweighted events, alpha=0.776453
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          162.710845      61.439960       total sum
# 3          7.000000        2.645751        Unweighted events, alpha=23.244406
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          133.901058      17.555067       total sum
# 4          58.000000       7.615773        Unweighted events, alpha=2.308639
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          167.180029      76.669357       total sum
# 5          5.000000        2.236068        Unweighted events, alpha=33.436006
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          137.383846      66.723128       total sum
# 6          4.000000        2.000000        Unweighted events, alpha=34.345962
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          108.000966      51.166714       total sum
# 7          4.000000        2.000000        Unweighted events, alpha=27.000241
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          48.648240       5.243820        total sum
# 8          86.000000       9.273618        Unweighted events, alpha=0.565677
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          44.718731       5.853478        total sum
# 9          58.000000       7.615773        Unweighted events, alpha=0.771013
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         41.736991       6.458394        total sum
# 10         42.000000       6.480741        Unweighted events, alpha=0.993738
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         36.510360       8.568493        total sum
# 11         18.000000       4.242641        Unweighted events, alpha=2.028353
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-qeEcMW.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 2.66051  -0.31461/+0.369851  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)

# %%
# !combine -M FitDiagnostics -n CR4  datacard_CR4.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          183.251453      42.338530       total sum
# 0          19.000000       4.358899        Unweighted events, alpha=9.644813
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          193.599092      31.162892       total sum
# 1          39.000000       6.244998        Unweighted events, alpha=4.964079
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          191.923967      15.146371       total sum
# 2          161.000000      12.688578       Unweighted events, alpha=1.192074
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          238.604774      13.909964       total sum
# 3          294.000000      17.146428       Unweighted events, alpha=0.811581
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          66.805698       11.204243       total sum
# 4          36.000000       6.000000        Unweighted events, alpha=1.855714
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          107.497276      31.617107       total sum
# 5          12.000000       3.464102        Unweighted events, alpha=8.958106
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          92.430641       13.148374       total sum
# 6          49.000000       7.000000        Unweighted events, alpha=1.886340
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          95.303307       14.214632       total sum
# 7          45.000000       6.708204        Unweighted events, alpha=2.117851
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          172.453060      21.164843       total sum
# 8          66.000000       8.124038        Unweighted events, alpha=2.612925
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          190.377262      23.251661       total sum
# 9          67.000000       8.185353        Unweighted events, alpha=2.841452
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         96.984936       13.966593       total sum
# 10         48.000000       6.928203        Unweighted events, alpha=2.020519
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         53.471361       7.552758        total sum
# 11         50.000000       7.071068        Unweighted events, alpha=1.069427
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         40.949902       5.097266        total sum
# 12         65.000000       8.062258        Unweighted events, alpha=0.629998
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         40.252436       5.240535        total sum
# 13         59.000000       7.681146        Unweighted events, alpha=0.682245
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         171.160618      10.221904       total sum
# 14         280.000000      16.733201       Unweighted events, alpha=0.611288
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         127.128561      6.288739        total sum
# 15         409.000000      20.223748       Unweighted events, alpha=0.310828
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         112.417372      5.697326        total sum
# 16         389.000000      19.723083       Unweighted events, alpha=0.288991
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         94.995937       11.298640       total sum
# 17         71.000000       8.426150        Unweighted events, alpha=1.337971
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         89.523351       11.842479       total sum
# 18         57.000000       7.549834        Unweighted events, alpha=1.570585
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         58.166749       6.141344        total sum
# 19         90.000000       9.486833        Unweighted events, alpha=0.646297
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          892.786455      675.545446      total sum
# 0          2.000000        1.414214        Unweighted events, alpha=446.393228
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          322.603592      26.620621       total sum
# 1          147.000000      12.124356       Unweighted events, alpha=2.194582
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          384.889122      42.219723       total sum
# 2          83.000000       9.110434        Unweighted events, alpha=4.637218
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          329.095516      14.588203       total sum
# 3          509.000000      22.561028       Unweighted events, alpha=0.646553
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          405.029663      57.577978       total sum
# 4          49.000000       7.000000        Unweighted events, alpha=8.265911
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          296.594734      28.696013       total sum
# 5          107.000000      10.344080       Unweighted events, alpha=2.771913
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          288.655308      45.356818       total sum
# 6          41.000000       6.403124        Unweighted events, alpha=7.040373
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          204.787941      15.547140       total sum
# 7          174.000000      13.190906       Unweighted events, alpha=1.176942
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          159.614304      14.646183       total sum
# 8          119.000000      10.908712       Unweighted events, alpha=1.341297
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          143.863054      14.437689       total sum
# 9          99.000000       9.949874        Unweighted events, alpha=1.453162
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         96.548082       6.285072        total sum
# 10         236.000000      15.362291       Unweighted events, alpha=0.409102
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         85.334460       6.519517        total sum
# 11         171.000000      13.076697       Unweighted events, alpha=0.499032
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-xcXa8q.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 2.49341  -0.22829/+0.270516  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)
