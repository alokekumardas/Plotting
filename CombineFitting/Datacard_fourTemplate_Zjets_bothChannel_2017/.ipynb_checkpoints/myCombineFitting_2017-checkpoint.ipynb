# %%
import ROOT
import os
# !pwd
# Out:
# Welcome to JupyROOT 6.12/07
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/ttgammaCombineFitting/Datacard_fourTemplate_Zjets_bothChannel_2017

# %%
# !combine -M FitDiagnostics -n CR123  datacard_CR123.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          143.019073      28.730077       total sum
# 0          25.000000       5.000000        Unweighted events, alpha=5.720763
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          121.181946      16.538318       total sum
# 1          54.000000       7.348469        Unweighted events, alpha=2.244110
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          153.060459      21.359381       total sum
# 2          51.000000       7.141428        Unweighted events, alpha=3.001185
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          139.384121      20.083791       total sum
# 3          48.000000       6.928203        Unweighted events, alpha=2.903836
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          177.412891      29.469996       total sum
# 4          36.000000       6.000000        Unweighted events, alpha=4.928136
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          140.247494      20.621513       total sum
# 5          46.000000       6.782330        Unweighted events, alpha=3.048859
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          187.734825      25.072044       total sum
# 6          56.000000       7.483315        Unweighted events, alpha=3.352408
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          175.995705      20.041435       total sum
# 7          77.000000       8.774964        Unweighted events, alpha=2.285659
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          202.424911      25.749835       total sum
# 8          62.000000       7.874008        Unweighted events, alpha=3.264918
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          321.419540      70.555972       total sum
# 9          21.000000       4.582576        Unweighted events, alpha=15.305692
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         289.128235      36.639859       total sum
# 10         62.000000       7.874008        Unweighted events, alpha=4.663359
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         347.995132      59.066314       total sum
# 11         35.000000       5.916080        Unweighted events, alpha=9.942718
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         983.141174      390.513358      total sum
# 12         6.000000        2.449490        Unweighted events, alpha=163.856862
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         967.266907      70.563968       total sum
# 13         188.000000      13.711309       Unweighted events, alpha=5.145037
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1482.590729     69.814714       total sum
# 14         451.000000      21.236761       Unweighted events, alpha=3.287341
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         1670.094971     90.572942       total sum
# 15         340.000000      18.439089       Unweighted events, alpha=4.912044
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         1027.474045     50.846118       total sum
# 16         408.000000      20.199010       Unweighted events, alpha=2.518319
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         508.371017      35.478917       total sum
# 17         205.000000      14.317821       Unweighted events, alpha=2.479859
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         557.328476      231.959504      total sum
# 18         6.000000        2.449490        Unweighted events, alpha=92.888079
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         325.423180      68.321510       total sum
# 19         23.000000       4.795832        Unweighted events, alpha=14.148834
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         197.699150      36.176117       total sum
# 20         30.000000       5.477226        Unweighted events, alpha=6.589972
#   => Total parameter prop_bineleJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         175.097099      22.195719       total sum
# 21         62.000000       7.874008        Unweighted events, alpha=2.824147
#   => Total parameter prop_bineleJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         122.279673      19.072188       total sum
# 22         41.000000       6.403124        Unweighted events, alpha=2.982431
#   => Total parameter prop_bineleJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         145.281773      50.578751       total sum
# 23         8.000000        2.828427        Unweighted events, alpha=18.160222
#   => Total parameter prop_bineleJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         83.148981       12.246577       total sum
# 24         46.000000       6.782330        Unweighted events, alpha=1.807587
#   => Total parameter prop_bineleJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         111.067406      16.534362       total sum
# 25         45.000000       6.708204        Unweighted events, alpha=2.468165
#   => Total parameter prop_bineleJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         61.171998       8.097269        total sum
# 26         57.000000       7.549834        Unweighted events, alpha=1.073193
#   => Total parameter prop_bineleJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         81.150343       16.242344       total sum
# 27         25.000000       5.000000        Unweighted events, alpha=3.246014
#   => Total parameter prop_bineleJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         73.704142       11.244533       total sum
# 28         43.000000       6.557439        Unweighted events, alpha=1.714050
#   => Total parameter prop_bineleJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         84.579338       19.250029       total sum
# 29         19.000000       4.358899        Unweighted events, alpha=4.451544
#   => Total parameter prop_bineleJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         155.616527      50.791781       total sum
# 30         9.000000        3.000000        Unweighted events, alpha=17.290725
#   => Total parameter prop_bineleJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         55.878000       8.430201        total sum
# 31         44.000000       6.633250        Unweighted events, alpha=1.269955
#   => Total parameter prop_bineleJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         72.478086       15.542750       total sum
# 32         22.000000       4.690416        Unweighted events, alpha=3.294458
#   => Total parameter prop_bineleJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         50.812400       10.084153       total sum
# 33         25.000000       5.000000        Unweighted events, alpha=2.032496
#   => Total parameter prop_bineleJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         114.343352      43.835936       total sum
# 34         7.000000        2.645751        Unweighted events, alpha=16.334765
#   => Total parameter prop_bineleJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         76.053516       18.577121       total sum
# 35         17.000000       4.123106        Unweighted events, alpha=4.473736
#   => Total parameter prop_bineleJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         47.908646       8.184852        total sum
# 36         34.000000       5.830952        Unweighted events, alpha=1.409078
#   => Total parameter prop_bineleJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         120.237803      52.023849       total sum
# 37         5.000000        2.236068        Unweighted events, alpha=24.047561
#   => Total parameter prop_bineleJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         41.957579       7.932366        total sum
# 38         28.000000       5.291503        Unweighted events, alpha=1.498485
#   => Total parameter prop_bineleJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         39.063083       7.125265        total sum
# 39         30.000000       5.477226        Unweighted events, alpha=1.302103
#   => Total parameter prop_bineleJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          547.040215      290.609062      total sum
# 0          4.000000        2.000000        Unweighted events, alpha=136.760054
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1289.555377     1023.583875     total sum
# 1          2.000000        1.414214        Unweighted events, alpha=644.777689
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          308.990498      56.290859       total sum
# 2          30.000000       5.477226        Unweighted events, alpha=10.299683
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          265.070090      38.633354       total sum
# 3          47.000000       6.855655        Unweighted events, alpha=5.639789
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          325.526014      60.564141       total sum
# 4          29.000000       5.385165        Unweighted events, alpha=11.225035
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          296.474872      55.937007       total sum
# 5          28.000000       5.291503        Unweighted events, alpha=10.588388
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          226.447425      25.800683       total sum
# 6          77.000000       8.774964        Unweighted events, alpha=2.940876
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          323.603081      68.358906       total sum
# 7          22.000000       4.690416        Unweighted events, alpha=14.709231
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          302.114270      69.908016       total sum
# 8          19.000000       4.358899        Unweighted events, alpha=15.900751
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          210.730936      20.862291       total sum
# 9          102.000000      10.099505       Unweighted events, alpha=2.065990
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         240.281595      37.971960       total sum
# 10         40.000000       6.324555        Unweighted events, alpha=6.007040
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         340.034097      68.798839       total sum
# 11         24.000000       4.898979        Unweighted events, alpha=14.168087
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         268.854937      48.729682       total sum
# 12         30.000000       5.477226        Unweighted events, alpha=8.961831
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         223.569357      30.937545       total sum
# 13         52.000000       7.211103        Unweighted events, alpha=4.299411
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         205.392657      41.396303       total sum
# 14         25.000000       5.000000        Unweighted events, alpha=8.215706
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         313.307333      78.894022       total sum
# 15         16.000000       4.000000        Unweighted events, alpha=19.581708
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         227.185028      80.979767       total sum
# 16         8.000000        2.828427        Unweighted events, alpha=28.398129
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         1401.688527     1207.694576     total sum
# 17         1.000000        1.000000        Unweighted events, alpha=1401.688527
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         111.983986      13.692840       total sum
# 18         67.000000       8.185353        Unweighted events, alpha=1.671403
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         182.738800      49.037499       total sum
# 19         14.000000       3.741657        Unweighted events, alpha=13.052771
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         206.561046      74.736411       total sum
# 20         8.000000        2.828427        Unweighted events, alpha=25.820131
#   => Total parameter prop_binmuJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         120.077276      13.907370       total sum
# 21         75.000000       8.660254        Unweighted events, alpha=1.601030
#   => Total parameter prop_binmuJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         396.348620      241.493041      total sum
# 22         3.000000        1.732051        Unweighted events, alpha=132.116207
#   => Total parameter prop_binmuJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         100.176283      17.012227       total sum
# 23         35.000000       5.916080        Unweighted events, alpha=2.862180
#   => Total parameter prop_binmuJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         144.185548      23.132216       total sum
# 24         39.000000       6.244998        Unweighted events, alpha=3.697065
#   => Total parameter prop_binmuJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         126.549185      51.551142       total sum
# 25         6.000000        2.449490        Unweighted events, alpha=21.091531
#   => Total parameter prop_binmuJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         116.066241      19.307070       total sum
# 26         36.000000       6.000000        Unweighted events, alpha=3.224062
#   => Total parameter prop_binmuJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         281.235094      141.023711      total sum
# 27         4.000000        2.000000        Unweighted events, alpha=70.308774
#   => Total parameter prop_binmuJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         98.508990       18.497824       total sum
# 28         28.000000       5.291503        Unweighted events, alpha=3.518178
#   => Total parameter prop_binmuJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         130.465235      21.405641       total sum
# 29         37.000000       6.082763        Unweighted events, alpha=3.526087
#   => Total parameter prop_binmuJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         77.360980       10.443694       total sum
# 30         55.000000       7.416198        Unweighted events, alpha=1.406563
#   => Total parameter prop_binmuJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         129.376435      49.779302       total sum
# 31         7.000000        2.645751        Unweighted events, alpha=18.482348
#   => Total parameter prop_binmuJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         115.067682      29.591356       total sum
# 32         15.000000       3.872983        Unweighted events, alpha=7.671179
#   => Total parameter prop_binmuJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         72.541148       12.422411       total sum
# 33         34.000000       5.830952        Unweighted events, alpha=2.133563
#   => Total parameter prop_binmuJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         76.649635       10.747917       total sum
# 34         51.000000       7.141428        Unweighted events, alpha=1.502934
#   => Total parameter prop_binmuJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         56.946443       9.659385        total sum
# 35         35.000000       5.916080        Unweighted events, alpha=1.627041
#   => Total parameter prop_binmuJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         69.107566       11.415761       total sum
# 36         37.000000       6.082763        Unweighted events, alpha=1.867772
#   => Total parameter prop_binmuJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         73.587996       14.919516       total sum
# 37         24.000000       4.898979        Unweighted events, alpha=3.066167
#   => Total parameter prop_binmuJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         32.289193       3.606617        total sum
# 38         80.000000       8.944272        Unweighted events, alpha=0.403615
#   => Total parameter prop_binmuJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         64.266379       9.704582        total sum
# 39         44.000000       6.633250        Unweighted events, alpha=1.460600
#   => Total parameter prop_binmuJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-5QUQck.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 2.56571  -0.0702349/+0.0731279  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)

# %%
# !combine -M FitDiagnostics -n CR1  datacard_CR1.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          103.397054      27.884463       total sum
# 0          14.000000       3.741657        Unweighted events, alpha=7.385504
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          81.553519       15.422712       total sum
# 1          28.000000       5.291503        Unweighted events, alpha=2.912626
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          85.709902       16.720373       total sum
# 2          26.000000       5.099020        Unweighted events, alpha=3.296535
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          87.881308       16.915169       total sum
# 3          27.000000       5.196152        Unweighted events, alpha=3.254863
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          95.766190       15.443217       total sum
# 4          38.000000       6.164414        Unweighted events, alpha=2.520163
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          92.044029       19.254446       total sum
# 5          23.000000       4.795832        Unweighted events, alpha=4.001914
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          145.781364      24.218994       total sum
# 6          36.000000       6.000000        Unweighted events, alpha=4.049482
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          119.271523      18.141927       total sum
# 7          43.000000       6.557439        Unweighted events, alpha=2.773756
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          131.236328      20.831741       total sum
# 8          40.000000       6.324555        Unweighted events, alpha=3.280908
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          150.174232      22.541455       total sum
# 9          44.000000       6.633250        Unweighted events, alpha=3.413051
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         219.280502      35.047978       total sum
# 10         39.000000       6.244998        Unweighted events, alpha=5.622577
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         257.435760      57.759690       total sum
# 11         20.000000       4.472136        Unweighted events, alpha=12.871788
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         875.226349      390.246347      total sum
# 12         5.000000        2.236068        Unweighted events, alpha=175.045270
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         746.838074      65.578850       total sum
# 13         130.000000      11.401754       Unweighted events, alpha=5.744908
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1121.097076     56.273468       total sum
# 14         397.000000      19.924859       Unweighted events, alpha=2.823922
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         1321.976318     85.699262       total sum
# 15         238.000000      15.427249       Unweighted events, alpha=5.554522
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         793.803787      45.287283       total sum
# 16         307.000000      17.521415       Unweighted events, alpha=2.585680
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         388.027069      31.850233       total sum
# 17         148.000000      12.165525       Unweighted events, alpha=2.621805
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         234.902367      50.501014       total sum
# 18         22.000000       4.690416        Unweighted events, alpha=10.677380
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         221.651539      63.048035       total sum
# 19         12.000000       3.464102        Unweighted events, alpha=18.470962
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         140.610138      33.431005       total sum
# 20         18.000000       4.242641        Unweighted events, alpha=7.811674
#   => Total parameter prop_bineleJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         124.156044      20.046390       total sum
# 21         38.000000       6.164414        Unweighted events, alpha=3.267264
#   => Total parameter prop_bineleJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         72.344582       14.517880       total sum
# 22         25.000000       5.000000        Unweighted events, alpha=2.893783
#   => Total parameter prop_bineleJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         109.853964      50.099374       total sum
# 23         5.000000        2.236068        Unweighted events, alpha=21.970793
#   => Total parameter prop_bineleJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         36.105869       7.273772        total sum
# 24         25.000000       5.000000        Unweighted events, alpha=1.444235
#   => Total parameter prop_bineleJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         78.033506       15.414477       total sum
# 25         26.000000       5.099020        Unweighted events, alpha=3.001289
#   => Total parameter prop_bineleJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         43.996147       7.818670        total sum
# 26         32.000000       5.656854        Unweighted events, alpha=1.374880
#   => Total parameter prop_bineleJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         43.120872       7.847533        total sum
# 27         30.000000       5.477226        Unweighted events, alpha=1.437362
#   => Total parameter prop_bineleJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         29.443057       6.676369        total sum
# 28         19.000000       4.358899        Unweighted events, alpha=1.549635
#   => Total parameter prop_bineleJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         43.820564       12.547583       total sum
# 29         12.000000       3.464102        Unweighted events, alpha=3.651714
#   => Total parameter prop_bineleJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         131.350916      50.505144       total sum
# 30         7.000000        2.645751        Unweighted events, alpha=18.764417
#   => Total parameter prop_bineleJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         34.718731       7.292291        total sum
# 31         23.000000       4.795832        Unweighted events, alpha=1.509510
#   => Total parameter prop_bineleJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         41.123749       13.988795       total sum
# 32         9.000000        3.000000        Unweighted events, alpha=4.569305
#   => Total parameter prop_bineleJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         19.951671       6.405551        total sum
# 33         10.000000       3.162278        Unweighted events, alpha=1.995167
#   => Total parameter prop_bineleJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         63.097422       31.476271       total sum
# 34         4.000000        2.000000        Unweighted events, alpha=15.774355
#   => Total parameter prop_bineleJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         44.311970       14.196438       total sum
# 35         10.000000       3.162278        Unweighted events, alpha=4.431197
#   => Total parameter prop_bineleJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         24.514865       5.786126        total sum
# 36         18.000000       4.242641        Unweighted events, alpha=1.361937
#   => Total parameter prop_bineleJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         101.463001      51.817783       total sum
# 37         4.000000        2.000000        Unweighted events, alpha=25.365750
#   => Total parameter prop_bineleJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         19.464542       5.905696        total sum
# 38         11.000000       3.316625        Unweighted events, alpha=1.769504
#   => Total parameter prop_bineleJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         22.366142       5.540678        total sum
# 39         16.000000       4.000000        Unweighted events, alpha=1.397884
#   => Total parameter prop_bineleJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          175.126607      26.190939       total sum
# 0          45.000000       6.708204        Unweighted events, alpha=3.891702
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1208.399709     1023.526604     total sum
# 1          1.000000        1.000000        Unweighted events, alpha=1208.399709
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          242.677598      55.269327       total sum
# 2          19.000000       4.358899        Unweighted events, alpha=12.772505
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          191.411093      37.170992       total sum
# 3          27.000000       5.196152        Unweighted events, alpha=7.089300
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          241.027959      59.090801       total sum
# 4          17.000000       4.123106        Unweighted events, alpha=14.178115
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          232.323913      55.401298       total sum
# 5          18.000000       4.242641        Unweighted events, alpha=12.906884
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          141.519893      22.279554       total sum
# 6          40.000000       6.324555        Unweighted events, alpha=3.537997
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          205.777792      59.170514       total sum
# 7          12.000000       3.464102        Unweighted events, alpha=17.148149
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          163.575132      31.622952       total sum
# 8          27.000000       5.196152        Unweighted events, alpha=6.058338
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          123.667952      15.802538       total sum
# 9          61.000000       7.810250        Unweighted events, alpha=2.027343
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         161.864451      35.946815       total sum
# 10         20.000000       4.472136        Unweighted events, alpha=8.093223
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         245.464374      66.292094       total sum
# 11         14.000000       3.741657        Unweighted events, alpha=17.533170
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         140.565688      27.928348       total sum
# 12         25.000000       5.000000        Unweighted events, alpha=5.622628
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         144.574602      28.919226       total sum
# 13         25.000000       5.000000        Unweighted events, alpha=5.782984
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         146.312310      40.517012       total sum
# 14         13.000000       3.605551        Unweighted events, alpha=11.254793
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         256.083892      78.435930       total sum
# 15         11.000000       3.316625        Unweighted events, alpha=23.280354
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         100.059056      25.350413       total sum
# 16         16.000000       4.000000        Unweighted events, alpha=6.253691
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         1331.167020     1207.637841     total sum
# 17         1.000000        1.000000        Unweighted events, alpha=1331.167020
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         64.037759       11.702394       total sum
# 18         30.000000       5.477226        Unweighted events, alpha=2.134592
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         100.692639      19.717609       total sum
# 19         26.000000       5.099020        Unweighted events, alpha=3.872794
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         92.134624       33.416322       total sum
# 20         8.000000        2.828427        Unweighted events, alpha=11.516828
#   => Total parameter prop_binmuJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         78.165759       12.411249       total sum
# 21         40.000000       6.324555        Unweighted events, alpha=1.954144
#   => Total parameter prop_binmuJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         353.187397      241.298000      total sum
# 22         2.000000        1.414214        Unweighted events, alpha=176.593698
#   => Total parameter prop_binmuJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         68.301456       16.136999       total sum
# 23         18.000000       4.242641        Unweighted events, alpha=3.794525
#   => Total parameter prop_binmuJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         91.142591       21.020129       total sum
# 24         19.000000       4.358899        Unweighted events, alpha=4.796978
#   => Total parameter prop_binmuJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         36.613247       6.235278        total sum
# 25         34.000000       5.830952        Unweighted events, alpha=1.076860
#   => Total parameter prop_binmuJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         67.975314       15.833303       total sum
# 26         18.000000       4.242641        Unweighted events, alpha=3.776406
#   => Total parameter prop_binmuJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         237.523134      140.697886      total sum
# 27         3.000000        1.732051        Unweighted events, alpha=79.174378
#   => Total parameter prop_binmuJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         64.722525       17.762141       total sum
# 28         13.000000       3.605551        Unweighted events, alpha=4.978656
#   => Total parameter prop_binmuJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         97.543675       20.319534       total sum
# 29         23.000000       4.795832        Unweighted events, alpha=4.241029
#   => Total parameter prop_binmuJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         39.830825       7.823429        total sum
# 30         26.000000       5.099020        Unweighted events, alpha=1.531955
#   => Total parameter prop_binmuJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         102.629950      49.550795       total sum
# 31         4.000000        2.000000        Unweighted events, alpha=25.657487
#   => Total parameter prop_binmuJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         75.431307       27.008495       total sum
# 32         8.000000        2.828427        Unweighted events, alpha=9.428913
#   => Total parameter prop_binmuJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         41.899305       11.044191       total sum
# 33         14.000000       3.741657        Unweighted events, alpha=2.992807
#   => Total parameter prop_binmuJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         51.973874       9.718398        total sum
# 34         29.000000       5.385165        Unweighted events, alpha=1.792203
#   => Total parameter prop_binmuJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         31.082925       8.167433        total sum
# 35         14.000000       3.741657        Unweighted events, alpha=2.220209
#   => Total parameter prop_binmuJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         46.356133       10.550090       total sum
# 36         19.000000       4.358899        Unweighted events, alpha=2.439796
#   => Total parameter prop_binmuJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         44.465054       13.559797       total sum
# 37         11.000000       3.316625        Unweighted events, alpha=4.042278
#   => Total parameter prop_binmuJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         16.863948       2.740675        total sum
# 38         38.000000       6.164414        Unweighted events, alpha=0.443788
#   => Total parameter prop_binmuJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         36.471684       7.640321        total sum
# 39         23.000000       4.795832        Unweighted events, alpha=1.585725
#   => Total parameter prop_binmuJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-I0jmws.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 2.51668  -0.0763398/+0.0795726  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)

# %%
# !combine -M FitDiagnostics -n CR2  datacard_CR2.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          26.826948       6.022113        total sum
# 0          20.000000       4.472136        Unweighted events, alpha=1.341347
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          28.525837       5.529171        total sum
# 1          27.000000       5.196152        Unweighted events, alpha=1.056512
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          50.900355       12.708246       total sum
# 2          16.000000       4.000000        Unweighted events, alpha=3.181272
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          32.620959       9.547634        total sum
# 3          12.000000       3.464102        Unweighted events, alpha=2.718413
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          66.980682       24.894805       total sum
# 4          7.000000        2.645751        Unweighted events, alpha=9.568669
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          35.072250       6.816720        total sum
# 5          26.000000       5.099020        Unweighted events, alpha=1.348933
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          23.069337       4.421670        total sum
# 6          27.000000       5.196152        Unweighted events, alpha=0.854420
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          36.456078       6.901931        total sum
# 7          28.000000       5.291503        Unweighted events, alpha=1.302003
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          44.403855       13.501114       total sum
# 8          11.000000       3.316625        Unweighted events, alpha=4.036714
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          111.146717      54.007352       total sum
# 9          4.000000        2.000000        Unweighted events, alpha=27.786679
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         47.919018       9.820471        total sum
# 10         24.000000       4.898979        Unweighted events, alpha=1.996626
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         58.977324       10.443146       total sum
# 11         32.000000       5.656854        Unweighted events, alpha=1.843041
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         82.502588       12.833764       total sum
# 12         41.000000       6.403124        Unweighted events, alpha=2.012258
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         153.913956      20.974846       total sum
# 13         54.000000       7.348469        Unweighted events, alpha=2.850258
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         278.127338      28.615023       total sum
# 14         94.000000       9.695360        Unweighted events, alpha=2.958801
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         279.335945      26.758564       total sum
# 15         109.000000      10.440307       Unweighted events, alpha=2.562715
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         186.857445      21.059665       total sum
# 16         79.000000       8.888194        Unweighted events, alpha=2.365284
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         84.335463       13.406336       total sum
# 17         40.000000       6.324555        Unweighted events, alpha=2.108387
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         283.885384      226.010837      total sum
# 18         2.000000        1.414214        Unweighted events, alpha=141.942692
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         79.566034       23.738309       total sum
# 19         11.000000       3.316625        Unweighted events, alpha=7.233276
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         43.316324       13.200142       total sum
# 20         11.000000       3.316625        Unweighted events, alpha=3.937848
#   => Total parameter prop_bineleJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         39.419642       8.931190        total sum
# 21         19.000000       4.358899        Unweighted events, alpha=2.074718
#   => Total parameter prop_bineleJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         36.411902       11.617623       total sum
# 22         10.000000       3.162278        Unweighted events, alpha=3.641190
#   => Total parameter prop_bineleJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         16.716141       4.271488        total sum
# 23         15.000000       3.872983        Unweighted events, alpha=1.114409
#   => Total parameter prop_bineleJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         23.851788       6.676307        total sum
# 24         13.000000       3.605551        Unweighted events, alpha=1.834753
#   => Total parameter prop_bineleJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         22.128611       5.411863        total sum
# 25         17.000000       4.123106        Unweighted events, alpha=1.301683
#   => Total parameter prop_bineleJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         10.079882       1.837451        total sum
# 26         30.000000       5.477226        Unweighted events, alpha=0.335996
#   => Total parameter prop_bineleJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         22.990250       13.616656       total sum
# 27         3.000000        1.732051        Unweighted events, alpha=7.663417
#   => Total parameter prop_bineleJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         25.434888       6.856846        total sum
# 28         14.000000       3.741657        Unweighted events, alpha=1.816778
#   => Total parameter prop_bineleJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         15.841458       3.835923        total sum
# 29         17.000000       4.123106        Unweighted events, alpha=0.931850
#   => Total parameter prop_bineleJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         13.917889       4.270597        total sum
# 30         11.000000       3.316625        Unweighted events, alpha=1.265263
#   => Total parameter prop_bineleJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         15.273812       4.149123        total sum
# 31         14.000000       3.741657        Unweighted events, alpha=1.090987
#   => Total parameter prop_bineleJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         23.753371       6.600024        total sum
# 32         13.000000       3.605551        Unweighted events, alpha=1.827182
#   => Total parameter prop_bineleJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         20.037425       7.169221        total sum
# 33         8.000000        2.828427        Unweighted events, alpha=2.504678
#   => Total parameter prop_bineleJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         44.210623       30.462580       total sum
# 34         2.000000        1.414214        Unweighted events, alpha=22.105311
#   => Total parameter prop_bineleJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         14.207919       3.661318        total sum
# 35         15.000000       3.872983        Unweighted events, alpha=0.947195
#   => Total parameter prop_bineleJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         16.222258       5.001587        total sum
# 36         11.000000       3.316625        Unweighted events, alpha=1.474751
#   => Total parameter prop_bineleJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         10.945084       3.417454        total sum
# 37         10.000000       3.162278        Unweighted events, alpha=1.094508
#   => Total parameter prop_bineleJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         15.804154       4.823624        total sum
# 38         11.000000       3.316625        Unweighted events, alpha=1.436741
#   => Total parameter prop_bineleJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         10.906622       4.140095        total sum
# 39         7.000000        2.645751        Unweighted events, alpha=1.558089
#   => Total parameter prop_bineleJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          354.958212      289.404723      total sum
# 0          2.000000        1.414214        Unweighted events, alpha=177.479106
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          55.604631       9.245697        total sum
# 1          36.000000       6.000000        Unweighted events, alpha=1.544573
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          46.695585       10.313861       total sum
# 2          20.000000       4.472136        Unweighted events, alpha=2.334779
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          59.679796       10.434915       total sum
# 3          33.000000       5.744563        Unweighted events, alpha=1.808479
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          62.668940       12.999067       total sum
# 4          23.000000       4.795832        Unweighted events, alpha=2.724737
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          44.863325       7.203412        total sum
# 5          39.000000       6.244998        Unweighted events, alpha=1.150342
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          58.749805       11.989050       total sum
# 6          24.000000       4.898979        Unweighted events, alpha=2.447909
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          100.956427      34.159412       total sum
# 7          9.000000        3.000000        Unweighted events, alpha=11.217381
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          62.286957       13.643453       total sum
# 8          21.000000       4.582576        Unweighted events, alpha=2.966046
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          65.269193       12.837029       total sum
# 9          26.000000       5.099020        Unweighted events, alpha=2.510354
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         51.168037       9.016458        total sum
# 10         32.000000       5.656854        Unweighted events, alpha=1.599001
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         53.752455       14.209022       total sum
# 11         14.000000       3.741657        Unweighted events, alpha=3.839461
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         103.338712      39.593823       total sum
# 12         7.000000        2.645751        Unweighted events, alpha=14.762673
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         54.614832       9.508962        total sum
# 13         33.000000       5.744563        Unweighted events, alpha=1.654995
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         45.482935       8.395198        total sum
# 14         29.000000       5.385165        Unweighted events, alpha=1.568377
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         35.476293       6.677091        total sum
# 15         28.000000       5.291503        Unweighted events, alpha=1.267010
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         34.329577       10.641373       total sum
# 16         10.000000       3.162278        Unweighted events, alpha=3.432958
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         46.975295       10.592478       total sum
# 17         20.000000       4.472136        Unweighted events, alpha=2.348765
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         35.368119       6.928890        total sum
# 18         26.000000       5.099020        Unweighted events, alpha=1.360312
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         66.192745       44.780362       total sum
# 19         2.000000        1.414214        Unweighted events, alpha=33.096373
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         34.200634       8.034172        total sum
# 20         18.000000       4.242641        Unweighted events, alpha=1.900035
#   => Total parameter prop_binmuJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         28.492228       5.705090        total sum
# 21         25.000000       5.000000        Unweighted events, alpha=1.139689
#   => Total parameter prop_binmuJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         32.166195       9.638889        total sum
# 22         11.000000       3.316625        Unweighted events, alpha=2.924200
#   => Total parameter prop_binmuJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         13.633978       1.393277        total sum
# 23         96.000000       9.797959        Unweighted events, alpha=0.142021
#   => Total parameter prop_binmuJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         38.956724       9.390490        total sum
# 24         17.000000       4.123106        Unweighted events, alpha=2.291572
#   => Total parameter prop_binmuJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         22.532600       4.219953        total sum
# 25         29.000000       5.385165        Unweighted events, alpha=0.776986
#   => Total parameter prop_binmuJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         33.843787       10.404005       total sum
# 26         11.000000       3.316625        Unweighted events, alpha=3.076708
#   => Total parameter prop_binmuJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         34.443206       9.515301        total sum
# 27         13.000000       3.605551        Unweighted events, alpha=2.649477
#   => Total parameter prop_binmuJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         23.239719       5.046757        total sum
# 28         21.000000       4.582576        Unweighted events, alpha=1.106653
#   => Total parameter prop_binmuJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         25.437580       6.642957        total sum
# 29         15.000000       3.872983        Unweighted events, alpha=1.695839
#   => Total parameter prop_binmuJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         27.448074       6.611224        total sum
# 30         17.000000       4.123106        Unweighted events, alpha=1.614593
#   => Total parameter prop_binmuJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         17.212646       4.303213        total sum
# 31         16.000000       4.000000        Unweighted events, alpha=1.075790
#   => Total parameter prop_binmuJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         30.423113       11.937093       total sum
# 32         6.000000        2.449490        Unweighted events, alpha=5.070519
#   => Total parameter prop_binmuJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         17.939891       4.229453        total sum
# 33         18.000000       4.242641        Unweighted events, alpha=0.996661
#   => Total parameter prop_binmuJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         17.325788       4.479162        total sum
# 34         15.000000       3.872983        Unweighted events, alpha=1.155053
#   => Total parameter prop_binmuJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         15.583448       3.965938        total sum
# 35         15.000000       3.872983        Unweighted events, alpha=1.038897
#   => Total parameter prop_binmuJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         12.837029       3.046129        total sum
# 36         18.000000       4.242641        Unweighted events, alpha=0.713168
#   => Total parameter prop_binmuJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         20.755133       5.980706        total sum
# 37         12.000000       3.464102        Unweighted events, alpha=1.729594
#   => Total parameter prop_binmuJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         8.487811        2.173704        total sum
# 38         15.000000       3.872983        Unweighted events, alpha=0.565854
#   => Total parameter prop_binmuJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         18.362521       5.085904        total sum
# 39         13.000000       3.605551        Unweighted events, alpha=1.412502
#   => Total parameter prop_binmuJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-XClPWM.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 2.73508  -0.173233/+0.191261  (68% CL)
# Done in 0.01 min (cpu), 0.02 min (real)

# %%
# !combine -M FitDiagnostics -n CR3  datacard_CR3.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          12.864566       3.407082        total sum
# 0          14.000000       3.741657        Unweighted events, alpha=0.918898
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          11.102595       2.254811        total sum
# 1          24.000000       4.898979        Unweighted events, alpha=0.462608
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          16.450190       3.892656        total sum
# 2          18.000000       4.242641        Unweighted events, alpha=0.913899
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          18.881876       5.106703        total sum
# 3          14.000000       3.741657        Unweighted events, alpha=1.348705
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          14.666034       3.199441        total sum
# 4          21.000000       4.582576        Unweighted events, alpha=0.698383
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          13.131230       2.836443        total sum
# 5          21.000000       4.582576        Unweighted events, alpha=0.625297
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          18.884147       4.743055        total sum
# 6          16.000000       4.000000        Unweighted events, alpha=1.180259
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          20.268095       4.989282        total sum
# 7          17.000000       4.123106        Unweighted events, alpha=1.192241
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          26.784730       6.841963        total sum
# 8          15.000000       3.872983        Unweighted events, alpha=1.785649
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          60.098579       39.411089       total sum
# 9          2.000000        1.414214        Unweighted events, alpha=30.049290
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         21.928707       4.204387        total sum
# 10         27.000000       5.196152        Unweighted events, alpha=0.812174
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         31.582052       6.602144        total sum
# 11         23.000000       4.795832        Unweighted events, alpha=1.373133
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         25.412304       6.615570        total sum
# 12         15.000000       3.872983        Unweighted events, alpha=1.694154
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         66.514820       15.451335       total sum
# 13         19.000000       4.358899        Unweighted events, alpha=3.500780
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         83.366608       29.808916       total sum
# 14         8.000000        2.828427        Unweighted events, alpha=10.420826
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         68.782614       11.961335       total sum
# 15         33.000000       5.744563        Unweighted events, alpha=2.084322
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         46.812712       9.533111        total sum
# 16         24.000000       4.898979        Unweighted events, alpha=1.950530
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         36.008522       8.036565        total sum
# 17         20.000000       4.472136        Unweighted events, alpha=1.800426
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         38.540754       13.189417       total sum
# 18         9.000000        3.000000        Unweighted events, alpha=4.282306
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         24.205596       11.369553       total sum
# 19         5.000000        2.236068        Unweighted events, alpha=4.841119
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         13.772700       4.103115        total sum
# 20         11.000000       3.316625        Unweighted events, alpha=1.252064
#   => Total parameter prop_bineleJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         11.521427       3.320547        total sum
# 21         12.000000       3.464102        Unweighted events, alpha=0.960119
#   => Total parameter prop_bineleJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         13.523187       4.243860        total sum
# 22         10.000000       3.162278        Unweighted events, alpha=1.352319
#   => Total parameter prop_bineleJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         18.711675       5.478798        total sum
# 23         12.000000       3.464102        Unweighted events, alpha=1.559306
#   => Total parameter prop_bineleJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         23.191320       7.245538        total sum
# 24         10.000000       3.162278        Unweighted events, alpha=2.319132
#   => Total parameter prop_bineleJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         10.905290       2.547696        total sum
# 25         18.000000       4.242641        Unweighted events, alpha=0.605849
#   => Total parameter prop_bineleJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         7.095974        1.028564        total sum
# 26         48.000000       6.928203        Unweighted events, alpha=0.147833
#   => Total parameter prop_bineleJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         15.039217       4.100813        total sum
# 27         13.000000       3.605551        Unweighted events, alpha=1.156863
#   => Total parameter prop_bineleJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         18.826203       5.903328        total sum
# 28         10.000000       3.162278        Unweighted events, alpha=1.882620
#   => Total parameter prop_bineleJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         24.917315       14.085719       total sum
# 29         3.000000        1.732051        Unweighted events, alpha=8.305772
#   => Total parameter prop_bineleJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         10.347733       3.285953        total sum
# 30         10.000000       3.162278        Unweighted events, alpha=1.034773
#   => Total parameter prop_bineleJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         5.885459        0.821927        total sum
# 31         51.000000       7.141428        Unweighted events, alpha=0.115401
#   => Total parameter prop_bineleJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         7.600972        1.526557        total sum
# 32         25.000000       5.000000        Unweighted events, alpha=0.304039
#   => Total parameter prop_bineleJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         10.823313       3.043244        total sum
# 33         13.000000       3.605551        Unweighted events, alpha=0.832563
#   => Total parameter prop_bineleJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         7.035305        1.692606        total sum
# 34         17.000000       4.123106        Unweighted events, alpha=0.413841
#   => Total parameter prop_bineleJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         17.533630       11.409002       total sum
# 35         2.000000        1.414214        Unweighted events, alpha=8.766815
#   => Total parameter prop_bineleJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         7.171525        2.914905        total sum
# 36         6.000000        2.449490        Unweighted events, alpha=1.195254
#   => Total parameter prop_bineleJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         7.829719        3.117580        total sum
# 37         6.000000        2.449490        Unweighted events, alpha=1.304953
#   => Total parameter prop_bineleJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         6.688882        2.185828        total sum
# 38         9.000000        3.000000        Unweighted events, alpha=0.743209
#   => Total parameter prop_bineleJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         5.790316        1.711695        total sum
# 39         11.000000       3.316625        Unweighted events, alpha=0.526392
#   => Total parameter prop_bineleJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          16.955398       3.545078        total sum
# 0          23.000000       4.795832        Unweighted events, alpha=0.737191
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          25.551018       5.635481        total sum
# 1          21.000000       4.582576        Unweighted events, alpha=1.216715
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          19.617306       2.754375        total sum
# 2          51.000000       7.141428        Unweighted events, alpha=0.384653
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          13.979179       1.402131        total sum
# 3          99.000000       9.949874        Unweighted events, alpha=0.141204
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          21.829146       2.704942        total sum
# 4          65.000000       8.062258        Unweighted events, alpha=0.335833
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          19.287782       2.784923        total sum
# 5          48.000000       6.928203        Unweighted events, alpha=0.401829
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          26.177704       5.055631        total sum
# 6          27.000000       5.196152        Unweighted events, alpha=0.969545
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          16.868897       2.219212        total sum
# 7          58.000000       7.615773        Unweighted events, alpha=0.290843
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          76.252200       60.835646       total sum
# 8          2.000000        1.414214        Unweighted events, alpha=38.126100
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          21.793780       4.552545        total sum
# 9          23.000000       4.795832        Unweighted events, alpha=0.947556
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         27.249122       8.270413        total sum
# 10         11.000000       3.316625        Unweighted events, alpha=2.477193
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         40.817284       11.693682       total sum
# 11         12.000000       3.464102        Unweighted events, alpha=3.401440
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         24.950606       5.188309        total sum
# 12         23.000000       4.795832        Unweighted events, alpha=1.084809
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         24.379919       5.512682        total sum
# 13         20.000000       4.472136        Unweighted events, alpha=1.218996
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         13.597378       1.243497        total sum
# 14         120.000000      10.954451       Unweighted events, alpha=0.113311
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         21.747154       5.242902        total sum
# 15         17.000000       4.123106        Unweighted events, alpha=1.279244
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         92.796410       76.169812       total sum
# 16         1.000000        1.000000        Unweighted events, alpha=92.796410
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         23.546227       4.983289        total sum
# 17         22.000000       4.690416        Unweighted events, alpha=1.070283
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         12.578099       1.593211        total sum
# 18         62.000000       7.874008        Unweighted events, alpha=0.202873
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         15.853428       3.257513        total sum
# 19         24.000000       4.898979        Unweighted events, alpha=0.660560
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         80.225773       66.365146       total sum
# 20         1.000000        1.000000        Unweighted events, alpha=80.225773
#   => Total parameter prop_binmuJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         13.419260       2.613006        total sum
# 21         26.000000       5.099020        Unweighted events, alpha=0.516125
#   => Total parameter prop_binmuJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         10.995055       1.120520        total sum
# 22         96.000000       9.797959        Unweighted events, alpha=0.114532
#   => Total parameter prop_binmuJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         18.240839       5.203066        total sum
# 23         12.000000       3.464102        Unweighted events, alpha=1.520070
#   => Total parameter prop_binmuJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         14.086222       2.252179        total sum
# 24         39.000000       6.244998        Unweighted events, alpha=0.361185
#   => Total parameter prop_binmuJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         67.403323       50.998368       total sum
# 25         2.000000        1.414214        Unweighted events, alpha=33.701662
#   => Total parameter prop_binmuJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         14.247125       3.718353        total sum
# 26         15.000000       3.872983        Unweighted events, alpha=0.949808
#   => Total parameter prop_binmuJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         9.268739        1.118465        total sum
# 27         69.000000       8.306624        Unweighted events, alpha=0.134330
#   => Total parameter prop_binmuJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         10.546747       1.098220        total sum
# 28         92.000000       9.591663        Unweighted events, alpha=0.114639
#   => Total parameter prop_binmuJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         7.483966        1.090478        total sum
# 29         47.000000       6.855655        Unweighted events, alpha=0.159233
#   => Total parameter prop_binmuJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         10.082109       2.038725        total sum
# 30         24.000000       4.898979        Unweighted events, alpha=0.420088
#   => Total parameter prop_binmuJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         9.533829        2.044503        total sum
# 31         22.000000       4.690416        Unweighted events, alpha=0.433356
#   => Total parameter prop_binmuJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         9.213277        1.922320        total sum
# 32         23.000000       4.795832        Unweighted events, alpha=0.400577
#   => Total parameter prop_binmuJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         12.701949       3.801823        total sum
# 33         11.000000       3.316625        Unweighted events, alpha=1.154723
#   => Total parameter prop_binmuJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         7.349981        1.003784        total sum
# 34         54.000000       7.348469        Unweighted events, alpha=0.136111
#   => Total parameter prop_binmuJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         10.280068       3.296678        total sum
# 35         10.000000       3.162278        Unweighted events, alpha=1.028007
#   => Total parameter prop_binmuJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         9.914406        3.120305        total sum
# 36         10.000000       3.162278        Unweighted events, alpha=0.991441
#   => Total parameter prop_binmuJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         8.367811        1.719010        total sum
# 37         24.000000       4.898979        Unweighted events, alpha=0.348659
#   => Total parameter prop_binmuJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         6.937431        0.878292        total sum
# 38         62.000000       7.874008        Unweighted events, alpha=0.111894
#   => Total parameter prop_binmuJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         9.432179        3.152458        total sum
# 39         9.000000        3.000000        Unweighted events, alpha=1.048020
#   => Total parameter prop_binmuJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-5WLDbY.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 3.01897  -0.350201/+0.424401  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)

# %%
# !combine -M FitDiagnostics -n CR4  datacard_CR4.txt --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel eleJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_bineleJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          38.301221       4.385439        total sum
# 0          76.000000       8.717798        Unweighted events, alpha=0.503963
#   => Total parameter prop_bineleJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          48.773758       12.886638       total sum
# 1          14.000000       3.741657        Unweighted events, alpha=3.483840
#   => Total parameter prop_bineleJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          36.057161       3.436989        total sum
# 2          110.000000      10.488088       Unweighted events, alpha=0.327792
#   => Total parameter prop_bineleJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          35.052343       3.240336        total sum
# 3          117.000000      10.816654       Unweighted events, alpha=0.299593
#   => Total parameter prop_bineleJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          34.358332       2.902416        total sum
# 4          140.000000      11.832160       Unweighted events, alpha=0.245417
#   => Total parameter prop_bineleJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          45.689977       4.714715        total sum
# 5          94.000000       9.695360        Unweighted events, alpha=0.486064
#   => Total parameter prop_bineleJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          44.945270       4.465014        total sum
# 6          101.000000      10.049876       Unweighted events, alpha=0.445003
#   => Total parameter prop_bineleJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          40.379832       5.214651        total sum
# 7          60.000000       7.745967        Unweighted events, alpha=0.672997
#   => Total parameter prop_bineleJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          49.092287       5.792143        total sum
# 8          72.000000       8.485281        Unweighted events, alpha=0.681837
#   => Total parameter prop_bineleJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          52.948193       6.642646        total sum
# 9          64.000000       8.000000        Unweighted events, alpha=0.827316
#   => Total parameter prop_bineleJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         59.819632       8.997915        total sum
# 10         44.000000       6.633250        Unweighted events, alpha=1.359537
#   => Total parameter prop_bineleJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         98.449959       30.583024       total sum
# 11         10.000000       3.162278        Unweighted events, alpha=9.844996
#   => Total parameter prop_bineleJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         80.860664       10.206573       total sum
# 12         63.000000       7.937254        Unweighted events, alpha=1.283503
#   => Total parameter prop_bineleJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         82.357483       11.034279       total sum
# 13         56.000000       7.483315        Unweighted events, alpha=1.470669
#   => Total parameter prop_bineleJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         142.966942      16.218123       total sum
# 14         78.000000       8.831761        Unweighted events, alpha=1.832910
#   => Total parameter prop_bineleJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         153.129223      17.767719       total sum
# 15         74.000000       8.602325        Unweighted events, alpha=2.069314
#   => Total parameter prop_bineleJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         82.228092       10.987667       total sum
# 16         56.000000       7.483315        Unweighted events, alpha=1.468359
#   => Total parameter prop_bineleJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         49.837587       6.133544        total sum
# 17         66.000000       8.124038        Unweighted events, alpha=0.755115
#   => Total parameter prop_bineleJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         39.410092       4.314229        total sum
# 18         83.000000       9.110434        Unweighted events, alpha=0.474820
#   => Total parameter prop_bineleJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         39.078148       4.789942        total sum
# 19         67.000000       8.185353        Unweighted events, alpha=0.583256
#   => Total parameter prop_bineleJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         32.945391       4.398897        total sum
# 20         56.000000       7.483315        Unweighted events, alpha=0.588311
#   => Total parameter prop_bineleJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         36.696784       3.444484        total sum
# 21         114.000000      10.677078       Unweighted events, alpha=0.321902
#   => Total parameter prop_bineleJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         33.557942       3.872895        total sum
# 22         75.000000       8.660254        Unweighted events, alpha=0.447439
#   => Total parameter prop_bineleJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         33.173365       4.313851        total sum
# 23         59.000000       7.681146        Unweighted events, alpha=0.562260
#   => Total parameter prop_bineleJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         31.778012       4.193847        total sum
# 24         57.000000       7.549834        Unweighted events, alpha=0.557509
#   => Total parameter prop_bineleJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         30.802982       2.910766        total sum
# 25         112.000000      10.583005       Unweighted events, alpha=0.275027
#   => Total parameter prop_bineleJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         25.139813       2.838853        total sum
# 26         78.000000       8.831761        Unweighted events, alpha=0.322305
#   => Total parameter prop_bineleJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         23.099238       3.051418        total sum
# 27         57.000000       7.549834        Unweighted events, alpha=0.405250
#   => Total parameter prop_bineleJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         25.983471       2.596235        total sum
# 28         100.000000      10.000000       Unweighted events, alpha=0.259835
#   => Total parameter prop_bineleJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         22.810294       2.694676        total sum
# 29         72.000000       8.485281        Unweighted events, alpha=0.316810
#   => Total parameter prop_bineleJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         24.600540       2.596849        total sum
# 30         90.000000       9.486833        Unweighted events, alpha=0.273339
#   => Total parameter prop_bineleJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         23.574393       2.638621        total sum
# 31         80.000000       8.944272        Unweighted events, alpha=0.294680
#   => Total parameter prop_bineleJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         22.014491       2.509562        total sum
# 32         77.000000       8.774964        Unweighted events, alpha=0.285902
#   => Total parameter prop_bineleJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         20.058758       2.319738        total sum
# 33         75.000000       8.660254        Unweighted events, alpha=0.267450
#   => Total parameter prop_bineleJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         22.755531       2.660654        total sum
# 34         73.000000       8.544004        Unweighted events, alpha=0.311720
#   => Total parameter prop_bineleJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         24.835411       9.183195        total sum
# 35         7.000000        2.645751        Unweighted events, alpha=3.547916
#   => Total parameter prop_bineleJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         15.477947       2.239460        total sum
# 36         48.000000       6.928203        Unweighted events, alpha=0.322457
#   => Total parameter prop_bineleJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         14.797329       1.978044        total sum
# 37         56.000000       7.483315        Unweighted events, alpha=0.264238
#   => Total parameter prop_bineleJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         21.202088       3.776904        total sum
# 38         32.000000       5.656854        Unweighted events, alpha=0.662565
#   => Total parameter prop_bineleJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         17.697245       3.498695        total sum
# 39         26.000000       5.099020        Unweighted events, alpha=0.680663
#   => Total parameter prop_bineleJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          70.568080       6.486375        total sum
# 0          118.000000      10.862780       Unweighted events, alpha=0.598035
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          99.320685       38.496128       total sum
# 1          7.000000        2.645751        Unweighted events, alpha=14.188669
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          58.333520       4.779236        total sum
# 2          149.000000      12.206556       Unweighted events, alpha=0.391500
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          78.305380       12.421822       total sum
# 3          40.000000       6.324555        Unweighted events, alpha=1.957635
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          72.901195       6.294717        total sum
# 4          134.000000      11.575837       Unweighted events, alpha=0.544039
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          66.654194       5.865029        total sum
# 5          129.000000      11.357817       Unweighted events, alpha=0.516699
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          62.399397       5.439072        total sum
# 6          132.000000      11.489125       Unweighted events, alpha=0.472723
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          64.360056       4.963695        total sum
# 7          168.000000      12.961481       Unweighted events, alpha=0.383096
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          64.461369       5.468701        total sum
# 8          139.000000      11.789826       Unweighted events, alpha=0.463751
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          68.746172       8.421051        total sum
# 9          67.000000       8.185353        Unweighted events, alpha=1.026062
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         89.889137       30.898902       total sum
# 10         8.000000        2.828427        Unweighted events, alpha=11.236142
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         63.085612       8.137130        total sum
# 11         60.000000       7.745967        Unweighted events, alpha=1.051427
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         77.504449       11.280791       total sum
# 12         47.000000       6.855655        Unweighted events, alpha=1.649031
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         108.469639      45.807619       total sum
# 13         6.000000        2.449490        Unweighted events, alpha=18.078273
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         62.612334       6.077275        total sum
# 14         106.000000      10.295630       Unweighted events, alpha=0.590682
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         53.157039       5.053939        total sum
# 15         111.000000      10.535654       Unweighted events, alpha=0.478892
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         62.813026       8.111397        total sum
# 16         60.000000       7.745967        Unweighted events, alpha=1.046884
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         60.458868       4.100007        total sum
# 17         217.000000      14.730920       Unweighted events, alpha=0.278612
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         47.710986       3.826130        total sum
# 18         155.000000      12.449900       Unweighted events, alpha=0.307813
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         74.637884       26.424585       total sum
# 19         8.000000        2.828427        Unweighted events, alpha=9.329736
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 20         68.592346       23.170128       total sum
# 20         9.000000        3.000000        Unweighted events, alpha=7.621372
#   => Total parameter prop_binmuJets_bin20[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 21         87.660472       38.430855       total sum
# 21         5.000000        2.236068        Unweighted events, alpha=17.532094
#   => Total parameter prop_binmuJets_bin21[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 22         48.396059       3.612773        total sum
# 22         179.000000      13.379088       Unweighted events, alpha=0.270369
#   => Total parameter prop_binmuJets_bin22[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 23         43.957502       3.537932        total sum
# 23         154.000000      12.409674       Unweighted events, alpha=0.285438
#   => Total parameter prop_binmuJets_bin23[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 24         41.424800       4.235566        total sum
# 24         96.000000       9.797959        Unweighted events, alpha=0.431508
#   => Total parameter prop_binmuJets_bin24[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 25         41.531870       4.479293        total sum
# 25         86.000000       9.273618        Unweighted events, alpha=0.482929
#   => Total parameter prop_binmuJets_bin25[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 26         48.560926       10.641789       total sum
# 26         21.000000       4.582576        Unweighted events, alpha=2.312425
#   => Total parameter prop_binmuJets_bin26[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 27         40.818710       3.371733        total sum
# 27         147.000000      12.124356       Unweighted events, alpha=0.277678
#   => Total parameter prop_binmuJets_bin27[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 28         36.398216       3.269866        total sum
# 28         124.000000      11.135529       Unweighted events, alpha=0.293534
#   => Total parameter prop_binmuJets_bin28[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 29         35.449266       3.347034        total sum
# 29         112.000000      10.583005       Unweighted events, alpha=0.316511
#   => Total parameter prop_binmuJets_bin29[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 30         31.110828       3.289204        total sum
# 30         89.000000       9.433981        Unweighted events, alpha=0.349560
#   => Total parameter prop_binmuJets_bin30[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 31         29.240040       3.446004        total sum
# 31         72.000000       8.485281        Unweighted events, alpha=0.406112
#   => Total parameter prop_binmuJets_bin31[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 32         47.616093       13.303515       total sum
# 32         13.000000       3.605551        Unweighted events, alpha=3.662776
#   => Total parameter prop_binmuJets_bin32[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 33         26.264865       2.947952        total sum
# 33         79.000000       8.888194        Unweighted events, alpha=0.332467
#   => Total parameter prop_binmuJets_bin33[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 34         26.178483       2.494758        total sum
# 34         110.000000      10.488088       Unweighted events, alpha=0.237986
#   => Total parameter prop_binmuJets_bin34[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 35         19.313601       3.031406        total sum
# 35         41.000000       6.403124        Unweighted events, alpha=0.471063
#   => Total parameter prop_binmuJets_bin35[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 36         24.726066       2.554448        total sum
# 36         94.000000       9.695360        Unweighted events, alpha=0.263043
#   => Total parameter prop_binmuJets_bin36[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 37         28.256459       5.388738        total sum
# 37         27.000000       5.196152        Unweighted events, alpha=1.046536
#   => Total parameter prop_binmuJets_bin37[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 38         27.718881       4.151404        total sum
# 38         45.000000       6.708204        Unweighted events, alpha=0.615975
#   => Total parameter prop_binmuJets_bin38[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 39         44.672179       12.103897       total sum
# 39         14.000000       3.741657        Unweighted events, alpha=3.190870
#   => Total parameter prop_binmuJets_bin39[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-Yet9oM.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 3.27555  -0.297491/+0.330635  (68% CL)
# Done in 0.01 min (cpu), 0.02 min (real)
